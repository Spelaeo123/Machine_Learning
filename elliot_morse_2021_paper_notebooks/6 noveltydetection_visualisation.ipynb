# %% [markdown]
# ### Visualisation of outlier classification

# %%
import pandas as pd
import numpy as np
import swifter
import seaborn as sns
pd.set_option('max.rows', None)
pd.set_option('max.columns', None)
import matplotlib.pyplot as plt


from sklearn.decomposition import PCA 
from sklearn.manifold import TSNE
from sklearn.preprocessing import StandardScaler
# %matplotlib inline

# %%
# %store -r  X_test_labeled_df

# %%
save_plots = True

# %%
X_test_labeled_df.head()
# Out:
#    Analysis  Zr90  Ba137  Sr88  Ge72  Cr52     S33      U238         Al27  \
# 0  06_DH1_1  1.43   5.95  2.00  1.37  5.18  806.55  0.250083   635.240000
# 1  07_DH1_2  1.47   7.51  1.84  1.93  5.43  807.55  0.250083   639.090000
# 2  08_DH1_3  1.16   4.40  1.93  2.14  2.61  837.73  0.250083   670.480000
# 3  09_DH2_1  1.45  12.48  4.29  1.59  2.87  750.62  0.080000  1515.220000
# 4  10_DH2_2  1.99  14.40  4.44  0.81  5.92  796.21  0.090000   710.920579
#
#      B11   Mg24  Nd146  Sc45         K39  Pr141    Li7  inlierLabel
# 0  93.21  27.83   0.34  1.08  443.100000   0.07   2.79            1
# 1  95.19  27.99   0.24  1.09  442.100000   0.06   2.37           -1
# 2  93.63  26.43   0.08  1.17  444.280000   0.03   2.46           -1
# 3  63.80  31.98   0.25  1.19  369.135675   0.06  18.47            1
# 4  60.96  44.95   0.51  1.22  369.135675   0.12  19.98            1

# %% [markdown]
# ## data preproccessing for dimensionality reduction and visualisation

# %%
element_data = X_test_labeled_df[X_test_labeled_df.columns.values[1:-1]]
element_data.head()
# Out:
#    Zr90  Ba137  Sr88  Ge72  Cr52     S33      U238         Al27    B11   Mg24  \
# 0  1.43   5.95  2.00  1.37  5.18  806.55  0.250083   635.240000  93.21  27.83
# 1  1.47   7.51  1.84  1.93  5.43  807.55  0.250083   639.090000  95.19  27.99
# 2  1.16   4.40  1.93  2.14  2.61  837.73  0.250083   670.480000  93.63  26.43
# 3  1.45  12.48  4.29  1.59  2.87  750.62  0.080000  1515.220000  63.80  31.98
# 4  1.99  14.40  4.44  0.81  5.92  796.21  0.090000   710.920579  60.96  44.95
#
#    Nd146  Sc45         K39  Pr141    Li7
# 0   0.34  1.08  443.100000   0.07   2.79
# 1   0.24  1.09  442.100000   0.06   2.37
# 2   0.08  1.17  444.280000   0.03   2.46
# 3   0.25  1.19  369.135675   0.06  18.47
# 4   0.51  1.22  369.135675   0.12  19.98

# %% [markdown]
# ### features are standardised

# %%
my_scaler_train = StandardScaler()

# %%
element_data_scaled = my_scaler_train.fit_transform(element_data)

# %% [markdown]
# ### T-Distributed Stochastic Neighbour Embedding is done

# %%
my_tsne = TSNE(n_components=2, n_iter=5000, verbose=3).fit_transform(element_data_scaled)
# Out:
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 363 samples in 0.001s...
# [t-SNE] Computed neighbors for 363 samples in 0.013s...
# [t-SNE] Computed conditional probabilities for sample 363 / 363
# [t-SNE] Mean sigma: 1.552641
# [t-SNE] Computed conditional probabilities in 0.018s
# [t-SNE] Iteration 50: error = 65.4153061, gradient norm = 0.5360993 (50 iterations in 0.136s)
# [t-SNE] Iteration 100: error = 64.8133163, gradient norm = 0.5333995 (50 iterations in 0.160s)
# [t-SNE] Iteration 150: error = 66.0834427, gradient norm = 0.5039111 (50 iterations in 0.130s)
# [t-SNE] Iteration 200: error = 65.8455734, gradient norm = 0.5296581 (50 iterations in 0.125s)
# [t-SNE] Iteration 250: error = 66.1200714, gradient norm = 0.5310043 (50 iterations in 0.136s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 66.120071
# [t-SNE] Iteration 300: error = 0.8548755, gradient norm = 0.0041841 (50 iterations in 0.110s)
# [t-SNE] Iteration 350: error = 0.8040689, gradient norm = 0.0009050 (50 iterations in 0.093s)
# [t-SNE] Iteration 400: error = 0.7948747, gradient norm = 0.0001962 (50 iterations in 0.104s)
# [t-SNE] Iteration 450: error = 0.7936493, gradient norm = 0.0001421 (50 iterations in 0.099s)
# [t-SNE] Iteration 500: error = 0.7855762, gradient norm = 0.0004351 (50 iterations in 0.096s)
# [t-SNE] Iteration 550: error = 0.7797134, gradient norm = 0.0002398 (50 iterations in 0.088s)
# [t-SNE] Iteration 600: error = 0.7711087, gradient norm = 0.0010370 (50 iterations in 0.116s)
# [t-SNE] Iteration 650: error = 0.7587196, gradient norm = 0.0004286 (50 iterations in 0.128s)
# [t-SNE] Iteration 700: error = 0.7568883, gradient norm = 0.0001876 (50 iterations in 0.101s)
# [t-SNE] Iteration 750: error = 0.7563666, gradient norm = 0.0002901 (50 iterations in 0.095s)
# [t-SNE] Iteration 800: error = 0.7559801, gradient norm = 0.0001131 (50 iterations in 0.103s)
# [t-SNE] Iteration 850: error = 0.7559884, gradient norm = 0.0000622 (50 iterations in 0.098s)
# [t-SNE] Iteration 900: error = 0.7559757, gradient norm = 0.0000955 (50 iterations in 0.110s)
# [t-SNE] Iteration 950: error = 0.7558544, gradient norm = 0.0000694 (50 iterations in 0.100s)
# [t-SNE] Iteration 1000: error = 0.7557941, gradient norm = 0.0000608 (50 iterations in 0.098s)
# [t-SNE] Iteration 1050: error = 0.7558535, gradient norm = 0.0000532 (50 iterations in 0.100s)
# [t-SNE] Iteration 1100: error = 0.7558224, gradient norm = 0.0000713 (50 iterations in 0.127s)
# [t-SNE] Iteration 1150: error = 0.7558658, gradient norm = 0.0000839 (50 iterations in 0.088s)
# [t-SNE] Iteration 1200: error = 0.7558444, gradient norm = 0.0000864 (50 iterations in 0.100s)
# [t-SNE] Iteration 1250: error = 0.7558265, gradient norm = 0.0000476 (50 iterations in 0.243s)
# [t-SNE] Iteration 1300: error = 0.7558223, gradient norm = 0.0000763 (50 iterations in 0.169s)
# [t-SNE] Iteration 1350: error = 0.7557946, gradient norm = 0.0000595 (50 iterations in 0.183s)
# [t-SNE] Iteration 1350: did not make any progress during the last 300 episodes. Finished.
# [t-SNE] KL divergence after 1350 iterations: 0.755795

# %% [markdown]
# ### the t-SNE dimensions are put into a dataframe

# %%
tsne_df = pd.DataFrame(data = my_tsne, columns = ['tsne1', 'tsne2'])

# %% [markdown]
# ### datasets are stored for the purpose of two-dimensional visualisations

# %%
tsne_data_with_colour = pd.concat([tsne_df, X_test_labeled_df['inlierLabel']], axis = 1)

# %%
tsne_data_with_colour.head()
# Out:
#        tsne1     tsne2  inlierLabel
# 0  -3.055922  6.589923            1
# 1  -3.502359  7.161299           -1
# 2  -3.738188  7.957530           -1
# 3 -22.568396 -1.331562            1
# 4 -25.773710 -2.542841            1

# %% [markdown]
# ### visualise t-SNE in two dimensions

# %%
sns.set(rc={'figure.figsize':(50,40)})
plot = sns.scatterplot(data = tsne_data_with_colour, x = 'tsne1', y = 'tsne2', hue='inlierLabel', s = 800, palette = ['red', 'blue'])
plt.title('test', fontsize=70)
plot.set_xlabel("train fold size (number of observations)",fontsize=50)
plot.set_ylabel("t-SNE 2",fontsize=50)
plot.set_xlabel("t-SNE 1",fontsize=50)
plot.tick_params(labelsize=40)
plot.set_title('t-SNE visualisation of artefact data coloured by outlier status', fontdict = {'fontsize': 80})

plt.legend(fontsize = 50, loc = 4, markerscale = 5)

if save_plots == True:
    fig = plot.get_figure()
    fig.savefig(fname='figures/tSNE_outlier_detection')

# %%
tsne_data_with_colour.to_csv('output_datasets/tsne_outlier_data.csv')
