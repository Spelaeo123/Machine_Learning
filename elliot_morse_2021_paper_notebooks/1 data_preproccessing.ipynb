# %% [markdown]
# # data preproccessing

# %% [markdown]
# ## import modules and configure notebook

# %%
import pandas as pd
import numpy as np
import swifter
import seaborn as sns
from sklearn.decomposition import PCA 
from sklearn.manifold import TSNE
from sklearn.preprocessing import StandardScaler

from functions.preproccessing import clean_columns, split_data, replace_outliers 

pd.set_option('max.rows', None)
pd.set_option('max.columns', None)
# %matplotlib inline

# %%
from config_and_dependencies.config import *

# %% [markdown]
# ### Import data

# %%
my_data = pd.read_csv(data_input_path)

# %%
sns.set(rc={'figure.figsize':(50.7,8.27)})
sns.countplot(my_data['Site'])

# %%
my_data['class'] = my_data['Site']

# %% [markdown]
# ### features

# %%
my_data.columns.values[features_start:features_end]
# Out:
# array(['Li7', 'Be9', 'B11', 'Mg24', 'Al27', 'Si28', 'P31', 'S33', 'K39',
#        'Ca42', 'Sc45', 'Ti47', 'V51', 'Cr52', 'Mn55', 'Fe56', 'Co59',
#        'Ni60', 'Cu63', 'Zn68', 'Ga69', 'Ge72', 'As75', 'Rb85', 'Sr88',
#        'Y89', 'Zr90', 'Nb93', 'Mo95', 'Cd111', 'In115', 'Sn118', 'Cs133',
#        'Ba137', 'La139', 'Ce140', 'Pr141', 'Nd146', 'Sm147', 'Eu153',
#        'Gd157', 'Tb159', 'Dy163', 'Ho165', 'Er166', 'Tm169', 'Yb172',
#        'Lu175', 'Hf178', 'Ta181', 'Pb208', 'Th232', 'U238'], dtype=object)

# %%
site_frequencies_df = pd.DataFrame(my_data.Site.value_counts()).reset_index(drop = False).rename(columns = {'Site':'Number of Observations', 'index':'Site'})
# %store site_frequencies_df
# Out:
# Stored 'site_frequencies_df' (DataFrame)

# %% [markdown]
# ### raw sample names including sample sites and artefacts

# %%
my_data['Site'].unique()
# Out:
# array(['FH', 'ER', 'WW', 'TC', 'CS', 'BC', 'KQ', 'AR', 'SL', 'FG', 'WB',
#        'BX', 'PF', 'BM', 'WH', 'SQ', 'BP', 'WN', 'BH', 'PH', 'LB', 'AB',
#        'LV', 'BR', 'KY', 'BF', 'ST', 'SH', 'CF', 'BG', 'AC', 'CR', 'GH',
#        'PX', 'WF', 'DH', 'NMAG_Gold', 'NMW_Gold', 'NMWGwern', 'UBSS',
#        'Cefn', 'Stockley', 'Pucha', 'Woodbury', 'Pimple', 'Wellington',
#        'Lyonshall', 'SymondsYatE', 'Madawg', nan], dtype=object)

# %% [markdown]
# ### define functions for making target classes for classification

# %%
def make_classes_grouped_reduced(row):
    if row['Geology'] == 'Bedrock':
        return(row['Site'])
    elif row['Geology'] == 'Superficial':
        if row['Region'] == 'SV' or row['Region'] == 'SE':
            return('SV_SE')
        else:
            return(row['Region'])

# %% [markdown]
# ### targets for classification are made

# %%
my_data['class'] = my_data.apply(make_classes_grouped_reduced, axis = 1)

# %% [markdown]
# ### remove bedrock site 'BP' because class-specific F1 score was very bad due to limited sample number

# %%
my_data = my_data[my_data['Site']!='BP']
my_data = my_data[my_data['Site']!='BX']


if bedrock_only:
    my_superficial = my_data[my_data['Geology'] == 'Superficial']
    my_data = my_data[my_data['Geology'] != 'Superficial']

# %%
if drop_semi_bedrock:
    my_data = my_data[(my_data['class'] != 'BM') & (my_data['class'] != 'BC') & (my_data['class'] != 'BP') ]

# %%
my_data['class'].unique()
# Out:
# array(['FH', 'ER', 'WW', 'TC', 'CS', 'KQ', 'AR', 'SL', 'FG', 'WB', 'PF',
#        'WH', 'SQ', 'WN', 'BH', 'PH', 'LB', None], dtype=object)

# %% [markdown]
# ### remove '<' signs and commas from feature values

# %%
my_data = clean_columns(my_data, 9, -1)    
my_superficial = clean_columns(my_superficial, 9, -1)
# Out:
# Li7
# C:\Users\tom\Anaconda3\lib\site-packages\tqdm\std.py:648: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   from pandas import Panel
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=1087, style=ProgressStyle(description_widt…
# Be9
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=1087, style=ProgressStyle(description_widt…
# B11
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=1087, style=ProgressStyle(description_widt…
# Mg24
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=1087, style=ProgressStyle(description_widt…
# Al27
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=1087, style=ProgressStyle(description_widt…
# Si28
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=1087, style=ProgressStyle(description_widt…
# P31
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=1087, style=ProgressStyle(description_widt…
# S33
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=1087, style=ProgressStyle(description_widt…
# K39
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=1087, style=ProgressStyle(description_widt…
# Ca42
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=1087, style=ProgressStyle(description_widt…
# Sc45
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=1087, style=ProgressStyle(description_widt…
# Ti47
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=1087, style=ProgressStyle(description_widt…
# V51
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=1087, style=ProgressStyle(description_widt…
# Cr52
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=1087, style=ProgressStyle(description_widt…
# Mn55
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=1087, style=ProgressStyle(description_widt…
# Fe56
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=1087, style=ProgressStyle(description_widt…
# Co59
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=1087, style=ProgressStyle(description_widt…
# Ni60
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=1087, style=ProgressStyle(description_widt…
# Cu63
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=1087, style=ProgressStyle(description_widt…
# Zn68
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=1087, style=ProgressStyle(description_widt…
# Ga69
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=1087, style=ProgressStyle(description_widt…
# Ge72
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=1087, style=ProgressStyle(description_widt…
# As75
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=1087, style=ProgressStyle(description_widt…
# Rb85
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=1087, style=ProgressStyle(description_widt…
# Sr88
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=1087, style=ProgressStyle(description_widt…
# Y89
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=1087, style=ProgressStyle(description_widt…
# Zr90
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=1087, style=ProgressStyle(description_widt…
# Nb93
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=1087, style=ProgressStyle(description_widt…
# Mo95
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=1087, style=ProgressStyle(description_widt…
# Cd111
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=1087, style=ProgressStyle(description_widt…
# In115
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=1087, style=ProgressStyle(description_widt…
# Sn118
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=1087, style=ProgressStyle(description_widt…
# Cs133
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=1087, style=ProgressStyle(description_widt…
# Ba137
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=1087, style=ProgressStyle(description_widt…
# La139
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=1087, style=ProgressStyle(description_widt…
# Ce140
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=1087, style=ProgressStyle(description_widt…
# Pr141
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=1087, style=ProgressStyle(description_widt…
# Nd146
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=1087, style=ProgressStyle(description_widt…
# Sm147
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=1087, style=ProgressStyle(description_widt…
# Eu153
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=1087, style=ProgressStyle(description_widt…
# Gd157
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=1087, style=ProgressStyle(description_widt…
# Tb159
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=1087, style=ProgressStyle(description_widt…
# Dy163
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=1087, style=ProgressStyle(description_widt…
# Ho165
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=1087, style=ProgressStyle(description_widt…
# Er166
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=1087, style=ProgressStyle(description_widt…
# Tm169
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=1087, style=ProgressStyle(description_widt…
# Yb172
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=1087, style=ProgressStyle(description_widt…
# Lu175
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=1087, style=ProgressStyle(description_widt…
# Hf178
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=1087, style=ProgressStyle(description_widt…
# Ta181
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=1087, style=ProgressStyle(description_widt…
# Pb208
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=1087, style=ProgressStyle(description_widt…
# Th232
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=1087, style=ProgressStyle(description_widt…
# U238
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=1087, style=ProgressStyle(description_widt…
# Li7
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=435, style=ProgressStyle(description_width…
# Be9
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=435, style=ProgressStyle(description_width…
# B11
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=435, style=ProgressStyle(description_width…
# Mg24
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=435, style=ProgressStyle(description_width…
# Al27
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=435, style=ProgressStyle(description_width…
# Si28
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=435, style=ProgressStyle(description_width…
# P31
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=435, style=ProgressStyle(description_width…
# S33
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=435, style=ProgressStyle(description_width…
# K39
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=435, style=ProgressStyle(description_width…
# Ca42
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=435, style=ProgressStyle(description_width…
# Sc45
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=435, style=ProgressStyle(description_width…
# Ti47
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=435, style=ProgressStyle(description_width…
# V51
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=435, style=ProgressStyle(description_width…
# Cr52
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=435, style=ProgressStyle(description_width…
# Mn55
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=435, style=ProgressStyle(description_width…
# Fe56
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=435, style=ProgressStyle(description_width…
# Co59
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=435, style=ProgressStyle(description_width…
# Ni60
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=435, style=ProgressStyle(description_width…
# Cu63
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=435, style=ProgressStyle(description_width…
# Zn68
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=435, style=ProgressStyle(description_width…
# Ga69
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=435, style=ProgressStyle(description_width…
# Ge72
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=435, style=ProgressStyle(description_width…
# As75
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=435, style=ProgressStyle(description_width…
# Rb85
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=435, style=ProgressStyle(description_width…
# Sr88
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=435, style=ProgressStyle(description_width…
# Y89
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=435, style=ProgressStyle(description_width…
# Zr90
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=435, style=ProgressStyle(description_width…
# Nb93
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=435, style=ProgressStyle(description_width…
# Mo95
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=435, style=ProgressStyle(description_width…
# Cd111
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=435, style=ProgressStyle(description_width…
# In115
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=435, style=ProgressStyle(description_width…
# Sn118
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=435, style=ProgressStyle(description_width…
# Cs133
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=435, style=ProgressStyle(description_width…
# Ba137
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=435, style=ProgressStyle(description_width…
# La139
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=435, style=ProgressStyle(description_width…
# Ce140
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=435, style=ProgressStyle(description_width…
# Pr141
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=435, style=ProgressStyle(description_width…
# Nd146
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=435, style=ProgressStyle(description_width…
# Sm147
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=435, style=ProgressStyle(description_width…
# Eu153
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=435, style=ProgressStyle(description_width…
# Gd157
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=435, style=ProgressStyle(description_width…
# Tb159
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=435, style=ProgressStyle(description_width…
# Dy163
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=435, style=ProgressStyle(description_width…
# Ho165
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=435, style=ProgressStyle(description_width…
# Er166
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=435, style=ProgressStyle(description_width…
# Tm169
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=435, style=ProgressStyle(description_width…
# Yb172
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=435, style=ProgressStyle(description_width…
# Lu175
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=435, style=ProgressStyle(description_width…
# Hf178
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=435, style=ProgressStyle(description_width…
# Ta181
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=435, style=ProgressStyle(description_width…
# Pb208
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=435, style=ProgressStyle(description_width…
# Th232
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=435, style=ProgressStyle(description_width…
# U238
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=435, style=ProgressStyle(description_width…

# %% [markdown]
# ### visualise na values

# %% [markdown]
# sns.set(rc={'figure.figsize':(20.7,50)})
# sns.heatmap(my_data.isna(), cbar=False)

# %% [markdown]
# ### remove rows where there are all element abundances are na values

# %%
my_data = my_data.dropna(subset=my_data.columns.values[9:-1], how = 'all' , axis = 0)
my_superficial = my_superficial.dropna(subset=my_superficial.columns.values[9:-1], how = 'all' , axis = 0)

# %% [markdown]
# ### split data into 'train_data' and 'test_data', the former consists of samples from known geological sites and the latter from flint artefacts fow which the original geological source site is unknown and to be predicted.

# %%
my_data_split_geological, my_data_split_artefacts = split_data(my_data, 'Geology','Artefacts')

# %% [markdown]
# ### Impute na values with feature mean

# %%
for column_name in my_data_split_geological.columns.values[9:-1]:
    my_data_split_geological[column_name] = my_data_split_geological[column_name].fillna(my_data_split_geological[column_name].mean()) 

for column_name in my_data_split_artefacts.columns.values[9:-1]:
    my_data_split_artefacts[column_name] = my_data_split_artefacts[column_name].fillna(my_data_split_artefacts[column_name].mean())  
    
for column_name in my_superficial.columns.values[9:-1]:
    my_superficial[column_name] = my_superficial[column_name].fillna(my_superficial[column_name].mean())
# Out:
# C:\Users\tom\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\tom\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# C:\Users\tom\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# ### Outliers defined as any values that exceed 2 standard deviations from the mean, such values are changed to the mean for that variable

# %%
my_data_split_geological = replace_outliers(my_data_split_geological, features_start, features_end, num_stds = 2)
my_data_split_artefacts = replace_outliers(my_data_split_artefacts, features_start, features_end, num_stds = 2)
my_superficial = replace_outliers(my_superficial, features_start, features_end, num_stds = 2)
# Out:
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=696, style=ProgressStyle(description_width…
# C:\Users\tom\Documents\GitHub\Machine_Learning\paper_1_notebooks\functions\preproccessing.py:111: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[col_name]= data.swifter.apply(impute_outliers_geo, axis = 1)
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=696, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=696, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=696, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=696, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=696, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=696, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=696, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=696, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=696, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=696, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=696, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=696, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=696, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=696, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=696, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=696, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=696, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=696, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=696, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=696, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=696, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=696, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=696, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=696, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=696, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=696, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=696, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=696, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=696, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=696, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=696, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=696, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=696, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=696, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=696, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=696, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=696, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=696, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=696, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=696, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=696, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=696, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=696, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=696, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=696, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=696, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=696, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=696, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=696, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=696, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=696, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=696, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=363, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=363, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=363, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=363, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=363, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=363, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=363, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=363, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=363, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=363, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=363, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=363, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=363, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=363, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=363, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=363, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=363, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=363, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=363, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=363, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=363, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=363, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=363, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=363, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=363, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=363, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=363, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=363, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=363, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=363, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=363, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=363, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=363, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=363, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=363, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=363, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=363, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=363, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=363, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=363, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=363, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=363, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=363, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=363, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=363, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=363, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=363, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=363, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=363, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=363, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=363, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=363, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=363, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=432, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=432, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=432, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=432, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=432, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=432, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=432, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=432, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=432, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=432, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=432, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=432, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=432, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=432, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=432, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=432, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=432, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=432, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=432, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=432, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=432, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=432, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=432, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=432, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=432, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=432, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=432, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=432, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=432, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=432, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=432, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=432, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=432, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=432, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=432, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=432, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=432, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=432, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=432, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=432, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=432, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=432, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=432, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=432, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=432, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=432, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=432, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=432, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=432, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=432, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=432, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=432, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=432, style=ProgressStyle(description_width…

# %%
print(my_data_split_geological['Geology'].unique())
print(my_data_split_artefacts['Geology'].unique())
print(my_superficial['Geology'].unique())
# Out:
# ['Bedrock']
# ['Artefacts']
# ['Superficial']

# %%
train_data = my_data_split_geological.copy(deep = True)
test_data = my_data_split_artefacts.copy(deep = True)

# %% [markdown]
# ### label encode the class to be predicted

# %%
if bedrock_only:
    train_data_formodel = train_data[train_data['Geology'] == 'Bedrock'].copy(deep = True)
    train_data_formodel['class'], uniques = pd.factorize(train_data_formodel['class'])
else:
    train_data_formodel = train_data.copy(deep = True)
    train_data_formodel['class'], uniques = pd.factorize(train_data_formodel['class'])

# %% [markdown]
# ### datasets are stored

# %%
# %store train_data_formodel
# %store train_data
# %store test_data
# %store my_data
# %store uniques
# Out:
# Stored 'train_data_formodel' (DataFrame)
# Stored 'train_data' (DataFrame)
# Stored 'test_data' (DataFrame)
# Stored 'my_data' (DataFrame)
# Stored 'uniques' (Index)

# %% [markdown]
# ## data preproccessing for dimensionality reduction and visualisation

# %% [markdown]
# ### four datasets are created, one containing all train data (bedrock and superficial types), one containing just bedrock types, one containing just superficial types and one containing the artefacts

# %%
#element_data_train = train_data[train_data.columns.values[9:-1]]
element_data_train_bedrock = train_data[train_data.columns.values[9:-1]]
element_data_train_superficial = my_superficial[my_superficial.columns.values[9:-1]]
element_data_test = test_data[test_data.columns.values[9:-1]]

# %% [markdown]
# ### features are standardised

# %%
my_scaler_train = StandardScaler()
my_scaler_train_bedrock = StandardScaler()
my_scaler_train_superficial = StandardScaler()
my_scaler_test = StandardScaler()

# %%
#element_data_train_scaled = my_scaler_train.fit_transform(element_data_train)
element_data_train_bedrock_scaled = my_scaler_train_bedrock.fit_transform(element_data_train_bedrock)
element_data_train_superficial_scaled = my_scaler_train_superficial.fit_transform(element_data_train_superficial)
element_data_test_scaled = my_scaler_test.fit_transform(element_data_test)

# %% [markdown]
# ### T-Distributed Stochastic Neighbour Embedding is done on the four datasets

# %%
#my_tsne_train = TSNE(n_components=2, n_iter=10000, verbose=3, random_state=random_seed_state).fit_transform(element_data_train_scaled)
my_tsne_bedrock_train = TSNE(n_components=2, n_iter=10000, verbose=3, random_state=random_seed_state).fit_transform(element_data_train_bedrock_scaled)
my_tsne_superficial_train = TSNE(n_components=2, n_iter=10000, verbose=3, random_state=random_seed_state).fit_transform(element_data_train_superficial_scaled)
my_tsne_test = TSNE(n_components=2, n_iter=10000, verbose=3, random_state=random_seed_state).fit_transform(element_data_test_scaled)
# Out:
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 696 samples in 0.003s...
# [t-SNE] Computed neighbors for 696 samples in 0.045s...
# [t-SNE] Computed conditional probabilities for sample 696 / 696
# [t-SNE] Mean sigma: 2.194450
# [t-SNE] Computed conditional probabilities in 0.033s
# [t-SNE] Iteration 50: error = 72.6145859, gradient norm = 0.4021802 (50 iterations in 0.283s)
# [t-SNE] Iteration 100: error = 73.0112534, gradient norm = 0.3905257 (50 iterations in 0.261s)
# [t-SNE] Iteration 150: error = 72.5663605, gradient norm = 0.4193480 (50 iterations in 0.274s)
# [t-SNE] Iteration 200: error = 73.5665207, gradient norm = 0.4036619 (50 iterations in 0.264s)
# [t-SNE] Iteration 250: error = 74.1057205, gradient norm = 0.3846155 (50 iterations in 0.263s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 74.105721
# [t-SNE] Iteration 300: error = 1.2320886, gradient norm = 0.0046994 (50 iterations in 0.178s)
# [t-SNE] Iteration 350: error = 1.1329243, gradient norm = 0.0006182 (50 iterations in 0.170s)
# [t-SNE] Iteration 400: error = 1.1012520, gradient norm = 0.0007823 (50 iterations in 0.166s)
# [t-SNE] Iteration 450: error = 1.0894717, gradient norm = 0.0004048 (50 iterations in 0.164s)
# [t-SNE] Iteration 500: error = 1.0854782, gradient norm = 0.0001638 (50 iterations in 0.166s)
# [t-SNE] Iteration 550: error = 1.0824929, gradient norm = 0.0002203 (50 iterations in 0.166s)
# [t-SNE] Iteration 600: error = 1.0806736, gradient norm = 0.0001727 (50 iterations in 0.166s)
# [t-SNE] Iteration 650: error = 1.0798759, gradient norm = 0.0001107 (50 iterations in 0.167s)
# [t-SNE] Iteration 700: error = 1.0795071, gradient norm = 0.0001133 (50 iterations in 0.169s)
# [t-SNE] Iteration 750: error = 1.0786992, gradient norm = 0.0001281 (50 iterations in 0.168s)
# [t-SNE] Iteration 800: error = 1.0778770, gradient norm = 0.0001705 (50 iterations in 0.171s)
# [t-SNE] Iteration 850: error = 1.0757366, gradient norm = 0.0001024 (50 iterations in 0.171s)
# [t-SNE] Iteration 900: error = 1.0750681, gradient norm = 0.0001056 (50 iterations in 0.170s)
# [t-SNE] Iteration 950: error = 1.0747648, gradient norm = 0.0000867 (50 iterations in 0.171s)
# [t-SNE] Iteration 1000: error = 1.0746268, gradient norm = 0.0001065 (50 iterations in 0.174s)
# [t-SNE] Iteration 1050: error = 1.0746760, gradient norm = 0.0000737 (50 iterations in 0.174s)
# [t-SNE] Iteration 1100: error = 1.0745194, gradient norm = 0.0000794 (50 iterations in 0.171s)
# [t-SNE] Iteration 1150: error = 1.0743593, gradient norm = 0.0000498 (50 iterations in 0.171s)
# [t-SNE] Iteration 1200: error = 1.0741662, gradient norm = 0.0000649 (50 iterations in 0.176s)
# [t-SNE] Iteration 1250: error = 1.0740312, gradient norm = 0.0000684 (50 iterations in 0.172s)
# [t-SNE] Iteration 1300: error = 1.0740697, gradient norm = 0.0001010 (50 iterations in 0.170s)
# [t-SNE] Iteration 1350: error = 1.0739125, gradient norm = 0.0000527 (50 iterations in 0.172s)
# [t-SNE] Iteration 1400: error = 1.0739416, gradient norm = 0.0000667 (50 iterations in 0.172s)
# [t-SNE] Iteration 1450: error = 1.0739279, gradient norm = 0.0000474 (50 iterations in 0.171s)
# [t-SNE] Iteration 1500: error = 1.0739448, gradient norm = 0.0000865 (50 iterations in 0.175s)
# [t-SNE] Iteration 1550: error = 1.0738297, gradient norm = 0.0000757 (50 iterations in 0.175s)
# [t-SNE] Iteration 1600: error = 1.0737736, gradient norm = 0.0000761 (50 iterations in 0.173s)
# [t-SNE] Iteration 1650: error = 1.0738078, gradient norm = 0.0000618 (50 iterations in 0.174s)
# [t-SNE] Iteration 1700: error = 1.0737956, gradient norm = 0.0000742 (50 iterations in 0.170s)
# [t-SNE] Iteration 1750: error = 1.0736872, gradient norm = 0.0000474 (50 iterations in 0.172s)
# [t-SNE] Iteration 1800: error = 1.0737040, gradient norm = 0.0000914 (50 iterations in 0.174s)
# [t-SNE] Iteration 1850: error = 1.0737294, gradient norm = 0.0000488 (50 iterations in 0.173s)
# [t-SNE] Iteration 1900: error = 1.0737776, gradient norm = 0.0000581 (50 iterations in 0.170s)
# [t-SNE] Iteration 1950: error = 1.0738162, gradient norm = 0.0000284 (50 iterations in 0.179s)
# [t-SNE] Iteration 2000: error = 1.0738257, gradient norm = 0.0000494 (50 iterations in 0.179s)
# [t-SNE] Iteration 2050: error = 1.0737807, gradient norm = 0.0000697 (50 iterations in 0.176s)
# [t-SNE] Iteration 2100: error = 1.0737343, gradient norm = 0.0000593 (50 iterations in 0.180s)
# [t-SNE] Iteration 2100: did not make any progress during the last 300 episodes. Finished.
# [t-SNE] KL divergence after 2100 iterations: 1.073734
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 432 samples in 0.000s...
# [t-SNE] Computed neighbors for 432 samples in 0.019s...
# [t-SNE] Computed conditional probabilities for sample 432 / 432
# [t-SNE] Mean sigma: 2.389667
# [t-SNE] Computed conditional probabilities in 0.019s
# [t-SNE] Iteration 50: error = 68.3014374, gradient norm = 0.5010166 (50 iterations in 0.141s)
# [t-SNE] Iteration 100: error = 69.6638565, gradient norm = 0.4785686 (50 iterations in 0.147s)
# [t-SNE] Iteration 150: error = 69.4635468, gradient norm = 0.5012308 (50 iterations in 0.149s)
# [t-SNE] Iteration 200: error = 69.1313248, gradient norm = 0.4979854 (50 iterations in 0.145s)
# [t-SNE] Iteration 250: error = 70.0408859, gradient norm = 0.4751097 (50 iterations in 0.150s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 70.040886
# [t-SNE] Iteration 300: error = 0.9154649, gradient norm = 0.0039472 (50 iterations in 0.114s)
# [t-SNE] Iteration 350: error = 0.8734978, gradient norm = 0.0004912 (50 iterations in 0.102s)
# [t-SNE] Iteration 400: error = 0.8634536, gradient norm = 0.0002614 (50 iterations in 0.105s)
# [t-SNE] Iteration 450: error = 0.8591237, gradient norm = 0.0001694 (50 iterations in 0.105s)
# [t-SNE] Iteration 500: error = 0.8576637, gradient norm = 0.0001098 (50 iterations in 0.110s)
# [t-SNE] Iteration 550: error = 0.8572168, gradient norm = 0.0000794 (50 iterations in 0.108s)
# [t-SNE] Iteration 600: error = 0.8564315, gradient norm = 0.0000816 (50 iterations in 0.113s)
# [t-SNE] Iteration 650: error = 0.8564563, gradient norm = 0.0000938 (50 iterations in 0.105s)
# [t-SNE] Iteration 700: error = 0.8563209, gradient norm = 0.0001106 (50 iterations in 0.105s)
# [t-SNE] Iteration 750: error = 0.8561734, gradient norm = 0.0000688 (50 iterations in 0.104s)
# [t-SNE] Iteration 800: error = 0.8562446, gradient norm = 0.0000500 (50 iterations in 0.106s)
# [t-SNE] Iteration 850: error = 0.8560773, gradient norm = 0.0000486 (50 iterations in 0.105s)
# [t-SNE] Iteration 900: error = 0.8560734, gradient norm = 0.0000529 (50 iterations in 0.107s)
# [t-SNE] Iteration 950: error = 0.8558979, gradient norm = 0.0000990 (50 iterations in 0.112s)
# [t-SNE] Iteration 1000: error = 0.8559440, gradient norm = 0.0001210 (50 iterations in 0.110s)
# [t-SNE] Iteration 1050: error = 0.8558060, gradient norm = 0.0000566 (50 iterations in 0.109s)
# [t-SNE] Iteration 1100: error = 0.8558529, gradient norm = 0.0000434 (50 iterations in 0.107s)
# [t-SNE] Iteration 1150: error = 0.8557441, gradient norm = 0.0000490 (50 iterations in 0.105s)
# [t-SNE] Iteration 1200: error = 0.8556973, gradient norm = 0.0000646 (50 iterations in 0.106s)
# [t-SNE] Iteration 1250: error = 0.8556895, gradient norm = 0.0000576 (50 iterations in 0.105s)
# [t-SNE] Iteration 1300: error = 0.8557404, gradient norm = 0.0000647 (50 iterations in 0.106s)
# [t-SNE] Iteration 1350: error = 0.8557310, gradient norm = 0.0000588 (50 iterations in 0.106s)
# [t-SNE] Iteration 1400: error = 0.8557144, gradient norm = 0.0000586 (50 iterations in 0.106s)
# [t-SNE] Iteration 1450: error = 0.8557412, gradient norm = 0.0000498 (50 iterations in 0.105s)
# [t-SNE] Iteration 1500: error = 0.8557305, gradient norm = 0.0000559 (50 iterations in 0.106s)
# [t-SNE] Iteration 1550: error = 0.8556932, gradient norm = 0.0000639 (50 iterations in 0.107s)
# [t-SNE] Iteration 1600: error = 0.8556970, gradient norm = 0.0000553 (50 iterations in 0.105s)
# [t-SNE] Iteration 1600: did not make any progress during the last 300 episodes. Finished.
# [t-SNE] KL divergence after 1600 iterations: 0.855697
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 363 samples in 0.001s...
# [t-SNE] Computed neighbors for 363 samples in 0.014s...
# [t-SNE] Computed conditional probabilities for sample 363 / 363
# [t-SNE] Mean sigma: 2.634226
# [t-SNE] Computed conditional probabilities in 0.018s
# [t-SNE] Iteration 50: error = 69.1382828, gradient norm = 0.4957461 (50 iterations in 0.118s)
# [t-SNE] Iteration 100: error = 72.5687408, gradient norm = 0.4725733 (50 iterations in 0.118s)
# [t-SNE] Iteration 150: error = 69.7755051, gradient norm = 0.4938209 (50 iterations in 0.129s)
# [t-SNE] Iteration 200: error = 72.4324036, gradient norm = 0.4680220 (50 iterations in 0.123s)
# [t-SNE] Iteration 250: error = 71.0638275, gradient norm = 0.4829374 (50 iterations in 0.119s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 71.063828
# [t-SNE] Iteration 300: error = 1.0468413, gradient norm = 0.0043641 (50 iterations in 0.092s)
# [t-SNE] Iteration 350: error = 0.9833659, gradient norm = 0.0012835 (50 iterations in 0.085s)
# [t-SNE] Iteration 400: error = 0.9475088, gradient norm = 0.0013901 (50 iterations in 0.088s)
# [t-SNE] Iteration 450: error = 0.9222216, gradient norm = 0.0011122 (50 iterations in 0.091s)
# [t-SNE] Iteration 500: error = 0.9135063, gradient norm = 0.0006995 (50 iterations in 0.094s)
# [t-SNE] Iteration 550: error = 0.9082296, gradient norm = 0.0004502 (50 iterations in 0.096s)
# [t-SNE] Iteration 600: error = 0.9017745, gradient norm = 0.0014291 (50 iterations in 0.093s)
# [t-SNE] Iteration 650: error = 0.8905861, gradient norm = 0.0001789 (50 iterations in 0.090s)
# [t-SNE] Iteration 700: error = 0.8900821, gradient norm = 0.0001171 (50 iterations in 0.091s)
# [t-SNE] Iteration 750: error = 0.8900330, gradient norm = 0.0000657 (50 iterations in 0.091s)
# [t-SNE] Iteration 800: error = 0.8897427, gradient norm = 0.0000720 (50 iterations in 0.094s)
# [t-SNE] Iteration 850: error = 0.8895415, gradient norm = 0.0000972 (50 iterations in 0.091s)
# [t-SNE] Iteration 900: error = 0.8894439, gradient norm = 0.0000811 (50 iterations in 0.091s)
# [t-SNE] Iteration 950: error = 0.8889126, gradient norm = 0.0001030 (50 iterations in 0.090s)
# [t-SNE] Iteration 1000: error = 0.8776568, gradient norm = 0.0004591 (50 iterations in 0.090s)
# [t-SNE] Iteration 1050: error = 0.8769341, gradient norm = 0.0000901 (50 iterations in 0.093s)
# [t-SNE] Iteration 1100: error = 0.8768419, gradient norm = 0.0000621 (50 iterations in 0.093s)
# [t-SNE] Iteration 1150: error = 0.8766589, gradient norm = 0.0001116 (50 iterations in 0.091s)
# [t-SNE] Iteration 1200: error = 0.8768839, gradient norm = 0.0000813 (50 iterations in 0.091s)
# [t-SNE] Iteration 1250: error = 0.8767918, gradient norm = 0.0000624 (50 iterations in 0.088s)
# [t-SNE] Iteration 1300: error = 0.8770486, gradient norm = 0.0000777 (50 iterations in 0.090s)
# [t-SNE] Iteration 1350: error = 0.8768248, gradient norm = 0.0000711 (50 iterations in 0.094s)
# [t-SNE] Iteration 1400: error = 0.8768657, gradient norm = 0.0000690 (50 iterations in 0.091s)
# [t-SNE] Iteration 1450: error = 0.8768588, gradient norm = 0.0000638 (50 iterations in 0.094s)
# [t-SNE] Iteration 1500: error = 0.8766367, gradient norm = 0.0000892 (50 iterations in 0.090s)
# [t-SNE] Iteration 1550: error = 0.8767527, gradient norm = 0.0000781 (50 iterations in 0.090s)
# [t-SNE] Iteration 1600: error = 0.8766111, gradient norm = 0.0000481 (50 iterations in 0.091s)
# [t-SNE] Iteration 1650: error = 0.8765722, gradient norm = 0.0001011 (50 iterations in 0.094s)
# [t-SNE] Iteration 1700: error = 0.8763360, gradient norm = 0.0000826 (50 iterations in 0.095s)
# [t-SNE] Iteration 1750: error = 0.8762765, gradient norm = 0.0000488 (50 iterations in 0.092s)
# [t-SNE] Iteration 1800: error = 0.8761551, gradient norm = 0.0000694 (50 iterations in 0.099s)
# [t-SNE] Iteration 1850: error = 0.8762009, gradient norm = 0.0000626 (50 iterations in 0.091s)
# [t-SNE] Iteration 1900: error = 0.8762320, gradient norm = 0.0000845 (50 iterations in 0.093s)
# [t-SNE] Iteration 1950: error = 0.8761944, gradient norm = 0.0001246 (50 iterations in 0.091s)
# [t-SNE] Iteration 2000: error = 0.8762525, gradient norm = 0.0001076 (50 iterations in 0.101s)
# [t-SNE] Iteration 2050: error = 0.8763356, gradient norm = 0.0000518 (50 iterations in 0.098s)
# [t-SNE] Iteration 2100: error = 0.8764909, gradient norm = 0.0000421 (50 iterations in 0.097s)
# [t-SNE] Iteration 2150: error = 0.8763729, gradient norm = 0.0000818 (50 iterations in 0.103s)
# [t-SNE] Iteration 2150: did not make any progress during the last 300 episodes. Finished.
# [t-SNE] KL divergence after 2150 iterations: 0.876373

# %% [markdown]
# ### the t-SNE dimensions for the four datasets are put into dataframes

# %%
#tsne_df_train = pd.DataFrame(data = my_tsne_train, columns = ['tsne1', 'tsne2'])
tsne_df_bedrock_train = pd.DataFrame(data = my_tsne_bedrock_train, columns = ['tsne1', 'tsne2'])
tsne_df_superficial_train = pd.DataFrame(data = my_tsne_superficial_train, columns = ['tsne1', 'tsne2'])
tsne_df_test = pd.DataFrame(data = my_tsne_test, columns = ['tsne1', 'tsne2'])

# %% [markdown]
# ### datasets are stored for the purpose of two-dimensional visualisations

# %%
#%store tsne_df_train

# %store tsne_df_bedrock_train
# %store tsne_df_superficial_train


# %store tsne_df_test

# %store my_superficial
# Out:
# Stored 'tsne_df_bedrock_train' (DataFrame)
# Stored 'tsne_df_superficial_train' (DataFrame)
# Stored 'tsne_df_test' (DataFrame)
# Stored 'my_superficial' (DataFrame)
