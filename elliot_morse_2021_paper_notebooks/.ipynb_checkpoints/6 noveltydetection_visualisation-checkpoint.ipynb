# %% [markdown]
# ### Visualisation of outlier classification

# %%
import pandas as pd
import numpy as np
import swifter
import seaborn as sns
pd.set_option('max.rows', None)
pd.set_option('max.columns', None)
import matplotlib.pyplot as plt


from sklearn.decomposition import PCA 
from sklearn.manifold import TSNE
from sklearn.preprocessing import StandardScaler
# %matplotlib inline

# %%
# %store -r  X_test_labeled_df

# %%
save_plots = True

# %%
X_test_labeled_df.head()
# Out:
#    Analysis      Zr90     Ba137      Sr88      Ge72      Cr52       S33  \
# 0  06_DH1_1  0.415835  0.368775 -0.637129  0.040125 -0.562542 -0.742558
# 1  07_DH1_2  0.466569  0.726320 -0.776295  1.494307 -0.407728 -0.730983
# 2  08_DH1_3  0.073374  0.013522 -0.698014  2.039624 -2.154028 -0.381635
# 3  09_DH2_1  0.441202  1.865423  1.354689  0.611411 -1.993021 -1.389974
# 4  10_DH2_2  1.126124  2.305478  1.485157 -1.414056 -0.104293 -0.862249
#
#        U238      Al27       B11      Mg24     Nd146      Sc45       K39  \
# 0  0.219193 -0.023444  1.533570  0.438877 -0.364648  1.545144  0.828576
# 1  0.219193 -0.011073  1.684246  0.456902 -0.704044  1.583953  0.820790
# 2  0.219193  0.089794  1.565532  0.281163 -1.247078  1.894423  0.837763
# 3 -1.161815  2.804214 -0.704501  0.906387 -0.670104  1.972041  0.252682
# 4 -1.080618  0.219742 -0.920622  2.367498  0.212325  2.088467  0.252682
#
#       Pr141       Li7  inlierLabel
# 0 -0.680255 -0.575952            1
# 1 -0.805314 -0.675981           -1
# 2 -1.180494 -0.654546           -1
# 3 -0.805314  3.158491            1
# 4 -0.054956  3.518122            1

# %% [markdown]
# ## data preproccessing for dimensionality reduction and visualisation

# %%
element_data = X_test_labeled_df[X_test_labeled_df.columns.values[1:-1]]
element_data.head()
# Out:
#        Zr90     Ba137      Sr88      Ge72      Cr52       S33      U238  \
# 0  0.415835  0.368775 -0.637129  0.040125 -0.562542 -0.742558  0.219193
# 1  0.466569  0.726320 -0.776295  1.494307 -0.407728 -0.730983  0.219193
# 2  0.073374  0.013522 -0.698014  2.039624 -2.154028 -0.381635  0.219193
# 3  0.441202  1.865423  1.354689  0.611411 -1.993021 -1.389974 -1.161815
# 4  1.126124  2.305478  1.485157 -1.414056 -0.104293 -0.862249 -1.080618
#
#        Al27       B11      Mg24     Nd146      Sc45       K39     Pr141  \
# 0 -0.023444  1.533570  0.438877 -0.364648  1.545144  0.828576 -0.680255
# 1 -0.011073  1.684246  0.456902 -0.704044  1.583953  0.820790 -0.805314
# 2  0.089794  1.565532  0.281163 -1.247078  1.894423  0.837763 -1.180494
# 3  2.804214 -0.704501  0.906387 -0.670104  1.972041  0.252682 -0.805314
# 4  0.219742 -0.920622  2.367498  0.212325  2.088467  0.252682 -0.054956
#
#         Li7
# 0 -0.575952
# 1 -0.675981
# 2 -0.654546
# 3  3.158491
# 4  3.518122

# %% [markdown]
# ### features are standardised

# %%
my_scaler_train = StandardScaler()

# %%
element_data_scaled = my_scaler_train.fit_transform(element_data)

# %% [markdown]
# ### T-Distributed Stochastic Neighbour Embedding is done

# %%
my_tsne = TSNE(n_components=2, n_iter=5000, verbose=3).fit_transform(element_data_scaled)
# Out:
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 363 samples in 0.001s...
# [t-SNE] Computed neighbors for 363 samples in 0.014s...
# [t-SNE] Computed conditional probabilities for sample 363 / 363
# [t-SNE] Mean sigma: 1.552641
# [t-SNE] Computed conditional probabilities in 0.023s
# [t-SNE] Iteration 50: error = 65.7703323, gradient norm = 0.5135126 (50 iterations in 0.137s)
# [t-SNE] Iteration 100: error = 66.9447327, gradient norm = 0.5018216 (50 iterations in 0.135s)
# [t-SNE] Iteration 150: error = 66.1691971, gradient norm = 0.5295836 (50 iterations in 0.153s)
# [t-SNE] Iteration 200: error = 66.7796478, gradient norm = 0.4941135 (50 iterations in 0.142s)
# [t-SNE] Iteration 250: error = 65.7323685, gradient norm = 0.5297832 (50 iterations in 0.140s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 65.732368
# [t-SNE] Iteration 300: error = 0.8886291, gradient norm = 0.0030267 (50 iterations in 0.114s)
# [t-SNE] Iteration 350: error = 0.8574522, gradient norm = 0.0006685 (50 iterations in 0.110s)
# [t-SNE] Iteration 400: error = 0.8309225, gradient norm = 0.0014840 (50 iterations in 0.111s)
# [t-SNE] Iteration 450: error = 0.8169497, gradient norm = 0.0002248 (50 iterations in 0.110s)
# [t-SNE] Iteration 500: error = 0.8153128, gradient norm = 0.0001962 (50 iterations in 0.107s)
# [t-SNE] Iteration 550: error = 0.8149967, gradient norm = 0.0001525 (50 iterations in 0.107s)
# [t-SNE] Iteration 600: error = 0.8146917, gradient norm = 0.0001362 (50 iterations in 0.107s)
# [t-SNE] Iteration 650: error = 0.8147255, gradient norm = 0.0000877 (50 iterations in 0.108s)
# [t-SNE] Iteration 700: error = 0.8146176, gradient norm = 0.0000969 (50 iterations in 0.112s)
# [t-SNE] Iteration 750: error = 0.8144825, gradient norm = 0.0000515 (50 iterations in 0.109s)
# [t-SNE] Iteration 800: error = 0.8145270, gradient norm = 0.0000738 (50 iterations in 0.115s)
# [t-SNE] Iteration 850: error = 0.8144723, gradient norm = 0.0001010 (50 iterations in 0.109s)
# [t-SNE] Iteration 900: error = 0.8144363, gradient norm = 0.0000691 (50 iterations in 0.106s)
# [t-SNE] Iteration 950: error = 0.8145087, gradient norm = 0.0000918 (50 iterations in 0.107s)
# [t-SNE] Iteration 1000: error = 0.8144548, gradient norm = 0.0000763 (50 iterations in 0.106s)
# [t-SNE] Iteration 1050: error = 0.8144555, gradient norm = 0.0000816 (50 iterations in 0.107s)
# [t-SNE] Iteration 1100: error = 0.8144122, gradient norm = 0.0001410 (50 iterations in 0.108s)
# [t-SNE] Iteration 1150: error = 0.8144311, gradient norm = 0.0000586 (50 iterations in 0.109s)
# [t-SNE] Iteration 1200: error = 0.8144554, gradient norm = 0.0000987 (50 iterations in 0.108s)
# [t-SNE] Iteration 1250: error = 0.8144210, gradient norm = 0.0000635 (50 iterations in 0.110s)
# [t-SNE] Iteration 1300: error = 0.8144595, gradient norm = 0.0000709 (50 iterations in 0.110s)
# [t-SNE] Iteration 1350: error = 0.8144872, gradient norm = 0.0000748 (50 iterations in 0.119s)
# [t-SNE] Iteration 1400: error = 0.8144054, gradient norm = 0.0000752 (50 iterations in 0.110s)
# [t-SNE] Iteration 1450: error = 0.8145145, gradient norm = 0.0000658 (50 iterations in 0.108s)
# [t-SNE] Iteration 1500: error = 0.8144733, gradient norm = 0.0000975 (50 iterations in 0.108s)
# [t-SNE] Iteration 1550: error = 0.8145042, gradient norm = 0.0001307 (50 iterations in 0.107s)
# [t-SNE] Iteration 1600: error = 0.8145036, gradient norm = 0.0000775 (50 iterations in 0.120s)
# [t-SNE] Iteration 1650: error = 0.8144553, gradient norm = 0.0001100 (50 iterations in 0.111s)
# [t-SNE] Iteration 1700: error = 0.8144990, gradient norm = 0.0000789 (50 iterations in 0.112s)
# [t-SNE] Iteration 1750: error = 0.8144353, gradient norm = 0.0001373 (50 iterations in 0.106s)
# [t-SNE] Iteration 1750: did not make any progress during the last 300 episodes. Finished.
# [t-SNE] KL divergence after 1750 iterations: 0.814435

# %% [markdown]
# ### the t-SNE dimensions are put into a dataframe

# %%
tsne_df = pd.DataFrame(data = my_tsne, columns = ['tsne1', 'tsne2'])

# %% [markdown]
# ### datasets are stored for the purpose of two-dimensional visualisations

# %%
tsne_data_with_colour = pd.concat([tsne_df, X_test_labeled_df['inlierLabel']], axis = 1)

# %%
tsne_data_with_colour.head()
# Out:
#        tsne1      tsne2  inlierLabel
# 0   8.112668  -3.973026            1
# 1   8.746178  -4.006448           -1
# 2   9.407042  -3.738037           -1
# 3 -10.643322 -21.800251            1
# 4 -13.250675 -20.838434            1

# %% [markdown]
# ### visualise t-SNE in two dimensions

# %%
sns.set(rc={'figure.figsize':(50,40)})
plot = sns.scatterplot(data = tsne_data_with_colour, x = 'tsne1', y = 'tsne2', hue='inlierLabel', s = 800, palette = ['red', 'blue'])
plt.title('test', fontsize=70)
plot.set_xlabel("train fold size (number of observations)",fontsize=50)
plot.set_ylabel("t-SNE 2",fontsize=50)
plot.set_xlabel("t-SNE 1",fontsize=50)
plot.tick_params(labelsize=40)
plot.set_title('t-SNE visualisation of artefact data coloured by outlier status', fontdict = {'fontsize': 80})

plt.legend(fontsize = 50, loc = 4, markerscale = 5)

if save_plots == True:
    fig = plot.get_figure()
    fig.savefig(fname='figures/tSNE_outlier_detection')

# %%
tsne_data_with_colour.to_csv('output_datasets/tsne_outlier_data.csv')
