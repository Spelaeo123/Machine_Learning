# %% [markdown]
# # data preproccessing

# %% [markdown]
# ## import modules and configure notebook

# %%
import pandas as pd
import numpy as np
import swifter
import seaborn as sns
pd.set_option('max.rows', None)
pd.set_option('max.columns', None)


from sklearn.decomposition import PCA 
from sklearn.manifold import TSNE
from sklearn.preprocessing import StandardScaler
# %matplotlib inline

# %% [markdown]
# ### configurations
# * data_input_path -> string, filepath to data to be read in
#
# * grouping -> boolean, if set to True them many sites are grouped
# * reduced_grouping -> boolean, if set to True then less sites grouped, only bedrock sites 'WB' and 'BX are grouped into one class and superficial sites 'SV' and 'SE' are grouped into one class.
# * raw -> boolean, if set to True then no grouping done
# * drop_semi_bedrock ->  True|False, if set to True then some bedrock sites deemed to be semi-bedrock sites are not used for classification

# %%
data_input_path = '../data/raw_data.csv'

drop_semi_bedrock = True

# %%
# %store -r X_test_labeled_df

# %% [markdown]
# ### Import data

# %%
my_data = pd.read_csv(data_input_path)

# %%
my_data.Geology.value_counts()
# Out:
# Bedrock        808
# Superficial    435
# Artefacts      363
# Name: Geology, dtype: int64

# %% [markdown]
# ### features

# %%
my_data.columns.values[9:-1]
# Out:
# array(['Li7', 'Be9', 'B11', 'Mg24', 'Al27', 'Si28', 'P31', 'S33', 'K39',
#        'Ca42', 'Sc45', 'Ti47', 'V51', 'Cr52', 'Mn55', 'Fe56', 'Co59',
#        'Ni60', 'Cu63', 'Zn68', 'Ga69', 'Ge72', 'As75', 'Rb85', 'Sr88',
#        'Y89', 'Zr90', 'Nb93', 'Mo95', 'Cd111', 'In115', 'Sn118', 'Cs133',
#        'Ba137', 'La139', 'Ce140', 'Pr141', 'Nd146', 'Sm147', 'Eu153',
#        'Gd157', 'Tb159', 'Dy163', 'Ho165', 'Er166', 'Tm169', 'Yb172',
#        'Lu175', 'Hf178', 'Ta181', 'Pb208', 'Th232'], dtype=object)

# %% [markdown]
# ### raw sample names including sample sites and artefacts

# %%
my_data['Site'].unique()
# Out:
# array(['FH', 'ER', 'WW', 'TC', 'CS', 'BC', 'KQ', 'AR', 'SL', 'FG', 'WB',
#        'BX', 'PF', 'BM', 'WH', 'SQ', 'BP', 'WN', 'BH', 'PH', 'LB', 'AB',
#        'LV', 'BR', 'KY', 'BF', 'ST', 'SH', 'CF', 'BG', 'AC', 'CR', 'GH',
#        'PX', 'WF', 'DH', 'NMAG_Gold', 'NMW_Gold', 'NMWGwern', 'UBSS',
#        'Cefn', 'Stockley', 'Pucha', 'Woodbury', 'Pimple', 'Wellington',
#        'Lyonshall', 'SymondsYatE', 'Madawg', nan], dtype=object)

# %% [markdown]
# ### define functions for making target classes for classification

# %%
def make_classes_grouped(row):
    if row['Geology'] == 'Bedrock':
        return(row['Site'])
    elif row['Geology'] == 'Superficial':
        if row['Region'] == 'SV' or row['Region'] == 'SE':
            return('SV_SE')
        else:
            return(row['Region'])

# %% [markdown]
# ### targets for classification are made

# %%
my_data['class'] = 'init'   

my_data['class'] = my_data.apply(make_classes_grouped, axis = 1)

# %%
if drop_semi_bedrock:
    my_data = my_data[(my_data['class'] != 'BM') & (my_data['class'] != 'BC') & (my_data['class'] != 'BP') ]

# %%
my_data = my_data[my_data['Site']!='BP']
my_data = my_data[my_data['Site']!='BX']

# %% [markdown]
# ### remove '<' signs and commas from feature values

# %%
for column_name in my_data.columns.values[9:-1]:
    def fill_less_than(row):
        if 'DL' in  str(row[column_name]):
            return(np.nan)
        if '<' in str(row[column_name]):
            return(float(row[column_name].replace('<', '').replace(',', '')))
        else:
            return(float(row[column_name]))
    my_data[column_name] = my_data.swifter.apply(fill_less_than, axis = 1)
# Out:
# Pandas Apply: 100%|██████████| 1522/1522 [00:00<00:00, 22856.10it/s]
# Pandas Apply: 100%|██████████| 1522/1522 [00:00<00:00, 22353.17it/s]
# Pandas Apply: 100%|██████████| 1522/1522 [00:00<00:00, 21714.85it/s]
# Pandas Apply: 100%|██████████| 1522/1522 [00:00<00:00, 21508.74it/s]
# Pandas Apply: 100%|██████████| 1522/1522 [00:00<00:00, 20988.21it/s]
# Pandas Apply: 100%|██████████| 1522/1522 [00:00<00:00, 19877.54it/s]
# Pandas Apply: 100%|██████████| 1522/1522 [00:00<00:00, 21340.06it/s]
# Pandas Apply: 100%|██████████| 1522/1522 [00:00<00:00, 21904.93it/s]
# Pandas Apply: 100%|██████████| 1522/1522 [00:00<00:00, 20521.12it/s]
# Pandas Apply: 100%|██████████| 1522/1522 [00:00<00:00, 20884.46it/s]
# Pandas Apply: 100%|██████████| 1522/1522 [00:00<00:00, 20415.72it/s]
# Pandas Apply: 100%|██████████| 1522/1522 [00:00<00:00, 21661.43it/s]
# Pandas Apply: 100%|██████████| 1522/1522 [00:00<00:00, 21753.62it/s]
# Pandas Apply: 100%|██████████| 1522/1522 [00:00<00:00, 21737.92it/s]
# Pandas Apply: 100%|██████████| 1522/1522 [00:00<00:00, 21711.08it/s]
# Pandas Apply: 100%|██████████| 1522/1522 [00:00<00:00, 21875.95it/s]
# Pandas Apply: 100%|██████████| 1522/1522 [00:00<00:00, 21536.83it/s]
# Pandas Apply: 100%|██████████| 1522/1522 [00:00<00:00, 20229.91it/s]
# Pandas Apply: 100%|██████████| 1522/1522 [00:00<00:00, 21931.11it/s]
# Pandas Apply: 100%|██████████| 1522/1522 [00:00<00:00, 22031.10it/s]
# Pandas Apply: 100%|██████████| 1522/1522 [00:00<00:00, 21835.99it/s]
# Pandas Apply: 100%|██████████| 1522/1522 [00:00<00:00, 21001.46it/s]
# Pandas Apply: 100%|██████████| 1522/1522 [00:00<00:00, 21400.95it/s]
# Pandas Apply: 100%|██████████| 1522/1522 [00:00<00:00, 19381.23it/s]
# Pandas Apply: 100%|██████████| 1522/1522 [00:00<00:00, 21720.61it/s]
# Pandas Apply: 100%|██████████| 1522/1522 [00:00<00:00, 21491.22it/s]
# Pandas Apply: 100%|██████████| 1522/1522 [00:00<00:00, 19828.58it/s]
# Pandas Apply: 100%|██████████| 1522/1522 [00:00<00:00, 21573.95it/s]
# Pandas Apply: 100%|██████████| 1522/1522 [00:00<00:00, 21746.88it/s]
# Pandas Apply: 100%|██████████| 1522/1522 [00:00<00:00, 21808.47it/s]
# Pandas Apply: 100%|██████████| 1522/1522 [00:00<00:00, 21208.62it/s]
# Pandas Apply: 100%|██████████| 1522/1522 [00:00<00:00, 21913.50it/s]
# Pandas Apply: 100%|██████████| 1522/1522 [00:00<00:00, 21645.27it/s]
# Pandas Apply: 100%|██████████| 1522/1522 [00:00<00:00, 22052.03it/s]
# Pandas Apply: 100%|██████████| 1522/1522 [00:00<00:00, 21379.51it/s]
# Pandas Apply: 100%|██████████| 1522/1522 [00:00<00:00, 21658.49it/s]
# Pandas Apply: 100%|██████████| 1522/1522 [00:00<00:00, 21360.49it/s]
# Pandas Apply: 100%|██████████| 1522/1522 [00:00<00:00, 20747.28it/s]
# Pandas Apply: 100%|██████████| 1522/1522 [00:00<00:00, 21083.59it/s]
# Pandas Apply: 100%|██████████| 1522/1522 [00:00<00:00, 21940.61it/s]
# Pandas Apply: 100%|██████████| 1522/1522 [00:00<00:00, 21417.89it/s]
# Pandas Apply: 100%|██████████| 1522/1522 [00:00<00:00, 21360.27it/s]
# Pandas Apply: 100%|██████████| 1522/1522 [00:00<00:00, 20686.03it/s]
# Pandas Apply: 100%|██████████| 1522/1522 [00:00<00:00, 22066.59it/s]
# Pandas Apply: 100%|██████████| 1522/1522 [00:00<00:00, 21433.78it/s]
# Pandas Apply: 100%|██████████| 1522/1522 [00:00<00:00, 20968.70it/s]
# Pandas Apply: 100%|██████████| 1522/1522 [00:00<00:00, 20915.25it/s]
# Pandas Apply: 100%|██████████| 1522/1522 [00:00<00:00, 21606.15it/s]
# Pandas Apply: 100%|██████████| 1522/1522 [00:00<00:00, 22680.69it/s]
# Pandas Apply: 100%|██████████| 1522/1522 [00:00<00:00, 22028.97it/s]
# Pandas Apply: 100%|██████████| 1522/1522 [00:00<00:00, 20844.90it/s]
# Pandas Apply: 100%|██████████| 1522/1522 [00:00<00:00, 21331.51it/s]
# Pandas Apply: 100%|██████████| 1522/1522 [00:00<00:00, 20695.09it/s]

# %% [markdown]
# ### remove rows where there are all element abundances are na values

# %%
my_data = my_data.dropna(subset=my_data.columns.values[9:-1], how = 'all' , axis = 0)

# %% [markdown]
# ### Impute na values with feature mean

# %%
for column_name in my_data.columns.values[9:-1]:
    my_data[column_name] = my_data[column_name].fillna(my_data[column_name].mean())

# %% [markdown]
# ### Outliers defined as any values that exceed 2 standard deviations from the mean, such values are changed to the mean for that variable

# %%
std_dict = {}
mean_dict = {}
median_dict = {}

for col in my_data.columns.values[9:-1]:
    std_dict[col] = my_data[col].std()
    
for col in my_data.columns.values[9:-1]:
    mean_dict[col] = my_data[col].mean()
    
for col in my_data.columns.values[9:-1]:
    median_dict[col] = my_data[col].median()

# %%
for col_name in my_data.columns.values[9:-1]:
    def impute_outliers(row):
        if np.abs(row[col_name] - mean_dict[col_name]) > 2*(std_dict[col_name]):
            return(mean_dict[col_name])
        else:
            return(row[col_name])
    my_data[col_name]= my_data.swifter.apply(impute_outliers, axis = 1)
# Out:
# Pandas Apply: 100%|██████████| 1491/1491 [00:00<00:00, 23960.75it/s]
# Pandas Apply: 100%|██████████| 1491/1491 [00:00<00:00, 23275.58it/s]
# Pandas Apply: 100%|██████████| 1491/1491 [00:00<00:00, 24399.76it/s]
# Pandas Apply: 100%|██████████| 1491/1491 [00:00<00:00, 24445.73it/s]
# Pandas Apply: 100%|██████████| 1491/1491 [00:00<00:00, 24034.88it/s]
# Pandas Apply: 100%|██████████| 1491/1491 [00:00<00:00, 23246.17it/s]
# Pandas Apply: 100%|██████████| 1491/1491 [00:00<00:00, 23382.54it/s]
# Pandas Apply: 100%|██████████| 1491/1491 [00:00<00:00, 23056.25it/s]
# Pandas Apply: 100%|██████████| 1491/1491 [00:00<00:00, 23524.06it/s]
# Pandas Apply: 100%|██████████| 1491/1491 [00:00<00:00, 23690.71it/s]
# Pandas Apply: 100%|██████████| 1491/1491 [00:00<00:00, 22985.49it/s]
# Pandas Apply: 100%|██████████| 1491/1491 [00:00<00:00, 20504.56it/s]
# Pandas Apply: 100%|██████████| 1491/1491 [00:00<00:00, 22223.87it/s]
# Pandas Apply: 100%|██████████| 1491/1491 [00:00<00:00, 22096.97it/s]
# Pandas Apply: 100%|██████████| 1491/1491 [00:00<00:00, 24278.70it/s]
# Pandas Apply: 100%|██████████| 1491/1491 [00:00<00:00, 24820.34it/s]
# Pandas Apply: 100%|██████████| 1491/1491 [00:00<00:00, 23785.41it/s]
# Pandas Apply: 100%|██████████| 1491/1491 [00:00<00:00, 23895.65it/s]
# Pandas Apply: 100%|██████████| 1491/1491 [00:00<00:00, 23542.22it/s]
# Pandas Apply: 100%|██████████| 1491/1491 [00:00<00:00, 23198.65it/s]
# Pandas Apply: 100%|██████████| 1491/1491 [00:00<00:00, 24766.47it/s]
# Pandas Apply: 100%|██████████| 1491/1491 [00:00<00:00, 23543.81it/s]
# Pandas Apply: 100%|██████████| 1491/1491 [00:00<00:00, 24580.93it/s]
# Pandas Apply: 100%|██████████| 1491/1491 [00:00<00:00, 24681.04it/s]
# Pandas Apply: 100%|██████████| 1491/1491 [00:00<00:00, 23265.89it/s]
# Pandas Apply: 100%|██████████| 1491/1491 [00:00<00:00, 24604.23it/s]
# Pandas Apply: 100%|██████████| 1491/1491 [00:00<00:00, 24502.05it/s]
# Pandas Apply: 100%|██████████| 1491/1491 [00:00<00:00, 23833.91it/s]
# Pandas Apply: 100%|██████████| 1491/1491 [00:00<00:00, 24804.39it/s]
# Pandas Apply: 100%|██████████| 1491/1491 [00:00<00:00, 24203.43it/s]
# Pandas Apply: 100%|██████████| 1491/1491 [00:00<00:00, 23322.37it/s]
# Pandas Apply: 100%|██████████| 1491/1491 [00:00<00:00, 22926.25it/s]
# Pandas Apply: 100%|██████████| 1491/1491 [00:00<00:00, 24885.92it/s]
# Pandas Apply: 100%|██████████| 1491/1491 [00:00<00:00, 24281.43it/s]
# Pandas Apply: 100%|██████████| 1491/1491 [00:00<00:00, 22745.47it/s]
# Pandas Apply: 100%|██████████| 1491/1491 [00:00<00:00, 24506.18it/s]
# Pandas Apply: 100%|██████████| 1491/1491 [00:00<00:00, 22795.21it/s]
# Pandas Apply: 100%|██████████| 1491/1491 [00:00<00:00, 24652.34it/s]
# Pandas Apply: 100%|██████████| 1491/1491 [00:00<00:00, 24994.23it/s]
# Pandas Apply: 100%|██████████| 1491/1491 [00:00<00:00, 22489.69it/s]
# Pandas Apply: 100%|██████████| 1491/1491 [00:00<00:00, 24716.65it/s]
# Pandas Apply: 100%|██████████| 1491/1491 [00:00<00:00, 22755.65it/s]
# Pandas Apply: 100%|██████████| 1491/1491 [00:00<00:00, 24338.70it/s]
# Pandas Apply: 100%|██████████| 1491/1491 [00:00<00:00, 25223.48it/s]
# Pandas Apply: 100%|██████████| 1491/1491 [00:00<00:00, 23388.31it/s]
# Pandas Apply: 100%|██████████| 1491/1491 [00:00<00:00, 24517.61it/s]
# Pandas Apply: 100%|██████████| 1491/1491 [00:00<00:00, 24561.33it/s]
# Pandas Apply: 100%|██████████| 1491/1491 [00:00<00:00, 22394.25it/s]
# Pandas Apply: 100%|██████████| 1491/1491 [00:00<00:00, 20871.50it/s]
# Pandas Apply: 100%|██████████| 1491/1491 [00:00<00:00, 24641.66it/s]
# Pandas Apply: 100%|██████████| 1491/1491 [00:00<00:00, 24258.73it/s]
# Pandas Apply: 100%|██████████| 1491/1491 [00:00<00:00, 21322.90it/s]
# Pandas Apply: 100%|██████████| 1491/1491 [00:00<00:00, 24964.50it/s]

# %% [markdown]
# ### split data into 'train_data' and 'test_data', the former consists of samples from known geological sites and the latter from flint artefacts fow which the original geological source site is unknown and to be predicted.

# %%
my_data.isna().any()
# Out:
# Analysis     False
# Geology      False
# Province      True
# Region        True
# Site         False
# SubSite       True
# Formation     True
# Band          True
# Nodule       False
# Li7          False
# Be9          False
# B11          False
# Mg24         False
# Al27         False
# Si28         False
# P31          False
# S33          False
# K39          False
# Ca42         False
# Sc45         False
# Ti47         False
# V51          False
# Cr52         False
# Mn55         False
# Fe56         False
# Co59         False
# Ni60         False
# Cu63         False
# Zn68         False
# Ga69         False
# Ge72         False
# As75         False
# Rb85         False
# Sr88         False
# Y89          False
# Zr90         False
# Nb93         False
# Mo95         False
# Cd111        False
# In115        False
# Sn118        False
# Cs133        False
# Ba137        False
# La139        False
# Ce140        False
# Pr141        False
# Nd146        False
# Sm147        False
# Eu153        False
# Gd157        False
# Tb159        False
# Dy163        False
# Ho165        False
# Er166        False
# Tm169        False
# Yb172        False
# Lu175        False
# Hf178        False
# Ta181        False
# Pb208        False
# Th232        False
# U238         False
# class         True
# dtype: bool

# %%
train_data = my_data[(my_data['Geology']== 'Bedrock') | (my_data['Geology'] == 'Superficial')]
test_data = my_data[my_data['Geology']=='Artefacts']

# %% [markdown]
# ### label encode the class to be predicted

# %% [markdown]
# ### 'training_data' is split into two datasets, one consisting of samples from superficial sites and one containing samples from bedrock sites.

# %%
train_data_bedrock = train_data[train_data['Geology'] == 'Bedrock']
train_data_superficial = train_data[train_data['Geology'] == 'Superficial']

# %% [markdown]
# ### four datasets are created, one containing all train data (bedrock and superficial types), one containing just bedrock types, one containing just superficial types and one containing the artefacts

# %%
element_data_train = train_data[train_data.columns.values[9:-1]]
element_data_train_bedrock = train_data_bedrock[train_data.columns.values[9:-1]]
element_data_train_superficial = train_data_superficial[train_data.columns.values[9:-1]]
element_data_test = test_data[test_data.columns.values[9:-1]]
element_data_everything = my_data[my_data.columns.values[9:-1]]

# %%
element_data_everything.shape
# Out:
# (1491, 53)

# %%
element_data_train.shape
# Out:
# (1128, 53)

# %%
element_data_everything.head()
# Out:
#      Li7   Be9    B11        Mg24     Al27           Si28          P31  \
# 0  15.63  0.12  48.36  154.630000   943.71  464944.180000    50.280000
# 1  11.50  0.09  44.77   33.872347  1077.11  465010.940000    70.910000
# 2  20.05  0.06  44.88   42.700000   620.21  465295.410000   104.470000
# 3  11.16  0.73  47.06   33.872347  1143.19  462172.810919  2420.945164
# 4  17.71  0.32  48.26   33.520000   547.22  465027.110000    44.440000
#
#        S33     K39     Ca42  Sc45   Ti47   V51    Cr52  Mn55    Fe56  Co59  \
# 0   538.57  455.94   712.39  0.42  15.58  0.27    3.30  0.69    8.46  0.05
# 1   438.20  387.82   515.24  0.44  18.47  0.29    3.45  1.01   11.59  0.11
# 2   372.66  363.71   957.89  0.76  19.89  0.55    3.25  1.21   87.99  0.21
# 3  1075.89  547.55  2174.30  0.43  42.30  0.67  152.42  4.84  145.34  0.30
# 4   464.78  278.25  1551.63  0.71  11.18  0.27    2.56  1.73   25.38  0.05
#
#    Ni60  Cu63   Zn68  Ga69  Ge72  As75  Rb85   Sr88   Y89  Zr90  Nb93  Mo95  \
# 0  0.80  1.62  10.82  0.25  1.22  0.16  0.43  12.94  0.88  1.51  0.09  0.05
# 1  0.36  0.53   8.93  0.34  0.85  0.10  0.45  13.22  0.95  1.74  0.07  0.01
# 2  1.68  1.53  11.98  0.25  1.71  0.13  0.43   8.52  0.87  0.93  0.10  0.02
# 3  2.45  5.02  17.15  0.35  2.13  0.84  0.76  13.16  0.97  2.00  0.10  0.29
# 4  0.80  0.55   9.80  0.41  1.41  0.12  0.28   9.90  0.90  0.90  0.08  0.04
#
#    Cd111  In115  Sn118  Cs133  Ba137  La139  Ce140  Pr141  Nd146  Sm147  \
# 0   0.02   0.00   0.05   0.01   6.54   0.84   0.95   0.23   0.87   0.16
# 1   0.02   0.00   0.04   0.02   8.04   0.92   1.01   0.23   0.98   0.18
# 2   0.02   0.00   0.05   0.01   3.13   0.90   1.08   0.26   0.84   0.15
# 3   0.18   0.01   0.78   0.04   8.74   0.93   0.95   0.21   0.75   0.13
# 4   0.10   0.00   0.09   0.01   2.74   0.97   1.09   0.27   1.00   0.17
#
#    Eu153  Gd157  Tb159  Dy163  Ho165  Er166  Tm169  Yb172  Lu175  Hf178  \
# 0   0.04   0.16   0.02   0.11   0.03   0.06   0.01   0.02   0.00   0.04
# 1   0.04   0.18   0.02   0.13   0.03   0.06   0.01   0.04   0.01   0.05
# 2   0.04   0.19   0.02   0.14   0.02   0.07   0.01   0.06   0.00   0.02
# 3   0.04   0.25   0.02   0.09   0.03   0.05   0.00   0.03   0.00   0.08
# 4   0.04   0.19   0.02   0.15   0.03   0.05   0.01   0.05   0.01   0.02
#
#    Ta181  Pb208  Th232  U238
# 0   0.01   0.24   0.07  0.05
# 1   0.00   0.07   0.08  0.04
# 2   0.01   0.46   0.05  0.05
# 3   0.00   0.64   0.05  0.03
# 4   0.01   0.59   0.06  0.09

# %% [markdown]
# ### features are standardised

# %%
my_scaler_train = StandardScaler()
my_scaler_train_bedrock = StandardScaler()
my_scaler_train_superficial = StandardScaler()
my_scaler_test = StandardScaler()
my_scaler_everything = StandardScaler()

# %%
element_data_train_scaled = my_scaler_train.fit_transform(element_data_train)
element_data_train_bedrock_scaled = my_scaler_train_bedrock.fit_transform(element_data_train_bedrock)
element_data_train_superficial_scaled = my_scaler_train_superficial.fit_transform(element_data_train_superficial)
element_data_test_scaled = my_scaler_test.fit_transform(element_data_test)
element_data_everything_scaled = my_scaler_everything.fit_transform(element_data_everything)

# %% [markdown]
# ### The four datasets are transformed using Principal component analysis

# %%
my_pca_train = PCA(n_components=element_data_train_scaled.shape[1])
my_pca_train_bedrock = PCA(n_components=element_data_train_bedrock_scaled.shape[1])
my_pca_train_superficial = PCA(n_components=element_data_train_superficial_scaled.shape[1])
my_pca_test = PCA(n_components=element_data_test_scaled.shape[1])
my_pca_everything = PCA(n_components=element_data_everything_scaled.shape[1])

element_data_train_pca = my_pca_train.fit_transform(element_data_train_scaled)
element_data_train_bedrock_pca = my_pca_train_bedrock.fit_transform(element_data_train_bedrock_scaled)
element_data_train_superficial_pca = my_pca_train_superficial.fit_transform(element_data_train_superficial_scaled)
element_data_test_pca = my_pca_test.fit_transform(element_data_test_scaled)
element_data_everything_pca = my_pca_everything.fit_transform(element_data_everything)

# %% [markdown]
# ### print details of PCA

# %%
print(my_pca_train)
# Out:
# PCA(copy=True, iterated_power='auto', n_components=53, random_state=None,
#   svd_solver='auto', tol=0.0, whiten=False)

# %% [markdown]
# ### the principal components for the four datasets are put into dataframes

# %%
no_PCs = element_data_train_scaled.shape[1]
PC_names = []
for i in range(0, no_PCs):
    number = i + 1
    column_name = 'PC' + str(number)
    PC_names.append(column_name)

# %%
PC_df_train = pd.DataFrame(data = element_data_train_pca, columns = PC_names)
PC_df_bedrock_train = pd.DataFrame(data = element_data_train_bedrock_pca, columns = PC_names)
PC_df_superficial_train = pd.DataFrame(data = element_data_train_superficial_pca, columns = PC_names)
PC_df_test = pd.DataFrame(data = element_data_test_pca, columns = PC_names)
PC_df_everything = pd.DataFrame(data = element_data_everything_pca, columns = PC_names)

# %% [markdown]
# ### T-Distributed Stochastic Neighbour Embedding is done on the four datasets

# %%
my_tsne_train = TSNE(n_components=3, n_iter=10000, verbose=3).fit_transform(element_data_train_scaled)
my_tsne_bedrock_train = TSNE(n_components=3, n_iter=10000, verbose=3).fit_transform(element_data_train_bedrock_scaled)
my_tsne_superficial_train = TSNE(n_components=3, n_iter=10000, verbose=3).fit_transform(element_data_train_superficial_scaled)
my_tsne_test = TSNE(n_components=3, n_iter=10000, verbose=3).fit_transform(element_data_test_scaled)
my_tsne_everything = TSNE(n_components=3, n_iter=10000, verbose=3).fit_transform(element_data_everything_scaled)
# Out:
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 1128 samples in 0.002s...
# [t-SNE] Computed neighbors for 1128 samples in 0.183s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 1128
# [t-SNE] Computed conditional probabilities for sample 1128 / 1128
# [t-SNE] Mean sigma: 2.025902
# [t-SNE] Computed conditional probabilities in 0.064s
# [t-SNE] Iteration 50: error = 71.7872467, gradient norm = 0.1449712 (50 iterations in 4.767s)
# [t-SNE] Iteration 100: error = 73.1344299, gradient norm = 0.1326146 (50 iterations in 4.345s)
# [t-SNE] Iteration 150: error = 73.2917786, gradient norm = 0.1184866 (50 iterations in 3.046s)
# [t-SNE] Iteration 200: error = 74.2052460, gradient norm = 0.0961905 (50 iterations in 2.948s)
# [t-SNE] Iteration 250: error = 74.1814117, gradient norm = 0.1043922 (50 iterations in 2.781s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 74.181412
# [t-SNE] Iteration 300: error = 1.5108082, gradient norm = 0.0005867 (50 iterations in 3.001s)
# [t-SNE] Iteration 350: error = 1.4056307, gradient norm = 0.0002115 (50 iterations in 3.457s)
# [t-SNE] Iteration 400: error = 1.3533508, gradient norm = 0.0001293 (50 iterations in 3.607s)
# [t-SNE] Iteration 450: error = 1.2790587, gradient norm = 0.0003360 (50 iterations in 3.598s)
# [t-SNE] Iteration 500: error = 1.2567363, gradient norm = 0.0000805 (50 iterations in 3.481s)
# [t-SNE] Iteration 550: error = 1.2408911, gradient norm = 0.0000627 (50 iterations in 3.431s)
# [t-SNE] Iteration 600: error = 1.2185611, gradient norm = 0.0000572 (50 iterations in 3.501s)
# [t-SNE] Iteration 650: error = 1.1891152, gradient norm = 0.0001068 (50 iterations in 3.661s)
# [t-SNE] Iteration 700: error = 1.1801318, gradient norm = 0.0003782 (50 iterations in 3.527s)
# [t-SNE] Iteration 750: error = 1.1601160, gradient norm = 0.0000605 (50 iterations in 2.960s)
# [t-SNE] Iteration 800: error = 1.1301365, gradient norm = 0.0001148 (50 iterations in 2.638s)
# [t-SNE] Iteration 850: error = 1.1272136, gradient norm = 0.0000438 (50 iterations in 2.275s)
# [t-SNE] Iteration 900: error = 1.1117742, gradient norm = 0.0000515 (50 iterations in 2.292s)
# [t-SNE] Iteration 950: error = 1.1041161, gradient norm = 0.0000430 (50 iterations in 2.325s)
# [t-SNE] Iteration 1000: error = 1.0851470, gradient norm = 0.0000864 (50 iterations in 2.355s)
# [t-SNE] Iteration 1050: error = 1.0817493, gradient norm = 0.0000430 (50 iterations in 2.369s)
# [t-SNE] Iteration 1100: error = 1.0802453, gradient norm = 0.0000256 (50 iterations in 2.365s)
# [t-SNE] Iteration 1150: error = 1.0801741, gradient norm = 0.0000219 (50 iterations in 2.306s)
# [t-SNE] Iteration 1200: error = 1.0797738, gradient norm = 0.0000205 (50 iterations in 2.310s)
# [t-SNE] Iteration 1250: error = 1.0796432, gradient norm = 0.0000205 (50 iterations in 2.303s)
# [t-SNE] Iteration 1300: error = 1.0799671, gradient norm = 0.0000155 (50 iterations in 2.339s)
# [t-SNE] Iteration 1350: error = 1.0799881, gradient norm = 0.0000137 (50 iterations in 2.352s)
# [t-SNE] Iteration 1400: error = 1.0799825, gradient norm = 0.0000155 (50 iterations in 2.342s)
# [t-SNE] Iteration 1450: error = 1.0802932, gradient norm = 0.0000133 (50 iterations in 2.383s)
# [t-SNE] Iteration 1500: error = 1.0806650, gradient norm = 0.0000119 (50 iterations in 2.347s)
# [t-SNE] Iteration 1550: error = 1.0809317, gradient norm = 0.0000112 (50 iterations in 2.360s)
# [t-SNE] Iteration 1600: error = 1.0809007, gradient norm = 0.0000098 (50 iterations in 2.354s)
# [t-SNE] Iteration 1600: did not make any progress during the last 300 episodes. Finished.
# [t-SNE] KL divergence after 1600 iterations: 1.080901
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 696 samples in 0.001s...
# [t-SNE] Computed neighbors for 696 samples in 0.068s...
# [t-SNE] Computed conditional probabilities for sample 696 / 696
# [t-SNE] Mean sigma: 2.154088
# [t-SNE] Computed conditional probabilities in 0.040s
# [t-SNE] Iteration 50: error = 80.9311371, gradient norm = 0.2379395 (50 iterations in 1.747s)
# [t-SNE] Iteration 100: error = 86.9918900, gradient norm = 0.2276230 (50 iterations in 1.751s)
# [t-SNE] Iteration 150: error = 91.7348251, gradient norm = 0.2142609 (50 iterations in 1.735s)
# [t-SNE] Iteration 200: error = 93.7457504, gradient norm = 0.2115575 (50 iterations in 1.750s)
# [t-SNE] Iteration 250: error = 95.1235046, gradient norm = 0.1959041 (50 iterations in 1.738s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 95.123505
# [t-SNE] Iteration 300: error = 2.7414293, gradient norm = 0.0008360 (50 iterations in 1.712s)
# [t-SNE] Iteration 350: error = 2.4005663, gradient norm = 0.0002979 (50 iterations in 1.906s)
# [t-SNE] Iteration 400: error = 2.2023010, gradient norm = 0.0001621 (50 iterations in 1.910s)
# [t-SNE] Iteration 450: error = 2.0754788, gradient norm = 0.0000996 (50 iterations in 1.932s)
# [t-SNE] Iteration 500: error = 1.9719357, gradient norm = 0.0000835 (50 iterations in 1.954s)
# [t-SNE] Iteration 550: error = 1.8798425, gradient norm = 0.0000596 (50 iterations in 2.041s)
# [t-SNE] Iteration 600: error = 1.7981077, gradient norm = 0.0000527 (50 iterations in 2.031s)
# [t-SNE] Iteration 650: error = 1.7331755, gradient norm = 0.0000462 (50 iterations in 2.104s)
# [t-SNE] Iteration 700: error = 1.6834768, gradient norm = 0.0000379 (50 iterations in 2.324s)
# [t-SNE] Iteration 750: error = 1.6407185, gradient norm = 0.0000349 (50 iterations in 2.284s)
# [t-SNE] Iteration 800: error = 1.6043330, gradient norm = 0.0000348 (50 iterations in 2.275s)
# [t-SNE] Iteration 850: error = 1.5767684, gradient norm = 0.0000423 (50 iterations in 2.241s)
# [t-SNE] Iteration 900: error = 1.5525048, gradient norm = 0.0000267 (50 iterations in 2.191s)
# [t-SNE] Iteration 950: error = 1.5339785, gradient norm = 0.0000227 (50 iterations in 2.128s)
# [t-SNE] Iteration 1000: error = 1.5131500, gradient norm = 0.0000266 (50 iterations in 2.047s)
# [t-SNE] Iteration 1050: error = 1.4961476, gradient norm = 0.0000208 (50 iterations in 1.982s)
# [t-SNE] Iteration 1100: error = 1.4830072, gradient norm = 0.0000161 (50 iterations in 1.905s)
# [t-SNE] Iteration 1150: error = 1.4716544, gradient norm = 0.0000148 (50 iterations in 1.823s)
# [t-SNE] Iteration 1200: error = 1.4594383, gradient norm = 0.0000137 (50 iterations in 1.804s)
# [t-SNE] Iteration 1250: error = 1.4455088, gradient norm = 0.0000130 (50 iterations in 1.758s)
# [t-SNE] Iteration 1300: error = 1.4316319, gradient norm = 0.0000123 (50 iterations in 1.713s)
# [t-SNE] Iteration 1350: error = 1.4154664, gradient norm = 0.0000138 (50 iterations in 1.620s)
# [t-SNE] Iteration 1400: error = 1.3959204, gradient norm = 0.0000173 (50 iterations in 1.572s)
# [t-SNE] Iteration 1450: error = 1.3806040, gradient norm = 0.0000140 (50 iterations in 1.609s)
# [t-SNE] Iteration 1500: error = 1.3698362, gradient norm = 0.0000121 (50 iterations in 1.521s)
# [t-SNE] Iteration 1550: error = 1.3619757, gradient norm = 0.0000100 (50 iterations in 1.490s)
# [t-SNE] Iteration 1600: error = 1.3546705, gradient norm = 0.0000097 (50 iterations in 1.434s)
# [t-SNE] Iteration 1650: error = 1.3459963, gradient norm = 0.0000101 (50 iterations in 1.404s)
# [t-SNE] Iteration 1700: error = 1.3397964, gradient norm = 0.0000079 (50 iterations in 1.372s)
# [t-SNE] Iteration 1750: error = 1.3330519, gradient norm = 0.0000072 (50 iterations in 1.306s)
# [t-SNE] Iteration 1800: error = 1.3255099, gradient norm = 0.0000066 (50 iterations in 1.257s)
# [t-SNE] Iteration 1850: error = 1.3171022, gradient norm = 0.0000066 (50 iterations in 1.244s)
# [t-SNE] Iteration 1900: error = 1.3084066, gradient norm = 0.0000078 (50 iterations in 1.246s)
# [t-SNE] Iteration 1950: error = 1.2983761, gradient norm = 0.0000099 (50 iterations in 1.280s)
# [t-SNE] Iteration 2000: error = 1.2923357, gradient norm = 0.0000079 (50 iterations in 1.277s)
# [t-SNE] Iteration 2050: error = 1.2884965, gradient norm = 0.0000067 (50 iterations in 1.248s)
# [t-SNE] Iteration 2100: error = 1.2853774, gradient norm = 0.0000058 (50 iterations in 1.282s)
# [t-SNE] Iteration 2150: error = 1.2825574, gradient norm = 0.0000052 (50 iterations in 1.273s)
# [t-SNE] Iteration 2200: error = 1.2799594, gradient norm = 0.0000049 (50 iterations in 1.252s)
# [t-SNE] Iteration 2250: error = 1.2774616, gradient norm = 0.0000047 (50 iterations in 1.260s)
# [t-SNE] Iteration 2300: error = 1.2747718, gradient norm = 0.0000045 (50 iterations in 1.224s)
# [t-SNE] Iteration 2350: error = 1.2721494, gradient norm = 0.0000041 (50 iterations in 1.195s)
# [t-SNE] Iteration 2400: error = 1.2698885, gradient norm = 0.0000039 (50 iterations in 1.202s)
# [t-SNE] Iteration 2450: error = 1.2678678, gradient norm = 0.0000037 (50 iterations in 1.199s)
# [t-SNE] Iteration 2500: error = 1.2659519, gradient norm = 0.0000035 (50 iterations in 1.186s)
# [t-SNE] Iteration 2550: error = 1.2642553, gradient norm = 0.0000034 (50 iterations in 1.200s)
# [t-SNE] Iteration 2600: error = 1.2626780, gradient norm = 0.0000033 (50 iterations in 1.190s)
# [t-SNE] Iteration 2650: error = 1.2611728, gradient norm = 0.0000032 (50 iterations in 1.224s)
# [t-SNE] Iteration 2700: error = 1.2592763, gradient norm = 0.0000031 (50 iterations in 1.209s)
# [t-SNE] Iteration 2750: error = 1.2571634, gradient norm = 0.0000031 (50 iterations in 1.216s)
# [t-SNE] Iteration 2800: error = 1.2547376, gradient norm = 0.0000032 (50 iterations in 1.177s)
# [t-SNE] Iteration 2850: error = 1.2520970, gradient norm = 0.0000029 (50 iterations in 1.234s)
# [t-SNE] Iteration 2900: error = 1.2502178, gradient norm = 0.0000029 (50 iterations in 1.228s)
# [t-SNE] Iteration 2950: error = 1.2480944, gradient norm = 0.0000030 (50 iterations in 1.226s)
# [t-SNE] Iteration 3000: error = 1.2453378, gradient norm = 0.0000031 (50 iterations in 1.209s)
# [t-SNE] Iteration 3050: error = 1.2429364, gradient norm = 0.0000029 (50 iterations in 1.240s)
# [t-SNE] Iteration 3100: error = 1.2404118, gradient norm = 0.0000028 (50 iterations in 1.230s)
# [t-SNE] Iteration 3150: error = 1.2382443, gradient norm = 0.0000027 (50 iterations in 1.199s)
# [t-SNE] Iteration 3200: error = 1.2365026, gradient norm = 0.0000026 (50 iterations in 1.187s)
# [t-SNE] Iteration 3250: error = 1.2348682, gradient norm = 0.0000025 (50 iterations in 1.228s)
# [t-SNE] Iteration 3300: error = 1.2332666, gradient norm = 0.0000025 (50 iterations in 1.217s)
# [t-SNE] Iteration 3350: error = 1.2316713, gradient norm = 0.0000024 (50 iterations in 1.219s)
# [t-SNE] Iteration 3400: error = 1.2298595, gradient norm = 0.0000024 (50 iterations in 1.201s)
# [t-SNE] Iteration 3450: error = 1.2281765, gradient norm = 0.0000024 (50 iterations in 1.224s)
# [t-SNE] Iteration 3500: error = 1.2265353, gradient norm = 0.0000023 (50 iterations in 1.202s)
# [t-SNE] Iteration 3550: error = 1.2247965, gradient norm = 0.0000022 (50 iterations in 1.195s)
# [t-SNE] Iteration 3600: error = 1.2229367, gradient norm = 0.0000021 (50 iterations in 1.211s)
# [t-SNE] Iteration 3650: error = 1.2208802, gradient norm = 0.0000021 (50 iterations in 1.213s)
# [t-SNE] Iteration 3700: error = 1.2184834, gradient norm = 0.0000021 (50 iterations in 1.242s)
# [t-SNE] Iteration 3750: error = 1.2157580, gradient norm = 0.0000022 (50 iterations in 1.236s)
# [t-SNE] Iteration 3800: error = 1.2123985, gradient norm = 0.0000022 (50 iterations in 1.208s)
# [t-SNE] Iteration 3850: error = 1.2088828, gradient norm = 0.0000023 (50 iterations in 1.204s)
# [t-SNE] Iteration 3900: error = 1.2050925, gradient norm = 0.0000022 (50 iterations in 1.211s)
# [t-SNE] Iteration 3950: error = 1.2020231, gradient norm = 0.0000021 (50 iterations in 1.217s)
# [t-SNE] Iteration 4000: error = 1.1989350, gradient norm = 0.0000022 (50 iterations in 1.205s)
# [t-SNE] Iteration 4050: error = 1.1959628, gradient norm = 0.0000021 (50 iterations in 1.180s)
# [t-SNE] Iteration 4100: error = 1.1936890, gradient norm = 0.0000020 (50 iterations in 1.188s)
# [t-SNE] Iteration 4150: error = 1.1918322, gradient norm = 0.0000019 (50 iterations in 1.161s)
# [t-SNE] Iteration 4200: error = 1.1903125, gradient norm = 0.0000019 (50 iterations in 1.138s)
# [t-SNE] Iteration 4250: error = 1.1889381, gradient norm = 0.0000018 (50 iterations in 1.210s)
# [t-SNE] Iteration 4300: error = 1.1878256, gradient norm = 0.0000018 (50 iterations in 1.183s)
# [t-SNE] Iteration 4350: error = 1.1868923, gradient norm = 0.0000018 (50 iterations in 1.188s)
# [t-SNE] Iteration 4400: error = 1.1859412, gradient norm = 0.0000016 (50 iterations in 1.189s)
# [t-SNE] Iteration 4450: error = 1.1852427, gradient norm = 0.0000016 (50 iterations in 1.212s)
# [t-SNE] Iteration 4500: error = 1.1846424, gradient norm = 0.0000015 (50 iterations in 1.188s)
# [t-SNE] Iteration 4550: error = 1.1840155, gradient norm = 0.0000015 (50 iterations in 1.210s)
# [t-SNE] Iteration 4600: error = 1.1834803, gradient norm = 0.0000014 (50 iterations in 1.204s)
# [t-SNE] Iteration 4650: error = 1.1828612, gradient norm = 0.0000014 (50 iterations in 1.202s)
# [t-SNE] Iteration 4700: error = 1.1824688, gradient norm = 0.0000014 (50 iterations in 1.213s)
# [t-SNE] Iteration 4750: error = 1.1820208, gradient norm = 0.0000013 (50 iterations in 1.194s)
# [t-SNE] Iteration 4800: error = 1.1816880, gradient norm = 0.0000013 (50 iterations in 1.190s)
# [t-SNE] Iteration 4850: error = 1.1812661, gradient norm = 0.0000013 (50 iterations in 1.217s)
# [t-SNE] Iteration 4900: error = 1.1809386, gradient norm = 0.0000013 (50 iterations in 1.227s)
# [t-SNE] Iteration 4950: error = 1.1804271, gradient norm = 0.0000013 (50 iterations in 1.187s)
# [t-SNE] Iteration 5000: error = 1.1799241, gradient norm = 0.0000013 (50 iterations in 1.229s)
# [t-SNE] Iteration 5050: error = 1.1791995, gradient norm = 0.0000013 (50 iterations in 1.209s)
# [t-SNE] Iteration 5100: error = 1.1785842, gradient norm = 0.0000013 (50 iterations in 1.226s)
# [t-SNE] Iteration 5150: error = 1.1779866, gradient norm = 0.0000013 (50 iterations in 1.210s)
# [t-SNE] Iteration 5200: error = 1.1774153, gradient norm = 0.0000012 (50 iterations in 1.223s)
# [t-SNE] Iteration 5250: error = 1.1769625, gradient norm = 0.0000012 (50 iterations in 1.194s)
# [t-SNE] Iteration 5300: error = 1.1765312, gradient norm = 0.0000012 (50 iterations in 1.222s)
# [t-SNE] Iteration 5350: error = 1.1759956, gradient norm = 0.0000012 (50 iterations in 1.237s)
# [t-SNE] Iteration 5400: error = 1.1755896, gradient norm = 0.0000012 (50 iterations in 1.192s)
# [t-SNE] Iteration 5450: error = 1.1751981, gradient norm = 0.0000011 (50 iterations in 1.205s)
# [t-SNE] Iteration 5500: error = 1.1748058, gradient norm = 0.0000011 (50 iterations in 1.204s)
# [t-SNE] Iteration 5550: error = 1.1743774, gradient norm = 0.0000011 (50 iterations in 1.245s)
# [t-SNE] Iteration 5600: error = 1.1738890, gradient norm = 0.0000011 (50 iterations in 1.239s)
# [t-SNE] Iteration 5650: error = 1.1734263, gradient norm = 0.0000011 (50 iterations in 1.222s)
# [t-SNE] Iteration 5700: error = 1.1727644, gradient norm = 0.0000012 (50 iterations in 1.200s)
# [t-SNE] Iteration 5750: error = 1.1720906, gradient norm = 0.0000013 (50 iterations in 1.192s)
# [t-SNE] Iteration 5800: error = 1.1709887, gradient norm = 0.0000013 (50 iterations in 1.206s)
# [t-SNE] Iteration 5850: error = 1.1699516, gradient norm = 0.0000012 (50 iterations in 1.208s)
# [t-SNE] Iteration 5900: error = 1.1690108, gradient norm = 0.0000012 (50 iterations in 1.202s)
# [t-SNE] Iteration 5950: error = 1.1683019, gradient norm = 0.0000012 (50 iterations in 1.253s)
# [t-SNE] Iteration 6000: error = 1.1676828, gradient norm = 0.0000013 (50 iterations in 1.200s)
# [t-SNE] Iteration 6050: error = 1.1666763, gradient norm = 0.0000014 (50 iterations in 1.179s)
# [t-SNE] Iteration 6100: error = 1.1656131, gradient norm = 0.0000011 (50 iterations in 1.186s)
# [t-SNE] Iteration 6150: error = 1.1652130, gradient norm = 0.0000010 (50 iterations in 1.191s)
# [t-SNE] Iteration 6200: error = 1.1649411, gradient norm = 0.0000010 (50 iterations in 1.160s)
# [t-SNE] Iteration 6250: error = 1.1646756, gradient norm = 0.0000010 (50 iterations in 1.204s)
# [t-SNE] Iteration 6300: error = 1.1643322, gradient norm = 0.0000010 (50 iterations in 1.202s)
# [t-SNE] Iteration 6350: error = 1.1641203, gradient norm = 0.0000010 (50 iterations in 1.222s)
# [t-SNE] Iteration 6400: error = 1.1637757, gradient norm = 0.0000009 (50 iterations in 1.215s)
# [t-SNE] Iteration 6450: error = 1.1635559, gradient norm = 0.0000009 (50 iterations in 1.197s)
# [t-SNE] Iteration 6500: error = 1.1633667, gradient norm = 0.0000009 (50 iterations in 1.199s)
# [t-SNE] Iteration 6550: error = 1.1629776, gradient norm = 0.0000009 (50 iterations in 1.210s)
# [t-SNE] Iteration 6600: error = 1.1626748, gradient norm = 0.0000009 (50 iterations in 1.189s)
# [t-SNE] Iteration 6650: error = 1.1623911, gradient norm = 0.0000009 (50 iterations in 1.183s)
# [t-SNE] Iteration 6700: error = 1.1621841, gradient norm = 0.0000009 (50 iterations in 1.157s)
# [t-SNE] Iteration 6750: error = 1.1619925, gradient norm = 0.0000008 (50 iterations in 1.162s)
# [t-SNE] Iteration 6800: error = 1.1617130, gradient norm = 0.0000008 (50 iterations in 1.215s)
# [t-SNE] Iteration 6850: error = 1.1615551, gradient norm = 0.0000008 (50 iterations in 1.209s)
# [t-SNE] Iteration 6900: error = 1.1613210, gradient norm = 0.0000008 (50 iterations in 1.219s)
# [t-SNE] Iteration 6950: error = 1.1611340, gradient norm = 0.0000008 (50 iterations in 1.196s)
# [t-SNE] Iteration 7000: error = 1.1608928, gradient norm = 0.0000008 (50 iterations in 1.199s)
# [t-SNE] Iteration 7050: error = 1.1605949, gradient norm = 0.0000008 (50 iterations in 1.177s)
# [t-SNE] Iteration 7100: error = 1.1603709, gradient norm = 0.0000008 (50 iterations in 1.216s)
# [t-SNE] Iteration 7150: error = 1.1601758, gradient norm = 0.0000008 (50 iterations in 1.210s)
# [t-SNE] Iteration 7200: error = 1.1598812, gradient norm = 0.0000007 (50 iterations in 1.221s)
# [t-SNE] Iteration 7250: error = 1.1595869, gradient norm = 0.0000007 (50 iterations in 1.235s)
# [t-SNE] Iteration 7300: error = 1.1593424, gradient norm = 0.0000007 (50 iterations in 1.240s)
# [t-SNE] Iteration 7350: error = 1.1591438, gradient norm = 0.0000007 (50 iterations in 1.209s)
# [t-SNE] Iteration 7400: error = 1.1589750, gradient norm = 0.0000007 (50 iterations in 1.223s)
# [t-SNE] Iteration 7450: error = 1.1587507, gradient norm = 0.0000007 (50 iterations in 1.221s)
# [t-SNE] Iteration 7500: error = 1.1585248, gradient norm = 0.0000007 (50 iterations in 1.202s)
# [t-SNE] Iteration 7550: error = 1.1583278, gradient norm = 0.0000006 (50 iterations in 1.233s)
# [t-SNE] Iteration 7600: error = 1.1581540, gradient norm = 0.0000006 (50 iterations in 1.218s)
# [t-SNE] Iteration 7650: error = 1.1579661, gradient norm = 0.0000006 (50 iterations in 1.216s)
# [t-SNE] Iteration 7700: error = 1.1578461, gradient norm = 0.0000006 (50 iterations in 1.233s)
# [t-SNE] Iteration 7750: error = 1.1577290, gradient norm = 0.0000006 (50 iterations in 1.218s)
# [t-SNE] Iteration 7800: error = 1.1575322, gradient norm = 0.0000006 (50 iterations in 1.236s)
# [t-SNE] Iteration 7850: error = 1.1573623, gradient norm = 0.0000006 (50 iterations in 1.219s)
# [t-SNE] Iteration 7900: error = 1.1572232, gradient norm = 0.0000006 (50 iterations in 1.206s)
# [t-SNE] Iteration 7950: error = 1.1570204, gradient norm = 0.0000006 (50 iterations in 1.194s)
# [t-SNE] Iteration 8000: error = 1.1567993, gradient norm = 0.0000006 (50 iterations in 1.200s)
# [t-SNE] Iteration 8050: error = 1.1565431, gradient norm = 0.0000006 (50 iterations in 1.218s)
# [t-SNE] Iteration 8100: error = 1.1563754, gradient norm = 0.0000006 (50 iterations in 1.221s)
# [t-SNE] Iteration 8150: error = 1.1561549, gradient norm = 0.0000006 (50 iterations in 1.192s)
# [t-SNE] Iteration 8200: error = 1.1559263, gradient norm = 0.0000006 (50 iterations in 1.223s)
# [t-SNE] Iteration 8250: error = 1.1557605, gradient norm = 0.0000006 (50 iterations in 1.201s)
# [t-SNE] Iteration 8300: error = 1.1555882, gradient norm = 0.0000005 (50 iterations in 1.215s)
# [t-SNE] Iteration 8350: error = 1.1553879, gradient norm = 0.0000005 (50 iterations in 1.235s)
# [t-SNE] Iteration 8400: error = 1.1552116, gradient norm = 0.0000005 (50 iterations in 1.206s)
# [t-SNE] Iteration 8450: error = 1.1550453, gradient norm = 0.0000005 (50 iterations in 1.197s)
# [t-SNE] Iteration 8500: error = 1.1548085, gradient norm = 0.0000005 (50 iterations in 1.204s)
# [t-SNE] Iteration 8550: error = 1.1545612, gradient norm = 0.0000005 (50 iterations in 1.229s)
# [t-SNE] Iteration 8600: error = 1.1544170, gradient norm = 0.0000005 (50 iterations in 1.189s)
# [t-SNE] Iteration 8650: error = 1.1541566, gradient norm = 0.0000005 (50 iterations in 1.209s)
# [t-SNE] Iteration 8700: error = 1.1539384, gradient norm = 0.0000005 (50 iterations in 1.199s)
# [t-SNE] Iteration 8750: error = 1.1537441, gradient norm = 0.0000005 (50 iterations in 1.204s)
# [t-SNE] Iteration 8800: error = 1.1535974, gradient norm = 0.0000005 (50 iterations in 1.244s)
# [t-SNE] Iteration 8850: error = 1.1534201, gradient norm = 0.0000005 (50 iterations in 1.232s)
# [t-SNE] Iteration 8900: error = 1.1532356, gradient norm = 0.0000005 (50 iterations in 1.216s)
# [t-SNE] Iteration 8950: error = 1.1529789, gradient norm = 0.0000005 (50 iterations in 1.216s)
# [t-SNE] Iteration 9000: error = 1.1527733, gradient norm = 0.0000005 (50 iterations in 1.204s)
# [t-SNE] Iteration 9050: error = 1.1526425, gradient norm = 0.0000005 (50 iterations in 1.256s)
# [t-SNE] Iteration 9100: error = 1.1524386, gradient norm = 0.0000005 (50 iterations in 1.211s)
# [t-SNE] Iteration 9150: error = 1.1522077, gradient norm = 0.0000005 (50 iterations in 1.212s)
# [t-SNE] Iteration 9200: error = 1.1519951, gradient norm = 0.0000005 (50 iterations in 1.246s)
# [t-SNE] Iteration 9250: error = 1.1517729, gradient norm = 0.0000005 (50 iterations in 1.245s)
# [t-SNE] Iteration 9300: error = 1.1515186, gradient norm = 0.0000005 (50 iterations in 1.226s)
# [t-SNE] Iteration 9350: error = 1.1512859, gradient norm = 0.0000005 (50 iterations in 1.201s)
# [t-SNE] Iteration 9400: error = 1.1510984, gradient norm = 0.0000005 (50 iterations in 1.223s)
# [t-SNE] Iteration 9450: error = 1.1507246, gradient norm = 0.0000005 (50 iterations in 1.237s)
# [t-SNE] Iteration 9500: error = 1.1504675, gradient norm = 0.0000005 (50 iterations in 1.201s)
# [t-SNE] Iteration 9550: error = 1.1502361, gradient norm = 0.0000005 (50 iterations in 1.242s)
# [t-SNE] Iteration 9600: error = 1.1498758, gradient norm = 0.0000005 (50 iterations in 1.195s)
# [t-SNE] Iteration 9650: error = 1.1496407, gradient norm = 0.0000004 (50 iterations in 1.214s)
# [t-SNE] Iteration 9700: error = 1.1494167, gradient norm = 0.0000004 (50 iterations in 1.227s)
# [t-SNE] Iteration 9750: error = 1.1492103, gradient norm = 0.0000004 (50 iterations in 1.224s)
# [t-SNE] Iteration 9800: error = 1.1490494, gradient norm = 0.0000004 (50 iterations in 1.286s)
# [t-SNE] Iteration 9850: error = 1.1488549, gradient norm = 0.0000004 (50 iterations in 1.247s)
# [t-SNE] Iteration 9900: error = 1.1486388, gradient norm = 0.0000004 (50 iterations in 1.217s)
# [t-SNE] Iteration 9950: error = 1.1484300, gradient norm = 0.0000004 (50 iterations in 1.208s)
# [t-SNE] Iteration 10000: error = 1.1481707, gradient norm = 0.0000004 (50 iterations in 1.212s)
# [t-SNE] KL divergence after 10000 iterations: 1.148171
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 432 samples in 0.001s...
# [t-SNE] Computed neighbors for 432 samples in 0.026s...
# [t-SNE] Computed conditional probabilities for sample 432 / 432
# [t-SNE] Mean sigma: 2.291786
# [t-SNE] Computed conditional probabilities in 0.028s
# [t-SNE] Iteration 50: error = 88.3797531, gradient norm = 0.2772600 (50 iterations in 0.837s)
# [t-SNE] Iteration 100: error = 104.0643311, gradient norm = 0.2201569 (50 iterations in 0.795s)
# [t-SNE] Iteration 150: error = 114.1866684, gradient norm = 0.2014898 (50 iterations in 0.729s)
# [t-SNE] Iteration 200: error = 121.8320312, gradient norm = 0.1768851 (50 iterations in 0.722s)
# [t-SNE] Iteration 250: error = 123.9353943, gradient norm = 0.1678223 (50 iterations in 0.720s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 123.935394
# [t-SNE] Iteration 300: error = 3.5238035, gradient norm = 0.0005646 (50 iterations in 0.815s)
# [t-SNE] Iteration 350: error = 2.9841974, gradient norm = 0.0002330 (50 iterations in 0.824s)
# [t-SNE] Iteration 400: error = 2.7297058, gradient norm = 0.0001378 (50 iterations in 0.804s)
# [t-SNE] Iteration 450: error = 2.5641558, gradient norm = 0.0000897 (50 iterations in 0.806s)
# [t-SNE] Iteration 500: error = 2.4400356, gradient norm = 0.0000673 (50 iterations in 0.800s)
# [t-SNE] Iteration 550: error = 2.3446894, gradient norm = 0.0000543 (50 iterations in 0.817s)
# [t-SNE] Iteration 600: error = 2.2736633, gradient norm = 0.0000441 (50 iterations in 0.810s)
# [t-SNE] Iteration 650: error = 2.2175734, gradient norm = 0.0000365 (50 iterations in 0.829s)
# [t-SNE] Iteration 700: error = 2.1720068, gradient norm = 0.0000310 (50 iterations in 0.844s)
# [t-SNE] Iteration 750: error = 2.1331038, gradient norm = 0.0000284 (50 iterations in 0.874s)
# [t-SNE] Iteration 800: error = 2.0977285, gradient norm = 0.0000245 (50 iterations in 0.850s)
# [t-SNE] Iteration 850: error = 2.0652292, gradient norm = 0.0000219 (50 iterations in 0.824s)
# [t-SNE] Iteration 900: error = 2.0346491, gradient norm = 0.0000204 (50 iterations in 0.834s)
# [t-SNE] Iteration 950: error = 2.0032449, gradient norm = 0.0000189 (50 iterations in 0.821s)
# [t-SNE] Iteration 1000: error = 1.9767995, gradient norm = 0.0000168 (50 iterations in 0.850s)
# [t-SNE] Iteration 1050: error = 1.9554237, gradient norm = 0.0000154 (50 iterations in 0.816s)
# [t-SNE] Iteration 1100: error = 1.9359428, gradient norm = 0.0000142 (50 iterations in 0.815s)
# [t-SNE] Iteration 1150: error = 1.9177295, gradient norm = 0.0000133 (50 iterations in 0.816s)
# [t-SNE] Iteration 1200: error = 1.9012418, gradient norm = 0.0000128 (50 iterations in 0.790s)
# [t-SNE] Iteration 1250: error = 1.8854541, gradient norm = 0.0000118 (50 iterations in 0.763s)
# [t-SNE] Iteration 1300: error = 1.8715129, gradient norm = 0.0000107 (50 iterations in 0.791s)
# [t-SNE] Iteration 1350: error = 1.8572482, gradient norm = 0.0000108 (50 iterations in 0.775s)
# [t-SNE] Iteration 1400: error = 1.8422948, gradient norm = 0.0000098 (50 iterations in 0.736s)
# [t-SNE] Iteration 1450: error = 1.8284217, gradient norm = 0.0000091 (50 iterations in 0.729s)
# [t-SNE] Iteration 1500: error = 1.8147118, gradient norm = 0.0000088 (50 iterations in 0.749s)
# [t-SNE] Iteration 1550: error = 1.8012931, gradient norm = 0.0000081 (50 iterations in 0.726s)
# [t-SNE] Iteration 1600: error = 1.7893351, gradient norm = 0.0000078 (50 iterations in 0.703s)
# [t-SNE] Iteration 1650: error = 1.7777153, gradient norm = 0.0000073 (50 iterations in 0.722s)
# [t-SNE] Iteration 1700: error = 1.7666626, gradient norm = 0.0000071 (50 iterations in 0.702s)
# [t-SNE] Iteration 1750: error = 1.7558997, gradient norm = 0.0000066 (50 iterations in 0.664s)
# [t-SNE] Iteration 1800: error = 1.7457911, gradient norm = 0.0000063 (50 iterations in 0.680s)
# [t-SNE] Iteration 1850: error = 1.7364712, gradient norm = 0.0000061 (50 iterations in 0.664s)
# [t-SNE] Iteration 1900: error = 1.7270017, gradient norm = 0.0000060 (50 iterations in 0.676s)
# [t-SNE] Iteration 1950: error = 1.7173227, gradient norm = 0.0000059 (50 iterations in 0.681s)
# [t-SNE] Iteration 2000: error = 1.7070875, gradient norm = 0.0000062 (50 iterations in 0.665s)
# [t-SNE] Iteration 2050: error = 1.6958704, gradient norm = 0.0000070 (50 iterations in 0.707s)
# [t-SNE] Iteration 2100: error = 1.6882963, gradient norm = 0.0000049 (50 iterations in 0.660s)
# [t-SNE] Iteration 2150: error = 1.6819205, gradient norm = 0.0000047 (50 iterations in 0.650s)
# [t-SNE] Iteration 2200: error = 1.6753854, gradient norm = 0.0000046 (50 iterations in 0.648s)
# [t-SNE] Iteration 2250: error = 1.6688904, gradient norm = 0.0000045 (50 iterations in 0.658s)
# [t-SNE] Iteration 2300: error = 1.6631126, gradient norm = 0.0000042 (50 iterations in 0.671s)
# [t-SNE] Iteration 2350: error = 1.6577410, gradient norm = 0.0000040 (50 iterations in 0.682s)
# [t-SNE] Iteration 2400: error = 1.6525414, gradient norm = 0.0000038 (50 iterations in 0.705s)
# [t-SNE] Iteration 2450: error = 1.6473292, gradient norm = 0.0000038 (50 iterations in 0.670s)
# [t-SNE] Iteration 2500: error = 1.6422050, gradient norm = 0.0000037 (50 iterations in 0.667s)
# [t-SNE] Iteration 2550: error = 1.6374471, gradient norm = 0.0000035 (50 iterations in 0.659s)
# [t-SNE] Iteration 2600: error = 1.6330062, gradient norm = 0.0000034 (50 iterations in 0.673s)
# [t-SNE] Iteration 2650: error = 1.6285745, gradient norm = 0.0000033 (50 iterations in 0.672s)
# [t-SNE] Iteration 2700: error = 1.6239026, gradient norm = 0.0000032 (50 iterations in 0.659s)
# [t-SNE] Iteration 2750: error = 1.6193832, gradient norm = 0.0000031 (50 iterations in 0.670s)
# [t-SNE] Iteration 2800: error = 1.6146914, gradient norm = 0.0000031 (50 iterations in 0.679s)
# [t-SNE] Iteration 2850: error = 1.6097780, gradient norm = 0.0000030 (50 iterations in 0.655s)
# [t-SNE] Iteration 2900: error = 1.6047844, gradient norm = 0.0000030 (50 iterations in 0.676s)
# [t-SNE] Iteration 2950: error = 1.5994821, gradient norm = 0.0000030 (50 iterations in 0.673s)
# [t-SNE] Iteration 3000: error = 1.5943687, gradient norm = 0.0000029 (50 iterations in 0.634s)
# [t-SNE] Iteration 3050: error = 1.5888692, gradient norm = 0.0000030 (50 iterations in 0.646s)
# [t-SNE] Iteration 3100: error = 1.5828950, gradient norm = 0.0000030 (50 iterations in 0.647s)
# [t-SNE] Iteration 3150: error = 1.5773919, gradient norm = 0.0000028 (50 iterations in 0.676s)
# [t-SNE] Iteration 3200: error = 1.5724869, gradient norm = 0.0000027 (50 iterations in 0.673s)
# [t-SNE] Iteration 3250: error = 1.5677763, gradient norm = 0.0000026 (50 iterations in 0.641s)
# [t-SNE] Iteration 3300: error = 1.5630355, gradient norm = 0.0000026 (50 iterations in 0.665s)
# [t-SNE] Iteration 3350: error = 1.5582401, gradient norm = 0.0000025 (50 iterations in 0.660s)
# [t-SNE] Iteration 3400: error = 1.5535986, gradient norm = 0.0000025 (50 iterations in 0.644s)
# [t-SNE] Iteration 3450: error = 1.5493284, gradient norm = 0.0000024 (50 iterations in 0.644s)
# [t-SNE] Iteration 3500: error = 1.5453335, gradient norm = 0.0000023 (50 iterations in 0.636s)
# [t-SNE] Iteration 3550: error = 1.5416296, gradient norm = 0.0000023 (50 iterations in 0.653s)
# [t-SNE] Iteration 3600: error = 1.5378901, gradient norm = 0.0000022 (50 iterations in 0.646s)
# [t-SNE] Iteration 3650: error = 1.5342734, gradient norm = 0.0000022 (50 iterations in 0.653s)
# [t-SNE] Iteration 3700: error = 1.5306922, gradient norm = 0.0000022 (50 iterations in 0.647s)
# [t-SNE] Iteration 3750: error = 1.5272799, gradient norm = 0.0000021 (50 iterations in 0.656s)
# [t-SNE] Iteration 3800: error = 1.5240073, gradient norm = 0.0000021 (50 iterations in 0.637s)
# [t-SNE] Iteration 3850: error = 1.5207182, gradient norm = 0.0000020 (50 iterations in 0.643s)
# [t-SNE] Iteration 3900: error = 1.5177742, gradient norm = 0.0000020 (50 iterations in 0.647s)
# [t-SNE] Iteration 3950: error = 1.5147929, gradient norm = 0.0000019 (50 iterations in 0.663s)
# [t-SNE] Iteration 4000: error = 1.5119066, gradient norm = 0.0000019 (50 iterations in 0.636s)
# [t-SNE] Iteration 4050: error = 1.5090305, gradient norm = 0.0000019 (50 iterations in 0.648s)
# [t-SNE] Iteration 4100: error = 1.5062274, gradient norm = 0.0000018 (50 iterations in 0.655s)
# [t-SNE] Iteration 4150: error = 1.5032783, gradient norm = 0.0000018 (50 iterations in 0.655s)
# [t-SNE] Iteration 4200: error = 1.5003200, gradient norm = 0.0000018 (50 iterations in 0.644s)
# [t-SNE] Iteration 4250: error = 1.4973724, gradient norm = 0.0000017 (50 iterations in 0.646s)
# [t-SNE] Iteration 4300: error = 1.4946154, gradient norm = 0.0000017 (50 iterations in 0.651s)
# [t-SNE] Iteration 4350: error = 1.4913679, gradient norm = 0.0000017 (50 iterations in 0.644s)
# [t-SNE] Iteration 4400: error = 1.4883085, gradient norm = 0.0000017 (50 iterations in 0.646s)
# [t-SNE] Iteration 4450: error = 1.4853333, gradient norm = 0.0000016 (50 iterations in 0.652s)
# [t-SNE] Iteration 4500: error = 1.4823345, gradient norm = 0.0000016 (50 iterations in 0.640s)
# [t-SNE] Iteration 4550: error = 1.4793737, gradient norm = 0.0000016 (50 iterations in 0.653s)
# [t-SNE] Iteration 4600: error = 1.4760621, gradient norm = 0.0000017 (50 iterations in 0.646s)
# [t-SNE] Iteration 4650: error = 1.4718351, gradient norm = 0.0000019 (50 iterations in 0.634s)
# [t-SNE] Iteration 4700: error = 1.4686222, gradient norm = 0.0000016 (50 iterations in 0.676s)
# [t-SNE] Iteration 4750: error = 1.4659538, gradient norm = 0.0000015 (50 iterations in 0.660s)
# [t-SNE] Iteration 4800: error = 1.4631056, gradient norm = 0.0000015 (50 iterations in 0.634s)
# [t-SNE] Iteration 4850: error = 1.4599828, gradient norm = 0.0000016 (50 iterations in 0.635s)
# [t-SNE] Iteration 4900: error = 1.4563521, gradient norm = 0.0000017 (50 iterations in 0.648s)
# [t-SNE] Iteration 4950: error = 1.4523906, gradient norm = 0.0000018 (50 iterations in 0.657s)
# [t-SNE] Iteration 5000: error = 1.4492712, gradient norm = 0.0000015 (50 iterations in 0.648s)
# [t-SNE] Iteration 5050: error = 1.4464754, gradient norm = 0.0000015 (50 iterations in 0.659s)
# [t-SNE] Iteration 5100: error = 1.4437883, gradient norm = 0.0000015 (50 iterations in 0.680s)
# [t-SNE] Iteration 5150: error = 1.4416064, gradient norm = 0.0000014 (50 iterations in 0.634s)
# [t-SNE] Iteration 5200: error = 1.4397491, gradient norm = 0.0000014 (50 iterations in 0.672s)
# [t-SNE] Iteration 5250: error = 1.4378562, gradient norm = 0.0000013 (50 iterations in 0.662s)
# [t-SNE] Iteration 5300: error = 1.4361037, gradient norm = 0.0000013 (50 iterations in 0.640s)
# [t-SNE] Iteration 5350: error = 1.4344567, gradient norm = 0.0000013 (50 iterations in 0.645s)
# [t-SNE] Iteration 5400: error = 1.4327942, gradient norm = 0.0000013 (50 iterations in 0.645s)
# [t-SNE] Iteration 5450: error = 1.4310899, gradient norm = 0.0000012 (50 iterations in 0.642s)
# [t-SNE] Iteration 5500: error = 1.4294727, gradient norm = 0.0000012 (50 iterations in 0.667s)
# [t-SNE] Iteration 5550: error = 1.4277754, gradient norm = 0.0000012 (50 iterations in 0.638s)
# [t-SNE] Iteration 5600: error = 1.4260215, gradient norm = 0.0000012 (50 iterations in 0.679s)
# [t-SNE] Iteration 5650: error = 1.4242902, gradient norm = 0.0000012 (50 iterations in 0.653s)
# [t-SNE] Iteration 5700: error = 1.4225774, gradient norm = 0.0000012 (50 iterations in 0.645s)
# [t-SNE] Iteration 5750: error = 1.4207829, gradient norm = 0.0000012 (50 iterations in 0.693s)
# [t-SNE] Iteration 5800: error = 1.4187663, gradient norm = 0.0000012 (50 iterations in 0.651s)
# [t-SNE] Iteration 5850: error = 1.4167975, gradient norm = 0.0000011 (50 iterations in 0.625s)
# [t-SNE] Iteration 5900: error = 1.4148464, gradient norm = 0.0000011 (50 iterations in 0.636s)
# [t-SNE] Iteration 5950: error = 1.4130337, gradient norm = 0.0000011 (50 iterations in 0.629s)
# [t-SNE] Iteration 6000: error = 1.4113196, gradient norm = 0.0000011 (50 iterations in 0.655s)
# [t-SNE] Iteration 6050: error = 1.4095416, gradient norm = 0.0000011 (50 iterations in 0.658s)
# [t-SNE] Iteration 6100: error = 1.4075198, gradient norm = 0.0000011 (50 iterations in 0.655s)
# [t-SNE] Iteration 6150: error = 1.4056193, gradient norm = 0.0000011 (50 iterations in 0.660s)
# [t-SNE] Iteration 6200: error = 1.4038236, gradient norm = 0.0000010 (50 iterations in 0.637s)
# [t-SNE] Iteration 6250: error = 1.4022503, gradient norm = 0.0000010 (50 iterations in 0.642s)
# [t-SNE] Iteration 6300: error = 1.4005338, gradient norm = 0.0000010 (50 iterations in 0.624s)
# [t-SNE] Iteration 6350: error = 1.3987427, gradient norm = 0.0000010 (50 iterations in 0.619s)
# [t-SNE] Iteration 6400: error = 1.3971517, gradient norm = 0.0000010 (50 iterations in 0.627s)
# [t-SNE] Iteration 6450: error = 1.3956373, gradient norm = 0.0000010 (50 iterations in 0.623s)
# [t-SNE] Iteration 6500: error = 1.3940490, gradient norm = 0.0000010 (50 iterations in 0.626s)
# [t-SNE] Iteration 6550: error = 1.3922668, gradient norm = 0.0000010 (50 iterations in 0.627s)
# [t-SNE] Iteration 6600: error = 1.3905424, gradient norm = 0.0000010 (50 iterations in 0.637s)
# [t-SNE] Iteration 6650: error = 1.3889389, gradient norm = 0.0000009 (50 iterations in 0.622s)
# [t-SNE] Iteration 6700: error = 1.3875905, gradient norm = 0.0000009 (50 iterations in 0.644s)
# [t-SNE] Iteration 6750: error = 1.3863502, gradient norm = 0.0000009 (50 iterations in 0.631s)
# [t-SNE] Iteration 6800: error = 1.3850951, gradient norm = 0.0000009 (50 iterations in 0.642s)
# [t-SNE] Iteration 6850: error = 1.3837259, gradient norm = 0.0000009 (50 iterations in 0.654s)
# [t-SNE] Iteration 6900: error = 1.3824679, gradient norm = 0.0000009 (50 iterations in 0.646s)
# [t-SNE] Iteration 6950: error = 1.3812165, gradient norm = 0.0000009 (50 iterations in 0.650s)
# [t-SNE] Iteration 7000: error = 1.3801087, gradient norm = 0.0000009 (50 iterations in 0.648s)
# [t-SNE] Iteration 7050: error = 1.3787200, gradient norm = 0.0000009 (50 iterations in 0.622s)
# [t-SNE] Iteration 7100: error = 1.3774321, gradient norm = 0.0000009 (50 iterations in 0.619s)
# [t-SNE] Iteration 7150: error = 1.3761288, gradient norm = 0.0000009 (50 iterations in 0.626s)
# [t-SNE] Iteration 7200: error = 1.3747112, gradient norm = 0.0000009 (50 iterations in 0.616s)
# [t-SNE] Iteration 7250: error = 1.3735559, gradient norm = 0.0000008 (50 iterations in 0.626s)
# [t-SNE] Iteration 7300: error = 1.3724997, gradient norm = 0.0000008 (50 iterations in 0.624s)
# [t-SNE] Iteration 7350: error = 1.3713529, gradient norm = 0.0000008 (50 iterations in 0.620s)
# [t-SNE] Iteration 7400: error = 1.3702960, gradient norm = 0.0000008 (50 iterations in 0.631s)
# [t-SNE] Iteration 7450: error = 1.3690965, gradient norm = 0.0000008 (50 iterations in 0.612s)
# [t-SNE] Iteration 7500: error = 1.3681934, gradient norm = 0.0000008 (50 iterations in 0.641s)
# [t-SNE] Iteration 7550: error = 1.3672688, gradient norm = 0.0000008 (50 iterations in 0.636s)
# [t-SNE] Iteration 7600: error = 1.3662626, gradient norm = 0.0000007 (50 iterations in 0.626s)
# [t-SNE] Iteration 7650: error = 1.3653030, gradient norm = 0.0000007 (50 iterations in 0.636s)
# [t-SNE] Iteration 7700: error = 1.3643210, gradient norm = 0.0000007 (50 iterations in 0.611s)
# [t-SNE] Iteration 7750: error = 1.3635281, gradient norm = 0.0000007 (50 iterations in 0.624s)
# [t-SNE] Iteration 7800: error = 1.3626161, gradient norm = 0.0000007 (50 iterations in 0.648s)
# [t-SNE] Iteration 7850: error = 1.3617541, gradient norm = 0.0000007 (50 iterations in 0.633s)
# [t-SNE] Iteration 7900: error = 1.3607577, gradient norm = 0.0000007 (50 iterations in 0.622s)
# [t-SNE] Iteration 7950: error = 1.3599340, gradient norm = 0.0000007 (50 iterations in 0.614s)
# [t-SNE] Iteration 8000: error = 1.3590406, gradient norm = 0.0000007 (50 iterations in 0.616s)
# [t-SNE] Iteration 8050: error = 1.3581626, gradient norm = 0.0000007 (50 iterations in 0.631s)
# [t-SNE] Iteration 8100: error = 1.3572468, gradient norm = 0.0000007 (50 iterations in 0.641s)
# [t-SNE] Iteration 8150: error = 1.3563105, gradient norm = 0.0000007 (50 iterations in 0.634s)
# [t-SNE] Iteration 8200: error = 1.3553926, gradient norm = 0.0000007 (50 iterations in 0.634s)
# [t-SNE] Iteration 8250: error = 1.3544923, gradient norm = 0.0000006 (50 iterations in 0.624s)
# [t-SNE] Iteration 8300: error = 1.3536245, gradient norm = 0.0000006 (50 iterations in 0.624s)
# [t-SNE] Iteration 8350: error = 1.3528121, gradient norm = 0.0000006 (50 iterations in 0.625s)
# [t-SNE] Iteration 8400: error = 1.3518976, gradient norm = 0.0000006 (50 iterations in 0.616s)
# [t-SNE] Iteration 8450: error = 1.3508817, gradient norm = 0.0000006 (50 iterations in 0.638s)
# [t-SNE] Iteration 8500: error = 1.3500451, gradient norm = 0.0000006 (50 iterations in 0.633s)
# [t-SNE] Iteration 8550: error = 1.3491561, gradient norm = 0.0000006 (50 iterations in 0.631s)
# [t-SNE] Iteration 8600: error = 1.3482009, gradient norm = 0.0000006 (50 iterations in 0.637s)
# [t-SNE] Iteration 8650: error = 1.3473446, gradient norm = 0.0000006 (50 iterations in 0.631s)
# [t-SNE] Iteration 8700: error = 1.3464118, gradient norm = 0.0000007 (50 iterations in 0.624s)
# [t-SNE] Iteration 8750: error = 1.3453003, gradient norm = 0.0000007 (50 iterations in 0.616s)
# [t-SNE] Iteration 8800: error = 1.3441479, gradient norm = 0.0000007 (50 iterations in 0.632s)
# [t-SNE] Iteration 8850: error = 1.3429374, gradient norm = 0.0000007 (50 iterations in 0.616s)
# [t-SNE] Iteration 8900: error = 1.3418721, gradient norm = 0.0000007 (50 iterations in 0.620s)
# [t-SNE] Iteration 8950: error = 1.3408217, gradient norm = 0.0000006 (50 iterations in 0.621s)
# [t-SNE] Iteration 9000: error = 1.3398927, gradient norm = 0.0000006 (50 iterations in 0.645s)
# [t-SNE] Iteration 9050: error = 1.3390332, gradient norm = 0.0000006 (50 iterations in 0.621s)
# [t-SNE] Iteration 9100: error = 1.3382406, gradient norm = 0.0000006 (50 iterations in 0.630s)
# [t-SNE] Iteration 9150: error = 1.3373419, gradient norm = 0.0000006 (50 iterations in 0.614s)
# [t-SNE] Iteration 9200: error = 1.3365226, gradient norm = 0.0000006 (50 iterations in 0.621s)
# [t-SNE] Iteration 9250: error = 1.3357430, gradient norm = 0.0000006 (50 iterations in 0.608s)
# [t-SNE] Iteration 9300: error = 1.3349465, gradient norm = 0.0000006 (50 iterations in 0.614s)
# [t-SNE] Iteration 9350: error = 1.3342960, gradient norm = 0.0000006 (50 iterations in 0.622s)
# [t-SNE] Iteration 9400: error = 1.3337038, gradient norm = 0.0000005 (50 iterations in 0.655s)
# [t-SNE] Iteration 9450: error = 1.3329771, gradient norm = 0.0000005 (50 iterations in 0.634s)
# [t-SNE] Iteration 9500: error = 1.3323994, gradient norm = 0.0000005 (50 iterations in 0.637s)
# [t-SNE] Iteration 9550: error = 1.3317466, gradient norm = 0.0000005 (50 iterations in 0.622s)
# [t-SNE] Iteration 9600: error = 1.3309729, gradient norm = 0.0000005 (50 iterations in 0.619s)
# [t-SNE] Iteration 9650: error = 1.3303612, gradient norm = 0.0000005 (50 iterations in 0.643s)
# [t-SNE] Iteration 9700: error = 1.3296950, gradient norm = 0.0000005 (50 iterations in 0.636s)
# [t-SNE] Iteration 9750: error = 1.3290745, gradient norm = 0.0000005 (50 iterations in 0.622s)
# [t-SNE] Iteration 9800: error = 1.3284456, gradient norm = 0.0000005 (50 iterations in 0.623s)
# [t-SNE] Iteration 9850: error = 1.3278087, gradient norm = 0.0000005 (50 iterations in 0.621s)
# [t-SNE] Iteration 9900: error = 1.3271618, gradient norm = 0.0000005 (50 iterations in 0.629s)
# [t-SNE] Iteration 9950: error = 1.3265409, gradient norm = 0.0000005 (50 iterations in 0.635s)
# [t-SNE] Iteration 10000: error = 1.3259474, gradient norm = 0.0000005 (50 iterations in 0.646s)
# [t-SNE] KL divergence after 10000 iterations: 1.325947
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 363 samples in 0.001s...
# [t-SNE] Computed neighbors for 363 samples in 0.020s...
# [t-SNE] Computed conditional probabilities for sample 363 / 363
# [t-SNE] Mean sigma: 2.394874
# [t-SNE] Computed conditional probabilities in 0.022s
# [t-SNE] Iteration 50: error = 94.5796738, gradient norm = 0.2699051 (50 iterations in 0.607s)
# [t-SNE] Iteration 100: error = 107.6972504, gradient norm = 0.2127213 (50 iterations in 0.592s)
# [t-SNE] Iteration 150: error = 115.5377731, gradient norm = 0.2038269 (50 iterations in 0.565s)
# [t-SNE] Iteration 200: error = 124.3387527, gradient norm = 0.2004893 (50 iterations in 0.556s)
# [t-SNE] Iteration 250: error = 128.2836456, gradient norm = 0.1397114 (50 iterations in 0.529s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 128.283646
# [t-SNE] Iteration 300: error = 3.6209042, gradient norm = 0.0005846 (50 iterations in 0.605s)
# [t-SNE] Iteration 350: error = 3.1582694, gradient norm = 0.0002211 (50 iterations in 0.607s)
# [t-SNE] Iteration 400: error = 2.9262078, gradient norm = 0.0001268 (50 iterations in 0.617s)
# [t-SNE] Iteration 450: error = 2.7744746, gradient norm = 0.0000865 (50 iterations in 0.602s)
# [t-SNE] Iteration 500: error = 2.6641152, gradient norm = 0.0000662 (50 iterations in 0.652s)
# [t-SNE] Iteration 550: error = 2.5800776, gradient norm = 0.0000511 (50 iterations in 0.615s)
# [t-SNE] Iteration 600: error = 2.5190761, gradient norm = 0.0000408 (50 iterations in 0.609s)
# [t-SNE] Iteration 650: error = 2.4701524, gradient norm = 0.0000355 (50 iterations in 0.622s)
# [t-SNE] Iteration 700: error = 2.4209747, gradient norm = 0.0000320 (50 iterations in 0.588s)
# [t-SNE] Iteration 750: error = 2.3788028, gradient norm = 0.0000270 (50 iterations in 0.592s)
# [t-SNE] Iteration 800: error = 2.3426595, gradient norm = 0.0000231 (50 iterations in 0.614s)
# [t-SNE] Iteration 850: error = 2.3104000, gradient norm = 0.0000206 (50 iterations in 0.586s)
# [t-SNE] Iteration 900: error = 2.2807176, gradient norm = 0.0000187 (50 iterations in 0.605s)
# [t-SNE] Iteration 950: error = 2.2511656, gradient norm = 0.0000187 (50 iterations in 0.574s)
# [t-SNE] Iteration 1000: error = 2.2247078, gradient norm = 0.0000155 (50 iterations in 0.578s)
# [t-SNE] Iteration 1050: error = 2.2022700, gradient norm = 0.0000140 (50 iterations in 0.595s)
# [t-SNE] Iteration 1100: error = 2.1798692, gradient norm = 0.0000132 (50 iterations in 0.564s)
# [t-SNE] Iteration 1150: error = 2.1569126, gradient norm = 0.0000129 (50 iterations in 0.581s)
# [t-SNE] Iteration 1200: error = 2.1330431, gradient norm = 0.0000132 (50 iterations in 0.561s)
# [t-SNE] Iteration 1250: error = 2.1126156, gradient norm = 0.0000109 (50 iterations in 0.549s)
# [t-SNE] Iteration 1300: error = 2.0960422, gradient norm = 0.0000103 (50 iterations in 0.539s)
# [t-SNE] Iteration 1350: error = 2.0792532, gradient norm = 0.0000098 (50 iterations in 0.549s)
# [t-SNE] Iteration 1400: error = 2.0636933, gradient norm = 0.0000093 (50 iterations in 0.548s)
# [t-SNE] Iteration 1450: error = 2.0502303, gradient norm = 0.0000085 (50 iterations in 0.535s)
# [t-SNE] Iteration 1500: error = 2.0388188, gradient norm = 0.0000080 (50 iterations in 0.506s)
# [t-SNE] Iteration 1550: error = 2.0283289, gradient norm = 0.0000076 (50 iterations in 0.509s)
# [t-SNE] Iteration 1600: error = 2.0189855, gradient norm = 0.0000073 (50 iterations in 0.502s)
# [t-SNE] Iteration 1650: error = 2.0098188, gradient norm = 0.0000070 (50 iterations in 0.520s)
# [t-SNE] Iteration 1700: error = 2.0013602, gradient norm = 0.0000066 (50 iterations in 0.507s)
# [t-SNE] Iteration 1750: error = 1.9927735, gradient norm = 0.0000064 (50 iterations in 0.519s)
# [t-SNE] Iteration 1800: error = 1.9848160, gradient norm = 0.0000060 (50 iterations in 0.515s)
# [t-SNE] Iteration 1850: error = 1.9771295, gradient norm = 0.0000057 (50 iterations in 0.526s)
# [t-SNE] Iteration 1900: error = 1.9694636, gradient norm = 0.0000055 (50 iterations in 0.515s)
# [t-SNE] Iteration 1950: error = 1.9613894, gradient norm = 0.0000056 (50 iterations in 0.515s)
# [t-SNE] Iteration 2000: error = 1.9530281, gradient norm = 0.0000054 (50 iterations in 0.524s)
# [t-SNE] Iteration 2050: error = 1.9457371, gradient norm = 0.0000049 (50 iterations in 0.520s)
# [t-SNE] Iteration 2100: error = 1.9390717, gradient norm = 0.0000046 (50 iterations in 0.493s)
# [t-SNE] Iteration 2150: error = 1.9327426, gradient norm = 0.0000045 (50 iterations in 0.507s)
# [t-SNE] Iteration 2200: error = 1.9266388, gradient norm = 0.0000044 (50 iterations in 0.499s)
# [t-SNE] Iteration 2250: error = 1.9204555, gradient norm = 0.0000043 (50 iterations in 0.507s)
# [t-SNE] Iteration 2300: error = 1.9140744, gradient norm = 0.0000041 (50 iterations in 0.500s)
# [t-SNE] Iteration 2350: error = 1.9078285, gradient norm = 0.0000040 (50 iterations in 0.523s)
# [t-SNE] Iteration 2400: error = 1.9019244, gradient norm = 0.0000039 (50 iterations in 0.494s)
# [t-SNE] Iteration 2450: error = 1.8961374, gradient norm = 0.0000038 (50 iterations in 0.500s)
# [t-SNE] Iteration 2500: error = 1.8901979, gradient norm = 0.0000037 (50 iterations in 0.512s)
# [t-SNE] Iteration 2550: error = 1.8843096, gradient norm = 0.0000036 (50 iterations in 0.503s)
# [t-SNE] Iteration 2600: error = 1.8783543, gradient norm = 0.0000035 (50 iterations in 0.511s)
# [t-SNE] Iteration 2650: error = 1.8721911, gradient norm = 0.0000035 (50 iterations in 0.507s)
# [t-SNE] Iteration 2700: error = 1.8663616, gradient norm = 0.0000034 (50 iterations in 0.500s)
# [t-SNE] Iteration 2750: error = 1.8602818, gradient norm = 0.0000033 (50 iterations in 0.494s)
# ...
# [t-SNE] Iteration 3300: error = 1.8005528, gradient norm = 0.0000026 (50 iterations in 0.507s)
# [t-SNE] Iteration 3350: error = 1.7955931, gradient norm = 0.0000025 (50 iterations in 0.521s)
# [t-SNE] Iteration 3400: error = 1.7908056, gradient norm = 0.0000024 (50 iterations in 0.504s)
# [t-SNE] Iteration 3450: error = 1.7862192, gradient norm = 0.0000024 (50 iterations in 0.504s)
# [t-SNE] Iteration 3500: error = 1.7815887, gradient norm = 0.0000023 (50 iterations in 0.523s)
# [t-SNE] Iteration 3550: error = 1.7773649, gradient norm = 0.0000023 (50 iterations in 0.506s)
# [t-SNE] Iteration 3600: error = 1.7729884, gradient norm = 0.0000023 (50 iterations in 0.508s)
# [t-SNE] Iteration 3650: error = 1.7685257, gradient norm = 0.0000023 (50 iterations in 0.506s)
# [t-SNE] Iteration 3700: error = 1.7641251, gradient norm = 0.0000022 (50 iterations in 0.515s)
# [t-SNE] Iteration 3750: error = 1.7598553, gradient norm = 0.0000023 (50 iterations in 0.507s)
# [t-SNE] Iteration 3800: error = 1.7555416, gradient norm = 0.0000023 (50 iterations in 0.511s)
# [t-SNE] Iteration 3850: error = 1.7507098, gradient norm = 0.0000023 (50 iterations in 0.509s)
# [t-SNE] Iteration 3900: error = 1.7460232, gradient norm = 0.0000023 (50 iterations in 0.513s)
# [t-SNE] Iteration 3950: error = 1.7414305, gradient norm = 0.0000022 (50 iterations in 0.522s)
# [t-SNE] Iteration 4000: error = 1.7369010, gradient norm = 0.0000021 (50 iterations in 0.515s)
# [t-SNE] Iteration 4050: error = 1.7325424, gradient norm = 0.0000020 (50 iterations in 0.507s)
# [t-SNE] Iteration 4100: error = 1.7284575, gradient norm = 0.0000020 (50 iterations in 0.509s)
# [t-SNE] Iteration 4150: error = 1.7242311, gradient norm = 0.0000019 (50 iterations in 0.502s)
# [t-SNE] Iteration 4200: error = 1.7203871, gradient norm = 0.0000019 (50 iterations in 0.500s)
# [t-SNE] Iteration 4250: error = 1.7164631, gradient norm = 0.0000019 (50 iterations in 0.526s)
# [t-SNE] Iteration 4300: error = 1.7126312, gradient norm = 0.0000018 (50 iterations in 0.503s)
# [t-SNE] Iteration 4350: error = 1.7087758, gradient norm = 0.0000018 (50 iterations in 0.496s)
# [t-SNE] Iteration 4400: error = 1.7051640, gradient norm = 0.0000018 (50 iterations in 0.522s)
# [t-SNE] Iteration 4450: error = 1.7012515, gradient norm = 0.0000018 (50 iterations in 0.508s)
# [t-SNE] Iteration 4500: error = 1.6975344, gradient norm = 0.0000018 (50 iterations in 0.524s)
# [t-SNE] Iteration 4550: error = 1.6938680, gradient norm = 0.0000017 (50 iterations in 0.515s)
# [t-SNE] Iteration 4600: error = 1.6905452, gradient norm = 0.0000016 (50 iterations in 0.512s)
# [t-SNE] Iteration 4650: error = 1.6873810, gradient norm = 0.0000016 (50 iterations in 0.522s)
# [t-SNE] Iteration 4700: error = 1.6841507, gradient norm = 0.0000016 (50 iterations in 0.522s)
# [t-SNE] Iteration 4750: error = 1.6810979, gradient norm = 0.0000015 (50 iterations in 0.541s)
# [t-SNE] Iteration 4800: error = 1.6781460, gradient norm = 0.0000015 (50 iterations in 0.508s)
# [t-SNE] Iteration 4850: error = 1.6751717, gradient norm = 0.0000015 (50 iterations in 0.523s)
# [t-SNE] Iteration 4900: error = 1.6721987, gradient norm = 0.0000015 (50 iterations in 0.515s)
# [t-SNE] Iteration 4950: error = 1.6694311, gradient norm = 0.0000014 (50 iterations in 0.540s)
# [t-SNE] Iteration 5000: error = 1.6667918, gradient norm = 0.0000014 (50 iterations in 0.538s)
# [t-SNE] Iteration 5050: error = 1.6644255, gradient norm = 0.0000013 (50 iterations in 0.544s)
# [t-SNE] Iteration 5100: error = 1.6619377, gradient norm = 0.0000013 (50 iterations in 0.515s)
# [t-SNE] Iteration 5150: error = 1.6596160, gradient norm = 0.0000013 (50 iterations in 0.512s)
# [t-SNE] Iteration 5200: error = 1.6573539, gradient norm = 0.0000013 (50 iterations in 0.515s)
# [t-SNE] Iteration 5250: error = 1.6548483, gradient norm = 0.0000013 (50 iterations in 0.509s)
# [t-SNE] Iteration 5300: error = 1.6522884, gradient norm = 0.0000013 (50 iterations in 0.520s)
# [t-SNE] Iteration 5350: error = 1.6500254, gradient norm = 0.0000013 (50 iterations in 0.523s)
# [t-SNE] Iteration 5400: error = 1.6474992, gradient norm = 0.0000013 (50 iterations in 0.531s)
# [t-SNE] Iteration 5450: error = 1.6450639, gradient norm = 0.0000013 (50 iterations in 0.525s)
# [t-SNE] Iteration 5500: error = 1.6428368, gradient norm = 0.0000012 (50 iterations in 0.507s)
# [t-SNE] Iteration 5550: error = 1.6406783, gradient norm = 0.0000012 (50 iterations in 0.508s)
# [t-SNE] Iteration 5600: error = 1.6384828, gradient norm = 0.0000011 (50 iterations in 0.521s)
# [t-SNE] Iteration 5650: error = 1.6363707, gradient norm = 0.0000011 (50 iterations in 0.518s)
# [t-SNE] Iteration 5700: error = 1.6343946, gradient norm = 0.0000011 (50 iterations in 0.523s)
# [t-SNE] Iteration 5750: error = 1.6325498, gradient norm = 0.0000011 (50 iterations in 0.516s)
# [t-SNE] Iteration 5800: error = 1.6306624, gradient norm = 0.0000011 (50 iterations in 0.505s)
# [t-SNE] Iteration 5850: error = 1.6288179, gradient norm = 0.0000010 (50 iterations in 0.508s)
# [t-SNE] Iteration 5900: error = 1.6270584, gradient norm = 0.0000010 (50 iterations in 0.526s)
# [t-SNE] Iteration 5950: error = 1.6253347, gradient norm = 0.0000010 (50 iterations in 0.525s)
# [t-SNE] Iteration 6000: error = 1.6237326, gradient norm = 0.0000010 (50 iterations in 0.507s)
# [t-SNE] Iteration 6050: error = 1.6220808, gradient norm = 0.0000010 (50 iterations in 0.522s)
# [t-SNE] Iteration 6100: error = 1.6204342, gradient norm = 0.0000010 (50 iterations in 0.522s)
# [t-SNE] Iteration 6150: error = 1.6188755, gradient norm = 0.0000010 (50 iterations in 0.517s)
# [t-SNE] Iteration 6200: error = 1.6173100, gradient norm = 0.0000009 (50 iterations in 0.522s)
# [t-SNE] Iteration 6250: error = 1.6155862, gradient norm = 0.0000009 (50 iterations in 0.512s)
# [t-SNE] Iteration 6300: error = 1.6140009, gradient norm = 0.0000009 (50 iterations in 0.523s)
# [t-SNE] Iteration 6350: error = 1.6124454, gradient norm = 0.0000009 (50 iterations in 0.519s)
# [t-SNE] Iteration 6400: error = 1.6109478, gradient norm = 0.0000009 (50 iterations in 0.522s)
# [t-SNE] Iteration 6450: error = 1.6094912, gradient norm = 0.0000009 (50 iterations in 0.501s)
# [t-SNE] Iteration 6500: error = 1.6079214, gradient norm = 0.0000009 (50 iterations in 0.507s)
# [t-SNE] Iteration 6550: error = 1.6063901, gradient norm = 0.0000009 (50 iterations in 0.501s)
# [t-SNE] Iteration 6600: error = 1.6048096, gradient norm = 0.0000009 (50 iterations in 0.508s)
# [t-SNE] Iteration 6650: error = 1.6032118, gradient norm = 0.0000009 (50 iterations in 0.509s)
# [t-SNE] Iteration 6700: error = 1.6016294, gradient norm = 0.0000008 (50 iterations in 0.504s)
# [t-SNE] Iteration 6750: error = 1.6000468, gradient norm = 0.0000008 (50 iterations in 0.519s)
# [t-SNE] Iteration 6800: error = 1.5985265, gradient norm = 0.0000008 (50 iterations in 0.513s)
# [t-SNE] Iteration 6850: error = 1.5969821, gradient norm = 0.0000008 (50 iterations in 0.515s)
# [t-SNE] Iteration 6900: error = 1.5953459, gradient norm = 0.0000008 (50 iterations in 0.519s)
# [t-SNE] Iteration 6950: error = 1.5940520, gradient norm = 0.0000008 (50 iterations in 0.498s)
# [t-SNE] Iteration 7000: error = 1.5924629, gradient norm = 0.0000008 (50 iterations in 0.498s)
# [t-SNE] Iteration 7050: error = 1.5908049, gradient norm = 0.0000008 (50 iterations in 0.514s)
# [t-SNE] Iteration 7100: error = 1.5891817, gradient norm = 0.0000008 (50 iterations in 0.501s)
# [t-SNE] Iteration 7150: error = 1.5874805, gradient norm = 0.0000008 (50 iterations in 0.509s)
# [t-SNE] Iteration 7200: error = 1.5858550, gradient norm = 0.0000008 (50 iterations in 0.501s)
# [t-SNE] Iteration 7250: error = 1.5841575, gradient norm = 0.0000008 (50 iterations in 0.509s)
# [t-SNE] Iteration 7300: error = 1.5825450, gradient norm = 0.0000008 (50 iterations in 0.539s)
# [t-SNE] Iteration 7350: error = 1.5808980, gradient norm = 0.0000008 (50 iterations in 0.534s)
# [t-SNE] Iteration 7400: error = 1.5791671, gradient norm = 0.0000008 (50 iterations in 0.524s)
# [t-SNE] Iteration 7450: error = 1.5774852, gradient norm = 0.0000008 (50 iterations in 0.506s)
# [t-SNE] Iteration 7500: error = 1.5757649, gradient norm = 0.0000007 (50 iterations in 0.527s)
# [t-SNE] Iteration 7550: error = 1.5740387, gradient norm = 0.0000007 (50 iterations in 0.506s)
# [t-SNE] Iteration 7600: error = 1.5723635, gradient norm = 0.0000007 (50 iterations in 0.517s)
# [t-SNE] Iteration 7650: error = 1.5706962, gradient norm = 0.0000007 (50 iterations in 0.511s)
# [t-SNE] Iteration 7700: error = 1.5690886, gradient norm = 0.0000007 (50 iterations in 0.509s)
# [t-SNE] Iteration 7750: error = 1.5674729, gradient norm = 0.0000007 (50 iterations in 0.500s)
# [t-SNE] Iteration 7800: error = 1.5657362, gradient norm = 0.0000007 (50 iterations in 0.505s)
# [t-SNE] Iteration 7850: error = 1.5639489, gradient norm = 0.0000007 (50 iterations in 0.518s)
# [t-SNE] Iteration 7900: error = 1.5621806, gradient norm = 0.0000007 (50 iterations in 0.505s)
# [t-SNE] Iteration 7950: error = 1.5604559, gradient norm = 0.0000007 (50 iterations in 0.500s)
# [t-SNE] Iteration 8000: error = 1.5589627, gradient norm = 0.0000007 (50 iterations in 0.495s)
# [t-SNE] Iteration 8050: error = 1.5574946, gradient norm = 0.0000007 (50 iterations in 0.502s)
# [t-SNE] Iteration 8100: error = 1.5561215, gradient norm = 0.0000007 (50 iterations in 0.507s)
# [t-SNE] Iteration 8150: error = 1.5547107, gradient norm = 0.0000006 (50 iterations in 0.490s)
# [t-SNE] Iteration 8200: error = 1.5533345, gradient norm = 0.0000006 (50 iterations in 0.505s)
# [t-SNE] Iteration 8250: error = 1.5519892, gradient norm = 0.0000006 (50 iterations in 0.507s)
# [t-SNE] Iteration 8300: error = 1.5505646, gradient norm = 0.0000006 (50 iterations in 0.510s)
# [t-SNE] Iteration 8350: error = 1.5492320, gradient norm = 0.0000006 (50 iterations in 0.515s)
# [t-SNE] Iteration 8400: error = 1.5478238, gradient norm = 0.0000006 (50 iterations in 0.499s)
# [t-SNE] Iteration 8450: error = 1.5464236, gradient norm = 0.0000006 (50 iterations in 0.506s)
# [t-SNE] Iteration 8500: error = 1.5449749, gradient norm = 0.0000006 (50 iterations in 0.507s)
# [t-SNE] Iteration 8550: error = 1.5435115, gradient norm = 0.0000006 (50 iterations in 0.504s)
# [t-SNE] Iteration 8600: error = 1.5420284, gradient norm = 0.0000006 (50 iterations in 0.508s)
# [t-SNE] Iteration 8650: error = 1.5405986, gradient norm = 0.0000006 (50 iterations in 0.515s)
# [t-SNE] Iteration 8700: error = 1.5391572, gradient norm = 0.0000006 (50 iterations in 0.500s)
# [t-SNE] Iteration 8750: error = 1.5377173, gradient norm = 0.0000006 (50 iterations in 0.504s)
# [t-SNE] Iteration 8800: error = 1.5362383, gradient norm = 0.0000006 (50 iterations in 0.513s)
# [t-SNE] Iteration 8850: error = 1.5348269, gradient norm = 0.0000006 (50 iterations in 0.531s)
# [t-SNE] Iteration 8900: error = 1.5333804, gradient norm = 0.0000006 (50 iterations in 0.516s)
# [t-SNE] Iteration 8950: error = 1.5319235, gradient norm = 0.0000006 (50 iterations in 0.505s)
# [t-SNE] Iteration 9000: error = 1.5305916, gradient norm = 0.0000006 (50 iterations in 0.526s)
# [t-SNE] Iteration 9050: error = 1.5291839, gradient norm = 0.0000006 (50 iterations in 0.511s)
# [t-SNE] Iteration 9100: error = 1.5279869, gradient norm = 0.0000006 (50 iterations in 0.526s)
# [t-SNE] Iteration 9150: error = 1.5268821, gradient norm = 0.0000006 (50 iterations in 0.505s)
# [t-SNE] Iteration 9200: error = 1.5258687, gradient norm = 0.0000006 (50 iterations in 0.570s)
# [t-SNE] Iteration 9250: error = 1.5247796, gradient norm = 0.0000006 (50 iterations in 0.515s)
# [t-SNE] Iteration 9300: error = 1.5237592, gradient norm = 0.0000005 (50 iterations in 0.546s)
# [t-SNE] Iteration 9350: error = 1.5226794, gradient norm = 0.0000005 (50 iterations in 0.535s)
# [t-SNE] Iteration 9400: error = 1.5216490, gradient norm = 0.0000005 (50 iterations in 0.526s)
# [t-SNE] Iteration 9450: error = 1.5206013, gradient norm = 0.0000005 (50 iterations in 0.529s)
# [t-SNE] Iteration 9500: error = 1.5195922, gradient norm = 0.0000005 (50 iterations in 0.515s)
# [t-SNE] Iteration 9550: error = 1.5186121, gradient norm = 0.0000005 (50 iterations in 0.527s)
# [t-SNE] Iteration 9600: error = 1.5176358, gradient norm = 0.0000005 (50 iterations in 0.527s)
# [t-SNE] Iteration 9650: error = 1.5165868, gradient norm = 0.0000005 (50 iterations in 0.548s)
# [t-SNE] Iteration 9700: error = 1.5155808, gradient norm = 0.0000005 (50 iterations in 0.529s)
# [t-SNE] Iteration 9750: error = 1.5145751, gradient norm = 0.0000005 (50 iterations in 0.518s)
# [t-SNE] Iteration 9800: error = 1.5135332, gradient norm = 0.0000005 (50 iterations in 0.525s)
# [t-SNE] Iteration 9850: error = 1.5126046, gradient norm = 0.0000005 (50 iterations in 0.536s)
# [t-SNE] Iteration 9900: error = 1.5115963, gradient norm = 0.0000005 (50 iterations in 0.529s)
# [t-SNE] Iteration 9950: error = 1.5105749, gradient norm = 0.0000005 (50 iterations in 0.511s)
# [t-SNE] Iteration 10000: error = 1.5096047, gradient norm = 0.0000005 (50 iterations in 0.523s)
# [t-SNE] KL divergence after 10000 iterations: 1.509605
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 1491 samples in 0.002s...
# [t-SNE] Computed neighbors for 1491 samples in 0.269s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 1491
# [t-SNE] Computed conditional probabilities for sample 1491 / 1491
# [t-SNE] Mean sigma: 1.950445
# [t-SNE] Computed conditional probabilities in 0.093s
# [t-SNE] Iteration 50: error = 73.5394058, gradient norm = 0.0599922 (50 iterations in 7.206s)
# [t-SNE] Iteration 100: error = 72.9063263, gradient norm = 0.0380494 (50 iterations in 3.011s)
# [t-SNE] Iteration 150: error = 73.0687561, gradient norm = 0.0555834 (50 iterations in 2.706s)
# [t-SNE] Iteration 200: error = 73.2498474, gradient norm = 0.0445633 (50 iterations in 2.759s)
# [t-SNE] Iteration 250: error = 73.2285843, gradient norm = 0.0413925 (50 iterations in 2.433s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 73.228584
# [t-SNE] Iteration 300: error = 1.4277844, gradient norm = 0.0007216 (50 iterations in 3.834s)
# [t-SNE] Iteration 350: error = 1.3116895, gradient norm = 0.0002000 (50 iterations in 4.948s)
# [t-SNE] Iteration 400: error = 1.2670054, gradient norm = 0.0001177 (50 iterations in 5.019s)
# [t-SNE] Iteration 450: error = 1.2482500, gradient norm = 0.0000819 (50 iterations in 5.083s)
# [t-SNE] Iteration 500: error = 1.2358291, gradient norm = 0.0000724 (50 iterations in 5.174s)
# [t-SNE] Iteration 550: error = 1.2252572, gradient norm = 0.0000585 (50 iterations in 5.259s)
# [t-SNE] Iteration 600: error = 1.2053062, gradient norm = 0.0000655 (50 iterations in 5.615s)
# [t-SNE] Iteration 650: error = 1.1833212, gradient norm = 0.0000585 (50 iterations in 5.901s)
# [t-SNE] Iteration 700: error = 1.1782819, gradient norm = 0.0000406 (50 iterations in 5.454s)
# [t-SNE] Iteration 750: error = 1.1690862, gradient norm = 0.0000395 (50 iterations in 4.439s)
# [t-SNE] Iteration 800: error = 1.1670907, gradient norm = 0.0000365 (50 iterations in 3.847s)
# [t-SNE] Iteration 850: error = 1.1592041, gradient norm = 0.0000367 (50 iterations in 3.910s)
# [t-SNE] Iteration 900: error = 1.1478274, gradient norm = 0.0000802 (50 iterations in 3.906s)
# [t-SNE] Iteration 950: error = 1.1472174, gradient norm = 0.0000339 (50 iterations in 3.889s)
# [t-SNE] Iteration 1000: error = 1.1476181, gradient norm = 0.0000264 (50 iterations in 3.941s)
# [t-SNE] Iteration 1050: error = 1.1482267, gradient norm = 0.0000251 (50 iterations in 3.921s)
# [t-SNE] Iteration 1100: error = 1.1490531, gradient norm = 0.0000230 (50 iterations in 3.922s)
# [t-SNE] Iteration 1150: error = 1.1496413, gradient norm = 0.0000210 (50 iterations in 3.965s)
# [t-SNE] Iteration 1200: error = 1.1500621, gradient norm = 0.0000198 (50 iterations in 3.974s)
# [t-SNE] Iteration 1250: error = 1.1500603, gradient norm = 0.0000337 (50 iterations in 4.022s)
# [t-SNE] Iteration 1300: error = 1.1500237, gradient norm = 0.0000179 (50 iterations in 3.912s)
# [t-SNE] Iteration 1300: did not make any progress during the last 300 episodes. Finished.
# [t-SNE] KL divergence after 1300 iterations: 1.150024

# %% [markdown]
# ### the t-SNE dimensions for the four datasets are put into dataframes

# %%
tsne_df_train = pd.DataFrame(data = my_tsne_train, columns = ['tsne1', 'tsne2', 'tsne3'])
tsne_df_bedrock_train = pd.DataFrame(data = my_tsne_bedrock_train, columns = ['tsne1', 'tsne2', 'tsne3'])
tsne_df_superficial_train = pd.DataFrame(data = my_tsne_superficial_train, columns = ['tsne1', 'tsne2', 'tsne3'])
tsne_df_test = pd.DataFrame(data = my_tsne_test, columns = ['tsne1', 'tsne2', 'tsne3'])
tsne_df_everything = pd.DataFrame(data = my_tsne_everything, columns = ['tsne1', 'tsne2', 'tsne3'])

# %%
bedrock_data = train_data[train_data['Geology'] == 'Bedrock']
superficial_data = train_data[train_data['Geology'] == 'Superficial'].reset_index(drop = True)
artefact_data = pd.concat([test_data.reset_index(drop = True), X_test_labeled_df['inlierLabel'].reset_index(drop = True)], axis = 1)

# %%
def addartefactclass(row):
    if row['Geology'] == 'Bedrock':
        return(row['class'])
    elif row['Geology'] == 'Superficial':
        return(row['class'])
    else:
        return('Artefact')
my_data['class'] = my_data.swifter.apply(addartefactclass, axis = 1)
# Out:
# Pandas Apply: 100%|██████████| 1491/1491 [00:00<00:00, 24583.15it/s]

# %%
artefact_data.head()
# Out:
#    Analysis    Geology Province Region Site SubSite Formation Band Nodule  \
# 0  06_DH1_1  Artefacts      NaN    NaN   DH     NaN       NaN  NaN    DH1
# 1  07_DH1_2  Artefacts      NaN    NaN   DH     NaN       NaN  NaN    DH1
# 2  08_DH1_3  Artefacts      NaN    NaN   DH     NaN       NaN  NaN    DH1
# 3  09_DH2_1  Artefacts      NaN    NaN   DH     NaN       NaN  NaN    DH2
# 4  10_DH2_2  Artefacts      NaN    NaN   DH     NaN       NaN  NaN    DH2
#
#      Li7   Be9    B11   Mg24        Al27       Si28    P31     S33  \
# 0   2.79  0.95  93.21  27.83  635.240000  465388.29  35.07  806.55
# 1   2.37  1.29  95.19  27.99  639.090000  465388.40  31.65  807.55
# 2   2.46  1.33  93.63  26.43  670.480000  465378.49  25.43  837.73
# 3  18.47  0.11  63.80  31.98  629.155064  464555.55  24.63  750.62
# 4  19.98  0.14  60.96  44.95  629.155064  464137.82  22.59  796.21
#
#           K39    Ca42  Sc45       Ti47   V51  Cr52  Mn55   Fe56  Co59  Ni60  \
# 0  443.100000  119.05  1.08  37.770000  0.51  5.18  3.27  35.38  0.11  1.03
# 1  442.100000  119.74  1.09  24.320000  0.60  5.43  2.30  49.23  0.10  1.22
# 2  444.280000  140.99  1.17  17.930000  0.62  2.61  1.40  16.46  0.10  1.01
# 3  385.676425  141.70  1.19  72.650000  1.52  2.87  1.09  16.76  0.09  1.07
# 4  385.676425  130.52  1.22  31.638934  2.44  5.92  1.26  62.16  0.08  0.93
#
#     Cu63   Zn68  Ga69  Ge72  As75     Rb85  Sr88   Y89  Zr90      Nb93  Mo95  \
# 0  11.14  20.75  0.69  1.37  0.44  0.72000  2.00  0.21  1.43  0.227163  0.08
# 1   8.64  18.15  0.86  1.93  0.44  0.77000  1.84  0.21  1.47  0.227163  0.11
# 2   3.44  17.54  0.79  2.14  0.42  0.71000  1.93  0.13  1.16  0.227163  0.04
# 3   1.10  14.33  0.75  1.59  0.46  1.62000  4.29  0.20  1.45  0.250000  0.03
# 4   1.23  14.59  0.76  0.81  0.43  0.73604  4.44  0.27  1.99  0.680000  0.05
#
#       Cd111  In115  Sn118  Cs133  Ba137  La139  Ce140  Pr141  Nd146  Sm147  \
# 0  0.211529   0.01   0.19   0.03   5.95   0.18   0.57   0.07   0.34   0.04
# 1  0.211529   0.01   0.19   0.03   7.51   0.19   0.53   0.06   0.24   0.07
# 2  0.211529   0.01   0.12   0.02   4.40   0.11   0.20   0.03   0.08   0.04
# 3  0.220000   0.01   0.19   0.04  12.48   0.23   0.40   0.06   0.25   0.06
# 4  0.090000   0.01   0.17   0.07  14.40   0.48   0.80   0.12   0.51   0.09
#
#    Eu153  Gd157  Tb159  Dy163  Ho165  Er166  Tm169  Yb172  Lu175  Hf178  \
# 0   0.01   0.05   0.01   0.06   0.01   0.03   0.01   0.03   0.02   0.04
# 1   0.02   0.05   0.01   0.05   0.01   0.02   0.00   0.01   0.00   0.04
# 2   0.01   0.03   0.00   0.02   0.01   0.01   0.00   0.01   0.00   0.04
# 3   0.02   0.05   0.01   0.05   0.01   0.02   0.00   0.05   0.00   0.05
# 4   0.04   0.03   0.01   0.06   0.01   0.02   0.01   0.03   0.00   0.07
#
#    Ta181  Pb208  Th232      U238 class  inlierLabel
# 0   0.01   6.12   0.11  0.298424  None            1
# 1   0.01   5.57   0.09  0.298424  None            1
# 2   0.03   3.51   0.08  0.298424  None            1
# 3   0.01   0.54   0.09  0.080000  None           -1
# 4   0.03   0.69   0.15  0.090000  None           -1

# %%
my_data_mod = my_data[my_data['Geology'] != 'Artefacts']

# %%
my_data_mod_final = pd.concat([my_data_mod, artefact_data], axis = 0).reset_index(drop = True)
# Out:
# /home/rmorse/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=True'.
#
# To retain the current behavior and silence the warning, pass sort=False
#
#   """Entry point for launching an IPython kernel.

# %%
def inlier_label(row):
    if row['Geology'] == 'Bedrock':
        return(row['class'])
    elif row['Geology'] == 'Superficial':
        return(row['class'])
    else:
        return(row['inlierLabel'])
my_data_mod_final['class'] = my_data_mod_final.swifter.apply(inlier_label, axis = 1)
# Out:
# Pandas Apply: 100%|██████████| 1491/1491 [00:00<00:00, 23706.60it/s]

# %%
my_data_mod_final.tail()
# Out:
#          Al27     Analysis  As75    B11      Ba137 Band   Be9    Ca42  Cd111  \
# 1486  1347.97  44_MDG367_2  0.54  65.51   5.525158  NaN  0.75  246.61   0.42
# 1487  1339.24  45_MDG367_3  0.60  55.05  28.690000  NaN  0.16  287.43   0.15
# 1488   512.46  46_MDG370_1  0.61  58.17   1.610000  NaN  0.68  269.73   0.10
# 1489   549.53  47_MDG370_2  0.66  67.16   1.800000  NaN  0.99  266.44   0.17
# 1490   532.25  48_MDG370_3  0.62  62.34   2.210000  NaN  0.99  232.31   0.05
#
#       Ce140  Co59  Cr52  Cs133  Cu63  Dy163  Er166  Eu153    Fe56 Formation  \
# 1486   0.85  0.23  6.96   0.05  0.44   0.13   0.05   0.04  161.72       NaN
# 1487   0.65  0.19  3.61   0.04  0.44   0.08   0.04   0.03  116.81       NaN
# 1488   0.64  0.17  2.37   0.02  0.54   0.07   0.04   0.05   49.28       NaN
# 1489   0.64  0.19  5.54   0.02  0.28   0.42   0.26   0.06   44.38       NaN
# 1490   0.58  0.20  5.65   0.02  0.28   0.08   0.08   0.01   46.68       NaN
#
#           Ga69  Gd157  Ge72    Geology     Hf178  Ho165  In115     K39  La139  \
# 1486  0.533617   0.10  1.14  Artefacts  0.010000   0.02   0.01  669.22   0.75
# 1487  0.610000   0.14  1.00  Artefacts  0.050000   0.01   0.01  662.40   0.57
# 1488  0.320000   0.15  0.80  Artefacts  0.050000   0.03   0.03  307.63   0.78
# 1489  0.250000   0.23  0.87  Artefacts  0.043702   0.08   0.02  321.96   0.77
# 1490  0.370000   0.06  0.88  Artefacts  0.060000   0.02   0.01  330.35   0.75
#
#         Li7     Lu175   Mg24  Mn55  Mo95  Nb93  Nd146  Ni60  Nodule     P31  \
# 1486   8.37  0.000000  32.90  0.59  0.08  0.31   0.73  2.35  MDG367  144.94
# 1487  10.77  0.010000  32.76  0.71  0.07  0.26   0.58  1.53  MDG367  125.81
# 1488   3.05  0.000000  23.46  0.63  0.10  0.24   0.63  1.27  MDG370  198.53
# 1489   3.06  0.017975  25.17  0.57  0.07  0.11   0.49  0.62  MDG370  168.92
# 1490   3.04  0.010000  25.49  0.62  0.09  0.08   0.61  1.25  MDG370  188.86
#
#       Pb208  Pr141 Province  Rb85 Region     S33  Sc45       Si28    Site  \
# 1486   0.34   0.18      NaN  1.64    NaN  773.07  0.61  464405.61  Madawg
# 1487   0.36   0.14      NaN  1.64    NaN  742.93  0.63  464611.17  Madawg
# 1488   0.26   0.15      NaN  0.67    NaN  689.45  0.57  465572.56  Madawg
# 1489   0.22   0.17      NaN  0.61    NaN  808.44  0.59  465382.48  Madawg
# 1490   0.25   0.16      NaN  0.65    NaN  802.52  0.50  465456.06  Madawg
#
#       Sm147  Sn118   Sr88 SubSite  Ta181  Tb159     Th232   Ti47     Tm169  \
# 1486   0.09   0.37  12.48     NaN   0.03   0.03  0.170000  36.79  0.000000
# 1487   0.08   0.25   3.93     NaN   0.03   0.02  0.160000  57.23  0.010000
# 1488   0.16   0.18   2.62     NaN   0.01   0.02  0.120000  82.86  0.010000
# 1489   0.15   0.20   2.42     NaN   0.02   0.06  0.102689  17.92  0.019048
# 1490   0.22   0.15   2.57     NaN   0.00   0.02  0.080000  28.52  0.010000
#
#       U238   V51   Y89     Yb172  Zn68      Zr90 class  inlierLabel
# 1486  0.11  1.54  0.50  0.010000  8.11  2.230000    -1         -1.0
# 1487  0.12  1.43  0.52  0.030000  8.75  1.370000    -1         -1.0
# 1488  0.20  1.85  0.80  0.040000  8.96  0.970000     1          1.0
# 1489  0.66  0.85  2.56  0.073763  8.45  1.317752     1          1.0
# 1490  0.24  0.68  0.77  0.040000  7.09  1.380000     1          1.0

# %%
tsne_df_train_labelled = pd.concat([tsne_df_train.reset_index(drop = True), train_data['class'].reset_index(drop = True)], axis = 1)
tsne_df_bedrock_train_labelled = pd.concat([tsne_df_bedrock_train.reset_index(drop = True), bedrock_data['class'].reset_index(drop = True)], axis = 1)
tsne_df_superficial_train_labelled = pd.concat([tsne_df_superficial_train, superficial_data['class']], axis = 1)
tsne_df_test['class'] = 1
tsne_df_everything_labelled = pd.concat([tsne_df_everything.reset_index(drop = True), my_data_mod_final['class'].reset_index(drop = True)], axis = 1)

# %%
PC_df_train_labelled = pd.concat([PC_df_train.reset_index(drop = True), train_data['class'].reset_index(drop = True)], axis = 1)
PC_df_superficial_train_labelled = pd.concat([PC_df_superficial_train.reset_index(drop = True), superficial_data['class']], axis = 1)
PC_df_bedrock_train_labelled = pd.concat([PC_df_bedrock_train.reset_index(drop = True), bedrock_data['class'].reset_index(drop = True)], axis = 1)
PC_df_everything_labelled = pd.concat([PC_df_everything.reset_index(drop = True), my_data_mod_final['class'].reset_index(drop = True)], axis = 1)

# %%
tsne_df_everything_labelled.head()
# Out:
#        tsne1      tsne2      tsne3 class
# 0  45.364891  -1.575627 -24.847095    FH
# 1  31.615215   1.033610 -38.219067    FH
# 2  27.788452  -5.070663 -42.580009    FH
# 3  -7.980391 -36.277615  10.026930    FH
# 4  27.078793  -2.385831 -42.315254    FH

# %%
tsne_df_superficial_train_labelled.tail()
# Out:
#           tsne1       tsne2       tsne3 class
# 427  -14.798692 -211.227509 -363.468658    MM
# 428  -85.224648 -229.542709 -307.218506    MM
# 429  182.583847  181.577133   68.908569    MM
# 430 -151.794876 -164.877060   34.424408    MM
# 431  421.650116   87.700005 -102.909714    MM

# %%
tsne_df_bedrock_train_labelled.tail()
# Out:
#           tsne1       tsne2       tsne3 class
# 691   -3.118002 -127.655220 -218.447311    LB
# 692 -252.093460  -39.192242  253.941635    LB
# 693   11.766911  292.908936   91.392784    LB
# 694 -116.620415  149.652893 -221.098969    LB
# 695   98.967003  269.937347  102.161407    LB

# %%
my_data['class'].unique()
# Out:
# array(['FH', 'ER', 'WW', 'TC', 'CS', 'KQ', 'AR', 'SL', 'FG', 'WB', 'PF',
#        'WH', 'SQ', 'WN', 'BH', 'PH', 'LB', 'AB', 'LV', 'SV_SE', 'BA',
#        'WA', 'MM', 'Artefact'], dtype=object)

# %%
tsne_df_train_labelled.to_csv('output_datasets/website/tsne_both.csv', index = False)
tsne_df_bedrock_train_labelled.to_csv('output_datasets/website/tsne_bedrock.csv', index = False)
tsne_df_superficial_train_labelled.to_csv('output_datasets/website/tsne_superficial.csv', index = False)
tsne_df_test.to_csv('output_datasets/website/tsne_artefacts.csv', index = False)
tsne_df_everything_labelled.to_csv('output_datasets/website/tsne_samples_and_artefacts.csv', index = False)

# %%
PC_df_train_labelled.to_csv('output_datasets/website/pca_both.csv', index = False)
PC_df_superficial_train_labelled.to_csv('output_datasets/website/pca_superficial.csv', index = False)
PC_df_bedrock_train_labelled.to_csv('output_datasets/website/pca_bedrock.csv', index = False)
PC_df_everything_labelled.to_csv('output_datasets/website/pca_samples_and_artefacts.csv', index = False)
