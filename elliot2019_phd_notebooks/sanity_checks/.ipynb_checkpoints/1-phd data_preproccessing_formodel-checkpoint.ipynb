# %% [markdown]
# # data preproccessing

# %% [markdown]
# ## import modules and configure notebook

# %%
import pandas as pd
import numpy as np
import swifter
import seaborn as sns
import matplotlib.pyplot

pd.set_option('max.rows', None)
pd.set_option('max.columns', None)

from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.metrics import log_loss, accuracy_score, f1_score
from sklearn.decomposition import PCA 
from sklearn.manifold import TSNE
from sklearn.preprocessing import StandardScaler


# %matplotlib inline

# %% [markdown]
# ### Configurations

# %%
data_input_path = 'data/AllData_2_All_Details_3_OutliersRem_1_SupDep_Regions.csv'

# %% [markdown]
# ### Import data

# %%
my_data = pd.read_csv(data_input_path)

# %%
group_superficial = False

# %%
my_data['Site'].unique()
# Out:
# array(['FH', 'ER', 'WW', 'TC', 'CS', 'BC', 'KQ', 'AR', 'SL', 'FG', 'WB',
#        'BX', 'PF', 'BM', 'WH', 'SQ', 'BP', 'WN', 'BH', 'PH', 'LB', 'AB',
#        'LV', 'BR', 'KY', 'BF', 'ST', 'SH', 'CF', 'BG', 'AC', 'CR', 'GH',
#        'PX', 'WF', 'DH', 'NMAG_Gold', 'NMW_Gold', 'NMWGwern', 'UBSS',
#        'Cefn', 'Stockley', 'Pucha', 'Woodbury', 'Pimple', 'Wellington',
#        'Lyonshall', 'SymondsYatE', 'Madawg'], dtype=object)

# %% [markdown]
# ### make labels for classification

# %%
def make_classes_grouped(row):
    if row['Geology'] == 'Bedrock':
        if row['Site'] == 'WB' or row['Site'] == 'BX':
            return('WB_BX')
        elif row['Site'] == 'BC' or row['Site'] == 'CS':
            return('BC_CS')
        elif row['Site'] == 'SQ' or row['Site'] == 'BP':
            return('SQ_BP')
        else:
            return(row['Site'])
    elif row['Geology'] == 'Superficial':
        if row['Region'] == 'SV' or row['Region'] == 'SE':
            return('SV_SE')
        else:
            return(row['Region'])

def make_classes_raw(row):
    if row['Geology'] == 'Bedrock':
        return(row['Site'])
    elif row['Geology'] == 'Superficial':
        return(row['Region'])

# %%
my_data['class'] = 'init'   

if group_superficial:
    my_data['class'] = my_data.apply(make_classes_grouped, axis = 1)
else:
    my_data['class'] = my_data.apply(make_classes_raw, axis = 1)

# %% [markdown]
# ### Impute values that contaion '<' sign with 0 because the sign represents a measurement below the detection liits of the instrument

# %%
for column_name in my_data.columns.values[9:-1]:
    def fill_less_than(row):
        if '<' in str(row[column_name]):
            return(float(row[column_name].replace('<', '').replace(',','')))
        else:
            return(float(row[column_name]))
    my_data[column_name] = my_data.swifter.apply(fill_less_than, axis = 1)
# Out:
# Pandas Apply: 100%|██████████| 1606/1606 [00:00<00:00, 21764.52it/s]
# Pandas Apply: 100%|██████████| 1606/1606 [00:00<00:00, 20173.32it/s]
# Pandas Apply: 100%|██████████| 1606/1606 [00:00<00:00, 22096.79it/s]
# Pandas Apply: 100%|██████████| 1606/1606 [00:00<00:00, 19704.53it/s]
# Pandas Apply: 100%|██████████| 1606/1606 [00:00<00:00, 21782.81it/s]
# Pandas Apply: 100%|██████████| 1606/1606 [00:00<00:00, 20610.39it/s]
# Pandas Apply: 100%|██████████| 1606/1606 [00:00<00:00, 21466.62it/s]
# Pandas Apply: 100%|██████████| 1606/1606 [00:00<00:00, 21090.96it/s]
# Pandas Apply: 100%|██████████| 1606/1606 [00:00<00:00, 21161.33it/s]
# Pandas Apply: 100%|██████████| 1606/1606 [00:00<00:00, 22124.95it/s]
# Pandas Apply: 100%|██████████| 1606/1606 [00:00<00:00, 21338.91it/s]
# Pandas Apply: 100%|██████████| 1606/1606 [00:00<00:00, 19227.73it/s]
# Pandas Apply: 100%|██████████| 1606/1606 [00:00<00:00, 20272.28it/s]
# Pandas Apply: 100%|██████████| 1606/1606 [00:00<00:00, 20690.79it/s]
# Pandas Apply: 100%|██████████| 1606/1606 [00:00<00:00, 19558.80it/s]
# Pandas Apply: 100%|██████████| 1606/1606 [00:00<00:00, 20539.88it/s]
# Pandas Apply: 100%|██████████| 1606/1606 [00:00<00:00, 21823.11it/s]
# Pandas Apply: 100%|██████████| 1606/1606 [00:00<00:00, 22288.79it/s]
# Pandas Apply: 100%|██████████| 1606/1606 [00:00<00:00, 18109.08it/s]
# Pandas Apply: 100%|██████████| 1606/1606 [00:00<00:00, 20876.56it/s]
# Pandas Apply: 100%|██████████| 1606/1606 [00:00<00:00, 20187.40it/s]
# Pandas Apply: 100%|██████████| 1606/1606 [00:00<00:00, 20133.52it/s]
# Pandas Apply: 100%|██████████| 1606/1606 [00:00<00:00, 19861.92it/s]
# Pandas Apply: 100%|██████████| 1606/1606 [00:00<00:00, 20148.76it/s]
# Pandas Apply: 100%|██████████| 1606/1606 [00:00<00:00, 19775.51it/s]
# Pandas Apply: 100%|██████████| 1606/1606 [00:00<00:00, 21484.62it/s]
# Pandas Apply: 100%|██████████| 1606/1606 [00:00<00:00, 20844.65it/s]
# Pandas Apply: 100%|██████████| 1606/1606 [00:00<00:00, 22378.02it/s]
# Pandas Apply: 100%|██████████| 1606/1606 [00:00<00:00, 21946.04it/s]
# Pandas Apply: 100%|██████████| 1606/1606 [00:00<00:00, 19529.77it/s]
# Pandas Apply: 100%|██████████| 1606/1606 [00:00<00:00, 18697.44it/s]
# Pandas Apply: 100%|██████████| 1606/1606 [00:00<00:00, 18780.43it/s]
# Pandas Apply: 100%|██████████| 1606/1606 [00:00<00:00, 22374.60it/s]
# Pandas Apply: 100%|██████████| 1606/1606 [00:00<00:00, 21583.34it/s]
# Pandas Apply: 100%|██████████| 1606/1606 [00:00<00:00, 21778.66it/s]
# Pandas Apply: 100%|██████████| 1606/1606 [00:00<00:00, 21840.30it/s]
# Pandas Apply: 100%|██████████| 1606/1606 [00:00<00:00, 22220.20it/s]
# Pandas Apply: 100%|██████████| 1606/1606 [00:00<00:00, 22545.79it/s]
# Pandas Apply: 100%|██████████| 1606/1606 [00:00<00:00, 21870.80it/s]
# Pandas Apply: 100%|██████████| 1606/1606 [00:00<00:00, 21442.70it/s]
# Pandas Apply: 100%|██████████| 1606/1606 [00:00<00:00, 19248.83it/s]
# Pandas Apply: 100%|██████████| 1606/1606 [00:00<00:00, 19757.76it/s]
# Pandas Apply: 100%|██████████| 1606/1606 [00:00<00:00, 21360.36it/s]
# Pandas Apply: 100%|██████████| 1606/1606 [00:00<00:00, 20823.64it/s]
# Pandas Apply: 100%|██████████| 1606/1606 [00:00<00:00, 21126.62it/s]
# Pandas Apply: 100%|██████████| 1606/1606 [00:00<00:00, 20859.62it/s]
# Pandas Apply: 100%|██████████| 1606/1606 [00:00<00:00, 21170.70it/s]
# Pandas Apply: 100%|██████████| 1606/1606 [00:00<00:00, 21672.99it/s]
# Pandas Apply: 100%|██████████| 1606/1606 [00:00<00:00, 21205.36it/s]
# Pandas Apply: 100%|██████████| 1606/1606 [00:00<00:00, 19657.15it/s]
# Pandas Apply: 100%|██████████| 1606/1606 [00:00<00:00, 19304.38it/s]
# Pandas Apply: 100%|██████████| 1606/1606 [00:00<00:00, 20119.57it/s]
# Pandas Apply: 100%|██████████| 1606/1606 [00:00<00:00, 18991.59it/s]

# %% [markdown]
# ### Impute na values with variable median, this is more resistant to the effect of outliers

# %%
for column_name in my_data.columns.values[9:-1]:
    my_data[column_name] = my_data[column_name].fillna(my_data[column_name].median())

# %%
my_data.head()
# Out:
#      Analysis  Geology  Province Region Site SubSite Formation Band   Nodule  \
# 0  10_FH1_1_1  Bedrock  Northern    NaN   FH     FH1   Burnham  FH1  FH1_1_1
# 1  11_FH1_1_1  Bedrock  Northern    NaN   FH     FH1   Burnham  FH1  FH1_1_1
# 2  12_FH1_1_1  Bedrock  Northern    NaN   FH     FH1   Burnham  FH1  FH1_1_1
# 3  13_FH1_1_2  Bedrock  Northern    NaN   FH     FH1   Burnham  FH1  FH1_1_2
# 4  14_FH1_1_2  Bedrock  Northern    NaN   FH     FH1   Burnham  FH1  FH1_1_2
#
#      Li7   Be9    B11    Mg24     Al27       Si28       P31      S33     K39  \
# 0  15.63  0.12  48.36  154.63   943.71  464944.18     50.28   538.57  455.94
# 1  11.50  0.09  44.77   22.42  1077.11  465010.94     70.91   438.20  387.82
# 2  20.05  0.06  44.88   42.70   620.21  465295.41    104.47   372.66  363.71
# 3  11.16  0.73  47.06  162.42  1143.19  465099.89  56367.93  1075.89  547.55
# 4  17.71  0.32  48.26   33.52   547.22  465027.11     44.44   464.78  278.25
#
#       Ca42  Sc45   Ti47   V51    Cr52  Mn55    Fe56  Co59  Ni60  Cu63   Zn68  \
# 0   712.39  0.42  15.58  0.27    3.30  0.69    8.46  0.05  0.80  1.62  10.82
# 1   515.24  0.44  18.47  0.29    3.45  1.01   11.59  0.11  0.36  0.53   8.93
# 2   957.89  0.76  19.89  0.55    3.25  1.21   87.99  0.21  1.68  1.53  11.98
# 3  2174.30  0.43  42.30  0.67  152.42  4.84  145.34  0.30  2.45  5.02  17.15
# 4  1551.63  0.71  11.18  0.27    2.56  1.73   25.38  0.05  0.80  0.55   9.80
#
#    Ga69  Ge72  As75  Rb85   Sr88   Y89  Zr90  Nb93  Mo95  Cd111  In115  Sn118  \
# 0  0.25  1.22  0.16  0.43  12.94  0.88  1.51  0.09  0.05   0.02   0.00   0.05
# 1  0.34  0.85  0.10  0.45  13.22  0.95  1.74  0.07  0.01   0.02   0.00   0.04
# 2  0.25  1.71  0.13  0.43   8.52  0.87  0.93  0.10  0.02   0.02   0.00   0.05
# 3  0.35  2.13  0.84  0.76  13.16  0.97  2.00  0.10  0.29   0.18   0.01   0.78
# 4  0.41  1.41  0.12  0.28   9.90  0.90  0.90  0.08  0.04   0.10   0.00   0.09
#
#    Cs133  Ba137  La139  Ce140  Pr141  Nd146  Sm147  Eu153  Gd157  Tb159  \
# 0   0.01   6.54   0.84   0.95   0.23   0.87   0.16   0.04   0.16   0.02
# 1   0.02   8.04   0.92   1.01   0.23   0.98   0.18   0.04   0.18   0.02
# 2   0.01   3.13   0.90   1.08   0.26   0.84   0.15   0.04   0.19   0.02
# 3   0.04   8.74   0.93   0.95   0.21   0.75   0.13   0.04   0.25   0.02
# 4   0.01   2.74   0.97   1.09   0.27   1.00   0.17   0.04   0.19   0.02
#
#    Dy163  Ho165  Er166  Tm169  Yb172  Lu175  Hf178  Ta181  Pb208  Th232  U238  \
# 0   0.11   0.03   0.06   0.01   0.02   0.00   0.04   0.01   0.24   0.07  0.05
# 1   0.13   0.03   0.06   0.01   0.04   0.01   0.05   0.00   0.07   0.08  0.04
# 2   0.14   0.02   0.07   0.01   0.06   0.00   0.02   0.01   0.46   0.05  0.05
# 3   0.09   0.03   0.05   0.00   0.03   0.00   0.08   0.00   0.64   0.05  0.03
# 4   0.15   0.03   0.05   0.01   0.05   0.01   0.02   0.01   0.59   0.06  0.09
#
#   class
# 0    FH
# 1    FH
# 2    FH
# 3    FH
# 4    FH

# %% [markdown]
# ### Filter for known data bedrock data for training the model

# %%
train_data = my_data[(my_data['Geology']== 'Bedrock') | (my_data['Geology'] == 'Superficial')]
test_data = my_data[my_data['Geology']=='Artefacts']

# %% [markdown]
# ### label encode the class to be predicted

# %%
train_data_formodel = train_data.copy(deep = True)
train_data_formodel['class'], uniques = pd.factorize(train_data_formodel['class'])

# %% [markdown]
# ### order of class labels as numbers 0 through 20

# %%
print(uniques)
# Out:
# Index(['FH', 'ER', 'WW', 'TC', 'CS', 'BC', 'KQ', 'AR', 'SL', 'FG', 'WB', 'BX',
#        'PF', 'BM', 'WH', 'SQ', 'BP', 'WN', 'BH', 'PH', 'LB', 'AB', 'LV', 'SE',
#        'BA', 'SV', 'WA', 'MM'],
#       dtype='object')

# %%
# %store train_data_formodel
# %store train_data
# %store test_data
# %store my_data
# %store uniques
# Out:
# Stored 'train_data_formodel' (DataFrame)
# Stored 'train_data' (DataFrame)
# Stored 'test_data' (DataFrame)
# Stored 'my_data' (DataFrame)
# Stored 'uniques' (Index)

# %%
train_data_bedrock = train_data[train_data['Geology'] == 'Bedrock']
train_data_superficial = train_data[train_data['Geology'] == 'Superficial']

# %%
train_data_bedrock.columns.values[9:-1]
# Out:
# array(['Li7', 'Be9', 'B11', 'Mg24', 'Al27', 'Si28', 'P31', 'S33', 'K39',
#        'Ca42', 'Sc45', 'Ti47', 'V51', 'Cr52', 'Mn55', 'Fe56', 'Co59',
#        'Ni60', 'Cu63', 'Zn68', 'Ga69', 'Ge72', 'As75', 'Rb85', 'Sr88',
#        'Y89', 'Zr90', 'Nb93', 'Mo95', 'Cd111', 'In115', 'Sn118', 'Cs133',
#        'Ba137', 'La139', 'Ce140', 'Pr141', 'Nd146', 'Sm147', 'Eu153',
#        'Gd157', 'Tb159', 'Dy163', 'Ho165', 'Er166', 'Tm169', 'Yb172',
#        'Lu175', 'Hf178', 'Ta181', 'Pb208', 'Th232', 'U238'], dtype=object)

# %%
element_data_train = train_data[train_data.columns.values[9:-1]]
element_data_train_bedrock = train_data_bedrock[train_data.columns.values[9:-1]]
element_data_train_superficial = train_data_superficial[train_data.columns.values[9:-1]]
element_data_test = test_data[test_data.columns.values[9:-1]]

# %%
my_scaler_train = StandardScaler()
my_scaler_train_bedrock = StandardScaler()
my_scaler_train_superficial = StandardScaler()
my_scaler_test = StandardScaler()

# %%
element_data_train_scaled = my_scaler_train.fit_transform(element_data_train)
element_data_train_bedrock_scaled = my_scaler_train_bedrock.fit_transform(element_data_train_bedrock)
element_data_train_superficial_scaled = my_scaler_train_superficial.fit_transform(element_data_train_superficial)
element_data_test_scaled = my_scaler_test.fit_transform(element_data_test)

# %%
my_pca_train = PCA(n_components=element_data_train_scaled.shape[1])

my_pca_train_bedrock = PCA(n_components=element_data_train_bedrock_scaled.shape[1])
my_pca_train_superficial = PCA(n_components=element_data_train_superficial_scaled.shape[1])

my_pca_test = PCA(n_components=element_data_test_scaled.shape[1])

element_data_train_pca = my_pca_train.fit_transform(element_data_train_scaled)

element_data_train_bedrock_pca = my_pca_train_bedrock.fit_transform(element_data_train_bedrock_scaled)
element_data_train_superficial_pca = my_pca_train_superficial.fit_transform(element_data_train_superficial_scaled)

element_data_test_pca = my_pca_test.fit_transform(element_data_test_scaled)

# %%
no_PCs = element_data_train_scaled.shape[1]
PC_names = []
for i in range(0, no_PCs):
    number = i + 1
    column_name = 'PC' + str(number)
    PC_names.append(column_name)

# %%
PC_df_train = pd.DataFrame(data = element_data_train_pca, columns = PC_names)

PC_df_bedrock_train = pd.DataFrame(data = element_data_train_bedrock_pca, columns = PC_names)
PC_df_superficial_train = pd.DataFrame(data = element_data_train_superficial_pca, columns = PC_names)

PC_df_test = pd.DataFrame(data = element_data_test_pca, columns = PC_names)

# %%
my_tsne_train = TSNE(n_components=3, n_iter=750, verbose=3).fit_transform(element_data_train_scaled)

my_tsne_bedrock_train = TSNE(n_components=3, n_iter=750, verbose=3).fit_transform(element_data_train_bedrock_scaled)
my_tsne_superficial_train = TSNE(n_components=3, n_iter=750, verbose=3).fit_transform(element_data_train_superficial_scaled)

my_tsne_test = TSNE(n_components=3, n_iter=750, verbose=3).fit_transform(element_data_test_scaled)
# Out:
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 1243 samples in 0.003s...
# [t-SNE] Computed neighbors for 1243 samples in 0.296s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 1243
# [t-SNE] Computed conditional probabilities for sample 1243 / 1243
# [t-SNE] Mean sigma: 1.771276
# [t-SNE] Computed conditional probabilities in 0.105s
# [t-SNE] Iteration 50: error = 76.8285370, gradient norm = 0.0798455 (50 iterations in 8.038s)
# [t-SNE] Iteration 100: error = 78.4137955, gradient norm = 0.0700876 (50 iterations in 6.405s)
# [t-SNE] Iteration 150: error = 79.4278259, gradient norm = 0.0689119 (50 iterations in 5.193s)
# [t-SNE] Iteration 200: error = 80.1398849, gradient norm = 0.0455261 (50 iterations in 4.922s)
# [t-SNE] Iteration 250: error = 80.2874832, gradient norm = 0.0498382 (50 iterations in 4.796s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 80.287483
# [t-SNE] Iteration 300: error = 1.7874633, gradient norm = 0.0007194 (50 iterations in 5.267s)
# [t-SNE] Iteration 350: error = 1.5937893, gradient norm = 0.0003734 (50 iterations in 5.812s)
# [t-SNE] Iteration 400: error = 1.5236962, gradient norm = 0.0001658 (50 iterations in 5.930s)
# [t-SNE] Iteration 450: error = 1.4864085, gradient norm = 0.0001199 (50 iterations in 5.911s)
# [t-SNE] Iteration 500: error = 1.4266583, gradient norm = 0.0001246 (50 iterations in 5.900s)
# [t-SNE] Iteration 550: error = 1.3375677, gradient norm = 0.0002534 (50 iterations in 5.555s)
# [t-SNE] Iteration 600: error = 1.3070937, gradient norm = 0.0001226 (50 iterations in 5.686s)
# [t-SNE] Iteration 650: error = 1.2786771, gradient norm = 0.0001116 (50 iterations in 5.573s)
# [t-SNE] Iteration 700: error = 1.2370563, gradient norm = 0.0000850 (50 iterations in 5.720s)
# [t-SNE] Iteration 750: error = 1.2063473, gradient norm = 0.0001996 (50 iterations in 6.119s)
# [t-SNE] Error after 750 iterations: 1.206347
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 808 samples in 0.001s...
# [t-SNE] Computed neighbors for 808 samples in 0.119s...
# [t-SNE] Computed conditional probabilities for sample 808 / 808
# [t-SNE] Mean sigma: 1.875790
# [t-SNE] Computed conditional probabilities in 0.067s
# [t-SNE] Iteration 50: error = 79.6488495, gradient norm = 0.1859000 (50 iterations in 4.369s)
# [t-SNE] Iteration 100: error = 84.1915207, gradient norm = 0.1715606 (50 iterations in 4.058s)
# [t-SNE] Iteration 150: error = 87.2701492, gradient norm = 0.1819382 (50 iterations in 4.045s)
# [t-SNE] Iteration 200: error = 88.5604630, gradient norm = 0.1619702 (50 iterations in 3.952s)
# [t-SNE] Iteration 250: error = 89.8184052, gradient norm = 0.1509960 (50 iterations in 3.838s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 89.818405
# [t-SNE] Iteration 300: error = 2.5912964, gradient norm = 0.0006997 (50 iterations in 3.425s)
# [t-SNE] Iteration 350: error = 2.3199334, gradient norm = 0.0002985 (50 iterations in 3.696s)
# [t-SNE] Iteration 400: error = 2.1656575, gradient norm = 0.0001484 (50 iterations in 3.738s)
# [t-SNE] Iteration 450: error = 2.0473034, gradient norm = 0.0000968 (50 iterations in 3.770s)
# [t-SNE] Iteration 500: error = 1.9511211, gradient norm = 0.0000726 (50 iterations in 3.710s)
# [t-SNE] Iteration 550: error = 1.8778092, gradient norm = 0.0000566 (50 iterations in 3.683s)
# [t-SNE] Iteration 600: error = 1.8137074, gradient norm = 0.0000461 (50 iterations in 3.769s)
# [t-SNE] Iteration 650: error = 1.7536726, gradient norm = 0.0000409 (50 iterations in 3.826s)
# [t-SNE] Iteration 700: error = 1.7038082, gradient norm = 0.0000358 (50 iterations in 3.742s)
# [t-SNE] Iteration 750: error = 1.6618477, gradient norm = 0.0000352 (50 iterations in 3.720s)
# [t-SNE] Error after 750 iterations: 1.661848
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 435 samples in 0.001s...
# [t-SNE] Computed neighbors for 435 samples in 0.038s...
# [t-SNE] Computed conditional probabilities for sample 435 / 435
# [t-SNE] Mean sigma: 2.099944
# [t-SNE] Computed conditional probabilities in 0.038s
# [t-SNE] Iteration 50: error = 90.1245117, gradient norm = 0.2598430 (50 iterations in 1.780s)
# [t-SNE] Iteration 100: error = 103.9583130, gradient norm = 0.2462950 (50 iterations in 1.737s)
# [t-SNE] Iteration 150: error = 112.6053162, gradient norm = 0.2241735 (50 iterations in 1.681s)
# [t-SNE] Iteration 200: error = 115.6702576, gradient norm = 0.2030834 (50 iterations in 1.578s)
# [t-SNE] Iteration 250: error = 124.6509399, gradient norm = 0.1755460 (50 iterations in 1.593s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 124.650940
# [t-SNE] Iteration 300: error = 3.6525807, gradient norm = 0.0005886 (50 iterations in 2.030s)
# [t-SNE] Iteration 350: error = 3.1012416, gradient norm = 0.0002205 (50 iterations in 2.118s)
# [t-SNE] Iteration 400: error = 2.8227408, gradient norm = 0.0001269 (50 iterations in 2.147s)
# [t-SNE] Iteration 450: error = 2.6421452, gradient norm = 0.0000891 (50 iterations in 2.130s)
# [t-SNE] Iteration 500: error = 2.5063336, gradient norm = 0.0000654 (50 iterations in 2.142s)
# [t-SNE] Iteration 550: error = 2.4016747, gradient norm = 0.0000512 (50 iterations in 2.125s)
# [t-SNE] Iteration 600: error = 2.3161371, gradient norm = 0.0000429 (50 iterations in 2.159s)
# [t-SNE] Iteration 650: error = 2.2420950, gradient norm = 0.0000374 (50 iterations in 2.210s)
# [t-SNE] Iteration 700: error = 2.1759083, gradient norm = 0.0000311 (50 iterations in 2.152s)
# [t-SNE] Iteration 750: error = 2.1227999, gradient norm = 0.0000274 (50 iterations in 2.113s)
# [t-SNE] Error after 750 iterations: 2.122800
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 363 samples in 0.001s...
# [t-SNE] Computed neighbors for 363 samples in 0.030s...
# [t-SNE] Computed conditional probabilities for sample 363 / 363
# [t-SNE] Mean sigma: 2.333606
# [t-SNE] Computed conditional probabilities in 0.042s
# [t-SNE] Iteration 50: error = 88.8476944, gradient norm = 0.2929370 (50 iterations in 1.390s)
# [t-SNE] Iteration 100: error = 107.9099426, gradient norm = 0.2324124 (50 iterations in 1.395s)
# [t-SNE] Iteration 150: error = 116.6830139, gradient norm = 0.2079011 (50 iterations in 1.316s)
# [t-SNE] Iteration 200: error = 125.0437317, gradient norm = 0.1950760 (50 iterations in 1.295s)
# [t-SNE] Iteration 250: error = 130.6161041, gradient norm = 0.1810326 (50 iterations in 1.298s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 130.616104
# [t-SNE] Iteration 300: error = 3.6782854, gradient norm = 0.0005293 (50 iterations in 1.445s)
# [t-SNE] Iteration 350: error = 3.1265671, gradient norm = 0.0002137 (50 iterations in 1.478s)
# [t-SNE] Iteration 400: error = 2.8371615, gradient norm = 0.0001239 (50 iterations in 1.477s)
# [t-SNE] Iteration 450: error = 2.6289978, gradient norm = 0.0000878 (50 iterations in 1.466s)
# [t-SNE] Iteration 500: error = 2.4802794, gradient norm = 0.0000658 (50 iterations in 1.484s)
# [t-SNE] Iteration 550: error = 2.3630624, gradient norm = 0.0000540 (50 iterations in 1.490s)
# [t-SNE] Iteration 600: error = 2.2800808, gradient norm = 0.0000421 (50 iterations in 1.505s)
# [t-SNE] Iteration 650: error = 2.2105219, gradient norm = 0.0000359 (50 iterations in 1.537s)
# [t-SNE] Iteration 700: error = 2.1479864, gradient norm = 0.0000318 (50 iterations in 1.519s)
# [t-SNE] Iteration 750: error = 2.0962958, gradient norm = 0.0000263 (50 iterations in 1.513s)
# [t-SNE] Error after 750 iterations: 2.096296

# %%
tsne_df_train = pd.DataFrame(data = my_tsne_train, columns = ['tsne1', 'tsne2', 'tsne3'])

tsne_df_bedrock_train = pd.DataFrame(data = my_tsne_bedrock_train, columns = ['tsne1', 'tsne2', 'tsne3'])
tsne_df_superficial_train = pd.DataFrame(data = my_tsne_superficial_train, columns = ['tsne1', 'tsne2', 'tsne3'])

tsne_df_test = pd.DataFrame(data = my_tsne_test, columns = ['tsne1', 'tsne2', 'tsne3'])

# %%
# %store PC_df_train
# %store my_pca_train

# %store PC_df_bedrock_train
# %store my_pca_train_bedrock

# %store PC_df_superficial_train
# %store my_pca_train_superficial

# %store PC_df_test
# %store my_pca_test

# %store tsne_df_train

# %store tsne_df_bedrock_train
# %store tsne_df_superficial_train


# %store tsne_df_test
# Out:
# Stored 'PC_df_train' (DataFrame)
# Stored 'my_pca_train' (PCA)
# Stored 'PC_df_bedrock_train' (DataFrame)
# Stored 'my_pca_train_bedrock' (PCA)
# Stored 'PC_df_superficial_train' (DataFrame)
# Stored 'my_pca_train_superficial' (PCA)
# Stored 'PC_df_test' (DataFrame)
# Stored 'my_pca_test' (PCA)
# Stored 'tsne_df_train' (DataFrame)
# Stored 'tsne_df_bedrock_train' (DataFrame)
# Stored 'tsne_df_superficial_train' (DataFrame)
# Stored 'tsne_df_test' (DataFrame)

# %%
import pandas as pd
# %store -r tsne_df_train
tsne_df_train.to_csv('tsne_df_train.csv', index = False)
# %store -r tsne_df_test
tsne_df_test.to_csv('tsne_df_test.csv', index=False)

# %store -r PC_df_train
PC_df_train.to_csv(' PC_df_train.csv', index=False)
# %store -r PC_df_test
PC_df_test.to_csv('PC_df_test.csv', index=False)
