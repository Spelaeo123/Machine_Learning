# %% [markdown]
# # Visualisations

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
from config_and_dependencies.config import *

# %% [markdown]
# ## Load Data

# %%
# %store -r mydata
# %store -r MintCol_RefCol_PCAs 
#MINT
# %store -r tsne_df_MintCol_comb 
#MINT

# %store -r EmpCol_RefCol_PCAs 
#EMPEROR
# %store -r tsne_df_EmpCol_comb 
#EMPEROR

# %% [markdown]
# ## Save Plot switch

# %%
save_plots = True

# %% [markdown]
# ## Boxplots

# %%
filepath = 'Figures/Boxplots/{}.png'

# %%
for column in mydata.columns[features_start:features_end]:  # Loop over all columns
    sns.set()
    fig, ax = plt.subplots()
    sns.set(style="ticks")
    sns.boxplot(x='MINT', y=column, data=mydata)  # column is chosen here
    sns.despine(offset=10, trim=True) 
    fig.set_size_inches(22,14)

    if save_plots == True:
        plt.savefig(fname=filepath.format(column), bbox_inches='tight')  # filename chosen here

# %% [markdown]
# ## PCA Visualisation

# %%
filepath = 'Figures/Butcher2005_Denarii_Tom_PCA_Emperor.png'

# %%
my_pallete = ['#e6194b', '#3cb44b', '#ffe119', '#4363d8', '#f58231', '#911eb4', '#46f0f0', '#f032e6', '#bcf60c', '#fabebe', '#008080', '#9a6324', '#fffac8', '#800000', '#aaffc3', '#808000', '#ffd8b1', '#000075', '#808080', '#000000']

# %%
sns.set(rc={'figure.figsize':(10,10)})
sns.set_palette(sns.color_palette(my_pallete, 19))

plot_on_x = 'PC1'
plot_on_y = 'PC2'

plot = sns.scatterplot(data = EmpCol_RefCol_PCAs, linewidth = 0.3, edgecolor = 'black', s= 5, x = plot_on_x, y = plot_on_y, hue='EMPEROR',
                #palette=sns.color_palette("colorblind", tsne_data_with_colour['class'].nunique())
                      )

plt.title('PCA Plot of Coins by Emperor', fontsize = 10)

plt.yticks(fontsize = 5)
plt.xticks(fontsize = 5)

plot.set_xlabel('PC1',fontsize=7)
plot.set_ylabel('PC2',fontsize=7)


plt.legend(fontsize=7, markerscale=0.5, bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

if save_plots == True:
    fig = plot.get_figure()
    fig.savefig(fname=filepath, dpi = 2000, pad_inches = 0.5, bbox_extra_artists=(plot,), bbox_inches='tight')

# %% [markdown]
# ## t-SNE Visualisation

# %%
#filepath = 'Figure/Coin_tsne.eps'
filepath = 'Figures/Butcher2005_Denarii_Tom_tsne_Emperor.png'

# %%
my_pallete = ['#e6194b', '#3cb44b', '#ffe119', '#4363d8', '#f58231', '#911eb4', '#46f0f0', '#f032e6', '#bcf60c', '#fabebe', '#008080', '#9a6324', '#fffac8', '#800000', '#aaffc3', '#808000', '#ffd8b1', '#000075', '#808080', '#000000']

# %%
sns.set(rc={'figure.figsize':(15,15)})
sns.set_palette(sns.color_palette(my_pallete, 14))

plot_on_x = 'tsne1'
plot_on_y = 'tsne2'

plot = sns.scatterplot(data = tsne_df_EmpCol_comb, linewidth = 0.3, edgecolor = '', s= 20, x = plot_on_x, y = plot_on_y, hue='EMPEROR',
                #palette=sns.color_palette("colorblind", tsne_data_with_colour['class'].nunique())
                      )

plt.title('t-SNE Analysis of Coins by Emperor', fontsize = 10)

plt.yticks(fontsize = 10)
plt.xticks(fontsize = 10)

plot.set_xlabel('tSNE1',fontsize=10)
plot.set_ylabel('tSNE2',fontsize=10)


plt.legend(fontsize=10, markerscale=0.5, bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)


fig = plot.get_figure()
fig.savefig(fname=filepath, dpi = 2000, pad_inches = 0.5, bbox_extra_artists=(plot,), bbox_inches='tight')
