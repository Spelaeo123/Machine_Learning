# %% [markdown]
# # Import libraries

# %%
# Import pandas, numpy, seabon, sklearn, pyplot
import pandas as pd
import numpy as np
import seaborn as sns
import sklearn as sk
import swifter

from matplotlib import pyplot as plt
from sklearn.decomposition import PCA
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.cluster import KMeans

pd.set_option('max.rows', None)
pd.set_option('max.columns', None)

# %matplotlib inline

# %%
from config_and_dependencies.config import *

# %% [markdown]
# # Import Data

# %%
mydata = pd.read_csv(data_input_path)

# %%
mydata.head()
# Out:
#       REF DENOMINATION                     OBVERSE  \
# 0   BCC10     denarius      CAESAR VESPASIANVS AVG
# 1   BCC11     denarius    T CAESAR IMP VESPASIANVS
# 2   BCC12     denarius  T CAESAR IMP VESPAS[IANVS]
# 3   BCC13     denarius    T CAESAR IMP VESPASIANVS
# 4  BCC137     denarius   IMP NERO CAESAR AVGVSTVS
#
#                            REVERSE  MINT    EMPEROR      NAMED  ARSENIC  \
# 0                     AN[NONA AVG]  Rome  Vespasian  Vespasian    0.003
# 1                  COS VI  , Mars.  Rome  Vespasian      Titus    0.003
# 2  TR POT VIII [COS VII] , trophy.  Rome  Vespasian      Titus    0.002
# 3                     IOVIS CVSTOS  Rome  Vespasian      Titus    0.011
# 4                  IVPPITER CVSTOS  Rome       Nero       Nero    0.003
#
#     GOLD  COPPER   IRON  NICKEL  LEAD  ANTIMONY     TIN    ZINC  MANGANESE  \
# 0  0.378   20.60  0.014   0.001  0.59     0.001  0.0023  0.0106    0.00007
# ...

# %%
sns.set(rc={'figure.figsize':(50,10)})
sns.countplot(mydata['MINT'])

# %% [markdown]
# # Descriptive Statistics

# %%
mydata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 728 entries, 0 to 727
# Data columns (total 27 columns):
# REF             728 non-null object
# DENOMINATION    728 non-null object
# OBVERSE         728 non-null object
# REVERSE         728 non-null object
# MINT            728 non-null object
# EMPEROR         728 non-null object
# NAMED           728 non-null object
# ARSENIC         728 non-null float64
# GOLD            728 non-null float64
# COPPER          728 non-null float64
# IRON            728 non-null float64
# NICKEL          728 non-null float64
# LEAD            728 non-null float64
# ANTIMONY        728 non-null float64
# TIN             728 non-null float64
# ZINC            728 non-null float64
# MANGANESE       728 non-null float64
# CHROMIUM        728 non-null float64
# COBALT          728 non-null float64
# BISMUTH         728 non-null float64
# SILVER          728 non-null float64
# BULLION         728 non-null float64
# ...

# %%
mydata.describe()
# Out:
#           ARSENIC        GOLD      COPPER        IRON      NICKEL        LEAD  \
# count  728.000000  728.000000  728.000000  728.000000  728.000000  728.000000
# mean     0.010192    0.485988   13.964437    0.017015    0.002374    0.517981
# std      0.008824    0.219025   10.665988    0.106985    0.015178    0.275122
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.005000    0.362000    6.467500    0.005000    0.000000    0.340000
# 50%      0.008000    0.486000   13.845000    0.009000    0.001000    0.460000
# 75%      0.013000    0.611000   21.165000    0.014000    0.002000    0.620000
# max      0.119000    1.810000   99.700000    2.831000    0.401000    1.770000
#
#          ANTIMONY         TIN        ZINC   MANGANESE    CHROMIUM      COBALT  \
# count  728.000000  728.000000  728.000000  728.000000  728.000000  728.000000
# mean     0.031282    0.101236    0.015680    0.000258    0.001256    0.012907
# ...

# %%
mydata.nunique()
# Out:
# REF             728
# DENOMINATION      1
# OBVERSE         299
# REVERSE         398
# MINT             14
# EMPEROR          14
# NAMED            17
# ARSENIC          40
# GOLD            437
# COPPER          606
# IRON             58
# NICKEL           20
# LEAD            126
# ANTIMONY         41
# TIN             228
# ZINC            150
# MANGANESE        93
# CHROMIUM        132
# COBALT          101
# BISMUTH         120
# SILVER          619
# BULLION         602
# Unnamed: 22      42
# Unnamed: 23      13
# Unnamed: 24      46
# Unnamed: 25       4
# Unnamed: 26       6
# dtype: int64

# %% [markdown]
# ## CONVERT REF TO NUMBERS FOR PCA COLOUR

# %%
#REFuniques = print(mydata['REF'].unique())

# %%
Ref = pd.Series(mydata['REF'].unique())

# %%
REFuniquesNewcolumn = Ref.to_frame().reset_index()

# %%
#rename column names

# %%
ToDF = pd.DataFrame(REFuniquesNewcolumn)

# %%
ToDF.columns = ['number', 'REFname']

# %%
#convert two columns to dictionary

# %%
REFdict = pd.Series(ToDF.REFname.values,index=ToDF.number).to_dict()

# %% [markdown]
# ## CONVERT MINT TO NUMBERS FOR PCA COLOURS

# %%
#MINTuniques = print(mydata['MINT'].unique())

# %%
mintuniques = pd.Series(mydata['MINT'].unique())

# %%
print(mintuniques)
# Out:
# 0              Rome
# 1           Spanish
# 2              Gaul
# 3     Gaul or Spain
# 4                 ?
# 5              Lyon
# 6               UG3
# 7           Ephesus
# 8            O mint
# 9           Antioch
# 10              UG5
# 11         Carthage
# 12          Tarraco
# 13           Antony
# dtype: object

# %%
MintuniquesNewcolumn = mintuniques.to_frame().reset_index()

# %%
MintToDF = pd.DataFrame(MintuniquesNewcolumn)

# %%
MintToDF.columns = ['number', 'MINTname']

# %%
#convert two columns to dictionary

# %%
MINTdict = pd.Series(MintToDF.MINTname.values,index=MintToDF.number).to_dict()

# %% [markdown]
# # PCA

# %%
#Colour variables
colour_byREF = REFdict
colour_byMint = MINTdict

# %%
my_pallete = ['#e6194b', '#3cb44b', '#ffe119', '#4363d8', '#f58231', '#911eb4', '#46f0f0', '#f032e6', '#bcf60c', '#fabebe', '#008080', '#9a6324', '#fffac8', '#800000', '#aaffc3', '#808000', '#ffd8b1', '#000075', '#808080', '#000000']

# %%
df = mydata.iloc[:,features_start:features_end]

# %%
df.head()
# Out:
#    ARSENIC   GOLD  COPPER   IRON  NICKEL  LEAD  ANTIMONY     TIN    ZINC  \
# 0    0.003  0.378   20.60  0.014   0.001  0.59     0.001  0.0023  0.0106
# 1    0.003  0.377   22.99  0.008   0.002  0.63     0.008  0.0270  0.2527
# 2    0.002  0.631   19.30  0.006   0.001  0.46     0.005  0.0010  0.0001
# 3    0.011  0.599   17.08  0.004   0.003  0.29     0.015  0.0009  0.0003
# 4    0.003  0.395    9.60  0.004   0.001  1.09     0.004  0.0013  0.0010
#
#    MANGANESE  CHROMIUM  COBALT  BISMUTH  SILVER
# 0    0.00007   0.00005  0.0001    0.009   78.40
# 1    0.00008   0.00005  0.0001    0.021   75.68
# 2    0.00014   0.00004  0.0003    0.000   79.59
# 3    0.00031   0.00004  0.0004    0.000   84.31
# 4    0.00014   0.00006  0.0001    0.029   88.87

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
scaler.fit(df)
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
scaled_data = scaler.transform(df)

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=2)

# %%
pca.fit(scaled_data)
# Out:
# PCA(copy=True, iterated_power='auto', n_components=2, random_state=None,
#     svd_solver='auto', tol=0.0, whiten=False)

# %%
x_pca = pca.transform(scaled_data)

# %%
print(x_pca)
# Out:
# [[ 0.15106404 -0.75396927]
#  [ 0.72741831 -0.61123278]
#  [-0.12379566 -0.74972592]
#  ...
#  [-1.7123046   1.62097051]
#  [-1.77846882  0.75219866]
#  [-1.82186992  1.31223412]]

# %%
scaled_data.shape
# Out:
# (728, 14)

# %%
x_pca.shape
# Out:
# (728, 2)

# %%
RefCol = pd.DataFrame(data=mydata['REF'])

# %%
RefCol.head()
# Out:
#       REF
# 0   BCC10
# 1   BCC11
# 2   BCC12
# 3   BCC13
# 4  BCC137

# %%
PCA_DF = pd.DataFrame(data=x_pca)

# %%
PCA_DF.head()
# Out:
#           0         1
# 0  0.151064 -0.753969
# 1  0.727418 -0.611233
# 2 -0.123796 -0.749726
# 3  0.060679 -0.342653
# 4 -0.467541 -0.174327

# %%
MintCol = mydata['MINT']

# %%
# %store MintCol
# Out:
# Stored 'MintCol' (Series)

# %%
MintCol_RefCol_PCAs = pd.concat([MintCol, RefCol, PCA_DF], axis=1)

# %%
MintCol_RefCol_PCAs.head()
# Out:
#    MINT     REF         0         1
# 0  Rome   BCC10  0.151064 -0.753969
# 1  Rome   BCC11  0.727418 -0.611233
# 2  Rome   BCC12 -0.123796 -0.749726
# 3  Rome   BCC13  0.060679 -0.342653
# 4  Rome  BCC137 -0.467541 -0.174327

# %%
MintCol_RefCol_PCAs.columns = ['MINT', 'REF', 'PC1', 'PC2']

# %%
MintCol_RefCol_PCAs.head()
# Out:
#    MINT     REF       PC1       PC2
# 0  Rome   BCC10  0.151064 -0.753969
# 1  Rome   BCC11  0.727418 -0.611233
# 2  Rome   BCC12 -0.123796 -0.749726
# 3  Rome   BCC13  0.060679 -0.342653
# 4  Rome  BCC137 -0.467541 -0.174327

# %%
filepath = 'Figure/Butcher2005_Denarii_Tom_PCA.png'

# %%
my_pallete = ['#e6194b', '#3cb44b', '#ffe119', '#4363d8', '#f58231', '#911eb4', '#46f0f0', '#f032e6', '#bcf60c', '#fabebe', '#008080', '#9a6324', '#fffac8', '#800000', '#aaffc3', '#808000', '#ffd8b1', '#000075', '#808080', '#000000']

# %%
sns.set(rc={'figure.figsize':(15,15)})
sns.set_palette(sns.color_palette(my_pallete, 14))

plot_on_x = 'PC1'
plot_on_y = 'PC2'

plot = sns.scatterplot(data = MintCol_RefCol_PCAs, linewidth = 0.3, edgecolor = '', s= 5, x = plot_on_x, y = plot_on_y, hue='MINT',
                #palette=sns.color_palette("colorblind", tsne_data_with_colour['class'].nunique())
                                             )

plt.title('PCA Analysis of Coins', fontsize = 10)

plt.yticks(fontsize = 5)
plt.xticks(fontsize = 5)

plot.set_xlabel('PC1',fontsize=7)
plot.set_ylabel('PC2',fontsize=7)


plt.legend(fontsize=7, markerscale=0.5, bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)


fig = plot.get_figure()
fig.savefig(fname=filepath, dpi = 2000, pad_inches = 0.5, bbox_extra_artists=(plot,), bbox_inches='tight')

# %% [markdown]
# # tSNE

# %%
from sklearn.manifold import TSNE

# %%
test_data = mydata.iloc[:,features_start:features_end]

# %%
test_data.head()
# Out:
#    ARSENIC   GOLD  COPPER   IRON  NICKEL  LEAD  ANTIMONY     TIN    ZINC  \
# 0    0.003  0.378   20.60  0.014   0.001  0.59     0.001  0.0023  0.0106
# 1    0.003  0.377   22.99  0.008   0.002  0.63     0.008  0.0270  0.2527
# 2    0.002  0.631   19.30  0.006   0.001  0.46     0.005  0.0010  0.0001
# 3    0.011  0.599   17.08  0.004   0.003  0.29     0.015  0.0009  0.0003
# 4    0.003  0.395    9.60  0.004   0.001  1.09     0.004  0.0013  0.0010
#
#    MANGANESE  CHROMIUM  COBALT  BISMUTH  SILVER
# 0    0.00007   0.00005  0.0001    0.009   78.40
# 1    0.00008   0.00005  0.0001    0.021   75.68
# 2    0.00014   0.00004  0.0003    0.000   79.59
# 3    0.00031   0.00004  0.0004    0.000   84.31
# 4    0.00014   0.00006  0.0001    0.029   88.87

# %%
# %store test_data
# Out:
# Stored 'test_data' (DataFrame)

# %%
#element_data_test = test_data[test_data.columns.values[features_start:features_end]]

# %%
#element_data_test.head()

# %%
my_scaler_test = StandardScaler()

# %%
#element_data_test_scaled = my_scaler_test.fit_transform(element_data_test)
element_data_test_scaled = my_scaler_test.fit_transform(test_data)

# %%
print(element_data_test_scaled)
# Out:
# [[-0.81562572 -0.49337633  0.62255133 ... -0.19601555 -0.48367169
#   -0.59419928]
#  [-0.81562572 -0.49794515  0.84678214 ... -0.19601555 -0.18713468
#   -0.84308867]
#  [-0.92902822  0.66253572  0.50058478 ... -0.19295458 -0.70607445
#   -0.48531017]
#  ...
#  [-0.36201569  2.11999003 -1.29419987 ... -0.19448507  2.40756418
#    1.25325541]
#  [-0.4754182   4.62370465 -1.30545832 ... -0.18989361  0.25767084
#    1.22854947]
#  [-0.36201569  3.81959193 -1.30545832 ... -0.1914241   1.71564449
#    1.23952989]]

# %%
my_tsne_test = TSNE(n_components=2, perplexity=25, learning_rate=200, n_iter=2000, verbose=3).fit_transform(element_data_test_scaled)
# Out:
# [t-SNE] Computing 76 nearest neighbors...
# [t-SNE] Indexed 728 samples in 0.008s...
# [t-SNE] Computed neighbors for 728 samples in 0.037s...
# [t-SNE] Computed conditional probabilities for sample 728 / 728
# [t-SNE] Mean sigma: 0.549050
# [t-SNE] Computed conditional probabilities in 0.037s
# [t-SNE] Iteration 50: error = 67.6899109, gradient norm = 0.4180031 (50 iterations in 0.263s)
# [t-SNE] Iteration 100: error = 67.1895142, gradient norm = 0.4056914 (50 iterations in 0.273s)
# [t-SNE] Iteration 150: error = 66.9942474, gradient norm = 0.3953414 (50 iterations in 0.248s)
# [t-SNE] Iteration 200: error = 66.8886337, gradient norm = 0.3956429 (50 iterations in 0.276s)
# [t-SNE] Iteration 250: error = 66.1966019, gradient norm = 0.4114038 (50 iterations in 0.264s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 66.196602
# [t-SNE] Iteration 300: error = 0.8848544, gradient norm = 0.0011771 (50 iterations in 0.179s)
# ...

# %%
tsne_df_test = pd.DataFrame(data = my_tsne_test, columns = ['tsne1', 'tsne2'])#, 'tsne3'])

# %%
tsne_df_test.head()
# Out:
#        tsne1      tsne2
# 0   3.976002  36.942032
# 1   4.016318  42.062733
# 2  23.789398  -3.031699
# 3  30.830019   7.400479
# 4 -29.772011   2.835665

# %%
#Add MINT back in

# %%
MintCol = mydata['MINT']

# %%
tsne_df_comb = pd.concat([tsne_df_test, MintCol], axis=1)

# %%
tsne_df_comb.head()
# Out:
#        tsne1      tsne2  MINT
# 0   3.976002  36.942032  Rome
# 1   4.016318  42.062733  Rome
# 2  23.789398  -3.031699  Rome
# 3  30.830019   7.400479  Rome
# 4 -29.772011   2.835665  Rome

# %%
#filepath = 'Figure/Coin_tsne.eps'
filepath = 'Figure/Butcher2005_Denarii_Tom_tsne.png'

# %%
my_pallete = ['#e6194b', '#3cb44b', '#ffe119', '#4363d8', '#f58231', '#911eb4', '#46f0f0', '#f032e6', '#bcf60c', '#fabebe', '#008080', '#9a6324', '#fffac8', '#800000', '#aaffc3', '#808000', '#ffd8b1', '#000075', '#808080', '#000000']

# %%
sns.set(rc={'figure.figsize':(15,15)})
sns.set_palette(sns.color_palette(my_pallete, 14))

plot_on_x = 'tsne1'
plot_on_y = 'tsne2'

plot = sns.scatterplot(data = tsne_df_comb, linewidth = 0.3, edgecolor = '', s= 20, x = plot_on_x, y = plot_on_y, hue='MINT',
                #palette=sns.color_palette("colorblind", tsne_data_with_colour['class'].nunique())
                      )

plt.title('t-SNE Analysis of Coins', fontsize = 10)

plt.yticks(fontsize = 10)
plt.xticks(fontsize = 10)

plot.set_xlabel('tSNE1',fontsize=10)
plot.set_ylabel('tSNE2',fontsize=10)


plt.legend(fontsize=10, markerscale=0.5, bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)


fig = plot.get_figure()
fig.savefig(fname=filepath, dpi = 2000, pad_inches = 0.5, bbox_extra_artists=(plot,), bbox_inches='tight')

# %% [markdown]
# # KMeans

# %%
df = test_data

# %%
df.head()
# Out:
#    ARSENIC   GOLD  COPPER   IRON  NICKEL  LEAD  ANTIMONY     TIN    ZINC  \
# 0    0.003  0.378   20.60  0.014   0.001  0.59     0.001  0.0023  0.0106
# 1    0.003  0.377   22.99  0.008   0.002  0.63     0.008  0.0270  0.2527
# 2    0.002  0.631   19.30  0.006   0.001  0.46     0.005  0.0010  0.0001
# 3    0.011  0.599   17.08  0.004   0.003  0.29     0.015  0.0009  0.0003
# 4    0.003  0.395    9.60  0.004   0.001  1.09     0.004  0.0013  0.0010
#
#    MANGANESE  CHROMIUM  COBALT  BISMUTH  SILVER
# 0    0.00007   0.00005  0.0001    0.009   78.40
# 1    0.00008   0.00005  0.0001    0.021   75.68
# 2    0.00014   0.00004  0.0003    0.000   79.59
# 3    0.00031   0.00004  0.0004    0.000   84.31
# 4    0.00014   0.00006  0.0001    0.029   88.87

# %%
from sklearn.cluster import KMeans, SpectralClustering

# %%
# Standardize the data
X_std = StandardScaler().fit_transform(df)

# %%
print(X_std[1])
# Out:
# [-0.81562572 -0.49794515  0.84678214 -0.08432335 -0.02463367  0.40744209
#  -0.03818781 -0.03075679  1.17988416 -0.16830846 -0.06685095 -0.19601555
#  -0.18713468 -0.84308867]

# %%
# Run local implementation of kmeans
km = KMeans(n_clusters=14, max_iter=300)
km.fit(X_std)
centroids = km.cluster_centers_
y_kmeans = km.predict(X_std)
kmeans.labels_

# Plot the clustered data
fig, ax = plt.subplots(figsize=(10, 10))

plt.scatter(X_std[:,0], X_std[:,9], c=y_kmeans, cmap='viridis', label='cluster')
#plt.scatter(X_std[:,2], X_std[:,3], c='blue', label='cluster 2')
#plt.scatter(centroids[:, 12], centroids[:, 9], marker='*', s=300, c='r', label='centroid')

plt.legend()
plt.xlim([-2, 2])
plt.ylim([-2, 2])
plt.xlabel('SILVER')
plt.ylabel('CHROMIUM')
plt.title('Visualization of clustered data', fontweight='bold')
ax.set_aspect('equal');
