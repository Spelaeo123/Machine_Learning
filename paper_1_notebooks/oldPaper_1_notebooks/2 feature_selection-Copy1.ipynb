# %% [markdown]
# # Feature selection

# %%
import pandas as pd
import numpy as np
import swifter
import seaborn as sns
import matplotlib.pyplot

pd.set_option('max.rows', None)
pd.set_option('max.columns', None)

from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.feature_selection import VarianceThreshold, RFECV
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import f1_score
# %matplotlib inline

# %% [markdown]
# ### load datasets

# %%
# %store -r train_data_formodel
data = train_data_formodel
# %store -r test_data
# %store -r my_data
# %store -r uniques

# %% [markdown]
# ## configurations
# * random_seed_state ->
# random_seed_state -> number, sets random state for model and for stratified splits

# %%
random_seed_state = 42

# %% [markdown]
# # RFE, this isnt working yet, rankings all came out as 1

# %%
data.head()
# Out:
#      Analysis  Geology  Province Region Site SubSite Formation Band   Nodule  \
# 0  10_FH1_1_1  Bedrock  Northern    NaN   FH     FH1   Burnham  FH1  FH1_1_1
# 1  11_FH1_1_1  Bedrock  Northern    NaN   FH     FH1   Burnham  FH1  FH1_1_1
# 2  12_FH1_1_1  Bedrock  Northern    NaN   FH     FH1   Burnham  FH1  FH1_1_1
# 3  13_FH1_1_2  Bedrock  Northern    NaN   FH     FH1   Burnham  FH1  FH1_1_2
# 4  14_FH1_1_2  Bedrock  Northern    NaN   FH     FH1   Burnham  FH1  FH1_1_2
#
#      Li7   Be9    B11       Mg24     Al27           Si28          P31  \
# 0  15.63  0.12  48.36  33.658126   943.71  464944.180000    50.280000
# 1  11.50  0.09  44.77  33.658126  1077.11  465010.940000    70.910000
# 2  20.05  0.06  44.88  42.700000   620.21  465295.410000   104.470000
# 3  11.16  0.73  47.06  33.658126  1143.19  462214.304116  2386.415832
# 4  17.71  0.32  48.26  33.520000   547.22  465027.110000    44.440000
#
#        S33     K39     Ca42  Sc45   Ti47   V51    Cr52  Mn55    Fe56  Co59  \
# 0   538.57  455.94   712.39  0.42  15.58  0.27    3.30  0.69    8.46  0.05
# 1   438.20  387.82   515.24  0.44  18.47  0.29    3.45  1.01   11.59  0.11
# 2   372.66  363.71   957.89  0.76  19.89  0.55    3.25  1.21   87.99  0.21
# 3  1075.89  547.55  2174.30  0.43  42.30  0.67  152.42  4.84  145.34  0.30
# 4   464.78  278.25  1551.63  0.71  11.18  0.27    2.56  1.73   25.38  0.05
#
#    Ni60  Cu63   Zn68  Ga69  Ge72  As75  Rb85   Sr88   Y89  Zr90  Nb93  Mo95  \
# 0  0.80  1.62  10.82  0.25  1.22  0.16  0.43  12.94  0.88  1.51  0.09  0.05
# 1  0.36  0.53   8.93  0.34  0.85  0.10  0.45  13.22  0.95  1.74  0.07  0.01
# 2  1.68  1.53  11.98  0.25  1.71  0.13  0.43   8.52  0.87  0.93  0.10  0.02
# 3  2.45  5.02  17.15  0.35  2.13  0.84  0.76  13.16  0.97  2.00  0.10  0.29
# 4  0.80  0.55   9.80  0.41  1.41  0.12  0.28   9.90  0.90  0.90  0.08  0.04
#
#    Cd111  In115  Sn118  Cs133  Ba137  La139  Ce140  Pr141  Nd146  Sm147  \
# 0   0.02   0.00   0.05   0.01   6.54   0.84   0.95   0.23   0.87   0.16
# 1   0.02   0.00   0.04   0.02   8.04   0.92   1.01   0.23   0.98   0.18
# 2   0.02   0.00   0.05   0.01   3.13   0.90   1.08   0.26   0.84   0.15
# 3   0.18   0.01   0.78   0.04   8.74   0.93   0.95   0.21   0.75   0.13
# 4   0.10   0.00   0.09   0.01   2.74   0.97   1.09   0.27   1.00   0.17
#
#    Eu153  Gd157  Tb159  Dy163  Ho165  Er166  Tm169  Yb172  Lu175  Hf178  \
# 0   0.04   0.16   0.02   0.11   0.03   0.06   0.01   0.02   0.00   0.04
# 1   0.04   0.18   0.02   0.13   0.03   0.06   0.01   0.04   0.01   0.05
# 2   0.04   0.19   0.02   0.14   0.02   0.07   0.01   0.06   0.00   0.02
# 3   0.04   0.25   0.02   0.09   0.03   0.05   0.00   0.03   0.00   0.08
# 4   0.04   0.19   0.02   0.15   0.03   0.05   0.01   0.05   0.01   0.02
#
#    Ta181  Pb208  Th232  U238  class
# 0   0.01   0.24   0.07  0.05      0
# 1   0.00   0.07   0.08  0.04      0
# 2   0.01   0.46   0.05  0.05      0
# 3   0.00   0.64   0.05  0.03      0
# 4   0.01   0.59   0.06  0.09      0

# %% [markdown]
# ### Recursive feature elimination with cross-validation is done using a random forest as the estimator

# %%
my_rfc = RandomForestClassifier(n_estimators=10, n_jobs=-1, random_state = random_seed_state)

# %%
my_rfc_selector = RFECV(estimator=my_rfc, step=1, cv=StratifiedKFold(3), verbose=2, scoring='f1_macro')

# %%
data.columns.values[9:-1]
# Out:
# array(['Li7', 'Be9', 'B11', 'Mg24', 'Al27', 'Si28', 'P31', 'S33', 'K39',
#        'Ca42', 'Sc45', 'Ti47', 'V51', 'Cr52', 'Mn55', 'Fe56', 'Co59',
#        'Ni60', 'Cu63', 'Zn68', 'Ga69', 'Ge72', 'As75', 'Rb85', 'Sr88',
#        'Y89', 'Zr90', 'Nb93', 'Mo95', 'Cd111', 'In115', 'Sn118', 'Cs133',
#        'Ba137', 'La139', 'Ce140', 'Pr141', 'Nd146', 'Sm147', 'Eu153',
#        'Gd157', 'Tb159', 'Dy163', 'Ho165', 'Er166', 'Tm169', 'Yb172',
#        'Lu175', 'Hf178', 'Ta181', 'Pb208', 'Th232', 'U238'], dtype=object)

# %% [markdown]
# data = pd.concat([data, tsne_dims_train, pca_dims_train[['PC1', 'PC2', 'PC3']]], axis = 1)

# %%
data.head()
# Out:
#      Analysis  Geology  Province Region Site SubSite Formation Band   Nodule  \
# 0  10_FH1_1_1  Bedrock  Northern    NaN   FH     FH1   Burnham  FH1  FH1_1_1
# 1  11_FH1_1_1  Bedrock  Northern    NaN   FH     FH1   Burnham  FH1  FH1_1_1
# 2  12_FH1_1_1  Bedrock  Northern    NaN   FH     FH1   Burnham  FH1  FH1_1_1
# 3  13_FH1_1_2  Bedrock  Northern    NaN   FH     FH1   Burnham  FH1  FH1_1_2
# 4  14_FH1_1_2  Bedrock  Northern    NaN   FH     FH1   Burnham  FH1  FH1_1_2
#
#      Li7   Be9    B11       Mg24     Al27           Si28          P31  \
# 0  15.63  0.12  48.36  33.658126   943.71  464944.180000    50.280000
# 1  11.50  0.09  44.77  33.658126  1077.11  465010.940000    70.910000
# 2  20.05  0.06  44.88  42.700000   620.21  465295.410000   104.470000
# 3  11.16  0.73  47.06  33.658126  1143.19  462214.304116  2386.415832
# 4  17.71  0.32  48.26  33.520000   547.22  465027.110000    44.440000
#
#        S33     K39     Ca42  Sc45   Ti47   V51    Cr52  Mn55    Fe56  Co59  \
# 0   538.57  455.94   712.39  0.42  15.58  0.27    3.30  0.69    8.46  0.05
# 1   438.20  387.82   515.24  0.44  18.47  0.29    3.45  1.01   11.59  0.11
# 2   372.66  363.71   957.89  0.76  19.89  0.55    3.25  1.21   87.99  0.21
# 3  1075.89  547.55  2174.30  0.43  42.30  0.67  152.42  4.84  145.34  0.30
# 4   464.78  278.25  1551.63  0.71  11.18  0.27    2.56  1.73   25.38  0.05
#
#    Ni60  Cu63   Zn68  Ga69  Ge72  As75  Rb85   Sr88   Y89  Zr90  Nb93  Mo95  \
# 0  0.80  1.62  10.82  0.25  1.22  0.16  0.43  12.94  0.88  1.51  0.09  0.05
# 1  0.36  0.53   8.93  0.34  0.85  0.10  0.45  13.22  0.95  1.74  0.07  0.01
# 2  1.68  1.53  11.98  0.25  1.71  0.13  0.43   8.52  0.87  0.93  0.10  0.02
# 3  2.45  5.02  17.15  0.35  2.13  0.84  0.76  13.16  0.97  2.00  0.10  0.29
# 4  0.80  0.55   9.80  0.41  1.41  0.12  0.28   9.90  0.90  0.90  0.08  0.04
#
#    Cd111  In115  Sn118  Cs133  Ba137  La139  Ce140  Pr141  Nd146  Sm147  \
# 0   0.02   0.00   0.05   0.01   6.54   0.84   0.95   0.23   0.87   0.16
# 1   0.02   0.00   0.04   0.02   8.04   0.92   1.01   0.23   0.98   0.18
# 2   0.02   0.00   0.05   0.01   3.13   0.90   1.08   0.26   0.84   0.15
# 3   0.18   0.01   0.78   0.04   8.74   0.93   0.95   0.21   0.75   0.13
# 4   0.10   0.00   0.09   0.01   2.74   0.97   1.09   0.27   1.00   0.17
#
#    Eu153  Gd157  Tb159  Dy163  Ho165  Er166  Tm169  Yb172  Lu175  Hf178  \
# 0   0.04   0.16   0.02   0.11   0.03   0.06   0.01   0.02   0.00   0.04
# 1   0.04   0.18   0.02   0.13   0.03   0.06   0.01   0.04   0.01   0.05
# 2   0.04   0.19   0.02   0.14   0.02   0.07   0.01   0.06   0.00   0.02
# 3   0.04   0.25   0.02   0.09   0.03   0.05   0.00   0.03   0.00   0.08
# 4   0.04   0.19   0.02   0.15   0.03   0.05   0.01   0.05   0.01   0.02
#
#    Ta181  Pb208  Th232  U238  class
# 0   0.01   0.24   0.07  0.05      0
# 1   0.00   0.07   0.08  0.04      0
# 2   0.01   0.46   0.05  0.05      0
# 3   0.00   0.64   0.05  0.03      0
# 4   0.01   0.59   0.06  0.09      0

# %%
X = data[data.columns.values[9:-1]]
y = data['class']

# %%
print(X.shape)
print(y.shape)
# Out:
# (1158, 53)
# (1158,)

# %%
selector = my_rfc_selector.fit(X, y)
# Out:
# Fitting estimator with 53 features.
# Fitting estimator with 52 features.
# Fitting estimator with 51 features.
# Fitting estimator with 50 features.
# Fitting estimator with 49 features.
# Fitting estimator with 48 features.
# Fitting estimator with 47 features.
# /home/rmorse/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Fitting estimator with 46 features.
# Fitting estimator with 45 features.
# Fitting estimator with 44 features.
# Fitting estimator with 43 features.
# Fitting estimator with 42 features.
# Fitting estimator with 41 features.
# Fitting estimator with 40 features.
# Fitting estimator with 39 features.
# Fitting estimator with 38 features.
# Fitting estimator with 37 features.
# Fitting estimator with 36 features.
# Fitting estimator with 35 features.
# Fitting estimator with 34 features.
# Fitting estimator with 33 features.
# Fitting estimator with 32 features.
# Fitting estimator with 31 features.
# Fitting estimator with 30 features.
# Fitting estimator with 29 features.
# Fitting estimator with 28 features.
# Fitting estimator with 27 features.
# Fitting estimator with 26 features.
# Fitting estimator with 25 features.
# Fitting estimator with 24 features.
# Fitting estimator with 23 features.
# Fitting estimator with 22 features.
# Fitting estimator with 21 features.
# Fitting estimator with 20 features.
# Fitting estimator with 19 features.
# Fitting estimator with 18 features.
# Fitting estimator with 17 features.
# Fitting estimator with 16 features.
# Fitting estimator with 15 features.
# Fitting estimator with 14 features.
# Fitting estimator with 13 features.
# Fitting estimator with 12 features.
# Fitting estimator with 11 features.
# Fitting estimator with 10 features.
# Fitting estimator with 9 features.
# Fitting estimator with 8 features.
# Fitting estimator with 7 features.
# Fitting estimator with 6 features.
# Fitting estimator with 5 features.
# Fitting estimator with 4 features.
# Fitting estimator with 3 features.
# Fitting estimator with 2 features.
# Fitting estimator with 53 features.
# Fitting estimator with 52 features.
# Fitting estimator with 51 features.
# Fitting estimator with 50 features.
# Fitting estimator with 49 features.
# Fitting estimator with 48 features.
# Fitting estimator with 47 features.
# Fitting estimator with 46 features.
# Fitting estimator with 45 features.
# Fitting estimator with 44 features.
# /home/rmorse/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Fitting estimator with 43 features.
# Fitting estimator with 42 features.
# Fitting estimator with 41 features.
# Fitting estimator with 40 features.
# Fitting estimator with 39 features.
# Fitting estimator with 38 features.
# Fitting estimator with 37 features.
# Fitting estimator with 36 features.
# Fitting estimator with 35 features.
# Fitting estimator with 34 features.
# Fitting estimator with 33 features.
# Fitting estimator with 32 features.
# Fitting estimator with 31 features.
# Fitting estimator with 30 features.
# Fitting estimator with 29 features.
# Fitting estimator with 28 features.
# Fitting estimator with 27 features.
# Fitting estimator with 26 features.
# Fitting estimator with 25 features.
# Fitting estimator with 24 features.
# Fitting estimator with 23 features.
# Fitting estimator with 22 features.
# Fitting estimator with 21 features.
# Fitting estimator with 20 features.
# Fitting estimator with 19 features.
# Fitting estimator with 18 features.
# Fitting estimator with 17 features.
# Fitting estimator with 16 features.
# Fitting estimator with 15 features.
# Fitting estimator with 14 features.
# Fitting estimator with 13 features.
# Fitting estimator with 12 features.
# Fitting estimator with 11 features.
# Fitting estimator with 10 features.
# Fitting estimator with 9 features.
# Fitting estimator with 8 features.
# Fitting estimator with 7 features.
# Fitting estimator with 6 features.
# Fitting estimator with 5 features.
# Fitting estimator with 4 features.
# Fitting estimator with 3 features.
# Fitting estimator with 2 features.
# Fitting estimator with 53 features.
# Fitting estimator with 52 features.
# Fitting estimator with 51 features.
# Fitting estimator with 50 features.
# /home/rmorse/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Fitting estimator with 49 features.
# Fitting estimator with 48 features.
# Fitting estimator with 47 features.
# Fitting estimator with 46 features.
# Fitting estimator with 45 features.
# Fitting estimator with 44 features.
# Fitting estimator with 43 features.
# Fitting estimator with 42 features.
# Fitting estimator with 41 features.
# Fitting estimator with 40 features.
# Fitting estimator with 39 features.
# Fitting estimator with 38 features.
# Fitting estimator with 37 features.
# Fitting estimator with 36 features.
# Fitting estimator with 35 features.
# Fitting estimator with 34 features.
# Fitting estimator with 33 features.
# /home/rmorse/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Fitting estimator with 32 features.
# Fitting estimator with 31 features.
# Fitting estimator with 30 features.
# Fitting estimator with 29 features.
# Fitting estimator with 28 features.
# Fitting estimator with 27 features.
# Fitting estimator with 26 features.
# Fitting estimator with 25 features.
# Fitting estimator with 24 features.
# Fitting estimator with 23 features.
# Fitting estimator with 22 features.
# Fitting estimator with 21 features.
# /home/rmorse/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Fitting estimator with 20 features.
# Fitting estimator with 19 features.
# Fitting estimator with 18 features.
# Fitting estimator with 17 features.
# Fitting estimator with 16 features.
# Fitting estimator with 15 features.
# /home/rmorse/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Fitting estimator with 14 features.
# Fitting estimator with 13 features.
# Fitting estimator with 12 features.
# Fitting estimator with 11 features.
# Fitting estimator with 10 features.
# Fitting estimator with 9 features.
# Fitting estimator with 8 features.
# Fitting estimator with 7 features.
# Fitting estimator with 6 features.
# Fitting estimator with 5 features.
# Fitting estimator with 4 features.
# Fitting estimator with 3 features.
# Fitting estimator with 2 features.
# Fitting estimator with 53 features.
# Fitting estimator with 52 features.
# Fitting estimator with 51 features.
# Fitting estimator with 50 features.
# Fitting estimator with 49 features.
# Fitting estimator with 48 features.
# Fitting estimator with 47 features.
# Fitting estimator with 46 features.
# Fitting estimator with 45 features.
# Fitting estimator with 44 features.
# Fitting estimator with 43 features.
# Fitting estimator with 42 features.
# Fitting estimator with 41 features.
# Fitting estimator with 40 features.
# Fitting estimator with 39 features.
# Fitting estimator with 38 features.
# Fitting estimator with 37 features.
# Fitting estimator with 36 features.
# Fitting estimator with 35 features.
# Fitting estimator with 34 features.
# Fitting estimator with 33 features.
# Fitting estimator with 32 features.
# Fitting estimator with 31 features.
# Fitting estimator with 30 features.
# Fitting estimator with 29 features.
# Fitting estimator with 28 features.
# Fitting estimator with 27 features.
# Fitting estimator with 26 features.
# Fitting estimator with 25 features.
# Fitting estimator with 24 features.
# Fitting estimator with 23 features.
# Fitting estimator with 22 features.
# Fitting estimator with 21 features.
# Fitting estimator with 20 features.
# Fitting estimator with 19 features.
# Fitting estimator with 18 features.
# Fitting estimator with 17 features.

# %% [markdown]
# ### The number of features with the best macro f1 score

# %%
my_rfc_selector.ranking_
feat_ranks = pd.DataFrame(data = {'features': data.columns.values[9:-1], 'rfe ranking': my_rfc_selector.ranking_} )

# %%
feat_ranks.sort_values(by = 'rfe ranking', inplace=True)

# %%
best_number_feats_rfe = my_rfc_selector.n_features_

# %%
best_number_feats_rfe
# Out:
# 16

# %%
feat_ranks
# Out:
#    features  rfe ranking
# 26     Zr90            1
# 37    Nd146            1
# 33    Ba137            1
# 24     Sr88            1
# 23     Rb85            1
# 21     Ge72            1
# 15     Fe56            1
# 13     Cr52            1
# 10     Sc45            1
# 52     U238            1
# 9      Ca42            1
# 2       B11            1
# 7       S33            1
# 6       P31            1
# 3      Mg24            1
# 4      Al27            1
# 12      V51            2
# 34    La139            3
# 0       Li7            4
# 14     Mn55            5
# 5      Si28            6
# 20     Ga69            7
# 17     Ni60            8
# 35    Ce140            9
# 36    Pr141           10
# 27     Nb93           11
# 22     As75           12
# 18     Cu63           13
# 29    Cd111           14
# 38    Sm147           15
# 16     Co59           16
# 8       K39           17
# 50    Pb208           18
# 11     Ti47           19
# 25      Y89           20
# 46    Yb172           21
# 31    Sn118           22
# 32    Cs133           23
# 19     Zn68           24
# 42    Dy163           25
# 1       Be9           26
# 39    Eu153           27
# 40    Gd157           28
# 28     Mo95           29
# 44    Er166           30
# 43    Ho165           31
# 51    Th232           32
# 48    Hf178           33
# 47    Lu175           34
# 30    In115           35
# 41    Tb159           36
# 45    Tm169           37
# 49    Ta181           38

# %%
best_feats = list(feat_ranks['features'][0: best_number_feats_rfe])

# %%
list(best_feats)
# Out:
# ['Zr90',
#  'Nd146',
#  'Ba137',
#  'Sr88',
#  'Rb85',
#  'Ge72',
#  'Fe56',
#  'Cr52',
#  'Sc45',
#  'U238',
#  'Ca42',
#  'B11',
#  'S33',
#  'P31',
#  'Mg24',
#  'Al27']

# %% [markdown]
# ### macro-f1 score is plotted against number of features

# %%
RFCV_df = pd.DataFrame(data = {'no_features' : range(1, len(my_rfc_selector.grid_scores_) + 1), 'scores': my_rfc_selector.grid_scores_})

# %%
RFCV_df
# Out:
#     no_features    scores
# 0             1  0.088932
# 1             2  0.185245
# 2             3  0.220312
# 3             4  0.274941
# 4             5  0.348424
# 5             6  0.373952
# 6             7  0.445433
# 7             8  0.433325
# 8             9  0.462546
# 9            10  0.479560
# 10           11  0.503327
# 11           12  0.503081
# 12           13  0.515862
# 13           14  0.522547
# 14           15  0.518808
# 15           16  0.553662
# 16           17  0.510355
# 17           18  0.525832
# 18           19  0.544125
# 19           20  0.531063
# 20           21  0.517787
# 21           22  0.532375
# 22           23  0.535656
# 23           24  0.521092
# 24           25  0.530193
# 25           26  0.515331
# 26           27  0.509061
# 27           28  0.534272
# 28           29  0.495414
# 29           30  0.476972
# 30           31  0.515068
# 31           32  0.511535
# 32           33  0.491400
# 33           34  0.517064
# 34           35  0.497343
# 35           36  0.510482
# 36           37  0.525205
# 37           38  0.492826
# 38           39  0.497765
# 39           40  0.477327
# 40           41  0.518542
# 41           42  0.484334
# 42           43  0.477985
# 43           44  0.500729
# 44           45  0.478681
# 45           46  0.491466
# 46           47  0.472769
# 47           48  0.477017
# 48           49  0.491347
# 49           50  0.489385
# 50           51  0.497208
# 51           52  0.481197
# 52           53  0.478753

# %%
sns.set(rc={'figure.figsize':(15.7,15.27)})
sns.lmplot(data = RFCV_df, x = 'no_features', y = 'scores', fit_reg=False)

# %% [markdown]
# ### Rankings of features based on multiple models
#
# * random forest classifier feature importances
# * RFE with RFC
# * gradient boosting machine feature importances
# * logistic regression coefficients

# %%
def getFeatImportances(model, X, y, featImportances = True):
    
    model.fit(X,y)
    return(model.feature_importances_)

# %%
my_scaler = MinMaxScaler()

# %%
RFC_ranks = my_scaler.fit_transform(getFeatImportances(RandomForestClassifier(random_state=random_seed_state), X, y).reshape(-1,1)).tolist()
RFC_ranks_scaled = []
for i in RFC_ranks:
    RFC_ranks_scaled.append(i[0])
# Out:
# /home/rmorse/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)

# %%
GBM_ranks = my_scaler.fit_transform(getFeatImportances(GradientBoostingClassifier(), X, y).reshape(-1,1)).tolist()
GBM_ranks_scaled = []
for i in GBM_ranks:
    GBM_ranks_scaled.append(i[0])

# %%
RFE_ranks = my_scaler.fit_transform(my_rfc_selector.ranking_.reshape(-1, 1)).tolist()
RFE_ranks_list = []
for i in RFE_ranks:
    RFE_ranks_list.append(i[0])
# Out:
# /home/rmorse/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)

# %%
RFE_ranks_scaled  = []
for i in RFE_ranks_list:
    RFE_ranks_scaled.append((1-i))

# %%
RFE_ranks_scaled
# Out:
# [0.9189189189189189,
#  0.32432432432432434,
#  1.0,
#  1.0,
#  1.0,
#  0.8648648648648649,
#  1.0,
#  1.0,
#  0.5675675675675675,
#  1.0,
#  1.0,
#  0.5135135135135134,
#  0.972972972972973,
#  1.0,
#  0.8918918918918919,
#  1.0,
#  0.5945945945945945,
#  0.8108108108108107,
#  0.6756756756756757,
#  0.3783783783783783,
#  0.8378378378378378,
#  1.0,
#  0.7027027027027026,
#  1.0,
#  1.0,
#  0.4864864864864864,
#  1.0,
#  0.7297297297297297,
#  0.2432432432432432,
#  0.6486486486486487,
#  0.08108108108108092,
#  0.43243243243243246,
#  0.40540540540540526,
#  1.0,
#  0.9459459459459459,
#  0.7837837837837838,
#  0.7567567567567568,
#  1.0,
#  0.6216216216216216,
#  0.29729729729729715,
#  0.2702702702702702,
#  0.054054054054053946,
#  0.3513513513513513,
#  0.18918918918918903,
#  0.21621621621621623,
#  0.027027027027026973,
#  0.45945945945945943,
#  0.10810810810810811,
#  0.1351351351351351,
#  -2.220446049250313e-16,
#  0.5405405405405406,
#  0.16216216216216206,
#  1.0]

# %%
RFC_ranks = getFeatImportances(RandomForestClassifier(random_state=random_seed_state),X,y)
# Out:
# /home/rmorse/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)

# %%
GBM_ranks = getFeatImportances(GradientBoostingClassifier(random_state=random_seed_state),X,y)

# %%
RFE_ranks = my_rfc_selector.ranking_

# %%
rankings = pd.DataFrame(data = {'feature':X.columns.values, 'RFC':list(RFC_ranks_scaled), 'GBM':list(GBM_ranks_scaled), 'RFE':list(RFE_ranks_scaled)})

# %%
def meanRanks(row):
    return((row['RFC'] + row['GBM'] + row['RFE']) / 3)
rankings['mean_rank'] = rankings.apply(meanRanks, axis = 1)

# %%
rankings.sort_values(by = 'mean_rank', ascending=False, inplace=True)

# %%
rankings
# Out:
#    feature       RFC       GBM           RFE  mean_rank
# 13    Cr52  1.000000  1.000000  1.000000e+00   1.000000
# 2      B11  0.774803  0.866326  1.000000e+00   0.880376
# 7      S33  0.600331  0.985823  1.000000e+00   0.862051
# 52    U238  0.662293  0.884139  1.000000e+00   0.848811
# 9     Ca42  0.638422  0.806316  1.000000e+00   0.814912
# 3     Mg24  0.601097  0.559197  1.000000e+00   0.720098
# 26    Zr90  0.435194  0.548232  1.000000e+00   0.661142
# 10    Sc45  0.379981  0.555160  1.000000e+00   0.645047
# 23    Rb85  0.480408  0.454281  1.000000e+00   0.644896
# 6      P31  0.415458  0.497167  1.000000e+00   0.637542
# 12     V51  0.368316  0.562267  9.729730e-01   0.634519
# 21    Ge72  0.550484  0.351138  1.000000e+00   0.633874
# 24    Sr88  0.424667  0.428591  1.000000e+00   0.617753
# 33   Ba137  0.591478  0.223582  1.000000e+00   0.605020
# 15    Fe56  0.373601  0.359501  1.000000e+00   0.577701
# 4     Al27  0.415047  0.237205  1.000000e+00   0.550751
# 0      Li7  0.374532  0.262544  9.189189e-01   0.518665
# 14    Mn55  0.229737  0.261753  8.918919e-01   0.461127
# 34   La139  0.200493  0.218493  9.459459e-01   0.454977
# 35   Ce140  0.410337  0.166051  7.837838e-01   0.453391
# 5     Si28  0.237698  0.256393  8.648649e-01   0.452985
# 37   Nd146  0.191914  0.147777  1.000000e+00   0.446564
# 20    Ga69  0.168334  0.324200  8.378378e-01   0.443457
# 36   Pr141  0.314025  0.162874  7.567568e-01   0.411218
# 17    Ni60  0.185612  0.202748  8.108108e-01   0.399723
# 8      K39  0.305150  0.292916  5.675676e-01   0.388545
# 18    Cu63  0.238775  0.185844  6.756757e-01   0.366765
# 22    As75  0.279281  0.093238  7.027027e-01   0.358407
# 27    Nb93  0.122401  0.187344  7.297297e-01   0.346492
# 50   Pb208  0.146164  0.222102  5.405405e-01   0.302936
# 29   Cd111  0.163291  0.087650  6.486486e-01   0.299863
# 38   Sm147  0.191257  0.050409  6.216216e-01   0.287763
# 25     Y89  0.229636  0.084668  4.864865e-01   0.266930
# 19    Zn68  0.199459  0.180004  3.783784e-01   0.252614
# 11    Ti47  0.061620  0.176577  5.135135e-01   0.250570
# 16    Co59  0.106264  0.048641  5.945946e-01   0.249833
# 31   Sn118  0.139272  0.134176  4.324324e-01   0.235293
# 46   Yb172  0.144839  0.065829  4.594595e-01   0.223376
# 32   Cs133  0.158579  0.087585  4.054054e-01   0.217190
# 42   Dy163  0.099193  0.071132  3.513514e-01   0.173892
# 1      Be9  0.074958  0.058102  3.243243e-01   0.152461
# 28    Mo95  0.147334  0.026109  2.432432e-01   0.138895
# 40   Gd157  0.097993  0.043265  2.702703e-01   0.137176
# 39   Eu153  0.052708  0.023928  2.972973e-01   0.124645
# 44   Er166  0.118847  0.013203  2.162162e-01   0.116089
# 51   Th232  0.069453  0.052526  1.621622e-01   0.094714
# 43   Ho165  0.033552  0.021460  1.891892e-01   0.081400
# 48   Hf178  0.042627  0.029949  1.351351e-01   0.069237
# 30   In115  0.063238  0.051391  8.108108e-02   0.065237
# 47   Lu175  0.050810  0.015861  1.081081e-01   0.058260
# 41   Tb159  0.070933  0.000000  5.405405e-02   0.041662
# 45   Tm169  0.033072  0.009778  2.702703e-02   0.023292
# 49   Ta181  0.000000  0.068265 -2.220446e-16   0.022755

# %%
y_array = np.array(y)

# %%
feats = []
scores = []
no_feats = []
features = list(rankings['feature'])
esti_rank = RandomForestClassifier(n_estimators=1000 , n_jobs=-1, random_state=random_seed_state)
for i in range(0, len(features)):
    i_2 = i + 1
    my_feats = features[0:i_2]
    feats.append(my_feats)
    no_feats.append(len(my_feats))
    print('building models with following features... {0}'.format(my_feats))
    
    X_array = np.array(X[my_feats])
    
    skf = StratifiedKFold(n_splits=3, random_state=random_seed_state)
    skf.get_n_splits(X_array, y_array)

    macro_f1_scores = []
    count = 0

    for train_index, test_index in skf.split(X_array, y_array):
        count = count + 1
        print('making model:')
        key = 'round' + str(count)
        print(count)
        X_train, X_test = X_array[train_index], X_array[test_index]
        y_train, y_test = y_array[train_index], y_array[test_index]

        esti_rank.fit(X_train, y_train)
        y_pred = esti_rank.predict(X_test)
        indi_score = f1_score(y_test, y_pred, average = 'weighted')
       
        macro_f1_scores.append(f1_score(y_test, y_pred, average = 'weighted'))
        
    
    
    scores.append(np.array(macro_f1_scores).mean())
# Out:
# building models with following features... ['Cr52']
# making model:
# 1
# making model:
# 2
# making model:
# 3
# building models with following features... ['Cr52', 'B11']
# making model:
# 1
# making model:
# 2
# making model:
# 3
# building models with following features... ['Cr52', 'B11', 'S33']
# making model:
# 1
# making model:
# 2
# /home/rmorse/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/rmorse/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# making model:
# 3
# building models with following features... ['Cr52', 'B11', 'S33', 'U238']
# making model:
# 1
# making model:
# 2
# making model:
# 3
# building models with following features... ['Cr52', 'B11', 'S33', 'U238', 'Ca42']
# making model:
# 1
# making model:
# 2
# making model:
# 3
# /home/rmorse/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/rmorse/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# building models with following features... ['Cr52', 'B11', 'S33', 'U238', 'Ca42', 'Mg24']
# making model:
# 1
# /home/rmorse/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/rmorse/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# making model:
# 2
# making model:
# 3
# building models with following features... ['Cr52', 'B11', 'S33', 'U238', 'Ca42', 'Mg24', 'Zr90']
# making model:
# 1
# /home/rmorse/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/rmorse/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# making model:
# 2
# making model:
# 3
# building models with following features... ['Cr52', 'B11', 'S33', 'U238', 'Ca42', 'Mg24', 'Zr90', 'Sc45']
# making model:
# 1
# making model:
# 2
# making model:
# 3
# building models with following features... ['Cr52', 'B11', 'S33', 'U238', 'Ca42', 'Mg24', 'Zr90', 'Sc45', 'Rb85']
# making model:
# 1
# making model:
# 2
# making model:
# 3
# building models with following features... ['Cr52', 'B11', 'S33', 'U238', 'Ca42', 'Mg24', 'Zr90', 'Sc45', 'Rb85', 'P31']
# making model:
# 1
# making model:
# 2
# making model:
# 3
# building models with following features... ['Cr52', 'B11', 'S33', 'U238', 'Ca42', 'Mg24', 'Zr90', 'Sc45', 'Rb85', 'P31', 'V51']
# making model:
# 1
# making model:
# 2
# making model:
# 3
# /home/rmorse/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/rmorse/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# building models with following features... ['Cr52', 'B11', 'S33', 'U238', 'Ca42', 'Mg24', 'Zr90', 'Sc45', 'Rb85', 'P31', 'V51', 'Ge72']
# making model:
# 1
# making model:
# 2
# making model:
# 3
# building models with following features... ['Cr52', 'B11', 'S33', 'U238', 'Ca42', 'Mg24', 'Zr90', 'Sc45', 'Rb85', 'P31', 'V51', 'Ge72', 'Sr88']
# making model:
# 1
# making model:
# 2
# making model:
# 3
# building models with following features... ['Cr52', 'B11', 'S33', 'U238', 'Ca42', 'Mg24', 'Zr90', 'Sc45', 'Rb85', 'P31', 'V51', 'Ge72', 'Sr88', 'Ba137']
# making model:
# 1
# making model:
# 2
# making model:
# 3
# building models with following features... ['Cr52', 'B11', 'S33', 'U238', 'Ca42', 'Mg24', 'Zr90', 'Sc45', 'Rb85', 'P31', 'V51', 'Ge72', 'Sr88', 'Ba137', 'Fe56']
# making model:
# 1
# making model:
# 2
# making model:
# 3
# building models with following features... ['Cr52', 'B11', 'S33', 'U238', 'Ca42', 'Mg24', 'Zr90', 'Sc45', 'Rb85', 'P31', 'V51', 'Ge72', 'Sr88', 'Ba137', 'Fe56', 'Al27']
# making model:
# 1
# making model:
# 2
# making model:
# 3
# building models with following features... ['Cr52', 'B11', 'S33', 'U238', 'Ca42', 'Mg24', 'Zr90', 'Sc45', 'Rb85', 'P31', 'V51', 'Ge72', 'Sr88', 'Ba137', 'Fe56', 'Al27', 'Li7']
# making model:
# 1
# making model:
# 2
# making model:
# 3
# building models with following features... ['Cr52', 'B11', 'S33', 'U238', 'Ca42', 'Mg24', 'Zr90', 'Sc45', 'Rb85', 'P31', 'V51', 'Ge72', 'Sr88', 'Ba137', 'Fe56', 'Al27', 'Li7', 'Mn55']
# making model:
# 1
# making model:
# 2
# making model:
# 3
# building models with following features... ['Cr52', 'B11', 'S33', 'U238', 'Ca42', 'Mg24', 'Zr90', 'Sc45', 'Rb85', 'P31', 'V51', 'Ge72', 'Sr88', 'Ba137', 'Fe56', 'Al27', 'Li7', 'Mn55', 'La139']
# making model:
# 1
# making model:
# 2
# making model:
# 3
# building models with following features... ['Cr52', 'B11', 'S33', 'U238', 'Ca42', 'Mg24', 'Zr90', 'Sc45', 'Rb85', 'P31', 'V51', 'Ge72', 'Sr88', 'Ba137', 'Fe56', 'Al27', 'Li7', 'Mn55', 'La139', 'Ce140']
# making model:
# 1
# making model:
# 2
# making model:
# 3
# building models with following features... ['Cr52', 'B11', 'S33', 'U238', 'Ca42', 'Mg24', 'Zr90', 'Sc45', 'Rb85', 'P31', 'V51', 'Ge72', 'Sr88', 'Ba137', 'Fe56', 'Al27', 'Li7', 'Mn55', 'La139', 'Ce140', 'Si28']
# making model:
# 1
# making model:
# 2
# making model:
# 3
# building models with following features... ['Cr52', 'B11', 'S33', 'U238', 'Ca42', 'Mg24', 'Zr90', 'Sc45', 'Rb85', 'P31', 'V51', 'Ge72', 'Sr88', 'Ba137', 'Fe56', 'Al27', 'Li7', 'Mn55', 'La139', 'Ce140', 'Si28', 'Nd146']
# making model:
# 1
# making model:
# 2
# making model:
# 3
# building models with following features... ['Cr52', 'B11', 'S33', 'U238', 'Ca42', 'Mg24', 'Zr90', 'Sc45', 'Rb85', 'P31', 'V51', 'Ge72', 'Sr88', 'Ba137', 'Fe56', 'Al27', 'Li7', 'Mn55', 'La139', 'Ce140', 'Si28', 'Nd146', 'Ga69']
# making model:
# 1
# making model:
# 2
# making model:
# 3
# building models with following features... ['Cr52', 'B11', 'S33', 'U238', 'Ca42', 'Mg24', 'Zr90', 'Sc45', 'Rb85', 'P31', 'V51', 'Ge72', 'Sr88', 'Ba137', 'Fe56', 'Al27', 'Li7', 'Mn55', 'La139', 'Ce140', 'Si28', 'Nd146', 'Ga69', 'Pr141']
# making model:
# 1
# making model:
# 2
# making model:
# 3
# building models with following features... ['Cr52', 'B11', 'S33', 'U238', 'Ca42', 'Mg24', 'Zr90', 'Sc45', 'Rb85', 'P31', 'V51', 'Ge72', 'Sr88', 'Ba137', 'Fe56', 'Al27', 'Li7', 'Mn55', 'La139', 'Ce140', 'Si28', 'Nd146', 'Ga69', 'Pr141', 'Ni60']
# making model:
# 1
# making model:
# 2
# making model:
# 3
# building models with following features... ['Cr52', 'B11', 'S33', 'U238', 'Ca42', 'Mg24', 'Zr90', 'Sc45', 'Rb85', 'P31', 'V51', 'Ge72', 'Sr88', 'Ba137', 'Fe56', 'Al27', 'Li7', 'Mn55', 'La139', 'Ce140', 'Si28', 'Nd146', 'Ga69', 'Pr141', 'Ni60', 'K39']
# making model:
# 1
# making model:
# 2
# making model:
# 3
# building models with following features... ['Cr52', 'B11', 'S33', 'U238', 'Ca42', 'Mg24', 'Zr90', 'Sc45', 'Rb85', 'P31', 'V51', 'Ge72', 'Sr88', 'Ba137', 'Fe56', 'Al27', 'Li7', 'Mn55', 'La139', 'Ce140', 'Si28', 'Nd146', 'Ga69', 'Pr141', 'Ni60', 'K39', 'Cu63']
# making model:
# 1
# making model:
# 2
# making model:
# 3
# building models with following features... ['Cr52', 'B11', 'S33', 'U238', 'Ca42', 'Mg24', 'Zr90', 'Sc45', 'Rb85', 'P31', 'V51', 'Ge72', 'Sr88', 'Ba137', 'Fe56', 'Al27', 'Li7', 'Mn55', 'La139', 'Ce140', 'Si28', 'Nd146', 'Ga69', 'Pr141', 'Ni60', 'K39', 'Cu63', 'As75']
# making model:
# 1
# making model:
# 2
# making model:
# 3
# building models with following features... ['Cr52', 'B11', 'S33', 'U238', 'Ca42', 'Mg24', 'Zr90', 'Sc45', 'Rb85', 'P31', 'V51', 'Ge72', 'Sr88', 'Ba137', 'Fe56', 'Al27', 'Li7', 'Mn55', 'La139', 'Ce140', 'Si28', 'Nd146', 'Ga69', 'Pr141', 'Ni60', 'K39', 'Cu63', 'As75', 'Nb93']
# making model:
# 1
# making model:
# 2
# making model:
# 3
# building models with following features... ['Cr52', 'B11', 'S33', 'U238', 'Ca42', 'Mg24', 'Zr90', 'Sc45', 'Rb85', 'P31', 'V51', 'Ge72', 'Sr88', 'Ba137', 'Fe56', 'Al27', 'Li7', 'Mn55', 'La139', 'Ce140', 'Si28', 'Nd146', 'Ga69', 'Pr141', 'Ni60', 'K39', 'Cu63', 'As75', 'Nb93', 'Pb208']
# making model:
# 1
# making model:
# 2
# making model:
# 3
# building models with following features... ['Cr52', 'B11', 'S33', 'U238', 'Ca42', 'Mg24', 'Zr90', 'Sc45', 'Rb85', 'P31', 'V51', 'Ge72', 'Sr88', 'Ba137', 'Fe56', 'Al27', 'Li7', 'Mn55', 'La139', 'Ce140', 'Si28', 'Nd146', 'Ga69', 'Pr141', 'Ni60', 'K39', 'Cu63', 'As75', 'Nb93', 'Pb208', 'Cd111']
# making model:
# 1
# making model:
# 2
# making model:
# 3
# building models with following features... ['Cr52', 'B11', 'S33', 'U238', 'Ca42', 'Mg24', 'Zr90', 'Sc45', 'Rb85', 'P31', 'V51', 'Ge72', 'Sr88', 'Ba137', 'Fe56', 'Al27', 'Li7', 'Mn55', 'La139', 'Ce140', 'Si28', 'Nd146', 'Ga69', 'Pr141', 'Ni60', 'K39', 'Cu63', 'As75', 'Nb93', 'Pb208', 'Cd111', 'Sm147']
# making model:
# 1
# making model:
# 2
# making model:
# 3
# building models with following features... ['Cr52', 'B11', 'S33', 'U238', 'Ca42', 'Mg24', 'Zr90', 'Sc45', 'Rb85', 'P31', 'V51', 'Ge72', 'Sr88', 'Ba137', 'Fe56', 'Al27', 'Li7', 'Mn55', 'La139', 'Ce140', 'Si28', 'Nd146', 'Ga69', 'Pr141', 'Ni60', 'K39', 'Cu63', 'As75', 'Nb93', 'Pb208', 'Cd111', 'Sm147', 'Y89']
# making model:
# 1
# making model:
# 2
# making model:
# 3
# building models with following features... ['Cr52', 'B11', 'S33', 'U238', 'Ca42', 'Mg24', 'Zr90', 'Sc45', 'Rb85', 'P31', 'V51', 'Ge72', 'Sr88', 'Ba137', 'Fe56', 'Al27', 'Li7', 'Mn55', 'La139', 'Ce140', 'Si28', 'Nd146', 'Ga69', 'Pr141', 'Ni60', 'K39', 'Cu63', 'As75', 'Nb93', 'Pb208', 'Cd111', 'Sm147', 'Y89', 'Zn68']
# making model:
# 1
# making model:
# 2
# making model:
# 3
# building models with following features... ['Cr52', 'B11', 'S33', 'U238', 'Ca42', 'Mg24', 'Zr90', 'Sc45', 'Rb85', 'P31', 'V51', 'Ge72', 'Sr88', 'Ba137', 'Fe56', 'Al27', 'Li7', 'Mn55', 'La139', 'Ce140', 'Si28', 'Nd146', 'Ga69', 'Pr141', 'Ni60', 'K39', 'Cu63', 'As75', 'Nb93', 'Pb208', 'Cd111', 'Sm147', 'Y89', 'Zn68', 'Ti47']
# making model:
# 1
# making model:
# 2
# making model:
# 3
# building models with following features... ['Cr52', 'B11', 'S33', 'U238', 'Ca42', 'Mg24', 'Zr90', 'Sc45', 'Rb85', 'P31', 'V51', 'Ge72', 'Sr88', 'Ba137', 'Fe56', 'Al27', 'Li7', 'Mn55', 'La139', 'Ce140', 'Si28', 'Nd146', 'Ga69', 'Pr141', 'Ni60', 'K39', 'Cu63', 'As75', 'Nb93', 'Pb208', 'Cd111', 'Sm147', 'Y89', 'Zn68', 'Ti47', 'Co59']
# making model:
# 1
# making model:
# 2
# making model:
# 3
# building models with following features... ['Cr52', 'B11', 'S33', 'U238', 'Ca42', 'Mg24', 'Zr90', 'Sc45', 'Rb85', 'P31', 'V51', 'Ge72', 'Sr88', 'Ba137', 'Fe56', 'Al27', 'Li7', 'Mn55', 'La139', 'Ce140', 'Si28', 'Nd146', 'Ga69', 'Pr141', 'Ni60', 'K39', 'Cu63', 'As75', 'Nb93', 'Pb208', 'Cd111', 'Sm147', 'Y89', 'Zn68', 'Ti47', 'Co59', 'Sn118']
# making model:
# 1
# making model:
# 2
# making model:
# 3
# building models with following features... ['Cr52', 'B11', 'S33', 'U238', 'Ca42', 'Mg24', 'Zr90', 'Sc45', 'Rb85', 'P31', 'V51', 'Ge72', 'Sr88', 'Ba137', 'Fe56', 'Al27', 'Li7', 'Mn55', 'La139', 'Ce140', 'Si28', 'Nd146', 'Ga69', 'Pr141', 'Ni60', 'K39', 'Cu63', 'As75', 'Nb93', 'Pb208', 'Cd111', 'Sm147', 'Y89', 'Zn68', 'Ti47', 'Co59', 'Sn118', 'Yb172']
# making model:
# 1
# making model:
# 2
# making model:
# 3
# building models with following features... ['Cr52', 'B11', 'S33', 'U238', 'Ca42', 'Mg24', 'Zr90', 'Sc45', 'Rb85', 'P31', 'V51', 'Ge72', 'Sr88', 'Ba137', 'Fe56', 'Al27', 'Li7', 'Mn55', 'La139', 'Ce140', 'Si28', 'Nd146', 'Ga69', 'Pr141', 'Ni60', 'K39', 'Cu63', 'As75', 'Nb93', 'Pb208', 'Cd111', 'Sm147', 'Y89', 'Zn68', 'Ti47', 'Co59', 'Sn118', 'Yb172', 'Cs133']
# making model:
# 1
# making model:
# 2
# making model:
# 3
# building models with following features... ['Cr52', 'B11', 'S33', 'U238', 'Ca42', 'Mg24', 'Zr90', 'Sc45', 'Rb85', 'P31', 'V51', 'Ge72', 'Sr88', 'Ba137', 'Fe56', 'Al27', 'Li7', 'Mn55', 'La139', 'Ce140', 'Si28', 'Nd146', 'Ga69', 'Pr141', 'Ni60', 'K39', 'Cu63', 'As75', 'Nb93', 'Pb208', 'Cd111', 'Sm147', 'Y89', 'Zn68', 'Ti47', 'Co59', 'Sn118', 'Yb172', 'Cs133', 'Dy163']
# making model:
# 1
# making model:
# 2
# making model:
# 3
# building models with following features... ['Cr52', 'B11', 'S33', 'U238', 'Ca42', 'Mg24', 'Zr90', 'Sc45', 'Rb85', 'P31', 'V51', 'Ge72', 'Sr88', 'Ba137', 'Fe56', 'Al27', 'Li7', 'Mn55', 'La139', 'Ce140', 'Si28', 'Nd146', 'Ga69', 'Pr141', 'Ni60', 'K39', 'Cu63', 'As75', 'Nb93', 'Pb208', 'Cd111', 'Sm147', 'Y89', 'Zn68', 'Ti47', 'Co59', 'Sn118', 'Yb172', 'Cs133', 'Dy163', 'Be9']
# making model:
# 1
# making model:
# 2
# making model:
# 3
# building models with following features... ['Cr52', 'B11', 'S33', 'U238', 'Ca42', 'Mg24', 'Zr90', 'Sc45', 'Rb85', 'P31', 'V51', 'Ge72', 'Sr88', 'Ba137', 'Fe56', 'Al27', 'Li7', 'Mn55', 'La139', 'Ce140', 'Si28', 'Nd146', 'Ga69', 'Pr141', 'Ni60', 'K39', 'Cu63', 'As75', 'Nb93', 'Pb208', 'Cd111', 'Sm147', 'Y89', 'Zn68', 'Ti47', 'Co59', 'Sn118', 'Yb172', 'Cs133', 'Dy163', 'Be9', 'Mo95']
# making model:
# 1
# making model:
# 2
# making model:
# 3
# building models with following features... ['Cr52', 'B11', 'S33', 'U238', 'Ca42', 'Mg24', 'Zr90', 'Sc45', 'Rb85', 'P31', 'V51', 'Ge72', 'Sr88', 'Ba137', 'Fe56', 'Al27', 'Li7', 'Mn55', 'La139', 'Ce140', 'Si28', 'Nd146', 'Ga69', 'Pr141', 'Ni60', 'K39', 'Cu63', 'As75', 'Nb93', 'Pb208', 'Cd111', 'Sm147', 'Y89', 'Zn68', 'Ti47', 'Co59', 'Sn118', 'Yb172', 'Cs133', 'Dy163', 'Be9', 'Mo95', 'Gd157']
# making model:
# 1
# making model:
# 2
# making model:
# 3
# building models with following features... ['Cr52', 'B11', 'S33', 'U238', 'Ca42', 'Mg24', 'Zr90', 'Sc45', 'Rb85', 'P31', 'V51', 'Ge72', 'Sr88', 'Ba137', 'Fe56', 'Al27', 'Li7', 'Mn55', 'La139', 'Ce140', 'Si28', 'Nd146', 'Ga69', 'Pr141', 'Ni60', 'K39', 'Cu63', 'As75', 'Nb93', 'Pb208', 'Cd111', 'Sm147', 'Y89', 'Zn68', 'Ti47', 'Co59', 'Sn118', 'Yb172', 'Cs133', 'Dy163', 'Be9', 'Mo95', 'Gd157', 'Eu153']
# making model:
# 1
# making model:
# 2
# making model:
# 3
# building models with following features... ['Cr52', 'B11', 'S33', 'U238', 'Ca42', 'Mg24', 'Zr90', 'Sc45', 'Rb85', 'P31', 'V51', 'Ge72', 'Sr88', 'Ba137', 'Fe56', 'Al27', 'Li7', 'Mn55', 'La139', 'Ce140', 'Si28', 'Nd146', 'Ga69', 'Pr141', 'Ni60', 'K39', 'Cu63', 'As75', 'Nb93', 'Pb208', 'Cd111', 'Sm147', 'Y89', 'Zn68', 'Ti47', 'Co59', 'Sn118', 'Yb172', 'Cs133', 'Dy163', 'Be9', 'Mo95', 'Gd157', 'Eu153', 'Er166']
# making model:
# 1
# making model:
# 2
# making model:
# 3
# building models with following features... ['Cr52', 'B11', 'S33', 'U238', 'Ca42', 'Mg24', 'Zr90', 'Sc45', 'Rb85', 'P31', 'V51', 'Ge72', 'Sr88', 'Ba137', 'Fe56', 'Al27', 'Li7', 'Mn55', 'La139', 'Ce140', 'Si28', 'Nd146', 'Ga69', 'Pr141', 'Ni60', 'K39', 'Cu63', 'As75', 'Nb93', 'Pb208', 'Cd111', 'Sm147', 'Y89', 'Zn68', 'Ti47', 'Co59', 'Sn118', 'Yb172', 'Cs133', 'Dy163', 'Be9', 'Mo95', 'Gd157', 'Eu153', 'Er166', 'Th232']
# making model:
# 1
# making model:
# 2
# making model:
# 3
# building models with following features... ['Cr52', 'B11', 'S33', 'U238', 'Ca42', 'Mg24', 'Zr90', 'Sc45', 'Rb85', 'P31', 'V51', 'Ge72', 'Sr88', 'Ba137', 'Fe56', 'Al27', 'Li7', 'Mn55', 'La139', 'Ce140', 'Si28', 'Nd146', 'Ga69', 'Pr141', 'Ni60', 'K39', 'Cu63', 'As75', 'Nb93', 'Pb208', 'Cd111', 'Sm147', 'Y89', 'Zn68', 'Ti47', 'Co59', 'Sn118', 'Yb172', 'Cs133', 'Dy163', 'Be9', 'Mo95', 'Gd157', 'Eu153', 'Er166', 'Th232', 'Ho165']
# making model:
# 1
# making model:
# 2
# making model:
# 3
# building models with following features... ['Cr52', 'B11', 'S33', 'U238', 'Ca42', 'Mg24', 'Zr90', 'Sc45', 'Rb85', 'P31', 'V51', 'Ge72', 'Sr88', 'Ba137', 'Fe56', 'Al27', 'Li7', 'Mn55', 'La139', 'Ce140', 'Si28', 'Nd146', 'Ga69', 'Pr141', 'Ni60', 'K39', 'Cu63', 'As75', 'Nb93', 'Pb208', 'Cd111', 'Sm147', 'Y89', 'Zn68', 'Ti47', 'Co59', 'Sn118', 'Yb172', 'Cs133', 'Dy163', 'Be9', 'Mo95', 'Gd157', 'Eu153', 'Er166', 'Th232', 'Ho165', 'Hf178']
# making model:
# 1
# making model:
# 2
# making model:
# 3
# building models with following features... ['Cr52', 'B11', 'S33', 'U238', 'Ca42', 'Mg24', 'Zr90', 'Sc45', 'Rb85', 'P31', 'V51', 'Ge72', 'Sr88', 'Ba137', 'Fe56', 'Al27', 'Li7', 'Mn55', 'La139', 'Ce140', 'Si28', 'Nd146', 'Ga69', 'Pr141', 'Ni60', 'K39', 'Cu63', 'As75', 'Nb93', 'Pb208', 'Cd111', 'Sm147', 'Y89', 'Zn68', 'Ti47', 'Co59', 'Sn118', 'Yb172', 'Cs133', 'Dy163', 'Be9', 'Mo95', 'Gd157', 'Eu153', 'Er166', 'Th232', 'Ho165', 'Hf178', 'In115']
# making model:
# 1
# making model:
# 2
# making model:
# 3
# building models with following features... ['Cr52', 'B11', 'S33', 'U238', 'Ca42', 'Mg24', 'Zr90', 'Sc45', 'Rb85', 'P31', 'V51', 'Ge72', 'Sr88', 'Ba137', 'Fe56', 'Al27', 'Li7', 'Mn55', 'La139', 'Ce140', 'Si28', 'Nd146', 'Ga69', 'Pr141', 'Ni60', 'K39', 'Cu63', 'As75', 'Nb93', 'Pb208', 'Cd111', 'Sm147', 'Y89', 'Zn68', 'Ti47', 'Co59', 'Sn118', 'Yb172', 'Cs133', 'Dy163', 'Be9', 'Mo95', 'Gd157', 'Eu153', 'Er166', 'Th232', 'Ho165', 'Hf178', 'In115', 'Lu175']
# making model:
# 1
# making model:
# 2
# making model:
# 3
# building models with following features... ['Cr52', 'B11', 'S33', 'U238', 'Ca42', 'Mg24', 'Zr90', 'Sc45', 'Rb85', 'P31', 'V51', 'Ge72', 'Sr88', 'Ba137', 'Fe56', 'Al27', 'Li7', 'Mn55', 'La139', 'Ce140', 'Si28', 'Nd146', 'Ga69', 'Pr141', 'Ni60', 'K39', 'Cu63', 'As75', 'Nb93', 'Pb208', 'Cd111', 'Sm147', 'Y89', 'Zn68', 'Ti47', 'Co59', 'Sn118', 'Yb172', 'Cs133', 'Dy163', 'Be9', 'Mo95', 'Gd157', 'Eu153', 'Er166', 'Th232', 'Ho165', 'Hf178', 'In115', 'Lu175', 'Tb159']
# making model:
# 1
# making model:
# 2
# making model:
# 3
# building models with following features... ['Cr52', 'B11', 'S33', 'U238', 'Ca42', 'Mg24', 'Zr90', 'Sc45', 'Rb85', 'P31', 'V51', 'Ge72', 'Sr88', 'Ba137', 'Fe56', 'Al27', 'Li7', 'Mn55', 'La139', 'Ce140', 'Si28', 'Nd146', 'Ga69', 'Pr141', 'Ni60', 'K39', 'Cu63', 'As75', 'Nb93', 'Pb208', 'Cd111', 'Sm147', 'Y89', 'Zn68', 'Ti47', 'Co59', 'Sn118', 'Yb172', 'Cs133', 'Dy163', 'Be9', 'Mo95', 'Gd157', 'Eu153', 'Er166', 'Th232', 'Ho165', 'Hf178', 'In115', 'Lu175', 'Tb159', 'Tm169']
# making model:
# 1
# making model:
# 2
# making model:
# 3
# building models with following features... ['Cr52', 'B11', 'S33', 'U238', 'Ca42', 'Mg24', 'Zr90', 'Sc45', 'Rb85', 'P31', 'V51', 'Ge72', 'Sr88', 'Ba137', 'Fe56', 'Al27', 'Li7', 'Mn55', 'La139', 'Ce140', 'Si28', 'Nd146', 'Ga69', 'Pr141', 'Ni60', 'K39', 'Cu63', 'As75', 'Nb93', 'Pb208', 'Cd111', 'Sm147', 'Y89', 'Zn68', 'Ti47', 'Co59', 'Sn118', 'Yb172', 'Cs133', 'Dy163', 'Be9', 'Mo95', 'Gd157', 'Eu153', 'Er166', 'Th232', 'Ho165', 'Hf178', 'In115', 'Lu175', 'Tb159', 'Tm169', 'Ta181']
# making model:
# 1
# making model:
# 2
# making model:
# 3

# %%
rankedModels_df = pd.DataFrame(data = {'features': feats, 'number_of_features': no_feats, 'scores': scores})

# %%
rankedModels_df
# Out:
#                                              features  number_of_features  \
# 0                                              [Cr52]                   1
# 1                                         [Cr52, B11]                   2
# 2                                    [Cr52, B11, S33]                   3
# 3                              [Cr52, B11, S33, U238]                   4
# 4                        [Cr52, B11, S33, U238, Ca42]                   5
# 5                  [Cr52, B11, S33, U238, Ca42, Mg24]                   6
# 6            [Cr52, B11, S33, U238, Ca42, Mg24, Zr90]                   7
# 7      [Cr52, B11, S33, U238, Ca42, Mg24, Zr90, Sc45]                   8
# 8   [Cr52, B11, S33, U238, Ca42, Mg24, Zr90, Sc45,...                   9
# 9   [Cr52, B11, S33, U238, Ca42, Mg24, Zr90, Sc45,...                  10
# 10  [Cr52, B11, S33, U238, Ca42, Mg24, Zr90, Sc45,...                  11
# 11  [Cr52, B11, S33, U238, Ca42, Mg24, Zr90, Sc45,...                  12
# 12  [Cr52, B11, S33, U238, Ca42, Mg24, Zr90, Sc45,...                  13
# 13  [Cr52, B11, S33, U238, Ca42, Mg24, Zr90, Sc45,...                  14
# 14  [Cr52, B11, S33, U238, Ca42, Mg24, Zr90, Sc45,...                  15
# 15  [Cr52, B11, S33, U238, Ca42, Mg24, Zr90, Sc45,...                  16
# 16  [Cr52, B11, S33, U238, Ca42, Mg24, Zr90, Sc45,...                  17
# 17  [Cr52, B11, S33, U238, Ca42, Mg24, Zr90, Sc45,...                  18
# 18  [Cr52, B11, S33, U238, Ca42, Mg24, Zr90, Sc45,...                  19
# 19  [Cr52, B11, S33, U238, Ca42, Mg24, Zr90, Sc45,...                  20
# 20  [Cr52, B11, S33, U238, Ca42, Mg24, Zr90, Sc45,...                  21
# 21  [Cr52, B11, S33, U238, Ca42, Mg24, Zr90, Sc45,...                  22
# 22  [Cr52, B11, S33, U238, Ca42, Mg24, Zr90, Sc45,...                  23
# 23  [Cr52, B11, S33, U238, Ca42, Mg24, Zr90, Sc45,...                  24
# 24  [Cr52, B11, S33, U238, Ca42, Mg24, Zr90, Sc45,...                  25
# 25  [Cr52, B11, S33, U238, Ca42, Mg24, Zr90, Sc45,...                  26
# 26  [Cr52, B11, S33, U238, Ca42, Mg24, Zr90, Sc45,...                  27
# 27  [Cr52, B11, S33, U238, Ca42, Mg24, Zr90, Sc45,...                  28
# 28  [Cr52, B11, S33, U238, Ca42, Mg24, Zr90, Sc45,...                  29
# 29  [Cr52, B11, S33, U238, Ca42, Mg24, Zr90, Sc45,...                  30
# 30  [Cr52, B11, S33, U238, Ca42, Mg24, Zr90, Sc45,...                  31
# 31  [Cr52, B11, S33, U238, Ca42, Mg24, Zr90, Sc45,...                  32
# 32  [Cr52, B11, S33, U238, Ca42, Mg24, Zr90, Sc45,...                  33
# 33  [Cr52, B11, S33, U238, Ca42, Mg24, Zr90, Sc45,...                  34
# 34  [Cr52, B11, S33, U238, Ca42, Mg24, Zr90, Sc45,...                  35
# 35  [Cr52, B11, S33, U238, Ca42, Mg24, Zr90, Sc45,...                  36
# 36  [Cr52, B11, S33, U238, Ca42, Mg24, Zr90, Sc45,...                  37
# 37  [Cr52, B11, S33, U238, Ca42, Mg24, Zr90, Sc45,...                  38
# 38  [Cr52, B11, S33, U238, Ca42, Mg24, Zr90, Sc45,...                  39
# 39  [Cr52, B11, S33, U238, Ca42, Mg24, Zr90, Sc45,...                  40
# 40  [Cr52, B11, S33, U238, Ca42, Mg24, Zr90, Sc45,...                  41
# 41  [Cr52, B11, S33, U238, Ca42, Mg24, Zr90, Sc45,...                  42
# 42  [Cr52, B11, S33, U238, Ca42, Mg24, Zr90, Sc45,...                  43
# 43  [Cr52, B11, S33, U238, Ca42, Mg24, Zr90, Sc45,...                  44
# 44  [Cr52, B11, S33, U238, Ca42, Mg24, Zr90, Sc45,...                  45
# 45  [Cr52, B11, S33, U238, Ca42, Mg24, Zr90, Sc45,...                  46
# 46  [Cr52, B11, S33, U238, Ca42, Mg24, Zr90, Sc45,...                  47
# 47  [Cr52, B11, S33, U238, Ca42, Mg24, Zr90, Sc45,...                  48
# 48  [Cr52, B11, S33, U238, Ca42, Mg24, Zr90, Sc45,...                  49
# 49  [Cr52, B11, S33, U238, Ca42, Mg24, Zr90, Sc45,...                  50
# 50  [Cr52, B11, S33, U238, Ca42, Mg24, Zr90, Sc45,...                  51
# 51  [Cr52, B11, S33, U238, Ca42, Mg24, Zr90, Sc45,...                  52
# 52  [Cr52, B11, S33, U238, Ca42, Mg24, Zr90, Sc45,...                  53
#
#       scores
# 0   0.125155
# 1   0.223884
# 2   0.281821
# 3   0.357163
# 4   0.405163
# 5   0.479352
# 6   0.524535
# 7   0.550284
# 8   0.591860
# 9   0.593932
# 10  0.593044
# 11  0.605944
# 12  0.624865
# 13  0.635630
# 14  0.638616
# 15  0.643518
# 16  0.636034
# 17  0.634664
# 18  0.654815
# 19  0.656818
# 20  0.657657
# 21  0.667813
# 22  0.661005
# 23  0.661827
# 24  0.670445
# 25  0.661078
# 26  0.666739
# 27  0.666789
# 28  0.658467
# 29  0.666763
# 30  0.668964
# 31  0.656951
# 32  0.660757
# 33  0.662021
# 34  0.665058
# 35  0.667531
# 36  0.667812
# 37  0.662019
# 38  0.670779
# 39  0.671754
# 40  0.661586
# 41  0.664016
# 42  0.653108
# 43  0.657988
# 44  0.657159
# 45  0.652073
# 46  0.649976
# 47  0.644537
# 48  0.654194
# 49  0.647764
# 50  0.651768
# 51  0.652868
# 52  0.653689

# %%
sns.lmplot(data = rankedModels_df, x = 'number_of_features', y = 'scores', fit_reg=False)

# %%
bestNumberFeats = list(rankedModels_df[rankedModels_df['scores']==rankedModels_df['scores'].max()]['number_of_features'])[0]

# %%
best_feats_row = rankedModels_df[rankedModels_df['number_of_features'] == bestNumberFeats]

# %%
best_feats_ranks = list(best_feats_row['features'])[0]

# %%
best_feats_ranks
# Out:
# ['Cr52',
#  'B11',
#  'S33',
#  'U238',
#  'Ca42',
#  'Mg24',
#  'Zr90',
#  'Sc45',
#  'Rb85',
#  'P31',
#  'V51',
#  'Ge72',
#  'Sr88',
#  'Ba137',
#  'Fe56',
#  'Al27',
#  'Li7',
#  'Mn55',
#  'La139',
#  'Ce140',
#  'Si28',
#  'Nd146',
#  'Ga69',
#  'Pr141',
#  'Ni60',
#  'K39',
#  'Cu63',
#  'As75',
#  'Nb93',
#  'Pb208',
#  'Cd111',
#  'Sm147',
#  'Y89',
#  'Zn68',
#  'Ti47',
#  'Co59',
#  'Sn118',
#  'Yb172',
#  'Cs133',
#  'Dy163']

# %%
# %store best_feats_ranks
# %store best_feats
# Out:
# Stored 'best_feats_ranks' (list)
# Stored 'best_feats' (list)
