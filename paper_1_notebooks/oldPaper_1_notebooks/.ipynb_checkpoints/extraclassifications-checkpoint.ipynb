# %%
import pickle
import pandas as pd
pd.set_option('max.rows', None)
pd.set_option('max.columns', None)
import numpy as np
import swifter

# %%
# %store -r uniques

# %%
my_rfc = pickle.load(open('models/grouped_rfc_model.sav', 'rb'))

# %%
data = pd.read_csv('../data/ExtraArtefacts_OutliersNOTRemoved.csv')

# %%
identifiers =  data['Analysis']

# %%
data.columns.values[2:,]
# Out:
# array(['Li7', 'Be9', 'B11', 'Mg24', 'Al27', 'Si28', 'P31', 'S33', 'K39',
#        'Ca42', 'Sc45', 'Ti47', 'V51', 'Cr52', 'Mn55', 'Fe56', 'Co59',
#        'Ni60', 'Cu63', 'Zn68', 'Ga69', 'Ge72', 'As75', 'Rb85', 'Sr88',
#        'Y89', 'Zr90', 'Nb93', 'Mo95', 'Cd111', 'In115', 'Sn118', 'Cs133',
#        'Ba137', 'La139', 'Ce140', 'Pr141', 'Nd146', 'Sm147', 'Eu153',
#        'Gd157', 'Tb159', 'Dy163', 'Ho165', 'Er166', 'Tm169', 'Yb172',
#        'Lu175', 'Hf178', 'Ta181', 'Pb208', 'Th232', 'U238'], dtype=object)

# %%
element_data = data[data.columns.values[2:,]]

# %%
# Out:
# array(['FH', 'ER', 'WW', 'TC', 'CS', 'BC', 'KQ', 'AR', 'SL', 'FG', 'WB',
#        'BX', 'PF', 'BM', 'WH', 'SQ', 'BP', 'WN', 'BH', 'PH', 'LB', 'AB',
#        'LV', 'BR', 'KY', 'BF', 'ST', 'SH', 'CF', 'BG', 'AC', 'CR', 'GH',
#        'PX', 'WF', 'DH', 'NMAG_Gold', 'NMW_Gold', 'NMWGwern', 'UBSS',
#        'Cefn', 'Stockley', 'Pucha', 'Woodbury', 'Pimple', 'Wellington',
#        'Lyonshall', 'SymondsYatE', 'Madawg'], dtype=object)

# %% [markdown]
# ### Remove '<' signs.

# %%
for column_name in element_data.columns.values:
    def fill_less_than(row):
        if '<' in str(row[column_name]):
            return(float(row[column_name].replace('<', '').replace(',','')))
        else:
            return(float(row[column_name]))
    element_data[column_name] = element_data.swifter.apply(fill_less_than, axis = 1)
# Out:
# Pandas Apply: 100%|██████████| 60/60 [00:00<00:00, 8214.73it/s]
# /home/robert/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# Pandas Apply: 100%|██████████| 60/60 [00:00<00:00, 7214.56it/s]
# Pandas Apply: 100%|██████████| 60/60 [00:00<00:00, 8481.05it/s]
# Pandas Apply: 100%|██████████| 60/60 [00:00<00:00, 13492.29it/s]
# Pandas Apply: 100%|██████████| 60/60 [00:00<00:00, 6575.17it/s]
# Pandas Apply: 100%|██████████| 60/60 [00:00<00:00, 12129.86it/s]
# Pandas Apply: 100%|██████████| 60/60 [00:00<00:00, 11444.73it/s]
# Pandas Apply: 100%|██████████| 60/60 [00:00<00:00, 6268.89it/s]
# Pandas Apply: 100%|██████████| 60/60 [00:00<00:00, 10576.99it/s]
# Pandas Apply: 100%|██████████| 60/60 [00:00<00:00, 14143.67it/s]
# Pandas Apply: 100%|██████████| 60/60 [00:00<00:00, 11203.23it/s]
# Pandas Apply: 100%|██████████| 60/60 [00:00<00:00, 11163.48it/s]
# Pandas Apply: 100%|██████████| 60/60 [00:00<00:00, 7363.81it/s]
# Pandas Apply: 100%|██████████| 60/60 [00:00<00:00, 11103.39it/s]
# Pandas Apply: 100%|██████████| 60/60 [00:00<00:00, 10545.08it/s]
# Pandas Apply: 100%|██████████| 60/60 [00:00<00:00, 6340.60it/s]
# Pandas Apply: 100%|██████████| 60/60 [00:00<00:00, 12270.03it/s]
# Pandas Apply: 100%|██████████| 60/60 [00:00<00:00, 6548.65it/s]
# Pandas Apply: 100%|██████████| 60/60 [00:00<00:00, 9813.53it/s]
# Pandas Apply: 100%|██████████| 60/60 [00:00<00:00, 10576.10it/s]
# Pandas Apply: 100%|██████████| 60/60 [00:00<00:00, 7899.62it/s]
# Pandas Apply: 100%|██████████| 60/60 [00:00<00:00, 10724.38it/s]
# Pandas Apply: 100%|██████████| 60/60 [00:00<00:00, 9684.75it/s]
# Pandas Apply: 100%|██████████| 60/60 [00:00<00:00, 7540.77it/s]
# Pandas Apply: 100%|██████████| 60/60 [00:00<00:00, 10906.57it/s]
# Pandas Apply: 100%|██████████| 60/60 [00:00<00:00, 5023.32it/s]
# Pandas Apply: 100%|██████████| 60/60 [00:00<00:00, 8952.94it/s]
# Pandas Apply: 100%|██████████| 60/60 [00:00<00:00, 12254.49it/s]
# Pandas Apply: 100%|██████████| 60/60 [00:00<00:00, 7403.89it/s]
# Pandas Apply: 100%|██████████| 60/60 [00:00<00:00, 7630.86it/s]
# Pandas Apply: 100%|██████████| 60/60 [00:00<00:00, 9962.72it/s]
# Pandas Apply: 100%|██████████| 60/60 [00:00<00:00, 10407.27it/s]
# Pandas Apply: 100%|██████████| 60/60 [00:00<00:00, 7185.92it/s]
# Pandas Apply: 100%|██████████| 60/60 [00:00<00:00, 5209.34it/s]
# Pandas Apply: 100%|██████████| 60/60 [00:00<00:00, 5468.57it/s]
# Pandas Apply: 100%|██████████| 60/60 [00:00<00:00, 7522.52it/s]
# Pandas Apply: 100%|██████████| 60/60 [00:00<00:00, 11617.50it/s]
# Pandas Apply: 100%|██████████| 60/60 [00:00<00:00, 7755.74it/s]
# Pandas Apply: 100%|██████████| 60/60 [00:00<00:00, 7205.47it/s]
# Pandas Apply: 100%|██████████| 60/60 [00:00<00:00, 5220.80it/s]
# Pandas Apply: 100%|██████████| 60/60 [00:00<00:00, 7509.94it/s]
# Pandas Apply: 100%|██████████| 60/60 [00:00<00:00, 7492.95it/s]
# Pandas Apply: 100%|██████████| 60/60 [00:00<00:00, 10859.51it/s]
# Pandas Apply: 100%|██████████| 60/60 [00:00<00:00, 9679.91it/s]
# Pandas Apply: 100%|██████████| 60/60 [00:00<00:00, 7722.66it/s]
# Pandas Apply: 100%|██████████| 60/60 [00:00<00:00, 8717.25it/s]
# Pandas Apply: 100%|██████████| 60/60 [00:00<00:00, 9826.18it/s]
# Pandas Apply: 100%|██████████| 60/60 [00:00<00:00, 7232.39it/s]
# Pandas Apply: 100%|██████████| 60/60 [00:00<00:00, 6768.46it/s]
# Pandas Apply: 100%|██████████| 60/60 [00:00<00:00, 5695.94it/s]
# Pandas Apply: 100%|██████████| 60/60 [00:00<00:00, 8610.47it/s]
# Pandas Apply: 100%|██████████| 60/60 [00:00<00:00,
anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
y_pred = my_rfc.predict(np.array(element_data))

y_pred_proba = my_rfc.predict_proba(np.array(element_data))

# %%
probabilities_df = pd.DataFrame(data = y_pred_proba, columns = uniques)
probabilities_df_final = pd.concat([probabilities_df, pd.Series(list(identifiers))], axis = 1)

# %%
probabilities_df_final.rename(columns = {0:'identifier'}, inplace=True)

# %%
final_pred_df = pd.concat([pd.Series(y_pred), probabilities_df_final], axis = 1)

# %%
final_pred_df.rename(columns={0:'class_number'}, inplace = True)

# %%
uniques_list = list(uniques)
def get_pred_names(row):
    return(uniques_list[row['class_number']])
final_pred_df['class_predictions'] = final_pred_df.apply(get_pred_names, axis = 1)

# %%
#final_pred_df_modal = final_pred_df.groupby(by = 'class_number')

# %%
final_pred_df.to_csv('output/Extrapredictions.csv')

# %%
final_pred_df.head()
# Out:
#    class_number        FH        ER      WW      TC   BC_CS      KQ      AR  \
# 0            20  0.064550  0.080150  0.0690  0.0585  0.0535  0.0210  0.0105
# 1            23  0.083175  0.084957  0.0520  0.0615  0.0535  0.0140  0.0105
# 2            16  0.051146  0.020141  0.0640  0.0400  0.0535  0.0155  0.0065
# 3            22  0.003411  0.007654  0.0025  0.0155  0.0405  0.0250  0.0085
# 4            20  0.009274  0.018504  0.0075  0.0220  0.0385  0.0255  0.0155
#
#        SL      FG     WB_BX      PF      BM      WH   SQ_BP      WN      BH  \
# 0  0.0255  0.0055  0.019050  0.0020  0.0415  0.0085  0.0150  0.0105  0.0015
# 1  0.0195  0.0025  0.012770  0.0015  0.0355  0.0120  0.0150  0.0160  0.0005
# 2  0.0175  0.0070  0.011682  0.0005  0.0250  0.0130  0.0245  0.0275  0.0025
# 3  0.0195  0.0035  0.022146  0.0020  0.0255  0.0060  0.0085  0.0065  0.0015
# 4  0.0200  0.0040  0.024017  0.0030  0.0235  0.0050  0.0030  0.0080  0.0055
#
#          PH      LB      AB      LV     SV_SE        BA      WA      MM  \
# 0  0.072300  0.0205  0.0145  0.0480  0.141767  0.025683  0.0615  0.1295
# 1  0.086270  0.0255  0.0115  0.0560  0.120187  0.027142  0.0775  0.1210
# 2  0.142660  0.0220  0.0295  0.1195  0.126841  0.022029  0.0730  0.0845
# 3  0.046208  0.0320  0.0100  0.0280  0.156653  0.037928  0.3880  0.1030
# 4  0.094050  0.0395  0.0285  0.0635  0.256530  0.061126  0.1340  0.0900
#
#       identifier class_predictions
# 0  06_VC77.5_1_1             SV_SE
# 1  07_VC77.5_1_2                MM
# 2  08_VC77.5_1_3                PH
# 3  09_VC77.5_2_1                WA
# 4  10_VC77.5_2_2             SV_SE
