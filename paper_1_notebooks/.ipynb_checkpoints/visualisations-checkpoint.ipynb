# %% [markdown]
# # final visualisations for paper

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# # tsne bedrock

# %%
save_plots = True

# %%
filepath = 'final_figures/bedrock_tsne.eps'
tsne_data_with_colour = pd.read_csv('output_datasets/pre_model_datasets/tsne_data_with_color_bedrock.csv')

# %%
sns.set(rc={'figure.figsize':(2.8,2.8)})


plot_on_x = 'tsne1'
plot_on_y = 'tsne2'
sns.set(font_scale=0.5)
plot = sns.scatterplot(data = tsne_data_with_colour, linewidth = 0.3, legend = False, edgecolor = 'black', s= 2.8, x = plot_on_x, y = plot_on_y, hue='class',
                palette=sns.color_palette("Paired", tsne_data_with_colour['class'].nunique()))

plt.title('t-SNE Analysis of Bedrock Sample Data', fontsize = 10)

plt.yticks(fontsize = 5)
plt.xticks(fontsize = 5)
plt.tight_layout()


if save_plots == True:
    fig = plot.get_figure()
    fig.savefig(fname=filepath, dpi = 2000, pad_inches = 0.5)

# %% [markdown]
# # tsne superficial

# %%
filepath = 'final_figures/superficial_tsne.eps'

tsne_data_with_colour = pd.read_csv('output_datasets/pre_model_datasets/tsne_data_with_color_superficial.csv')

# %%
sns.set(rc={'figure.figsize':(2.8,2.8)})


plot_on_x = 'tsne1'
plot_on_y = 'tsne2'
sns.set(font_scale=0.5)
plot = sns.scatterplot(data = tsne_data_with_colour, linewidth = 0.3, edgecolor = 'black', s= 2.8, x = plot_on_x, y = plot_on_y, hue='class',
                palette=sns.color_palette("Paired", tsne_data_with_colour['class'].nunique()))

plt.title('t-SNE of Superficial Sample Data', fontsize = 8)
plt.legend(fontsize=2.5, markerscale=0.07)
plt.yticks(fontsize = 5)
plt.xticks(fontsize = 5)
plt.tight_layout()

if save_plots == True:
    fig = plot.get_figure()
    fig.savefig(fname=filepath, dpi = 2000, pad_inches = 0.5)

# %% [markdown]
# # tsne artefact

# %%
filepath = 'final_figures/artefact_tsne.eps'

tsne_data_with_colour = pd.read_csv('output_datasets/pre_model_datasets/tsne_data_with_color_test.csv')

# %%
sns.set(rc={'figure.figsize':(2.8,2.8)})


plot_on_x = 'tsne1'
plot_on_y = 'tsne2'
sns.set(font_scale=0.5)
plot = sns.scatterplot(data = tsne_data_with_colour, linewidth = 0.3, edgecolor = 'black', s= 2.8, x = plot_on_x, y = plot_on_y, hue='class',
                palette=sns.color_palette("Paired", tsne_data_with_colour['class'].nunique()))

plt.title('t-SNE of Artefact Sample Data', fontsize = 8)
plt.legend(fontsize=2.5, markerscale=0.07)
plt.yticks(fontsize = 5)
plt.xticks(fontsize = 5)
plt.tight_layout()

if save_plots == True:
    fig = plot.get_figure()
    fig.savefig(fname=filepath, dpi = 2000, pad_inches = 0.5)

# %% [markdown]
# # tsne outliers

# %%
filepath = 'final_figures/outlier_tsne.eps'

tsne_data_with_colour = pd.read_csv('output_datasets/pre_model_datasets/tsne_outlier_data.csv')

# %%
sns.set(rc={'figure.figsize':(2.8,2.8)})

plot_on_x = 'tsne1'
plot_on_y = 'tsne2'

sns.set(font_scale=0.8)
plot = sns.scatterplot(data = tsne_data_with_colour, s= 8, x = plot_on_x, y = plot_on_y, hue='inlierLabel', linewidth = 0.3, edgecolor = 'black',
                palette=sns.color_palette("muted", tsne_data_with_colour['inlierLabel'].nunique())
               )
plt.title('t-SNE of Superficial Sample Data', fontsize = 10)
plt.legend(fontsize=5, markerscale=0.16)

plt.tight_layout()


if save_plots == True:
    fig = plot.get_figure()
    fig.savefig(fname=filepath, dpi = 2000, pad_inches = 0.5)

# %% [markdown]
# # RFE

# %%
filepath = 'final_figures/RFE.eps'

RFCV_df = pd.read_csv('output_datasets/pre_model_datasets/RFCV_DF.csv')

# %%
sns.set(rc={'figure.figsize':(2.7,2.7)})
sns.set(font_scale=0.6)

plot = sns.scatterplot(data = RFCV_df, x = 'Number of Features', y = 'F1 Score', s = 8, alpha = 0.2)

plt.title('Features evaluated by F1 score', fontsize = 10)
plot.set_xlabel('Number of Features',fontsize=8)
plot.set_ylabel('F1 Score',fontsize=8)

plt.yticks(fontsize = 7)
plt.xticks(fontsize = 7)
plt.tight_layout()

if save_plots:
    fig = plot.get_figure()
    fig.savefig(filepath)

# %% [markdown]
# # learning curve

# %%
filepath = 'final_figures/LC.eps'

rfc_lc = pd.read_csv('output_datasets/pre_model_datasets/rfc_lc.csv')

# %%
sns.set(rc={'figure.figsize':(2.7,2.7)})
sns.set(rc={"lines.linewidth": 0.6})

plot = sns.lineplot(x = 'train_sizes', y = 'k_fold_stratified_scores', hue = 'train_or_test_data', ci = 'sd', err_style='bars', data = rfc_lc, markers = True)




plot.set_ylabel("F1 score",fontsize=8)
plot.set_xlabel("train fold size (number of observations)",fontsize=8)
plot.tick_params(labelsize=5, length=8, width=2 )

plt.title('learning curve', fontsize = 10)

plt.yticks(fontsize = 7)
plt.xticks(fontsize = 7)

plt.tight_layout()

plt.legend(fontsize = 5, loc = 4)

if save_plots == True:
    fig = plot.get_figure()
    fig.savefig(filepath)

# %% [markdown]
# # knn boxplot

# %%
filepath = 'final_figures/macro_f1_knn.eps'
data = pd.read_table('output_datasets/knn_datasets/macro_f1_scores', header = None)

# %%
sns.set(rc={'figure.figsize':(2.7,2.7)})

plot = sns.boxplot(data, width = 0.4)
plot.set_title('KNN classifier evaluation', fontdict={'fontsize': 10.4})
plot.set_xlabel("F1-score", fontdict={'fontsize': 9})
plot.tick_params(labelsize=5, length=6, width=2 )
plt.tight_layout()
if save_plots == True:
    fig = plot.get_figure()
    fig.savefig(filepath)

# %% [markdown]
# # svm boxplot

# %%
filepath = 'final_figures/macro_f1_svm.eps'
data = pd.read_table('output_datasets/svm_datasets/macro_f1_scores', header = None)

# %%
sns.set(rc={'figure.figsize':(2.7,2.7)})

plot = sns.boxplot(data, width = 0.4)
plot.set_title('svm classifier evaluation', fontdict={'fontsize': 10.4})
plot.set_xlabel("F1-score", fontdict={'fontsize': 9})
plot.tick_params(labelsize=5, length=6, width=2 )
plt.tight_layout()
if save_plots == True:
    fig = plot.get_figure()
    fig.savefig(filepath)

# %% [markdown]
# # rfc boxplot

# %%
filepath = 'final_figures/macro_f1_rfc.eps'
data = pd.read_table('output_datasets/rfc_datasets/macro_f1_scores', header = None)

# %%
sns.set(rc={'figure.figsize':(2.7,2.7)})

plot = sns.boxplot(data, width = 0.4)
plot.set_title('RFC classifier evaluation', fontdict={'fontsize': 10.4})
plot.set_xlabel("F1-score", fontdict={'fontsize': 9})
plot.tick_params(labelsize=5, length=6, width=2 )
plt.tight_layout()
if save_plots == True:
    fig = plot.get_figure()
    fig.savefig(filepath)

# %% [markdown]
# # knn class F1 scores

# %%
filepath = 'final_figures/site_specific_f1_scores_knn.eps'
f1_df_final = pd.read_csv('output_datasets/knn_datasets/cross_validation_results.csv')

# %%
f1_df_final.set_index('class', inplace=True)

# %%
sns.set(rc={'figure.figsize':(2.5,2.5)})
sns.set( rc={"lines.linewidth": 0.6})
plot = sns.boxplot(data = f1_df_final.T, width = 0.6)
plot.set_title('F1 scores for each site (KNN)', fontdict={'fontsize': 10})

plot.set_ylabel('F1 score', fontdict={'fontsize': 6})
plot.set_xlabel("Archeological site", fontdict={'fontsize': 6})
plot.tick_params(labelsize=3, length=10, width=2 )
plt.tight_layout()
plot.set_yticklabels(labels = plot.get_yticklabels(), fontsize = 4)
plot.set_xticklabels(labels = plot.get_xticklabels(), rotation=50, fontsize = 4, ha = 'right')

if save_plots:
    fig = plot.get_figure()
    fig.savefig(filepath)

# %% [markdown]
# # svm class F1 scores

# %%
filepath = 'final_figures/site_specific_f1_scores_svm.eps'
f1_df_final = pd.read_csv('output_datasets/svm_datasets/cross_validation_results.csv')

# %%
f1_df_final.set_index('class', inplace=True)

# %%
sns.set(rc={'figure.figsize':(2.5,2.5)})
sns.set( rc={"lines.linewidth": 0.6})
plot = sns.boxplot(data = f1_df_final.T, width = 0.6)
plot.set_title('F1 scores for each site (SVM)', fontdict={'fontsize': 10})

plot.set_ylabel('F1 score', fontdict={'fontsize': 6})
plot.set_xlabel("Archeological site", fontdict={'fontsize': 6})
plot.tick_params(labelsize=3, length=10, width=2 )
plt.tight_layout()
plot.set_yticklabels(labels = plot.get_yticklabels(), fontsize = 4)
plot.set_xticklabels(labels = plot.get_xticklabels(), rotation=50, fontsize = 4, ha = 'right')

if save_plots:
    fig = plot.get_figure()
    fig.savefig(filepath)

# %% [markdown]
# # RFC class F1 scores

# %%
filepath = 'final_figures/site_specific_f1_scores_rfc.eps'
f1_df_final = pd.read_csv('output_datasets/rfc_datasets/cross_validation_results.csv')

# %%
f1_df_final.set_index('class', inplace=True)

# %%
sns.set(rc={'figure.figsize':(2.5,2.5)})
sns.set( rc={"lines.linewidth": 0.6})
plot = sns.boxplot(data = f1_df_final.T, width = 0.6)
plot.set_title('F1 scores for each site (RFC)', fontdict={'fontsize': 10})

plot.set_ylabel('F1 score', fontdict={'fontsize': 6})
plot.set_xlabel("Archeological site", fontdict={'fontsize': 6})
plot.tick_params(labelsize=3, length=10, width=2 )
plt.tight_layout()
plot.set_yticklabels(labels = plot.get_yticklabels(), fontsize = 4)
plot.set_xticklabels(labels = plot.get_xticklabels(), rotation=50, fontsize = 4, ha = 'right')

if save_plots:
    fig = plot.get_figure()
    fig.savefig(filepath)

# %% [markdown]
# # knn f1 vs sample size

# %%
forPlot = pd.read_csv('output_datasets/knn_datasets/score_vs_sample_number.csv')
filepath = 'final_figures/f1vssamplesizeknn.eps'

# %%
    
    
sns.set(rc={'figure.figsize':(2.8,2.5)})
sns.set(font_scale=0.6)

plot = sns.scatterplot(x ='Number of Observations', y = 'Mean F1 Score', data = forPlot, s = 8, alpha = 0.2)

plt.title("effect of sample size on f1 score (KNN)", fontsize = 8)


plt.yticks(fontsize = 7)
plt.xticks(fontsize = 7)
plt.tight_layout()

if save_plots:
    fig = plot.get_figure()
    fig.savefig(filepath)

# %% [markdown]
# # svm f1 vs sample size

# %%
forPlot = pd.read_csv('output_datasets/svm_datasets//score_vs_sample_number.csv')
filepath = 'final_figures/f1vssamplesize_svm.eps'

# %%
    
    
sns.set(rc={'figure.figsize':(2.8,2.5)})
sns.set(font_scale=0.6)

plot = sns.scatterplot(x ='Number of Observations', y = 'Mean F1 Score', data = forPlot, s = 8, alpha = 0.2)

plt.title("effect of sample size on f1 score (SVM)", fontsize = 8)


plt.yticks(fontsize = 7)
plt.xticks(fontsize = 7)
plt.tight_layout()

if save_plots:
    fig = plot.get_figure()
    fig.savefig(filepath)

# %% [markdown]
# # rfc f1 vs sample size

# %%
forPlot = pd.read_csv('output_datasets/rfc_datasets/score_vs_sample_number.csv')
filepath = 'final_figures/f1vssamplesizerfc.eps'

# %%
    
    
sns.set(rc={'figure.figsize':(2.8,2.5)})
sns.set(font_scale=0.6)

plot = sns.scatterplot(x ='Number of Observations', y = 'Mean F1 Score', data = forPlot, s = 8, alpha = 0.2)

plt.title("effect of sample size on f1 score (RFC)", fontsize = 8)


plt.yticks(fontsize = 7)
plt.xticks(fontsize = 7)
plt.tight_layout()

if save_plots:
    fig = plot.get_figure()
    fig.savefig(filepath)
