# %%
import pandas as pd
import numpy as np
import swifter
import seaborn as sns
pd.set_option('max.rows', None)
pd.set_option('max.columns', None)
import matplotlib.pyplot as plt


from sklearn.decomposition import PCA 
from sklearn.manifold import TSNE
from sklearn.preprocessing import StandardScaler
# %matplotlib inline
# Out:
# /Users/robbie.morse/anaconda3/lib/python3.7/site-packages/tqdm/autonotebook/__init__.py:14: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   " (e.g. in jupyter console)", TqdmExperimentalWarning)

# %%
# %store -r  X_test_labeled_df

# %%
save_plots = True

# %%
X_test_labeled_df.head()
# Out:
#    Analysis  Zr90  Nd146  Ba137  Sr88  Ge72  Ga69   Fe56  Cr52   V51  Sc45  \
# 0  06_DH1_1  1.43   0.34   5.95  2.00  1.37  0.69  35.38  5.18  0.51  1.08
# 1  07_DH1_2  1.47   0.24   7.51  1.84  1.93  0.86  49.23  5.43  0.60  1.09
# 2  08_DH1_3  1.16   0.08   4.40  1.93  2.14  0.79  16.46  2.61  0.62  1.17
# 3  09_DH2_1  1.45   0.25  12.48  4.29  1.59  0.75  16.76  2.87  1.52  1.19
# 4  10_DH2_2  1.99   0.51  14.40  4.44  0.81  0.76  62.16  5.92  2.44  1.22
#
#        U238     S33    B11    Ca42        Al27   Mg24    P31         K39  \
# 0  0.308493  806.55  93.21  119.05  635.240000  27.83  35.07  443.100000
# 1  0.308493  807.55  95.19  119.74  639.090000  27.99  31.65  442.100000
# 2  0.308493  837.73  93.63  140.99  670.480000  26.43  25.43  444.280000
# 3  0.080000  750.62  63.80  141.70  622.829745  31.98  24.63  384.321679
# 4  0.090000  796.21  60.96  130.52  622.829745  44.95  22.59  384.321679
#
#    Ce140  La139   Cu63  Mn55       Si28      Rb85      Nb93    Cd111  Pr141  \
# 0   0.57   0.18  11.14  3.27  465388.29  0.720000  0.224476  0.20924   0.07
# 1   0.53   0.19   8.64  2.30  465388.40  0.770000  0.224476  0.20924   0.06
# 2   0.20   0.11   3.44  1.40  465378.49  0.710000  0.224476  0.20924   0.03
# 3   0.40   0.23   1.10  1.09  464555.55  1.620000  0.250000  0.22000   0.06
# 4   0.80   0.48   1.23  1.26  464137.82  0.735489  0.680000  0.09000   0.12
#
#      Li7  Ni60   Zn68  inlierLabel
# 0   2.79  1.03  20.75            1
# 1   2.37  1.22  18.15            1
# 2   2.46  1.01  17.54            1
# 3  18.47  1.07  14.33           -1
# 4  19.98  0.93  14.59            1

# %% [markdown]
# ## data preproccessing for dimensionality reduction and visualisation

# %%
element_data = X_test_labeled_df[X_test_labeled_df.columns.values[1:-1]]
element_data.head()
# Out:
#    Zr90  Nd146  Ba137  Sr88  Ge72  Ga69   Fe56  Cr52   V51  Sc45      U238  \
# 0  1.43   0.34   5.95  2.00  1.37  0.69  35.38  5.18  0.51  1.08  0.308493
# 1  1.47   0.24   7.51  1.84  1.93  0.86  49.23  5.43  0.60  1.09  0.308493
# 2  1.16   0.08   4.40  1.93  2.14  0.79  16.46  2.61  0.62  1.17  0.308493
# 3  1.45   0.25  12.48  4.29  1.59  0.75  16.76  2.87  1.52  1.19  0.080000
# 4  1.99   0.51  14.40  4.44  0.81  0.76  62.16  5.92  2.44  1.22  0.090000
#
#       S33    B11    Ca42        Al27   Mg24    P31         K39  Ce140  La139  \
# 0  806.55  93.21  119.05  635.240000  27.83  35.07  443.100000   0.57   0.18
# 1  807.55  95.19  119.74  639.090000  27.99  31.65  442.100000   0.53   0.19
# 2  837.73  93.63  140.99  670.480000  26.43  25.43  444.280000   0.20   0.11
# 3  750.62  63.80  141.70  622.829745  31.98  24.63  384.321679   0.40   0.23
# 4  796.21  60.96  130.52  622.829745  44.95  22.59  384.321679   0.80   0.48
#
#     Cu63  Mn55       Si28      Rb85      Nb93    Cd111  Pr141    Li7  Ni60  \
# 0  11.14  3.27  465388.29  0.720000  0.224476  0.20924   0.07   2.79  1.03
# 1   8.64  2.30  465388.40  0.770000  0.224476  0.20924   0.06   2.37  1.22
# 2   3.44  1.40  465378.49  0.710000  0.224476  0.20924   0.03   2.46  1.01
# 3   1.10  1.09  464555.55  1.620000  0.250000  0.22000   0.06  18.47  1.07
# 4   1.23  1.26  464137.82  0.735489  0.680000  0.09000   0.12  19.98  0.93
#
#     Zn68
# 0  20.75
# 1  18.15
# 2  17.54
# 3  14.33
# 4  14.59

# %% [markdown]
# ### features are standardised

# %%
my_scaler_train = StandardScaler()

# %%
element_data_scaled = my_scaler_train.fit_transform(element_data)

# %% [markdown]
# ### T-Distributed Stochastic Neighbour Embedding is done

# %%
my_tsne = TSNE(n_components=2, n_iter=5000, verbose=3).fit_transform(element_data_scaled)
# Out:
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 363 samples in 0.000s...
# [t-SNE] Computed neighbors for 363 samples in 0.011s...
# [t-SNE] Computed conditional probabilities for sample 363 / 363
# [t-SNE] Mean sigma: 1.945459
# [t-SNE] Computed conditional probabilities in 0.012s
# [t-SNE] Iteration 50: error = 64.9480743, gradient norm = 0.5257088 (50 iterations in 0.106s)
# [t-SNE] Iteration 100: error = 63.8108597, gradient norm = 0.5564712 (50 iterations in 0.111s)
# [t-SNE] Iteration 150: error = 65.9767685, gradient norm = 0.4970888 (50 iterations in 0.114s)
# [t-SNE] Iteration 200: error = 68.0332489, gradient norm = 0.4947494 (50 iterations in 0.116s)
# [t-SNE] Iteration 250: error = 66.0228119, gradient norm = 0.5248109 (50 iterations in 0.117s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 66.022812
# [t-SNE] Iteration 300: error = 0.8187100, gradient norm = 0.0029216 (50 iterations in 0.098s)
# [t-SNE] Iteration 350: error = 0.7056741, gradient norm = 0.0010137 (50 iterations in 0.085s)
# [t-SNE] Iteration 400: error = 0.6781244, gradient norm = 0.0009457 (50 iterations in 0.084s)
# [t-SNE] Iteration 450: error = 0.6688634, gradient norm = 0.0002344 (50 iterations in 0.084s)
# [t-SNE] Iteration 500: error = 0.6672264, gradient norm = 0.0001868 (50 iterations in 0.081s)
# [t-SNE] Iteration 550: error = 0.6670708, gradient norm = 0.0001180 (50 iterations in 0.080s)
# [t-SNE] Iteration 600: error = 0.6669490, gradient norm = 0.0000993 (50 iterations in 0.082s)
# [t-SNE] Iteration 650: error = 0.6667598, gradient norm = 0.0000720 (50 iterations in 0.080s)
# [t-SNE] Iteration 700: error = 0.6667369, gradient norm = 0.0000840 (50 iterations in 0.079s)
# [t-SNE] Iteration 750: error = 0.6664246, gradient norm = 0.0001215 (50 iterations in 0.081s)
# [t-SNE] Iteration 800: error = 0.6664775, gradient norm = 0.0001104 (50 iterations in 0.080s)
# [t-SNE] Iteration 850: error = 0.6664091, gradient norm = 0.0000690 (50 iterations in 0.085s)
# [t-SNE] Iteration 900: error = 0.6662800, gradient norm = 0.0000751 (50 iterations in 0.088s)
# [t-SNE] Iteration 950: error = 0.6662356, gradient norm = 0.0000803 (50 iterations in 0.086s)
# [t-SNE] Iteration 1000: error = 0.6663092, gradient norm = 0.0001147 (50 iterations in 0.083s)
# [t-SNE] Iteration 1050: error = 0.6662891, gradient norm = 0.0000848 (50 iterations in 0.085s)
# [t-SNE] Iteration 1100: error = 0.6662936, gradient norm = 0.0001148 (50 iterations in 0.085s)
# [t-SNE] Iteration 1150: error = 0.6660414, gradient norm = 0.0000946 (50 iterations in 0.088s)
# [t-SNE] Iteration 1200: error = 0.6659653, gradient norm = 0.0001688 (50 iterations in 0.086s)
# [t-SNE] Iteration 1250: error = 0.6660860, gradient norm = 0.0000824 (50 iterations in 0.080s)
# [t-SNE] Iteration 1300: error = 0.6661034, gradient norm = 0.0000822 (50 iterations in 0.081s)
# [t-SNE] Iteration 1350: error = 0.6659136, gradient norm = 0.0001082 (50 iterations in 0.083s)
# [t-SNE] Iteration 1400: error = 0.6658776, gradient norm = 0.0001258 (50 iterations in 0.081s)
# [t-SNE] Iteration 1450: error = 0.6658087, gradient norm = 0.0001525 (50 iterations in 0.086s)
# [t-SNE] Iteration 1500: error = 0.6658091, gradient norm = 0.0001019 (50 iterations in 0.089s)
# [t-SNE] Iteration 1550: error = 0.6658328, gradient norm = 0.0000971 (50 iterations in 0.086s)
# [t-SNE] Iteration 1600: error = 0.6660092, gradient norm = 0.0000844 (50 iterations in 0.079s)
# [t-SNE] Iteration 1650: error = 0.6660171, gradient norm = 0.0000988 (50 iterations in 0.083s)
# [t-SNE] Iteration 1700: error = 0.6659886, gradient norm = 0.0001061 (50 iterations in 0.091s)
# [t-SNE] Iteration 1750: error = 0.6659074, gradient norm = 0.0001261 (50 iterations in 0.089s)
# [t-SNE] Iteration 1800: error = 0.6659324, gradient norm = 0.0001034 (50 iterations in 0.085s)
# [t-SNE] Iteration 1800: did not make any progress during the last 300 episodes. Finished.
# [t-SNE] KL divergence after 1800 iterations: 0.665932

# %% [markdown]
# ### the t-SNE dimensions are put into a dataframe

# %%
tsne_df = pd.DataFrame(data = my_tsne, columns = ['tsne1', 'tsne2'])

# %% [markdown]
# ### datasets are stored for the purpose of two-dimensional visualisations

# %%
tsne_data_with_colour = pd.concat([tsne_df, X_test_labeled_df['inlierLabel']], axis = 1)

# %%
tsne_data_with_colour.head()
# Out:
#        tsne1      tsne2  inlierLabel
# 0   2.222644 -16.813370            1
# 1   2.785129 -16.547159            1
# 2   3.674113 -16.154581            1
# 3 -16.101217 -14.507850           -1
# 4 -20.397480 -14.855265            1

# %% [markdown]
# ### visualise t-SNE in two dimensions

# %%
sns.set(rc={'figure.figsize':(50,40)})
plot = sns.scatterplot(data = tsne_data_with_colour, x = 'tsne1', y = 'tsne2', hue='inlierLabel', s = 800, palette = ['red', 'blue'])
plt.title('test')
plot.set_xlabel("train fold size (number of observations)",fontsize=50)
plot.set_ylabel("weighted F1 score",fontsize=50)
plot.set_xlabel("train fold size (number of observations)",fontsize=50)
plot.tick_params(labelsize=40)
plot.set_title('t-SNE visualisation of artefact data to show data points classified as outliers by the local outlier factor model', fontdict = {'fontsize': 80})

plt.legend(fontsize = 50, loc = 4, markerscale = 5)

if save_plots == True:
    fig = plot.get_figure()
    fig.savefig(fname='figures/2d_tSNE')
