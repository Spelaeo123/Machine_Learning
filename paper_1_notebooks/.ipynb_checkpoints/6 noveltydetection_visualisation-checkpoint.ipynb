# %% [markdown]
# ### Visualisation of outlier classification

# %%
import pandas as pd
import numpy as np
import swifter
import seaborn as sns
pd.set_option('max.rows', None)
pd.set_option('max.columns', None)
import matplotlib.pyplot as plt


from sklearn.decomposition import PCA 
from sklearn.manifold import TSNE
from sklearn.preprocessing import StandardScaler
# %matplotlib inline

# %%
# %store -r  X_test_labeled_df

# %%
save_plots = True

# %%
X_test_labeled_df.head()
# Out:
#    Analysis    Li7  Pr141  La139  Ba137  Sr88      Rb85  As75  Ge72  Ga69  \
# 0  06_DH1_1   2.79   0.07   0.18   5.95  2.00  0.720000  0.44  1.37  0.69
# 1  07_DH1_2   2.37   0.06   0.19   7.51  1.84  0.770000  0.44  1.93  0.86
# 2  08_DH1_3   2.46   0.03   0.11   4.40  1.93  0.710000  0.42  2.14  0.79
# 3  09_DH2_1  18.47   0.06   0.23  12.48  4.29  1.620000  0.46  1.59  0.75
# 4  10_DH2_2  19.98   0.12   0.48  14.40  4.44  0.753774  0.43  0.81  0.76
#
#     Fe56  Mn55  Cr52  Zr90      U238  Sc45    B11   Mg24  inlierLabel
# 0  35.38  3.27  5.18  1.43  0.250083  1.08  93.21  27.83            1
# 1  49.23  2.30  5.43  1.47  0.250083  1.09  95.19  27.99            1
# 2  16.46  1.40  2.61  1.16  0.250083  1.17  93.63  26.43            1
# 3  16.76  1.09  2.87  1.45  0.080000  1.19  63.80  31.98            1
# 4  62.16  1.26  5.92  1.99  0.090000  1.22  60.96  44.95            1

# %% [markdown]
# ## data preproccessing for dimensionality reduction and visualisation

# %%
element_data = X_test_labeled_df[X_test_labeled_df.columns.values[1:-1]]
element_data.head()
# Out:
#      Li7  Pr141  La139  Ba137  Sr88      Rb85  As75  Ge72  Ga69   Fe56  Mn55  \
# 0   2.79   0.07   0.18   5.95  2.00  0.720000  0.44  1.37  0.69  35.38  3.27
# 1   2.37   0.06   0.19   7.51  1.84  0.770000  0.44  1.93  0.86  49.23  2.30
# 2   2.46   0.03   0.11   4.40  1.93  0.710000  0.42  2.14  0.79  16.46  1.40
# 3  18.47   0.06   0.23  12.48  4.29  1.620000  0.46  1.59  0.75  16.76  1.09
# 4  19.98   0.12   0.48  14.40  4.44  0.753774  0.43  0.81  0.76  62.16  1.26
#
#    Cr52  Zr90      U238  Sc45    B11   Mg24
# 0  5.18  1.43  0.250083  1.08  93.21  27.83
# 1  5.43  1.47  0.250083  1.09  95.19  27.99
# 2  2.61  1.16  0.250083  1.17  93.63  26.43
# 3  2.87  1.45  0.080000  1.19  63.80  31.98
# 4  5.92  1.99  0.090000  1.22  60.96  44.95

# %% [markdown]
# ### features are standardised

# %%
my_scaler_train = StandardScaler()

# %%
element_data_scaled = my_scaler_train.fit_transform(element_data)

# %% [markdown]
# ### T-Distributed Stochastic Neighbour Embedding is done

# %%
my_tsne = TSNE(n_components=2, n_iter=5000, verbose=3).fit_transform(element_data_scaled)
# Out:
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 363 samples in 0.001s...
# [t-SNE] Computed neighbors for 363 samples in 0.014s...
# [t-SNE] Computed conditional probabilities for sample 363 / 363
# [t-SNE] Mean sigma: 1.591012
# [t-SNE] Computed conditional probabilities in 0.022s
# [t-SNE] Iteration 50: error = 65.4982605, gradient norm = 0.5332257 (50 iterations in 0.137s)
# [t-SNE] Iteration 100: error = 65.8143845, gradient norm = 0.5182995 (50 iterations in 0.146s)
# [t-SNE] Iteration 150: error = 66.2719269, gradient norm = 0.5145708 (50 iterations in 0.144s)
# [t-SNE] Iteration 200: error = 65.1184158, gradient norm = 0.5285295 (50 iterations in 0.142s)
# [t-SNE] Iteration 250: error = 66.0900040, gradient norm = 0.5234619 (50 iterations in 0.141s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 66.090004
# [t-SNE] Iteration 300: error = 0.9969393, gradient norm = 0.0035821 (50 iterations in 0.109s)
# [t-SNE] Iteration 350: error = 0.9269748, gradient norm = 0.0023277 (50 iterations in 0.103s)
# [t-SNE] Iteration 400: error = 0.8971508, gradient norm = 0.0008478 (50 iterations in 0.103s)
# [t-SNE] Iteration 450: error = 0.8840039, gradient norm = 0.0003972 (50 iterations in 0.103s)
# [t-SNE] Iteration 500: error = 0.8778222, gradient norm = 0.0002877 (50 iterations in 0.116s)
# [t-SNE] Iteration 550: error = 0.8668123, gradient norm = 0.0003805 (50 iterations in 0.112s)
# [t-SNE] Iteration 600: error = 0.8633876, gradient norm = 0.0001853 (50 iterations in 0.108s)
# [t-SNE] Iteration 650: error = 0.8606314, gradient norm = 0.0002465 (50 iterations in 0.108s)
# [t-SNE] Iteration 700: error = 0.8533103, gradient norm = 0.0002168 (50 iterations in 0.110s)
# [t-SNE] Iteration 750: error = 0.8527030, gradient norm = 0.0002655 (50 iterations in 0.110s)
# [t-SNE] Iteration 800: error = 0.8509929, gradient norm = 0.0005135 (50 iterations in 0.111s)
# [t-SNE] Iteration 850: error = 0.8485298, gradient norm = 0.0003159 (50 iterations in 0.111s)
# [t-SNE] Iteration 900: error = 0.8480347, gradient norm = 0.0001049 (50 iterations in 0.120s)
# [t-SNE] Iteration 950: error = 0.8482165, gradient norm = 0.0001090 (50 iterations in 0.112s)
# [t-SNE] Iteration 1000: error = 0.8480951, gradient norm = 0.0000993 (50 iterations in 0.110s)
# [t-SNE] Iteration 1050: error = 0.8480893, gradient norm = 0.0000954 (50 iterations in 0.110s)
# [t-SNE] Iteration 1100: error = 0.8481773, gradient norm = 0.0000678 (50 iterations in 0.112s)
# [t-SNE] Iteration 1150: error = 0.8480975, gradient norm = 0.0000947 (50 iterations in 0.111s)
# [t-SNE] Iteration 1200: error = 0.8479784, gradient norm = 0.0000673 (50 iterations in 0.111s)
# [t-SNE] Iteration 1250: error = 0.8480350, gradient norm = 0.0000758 (50 iterations in 0.111s)
# [t-SNE] Iteration 1300: error = 0.8478028, gradient norm = 0.0001067 (50 iterations in 0.111s)
# [t-SNE] Iteration 1350: error = 0.8478512, gradient norm = 0.0000648 (50 iterations in 0.109s)
# [t-SNE] Iteration 1400: error = 0.8479633, gradient norm = 0.0000779 (50 iterations in 0.113s)
# [t-SNE] Iteration 1450: error = 0.8478790, gradient norm = 0.0000677 (50 iterations in 0.111s)
# [t-SNE] Iteration 1500: error = 0.8479478, gradient norm = 0.0000600 (50 iterations in 0.112s)
# [t-SNE] Iteration 1550: error = 0.8479185, gradient norm = 0.0000623 (50 iterations in 0.111s)
# [t-SNE] Iteration 1600: error = 0.8479081, gradient norm = 0.0000799 (50 iterations in 0.109s)
# [t-SNE] Iteration 1650: error = 0.8478726, gradient norm = 0.0000757 (50 iterations in 0.109s)
# [t-SNE] Iteration 1650: did not make any progress during the last 300 episodes. Finished.
# [t-SNE] KL divergence after 1650 iterations: 0.847873

# %% [markdown]
# ### the t-SNE dimensions are put into a dataframe

# %%
tsne_df = pd.DataFrame(data = my_tsne, columns = ['tsne1', 'tsne2'])

# %% [markdown]
# ### datasets are stored for the purpose of two-dimensional visualisations

# %%
tsne_data_with_colour = pd.concat([tsne_df, X_test_labeled_df['inlierLabel']], axis = 1)

# %%
tsne_data_with_colour.head()
# Out:
#        tsne1      tsne2  inlierLabel
# 0 -11.126293  -2.441226            1
# 1 -11.518110  -2.555675            1
# 2 -12.069373  -2.554009            1
# 3 -21.552116   8.112810            1
# 4 -25.963219  10.374619            1

# %% [markdown]
# ### visualise t-SNE in two dimensions

# %%
sns.set(rc={'figure.figsize':(50,40)})
plot = sns.scatterplot(data = tsne_data_with_colour, x = 'tsne1', y = 'tsne2', hue='inlierLabel', s = 800, palette = ['red', 'blue'])
plt.title('test', fontsize=70)
plot.set_xlabel("train fold size (number of observations)",fontsize=50)
plot.set_ylabel("t-SNE 2",fontsize=50)
plot.set_xlabel("t-SNE 1",fontsize=50)
plot.tick_params(labelsize=40)
plot.set_title('t-SNE visualisation of artefact data coloured by outlier status', fontdict = {'fontsize': 80})

plt.legend(fontsize = 50, loc = 4, markerscale = 5)

if save_plots == True:
    fig = plot.get_figure()
    fig.savefig(fname='figures/tSNE_outlier_detection')

# %%
tsne_data_with_colour.to_csv('output_datasets/tsne_outlier_data.csv')
