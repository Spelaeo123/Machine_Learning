# %% [markdown]
# # data preproccessing

# %% [markdown]
# ## import modules and configure notebook

# %%
import pandas as pd
import numpy as np
import swifter
import seaborn as sns
pd.set_option('max.rows', None)
pd.set_option('max.columns', None)


from sklearn.decomposition import PCA 
from sklearn.manifold import TSNE
from sklearn.preprocessing import StandardScaler
# %matplotlib inline

# %% [markdown]
# ### configurations
# * data_input_path -> string, filepath to data to be read in
#
# * grouping -> boolean, if set to True them many sites are grouped
# * reduced_grouping -> boolean, if set to True then less sites grouped, only bedrock sites 'WB' and 'BX are grouped into one class and superficial sites 'SV' and 'SE' are grouped into one class.
# * raw -> boolean, if set to True then no grouping done
# * drop_semi_bedrock ->  True|False, if set to True then some bedrock sites deemed to be semi-bedrock sites are not used for classification
# * bedrock_only -> only train model using bedrock samples

# %%
data_input_path = '../data/raw_data.csv'


grouping = False
reduced_grouping = True
raw = False
drop_semi_bedrock = False
bedrock_only = True

# %% [markdown]
# ### Import data

# %%
my_data = pd.read_csv(data_input_path)

# %%
sns.set(rc={'figure.figsize':(50.7,8.27)})
sns.countplot(my_data['Site'])

# %% [markdown]
# ### features

# %%
my_data.columns.values[9:-1]
# Out:
# array(['Li7', 'Be9', 'B11', 'Mg24', 'Al27', 'Si28', 'P31', 'S33', 'K39',
#        'Ca42', 'Sc45', 'Ti47', 'V51', 'Cr52', 'Mn55', 'Fe56', 'Co59',
#        'Ni60', 'Cu63', 'Zn68', 'Ga69', 'Ge72', 'As75', 'Rb85', 'Sr88',
#        'Y89', 'Zr90', 'Nb93', 'Mo95', 'Cd111', 'In115', 'Sn118', 'Cs133',
#        'Ba137', 'La139', 'Ce140', 'Pr141', 'Nd146', 'Sm147', 'Eu153',
#        'Gd157', 'Tb159', 'Dy163', 'Ho165', 'Er166', 'Tm169', 'Yb172',
#        'Lu175', 'Hf178', 'Ta181', 'Pb208', 'Th232'], dtype=object)

# %% [markdown]
# ### remove bedrock site 'BP' because class-specific F1 score was very bad due to limited sample number

# %%
my_data = my_data[my_data['Site']!='BP']

# %%
site_frequencies_df = pd.DataFrame(my_data.Site.value_counts()).reset_index(drop = False).rename(columns = {'Site':'Number of Observations', 'index':'Site'})
# %store site_frequencies_df
# Out:
# Stored 'site_frequencies_df' (DataFrame)

# %% [markdown]
# ### raw sample names including sample sites and artefacts

# %%
my_data['Site'].unique()
# Out:
# array(['FH', 'ER', 'WW', 'TC', 'CS', 'BC', 'KQ', 'AR', 'SL', 'FG', 'WB',
#        'BX', 'PF', 'BM', 'WH', 'SQ', 'WN', 'BH', 'PH', 'LB', 'AB', 'LV',
#        'BR', 'KY', 'BF', 'ST', 'SH', 'CF', 'BG', 'AC', 'CR', 'GH', 'PX',
#        'WF', 'DH', 'NMAG_Gold', 'NMW_Gold', 'NMWGwern', 'UBSS', 'Cefn',
#        'Stockley', 'Pucha', 'Woodbury', 'Pimple', 'Wellington',
#        'Lyonshall', 'SymondsYatE', 'Madawg', nan], dtype=object)

# %% [markdown]
# ### define functions for making target classes for classification

# %%
def make_classes_grouped(row):
    if row['Geology'] == 'Bedrock':
        if row['Site'] == 'WB' or row['Site'] == 'BX':
            return('WB_BX')
        elif row['Site'] == 'BC' or row['Site'] == 'CS':
            return('BC_CS')
        elif row['Site'] == 'SQ' or row['Site'] == 'BP':
            return('SQ_BP')
        else:
            return(row['Site'])
    elif row['Geology'] == 'Superficial':
        if row['Region'] == 'SV' or row['Region'] == 'SE':
            return('SV_SE')
        else:
            return(row['Region'])
        
def make_classes_grouped_reduced(row):
    if row['Geology'] == 'Bedrock':
        if row['Site'] == 'WB' or row['Site'] == 'BX':
            return('WB_BX')
        else:
            return(row['Site'])
    elif row['Geology'] == 'Superficial':
        if row['Region'] == 'SV' or row['Region'] == 'SE':
            return('SV_SE')
        else:
            return(row['Region'])

def make_classes_raw(row):
    if row['Geology'] == 'Bedrock':
        return(row['Site'])
    elif row['Geology'] == 'Superficial':
        return(row['Region'])

# %% [markdown]
# ### targets for classification are made

# %%
my_data['class'] = 'init'   

if grouping:
    my_data['class'] = my_data.apply(make_classes_grouped, axis = 1)
elif reduced_grouping:
    my_data['class'] = my_data.apply(make_classes_grouped_reduced, axis = 1)
elif raw:
    my_data['class'] = my_data.apply(make_classes_raw, axis = 1)

# %%
if drop_semi_bedrock:
    my_data = my_data[(my_data['class'] != 'BM') & (my_data['class'] != 'BC') & (my_data['class'] != 'BP') ]

# %% [markdown]
# ### remove '<' signs and commas from feature values

# %%
for column_name in my_data.columns.values[9:-1]:
    def fill_less_than(row):
        if 'DL' in  str(row[column_name]):
            return(np.nan)
        if '<' in str(row[column_name]):
            return(float(row[column_name].replace('<', '').replace(',', '')))
        else:
            return(float(row[column_name]))
    my_data[column_name] = my_data.swifter.apply(fill_less_than, axis = 1)
# Out:
# Pandas Apply: 100%|██████████| 1612/1612 [00:00<00:00, 28724.08it/s]
# Pandas Apply: 100%|██████████| 1612/1612 [00:00<00:00, 28911.52it/s]
# Pandas Apply: 100%|██████████| 1612/1612 [00:00<00:00, 29018.73it/s]
# Pandas Apply: 100%|██████████| 1612/1612 [00:00<00:00, 27383.66it/s]
# Pandas Apply: 100%|██████████| 1612/1612 [00:00<00:00, 26129.50it/s]
# Pandas Apply: 100%|██████████| 1612/1612 [00:00<00:00, 27066.09it/s]
# Pandas Apply: 100%|██████████| 1612/1612 [00:00<00:00, 28087.25it/s]
# Pandas Apply: 100%|██████████| 1612/1612 [00:00<00:00, 28337.28it/s]
# Pandas Apply: 100%|██████████| 1612/1612 [00:00<00:00, 27811.35it/s]
# Pandas Apply: 100%|██████████| 1612/1612 [00:00<00:00, 28182.19it/s]
# Pandas Apply: 100%|██████████| 1612/1612 [00:00<00:00, 28600.51it/s]
# Pandas Apply: 100%|██████████| 1612/1612 [00:00<00:00, 29039.17it/s]
# Pandas Apply: 100%|██████████| 1612/1612 [00:00<00:00, 27708.21it/s]
# Pandas Apply: 100%|██████████| 1612/1612 [00:00<00:00, 28576.70it/s]
# Pandas Apply: 100%|██████████| 1612/1612 [00:00<00:00, 25125.77it/s]
# Pandas Apply: 100%|██████████| 1612/1612 [00:00<00:00, 27841.36it/s]
# Pandas Apply: 100%|██████████| 1612/1612 [00:00<00:00, 28409.55it/s]
# Pandas Apply: 100%|██████████| 1612/1612 [00:00<00:00, 27017.75it/s]
# Pandas Apply: 100%|██████████| 1612/1612 [00:00<00:00, 28980.79it/s]
# Pandas Apply: 100%|██████████| 1612/1612 [00:00<00:00, 28122.53it/s]
# Pandas Apply: 100%|██████████| 1612/1612 [00:00<00:00, 26603.47it/s]
# Pandas Apply: 100%|██████████| 1612/1612 [00:00<00:00, 28304.18it/s]
# Pandas Apply: 100%|██████████| 1612/1612 [00:00<00:00, 28636.37it/s]
# Pandas Apply: 100%|██████████| 1612/1612 [00:00<00:00, 27557.44it/s]
# Pandas Apply: 100%|██████████| 1612/1612 [00:00<00:00, 29328.76it/s]
# Pandas Apply: 100%|██████████| 1612/1612 [00:00<00:00, 28334.19it/s]
# Pandas Apply: 100%|██████████| 1612/1612 [00:00<00:00, 27512.59it/s]
# Pandas Apply: 100%|██████████| 1612/1612 [00:00<00:00, 29280.62it/s]
# Pandas Apply: 100%|██████████| 1612/1612 [00:00<00:00, 28184.07it/s]
# Pandas Apply: 100%|██████████| 1612/1612 [00:00<00:00, 26491.83it/s]
# Pandas Apply: 100%|██████████| 1612/1612 [00:00<00:00, 28560.04it/s]
# Pandas Apply: 100%|██████████| 1612/1612 [00:00<00:00, 25273.13it/s]
# Pandas Apply: 100%|██████████| 1612/1612 [00:00<00:00, 27759.86it/s]
# Pandas Apply: 100%|██████████| 1612/1612 [00:00<00:00, 28435.60it/s]
# Pandas Apply: 100%|██████████| 1612/1612 [00:00<00:00, 28867.94it/s]
# Pandas Apply: 100%|██████████| 1612/1612 [00:00<00:00, 27850.76it/s]
# Pandas Apply: 100%|██████████| 1612/1612 [00:00<00:00, 28854.76it/s]
# Pandas Apply: 100%|██████████| 1612/1612 [00:00<00:00, 28770.65it/s]
# Pandas Apply: 100%|██████████| 1612/1612 [00:00<00:00, 29066.76it/s]
# Pandas Apply: 100%|██████████| 1612/1612 [00:00<00:00, 28790.01it/s]
# Pandas Apply: 100%|██████████| 1612/1612 [00:00<00:00, 28708.59it/s]
# Pandas Apply: 100%|██████████| 1612/1612 [00:00<00:00, 28580.68it/s]
# Pandas Apply: 100%|██████████| 1612/1612 [00:00<00:00, 27458.28it/s]
# Pandas Apply: 100%|██████████| 1612/1612 [00:00<00:00, 28912.01it/s]
# Pandas Apply: 100%|██████████| 1612/1612 [00:00<00:00, 27472.12it/s]
# Pandas Apply: 100%|██████████| 1612/1612 [00:00<00:00, 27598.16it/s]
# Pandas Apply: 100%|██████████| 1612/1612 [00:00<00:00, 25869.57it/s]
# Pandas Apply: 100%|██████████| 1612/1612 [00:00<00:00, 28334.67it/s]
# Pandas Apply: 100%|██████████| 1612/1612 [00:00<00:00, 25940.33it/s]
# Pandas Apply: 100%|██████████| 1612/1612 [00:00<00:00, 27922.53it/s]
# Pandas Apply: 100%|██████████| 1612/1612 [00:00<00:00, 28048.33it/s]
# Pandas Apply: 100%|██████████| 1612/1612 [00:00<00:00, 28701.77it/s]
# Pandas Apply: 100%|██████████| 1612/1612 [00:00<00:00, 27712.41it/s]

# %% [markdown]
# ### visualise na values

# %%
sns.set(rc={'figure.figsize':(20.7,50)})
sns.heatmap(my_data.isna(), cbar=False)

# %% [markdown]
# ### remove rows where there are all element abundances are na values

# %%
my_data = my_data.dropna(subset=my_data.columns.values[9:-1], how = 'all' , axis = 0)

# %% [markdown]
# ### Impute na values with feature mean

# %%
for column_name in my_data.columns.values[9:-1]:
    my_data[column_name] = my_data[column_name].fillna(my_data[column_name].mean())

# %% [markdown]
# ### Outliers defined as any values that exceed 2 standard deviations from the mean, such values are changed to the mean for that variable

# %%
std_dict = {}
mean_dict = {}
median_dict = {}

for col in my_data.columns.values[9:-1]:
    std_dict[col] = my_data[col].std()
    
for col in my_data.columns.values[9:-1]:
    mean_dict[col] = my_data[col].mean()
    
for col in my_data.columns.values[9:-1]:
    median_dict[col] = my_data[col].median()

# %%
for col_name in my_data.columns.values[9:-1]:
    def impute_outliers(row):
        if np.abs(row[col_name] - mean_dict[col_name]) > 2*(std_dict[col_name]):
            return(mean_dict[col_name])
        else:
            return(row[col_name])
    my_data[col_name]= my_data.swifter.apply(impute_outliers, axis = 1)
# Out:
# Pandas Apply: 100%|██████████| 1581/1581 [00:00<00:00, 31703.02it/s]
# Pandas Apply: 100%|██████████| 1581/1581 [00:00<00:00, 33506.79it/s]
# Pandas Apply: 100%|██████████| 1581/1581 [00:00<00:00, 33916.03it/s]
# Pandas Apply: 100%|██████████| 1581/1581 [00:00<00:00, 32392.48it/s]
# Pandas Apply: 100%|██████████| 1581/1581 [00:00<00:00, 34070.07it/s]
# Pandas Apply: 100%|██████████| 1581/1581 [00:00<00:00, 34137.60it/s]
# Pandas Apply: 100%|██████████| 1581/1581 [00:00<00:00, 33981.38it/s]
# Pandas Apply: 100%|██████████| 1581/1581 [00:00<00:00, 31598.78it/s]
# Pandas Apply: 100%|██████████| 1581/1581 [00:00<00:00, 33731.77it/s]
# Pandas Apply: 100%|██████████| 1581/1581 [00:00<00:00, 32209.34it/s]
# Pandas Apply: 100%|██████████| 1581/1581 [00:00<00:00, 31529.22it/s]
# Pandas Apply: 100%|██████████| 1581/1581 [00:00<00:00, 33398.78it/s]
# Pandas Apply: 100%|██████████| 1581/1581 [00:00<00:00, 32948.07it/s]
# Pandas Apply: 100%|██████████| 1581/1581 [00:00<00:00, 32973.79it/s]
# Pandas Apply: 100%|██████████| 1581/1581 [00:00<00:00, 33121.53it/s]
# Pandas Apply: 100%|██████████| 1581/1581 [00:00<00:00, 34263.90it/s]
# Pandas Apply: 100%|██████████| 1581/1581 [00:00<00:00, 33255.74it/s]
# Pandas Apply: 100%|██████████| 1581/1581 [00:00<00:00, 33886.05it/s]
# Pandas Apply: 100%|██████████| 1581/1581 [00:00<00:00, 31904.06it/s]
# Pandas Apply: 100%|██████████| 1581/1581 [00:00<00:00, 34027.76it/s]
# Pandas Apply: 100%|██████████| 1581/1581 [00:00<00:00, 34086.19it/s]
# Pandas Apply: 100%|██████████| 1581/1581 [00:00<00:00, 34090.39it/s]
# Pandas Apply: 100%|██████████| 1581/1581 [00:00<00:00, 33461.98it/s]
# Pandas Apply: 100%|██████████| 1581/1581 [00:00<00:00, 30928.94it/s]
# Pandas Apply: 100%|██████████| 1581/1581 [00:00<00:00, 34956.03it/s]
# Pandas Apply: 100%|██████████| 1581/1581 [00:00<00:00, 34975.95it/s]
# Pandas Apply: 100%|██████████| 1581/1581 [00:00<00:00, 34970.60it/s]
# Pandas Apply: 100%|██████████| 1581/1581 [00:00<00:00, 33749.97it/s]
# Pandas Apply: 100%|██████████| 1581/1581 [00:00<00:00, 34097.05it/s]
# Pandas Apply: 100%|██████████| 1581/1581 [00:00<00:00, 33659.52it/s]
# Pandas Apply: 100%|██████████| 1581/1581 [00:00<00:00, 34471.58it/s]
# Pandas Apply: 100%|██████████| 1581/1581 [00:00<00:00, 31676.07it/s]
# Pandas Apply: 100%|██████████| 1581/1581 [00:00<00:00, 34339.13it/s]
# Pandas Apply: 100%|██████████| 1581/1581 [00:00<00:00, 32242.86it/s]
# Pandas Apply: 100%|██████████| 1581/1581 [00:00<00:00, 33755.30it/s]
# Pandas Apply: 100%|██████████| 1581/1581 [00:00<00:00, 33788.32it/s]
# Pandas Apply: 100%|██████████| 1581/1581 [00:00<00:00, 33976.51it/s]
# Pandas Apply: 100%|██████████| 1581/1581 [00:00<00:00, 31377.05it/s]
# Pandas Apply: 100%|██████████| 1581/1581 [00:00<00:00, 34931.36it/s]
# Pandas Apply: 100%|██████████| 1581/1581 [00:00<00:00, 31570.05it/s]
# Pandas Apply: 100%|██████████| 1581/1581 [00:00<00:00, 33314.05it/s]
# Pandas Apply: 100%|██████████| 1581/1581 [00:00<00:00, 33852.66it/s]
# Pandas Apply: 100%|██████████| 1581/1581 [00:00<00:00, 33652.00it/s]
# Pandas Apply: 100%|██████████| 1581/1581 [00:00<00:00, 33773.01it/s]
# Pandas Apply: 100%|██████████| 1581/1581 [00:00<00:00, 31383.44it/s]
# Pandas Apply: 100%|██████████| 1581/1581 [00:00<00:00, 34167.50it/s]
# Pandas Apply: 100%|██████████| 1581/1581 [00:00<00:00, 34648.82it/s]
# Pandas Apply: 100%|██████████| 1581/1581 [00:00<00:00, 34873.68it/s]
# Pandas Apply: 100%|██████████| 1581/1581 [00:00<00:00, 32257.91it/s]
# Pandas Apply: 100%|██████████| 1581/1581 [00:00<00:00, 33587.40it/s]
# Pandas Apply: 100%|██████████| 1581/1581 [00:00<00:00, 27736.42it/s]
# Pandas Apply: 100%|██████████| 1581/1581 [00:00<00:00, 32081.56it/s]
# Pandas Apply: 100%|██████████| 1581/1581 [00:00<00:00, 29214.24it/s]

# %% [markdown]
# ### split data into 'train_data' and 'test_data', the former consists of samples from known geological sites and the latter from flint artefacts fow which the original geological source site is unknown and to be predicted.

# %%
train_data = my_data[(my_data['Geology']== 'Bedrock') | (my_data['Geology'] == 'Superficial')]
test_data = my_data[my_data['Geology']=='Artefacts']

# %% [markdown]
# ### label encode the class to be predicted

# %%
if bedrock_only:
    train_data_formodel = train_data[train_data['Geology'] == 'Bedrock'].copy(deep = True)
    train_data_formodel['class'], uniques = pd.factorize(train_data_formodel['class'])
else:
    train_data_formodel = train_data.copy(deep = True)
    train_data_formodel['class'], uniques = pd.factorize(train_data_formodel['class'])

# %% [markdown]
# ### datasets are stored

# %%
# %store train_data_formodel
# %store train_data
# %store test_data
# %store my_data
# %store uniques
# Out:
# Stored 'train_data_formodel' (DataFrame)
# Stored 'train_data' (DataFrame)
# Stored 'test_data' (DataFrame)
# Stored 'my_data' (DataFrame)
# Stored 'uniques' (Index)

# %% [markdown]
# ## data preproccessing for dimensionality reduction and visualisation

# %% [markdown]
# ### 'training_data' is split into two datasets, one consisting of samples from superficial sites and one containing samples from bedrock sites.

# %%
train_data_bedrock = train_data[train_data['Geology'] == 'Bedrock']
train_data_superficial = train_data[train_data['Geology'] == 'Superficial']

# %% [markdown]
# ### four datasets are created, one containing all train data (bedrock and superficial types), one containing just bedrock types, one containing just superficial types and one containing the artefacts

# %%
element_data_train = train_data[train_data.columns.values[9:-1]]
element_data_train_bedrock = train_data_bedrock[train_data.columns.values[9:-1]]
element_data_train_superficial = train_data_superficial[train_data.columns.values[9:-1]]
element_data_test = test_data[test_data.columns.values[9:-1]]

# %% [markdown]
# ### features are standardised

# %%
my_scaler_train = StandardScaler()
my_scaler_train_bedrock = StandardScaler()
my_scaler_train_superficial = StandardScaler()
my_scaler_test = StandardScaler()

# %%
element_data_train_scaled = my_scaler_train.fit_transform(element_data_train)
element_data_train_bedrock_scaled = my_scaler_train_bedrock.fit_transform(element_data_train_bedrock)
element_data_train_superficial_scaled = my_scaler_train_superficial.fit_transform(element_data_train_superficial)
element_data_test_scaled = my_scaler_test.fit_transform(element_data_test)

# %% [markdown]
# ### The four datasets are transformed using Principal component analysis

# %%
my_pca_train = PCA(n_components=element_data_train_scaled.shape[1])
my_pca_train_bedrock = PCA(n_components=element_data_train_bedrock_scaled.shape[1])
my_pca_train_superficial = PCA(n_components=element_data_train_superficial_scaled.shape[1])
my_pca_test = PCA(n_components=element_data_test_scaled.shape[1])

element_data_train_pca = my_pca_train.fit_transform(element_data_train_scaled)
element_data_train_bedrock_pca = my_pca_train_bedrock.fit_transform(element_data_train_bedrock_scaled)
element_data_train_superficial_pca = my_pca_train_superficial.fit_transform(element_data_train_superficial_scaled)
element_data_test_pca = my_pca_test.fit_transform(element_data_test_scaled)

# %% [markdown]
# ### print details of PCA

# %%
print(my_pca_train)
# Out:
# PCA(copy=True, iterated_power='auto', n_components=53, random_state=None,
#   svd_solver='auto', tol=0.0, whiten=False)

# %% [markdown]
# ### the principal components for the four datasets are put into dataframes

# %%
no_PCs = element_data_train_scaled.shape[1]
PC_names = []
for i in range(0, no_PCs):
    number = i + 1
    column_name = 'PC' + str(number)
    PC_names.append(column_name)

# %%
PC_df_train = pd.DataFrame(data = element_data_train_pca, columns = PC_names)
PC_df_bedrock_train = pd.DataFrame(data = element_data_train_bedrock_pca, columns = PC_names)
PC_df_superficial_train = pd.DataFrame(data = element_data_train_superficial_pca, columns = PC_names)
PC_df_test = pd.DataFrame(data = element_data_test_pca, columns = PC_names)

# %% [markdown]
# ### T-Distributed Stochastic Neighbour Embedding is done on the four datasets

# %%
my_tsne_train = TSNE(n_components=2, n_iter=5000, verbose=3).fit_transform(element_data_train_scaled)
my_tsne_bedrock_train = TSNE(n_components=2, n_iter=5000, verbose=3).fit_transform(element_data_train_bedrock_scaled)
my_tsne_superficial_train = TSNE(n_components=2, n_iter=5000, verbose=3).fit_transform(element_data_train_superficial_scaled)
my_tsne_test = TSNE(n_components=2, n_iter=5000, verbose=3).fit_transform(element_data_test_scaled)
# Out:
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 1218 samples in 0.013s...
# [t-SNE] Computed neighbors for 1218 samples in 0.185s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 1218
# [t-SNE] Computed conditional probabilities for sample 1218 / 1218
# [t-SNE] Mean sigma: 1.999193
# [t-SNE] Computed conditional probabilities in 0.071s
# [t-SNE] Iteration 50: error = 71.8703003, gradient norm = 0.2459463 (50 iterations in 0.657s)
# [t-SNE] Iteration 100: error = 71.8705597, gradient norm = 0.2331831 (50 iterations in 0.585s)
# [t-SNE] Iteration 150: error = 72.4917526, gradient norm = 0.2223642 (50 iterations in 0.594s)
# [t-SNE] Iteration 200: error = 72.2381592, gradient norm = 0.2170832 (50 iterations in 0.670s)
# [t-SNE] Iteration 250: error = 71.7583847, gradient norm = 0.2354358 (50 iterations in 0.640s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 71.758385
# [t-SNE] Iteration 300: error = 1.4393363, gradient norm = 0.0012575 (50 iterations in 0.383s)
# [t-SNE] Iteration 350: error = 1.3462116, gradient norm = 0.0003537 (50 iterations in 0.329s)
# [t-SNE] Iteration 400: error = 1.3134329, gradient norm = 0.0002717 (50 iterations in 0.325s)
# [t-SNE] Iteration 450: error = 1.2971988, gradient norm = 0.0004165 (50 iterations in 0.334s)
# [t-SNE] Iteration 500: error = 1.2907367, gradient norm = 0.0001337 (50 iterations in 0.336s)
# [t-SNE] Iteration 550: error = 1.2863698, gradient norm = 0.0001075 (50 iterations in 0.335s)
# [t-SNE] Iteration 600: error = 1.2827586, gradient norm = 0.0001043 (50 iterations in 0.339s)
# [t-SNE] Iteration 650: error = 1.2809602, gradient norm = 0.0000798 (50 iterations in 0.337s)
# [t-SNE] Iteration 700: error = 1.2795873, gradient norm = 0.0000661 (50 iterations in 0.338s)
# [t-SNE] Iteration 750: error = 1.2782042, gradient norm = 0.0000793 (50 iterations in 0.337s)
# [t-SNE] Iteration 800: error = 1.2772655, gradient norm = 0.0000535 (50 iterations in 0.339s)
# [t-SNE] Iteration 850: error = 1.2765608, gradient norm = 0.0000572 (50 iterations in 0.335s)
# [t-SNE] Iteration 900: error = 1.2759024, gradient norm = 0.0000566 (50 iterations in 0.364s)
# [t-SNE] Iteration 950: error = 1.2756532, gradient norm = 0.0000450 (50 iterations in 0.355s)
# [t-SNE] Iteration 1000: error = 1.2752677, gradient norm = 0.0000492 (50 iterations in 0.352s)
# [t-SNE] Iteration 1050: error = 1.2749636, gradient norm = 0.0000469 (50 iterations in 0.338s)
# [t-SNE] Iteration 1100: error = 1.2747267, gradient norm = 0.0000439 (50 iterations in 0.347s)
# [t-SNE] Iteration 1150: error = 1.2744731, gradient norm = 0.0000354 (50 iterations in 0.343s)
# [t-SNE] Iteration 1200: error = 1.2741808, gradient norm = 0.0000457 (50 iterations in 0.333s)
# [t-SNE] Iteration 1250: error = 1.2740655, gradient norm = 0.0000384 (50 iterations in 0.343s)
# [t-SNE] Iteration 1300: error = 1.2737926, gradient norm = 0.0000347 (50 iterations in 0.359s)
# [t-SNE] Iteration 1350: error = 1.2736470, gradient norm = 0.0000411 (50 iterations in 0.334s)
# [t-SNE] Iteration 1400: error = 1.2735182, gradient norm = 0.0000373 (50 iterations in 0.339s)
# [t-SNE] Iteration 1450: error = 1.2734562, gradient norm = 0.0000312 (50 iterations in 0.344s)
# [t-SNE] Iteration 1500: error = 1.2733840, gradient norm = 0.0000399 (50 iterations in 0.337s)
# [t-SNE] Iteration 1550: error = 1.2732239, gradient norm = 0.0000431 (50 iterations in 0.382s)
# [t-SNE] Iteration 1600: error = 1.2732004, gradient norm = 0.0000267 (50 iterations in 0.411s)
# [t-SNE] Iteration 1650: error = 1.2730953, gradient norm = 0.0000388 (50 iterations in 0.384s)
# [t-SNE] Iteration 1700: error = 1.2730266, gradient norm = 0.0000333 (50 iterations in 0.359s)
# [t-SNE] Iteration 1750: error = 1.2729659, gradient norm = 0.0000303 (50 iterations in 0.358s)
# [t-SNE] Iteration 1800: error = 1.2729435, gradient norm = 0.0000252 (50 iterations in 0.362s)
# [t-SNE] Iteration 1850: error = 1.2728295, gradient norm = 0.0000318 (50 iterations in 0.341s)
# [t-SNE] Iteration 1900: error = 1.2727147, gradient norm = 0.0000256 (50 iterations in 0.342s)
# [t-SNE] Iteration 1950: error = 1.2726324, gradient norm = 0.0000300 (50 iterations in 0.350s)
# [t-SNE] Iteration 2000: error = 1.2725774, gradient norm = 0.0000440 (50 iterations in 0.339s)
# [t-SNE] Iteration 2050: error = 1.2724638, gradient norm = 0.0000568 (50 iterations in 0.338s)
# [t-SNE] Iteration 2100: error = 1.2724719, gradient norm = 0.0000222 (50 iterations in 0.345s)
# [t-SNE] Iteration 2150: error = 1.2723639, gradient norm = 0.0000226 (50 iterations in 0.347s)
# [t-SNE] Iteration 2200: error = 1.2722467, gradient norm = 0.0000322 (50 iterations in 0.337s)
# [t-SNE] Iteration 2250: error = 1.2723039, gradient norm = 0.0000275 (50 iterations in 0.347s)
# [t-SNE] Iteration 2300: error = 1.2722489, gradient norm = 0.0000276 (50 iterations in 0.344s)
# [t-SNE] Iteration 2350: error = 1.2722616, gradient norm = 0.0000284 (50 iterations in 0.337s)
# [t-SNE] Iteration 2400: error = 1.2722288, gradient norm = 0.0000277 (50 iterations in 0.379s)
# [t-SNE] Iteration 2450: error = 1.2721201, gradient norm = 0.0000268 (50 iterations in 0.353s)
# [t-SNE] Iteration 2500: error = 1.2720677, gradient norm = 0.0000213 (50 iterations in 0.344s)
# [t-SNE] Iteration 2550: error = 1.2720194, gradient norm = 0.0000311 (50 iterations in 0.342s)
# [t-SNE] Iteration 2600: error = 1.2720077, gradient norm = 0.0000294 (50 iterations in 0.341s)
# [t-SNE] Iteration 2650: error = 1.2719569, gradient norm = 0.0000433 (50 iterations in 0.341s)
# [t-SNE] Iteration 2700: error = 1.2719393, gradient norm = 0.0000252 (50 iterations in 0.340s)
# [t-SNE] Iteration 2750: error = 1.2719228, gradient norm = 0.0000305 (50 iterations in 0.345s)
# [t-SNE] Iteration 2800: error = 1.2718807, gradient norm = 0.0000357 (50 iterations in 0.344s)
# [t-SNE] Iteration 2850: error = 1.2719648, gradient norm = 0.0000221 (50 iterations in 0.345s)
# [t-SNE] Iteration 2900: error = 1.2719483, gradient norm = 0.0000244 (50 iterations in 0.342s)
# [t-SNE] Iteration 2950: error = 1.2719561, gradient norm = 0.0000247 (50 iterations in 0.361s)
# [t-SNE] Iteration 3000: error = 1.2718780, gradient norm = 0.0000237 (50 iterations in 0.342s)
# [t-SNE] Iteration 3050: error = 1.2719504, gradient norm = 0.0000311 (50 iterations in 0.350s)
# [t-SNE] Iteration 3100: error = 1.2719107, gradient norm = 0.0000315 (50 iterations in 0.358s)
# [t-SNE] Iteration 3150: error = 1.2719246, gradient norm = 0.0000306 (50 iterations in 0.367s)
# [t-SNE] Iteration 3200: error = 1.2718912, gradient norm = 0.0000245 (50 iterations in 0.337s)
# [t-SNE] Iteration 3250: error = 1.2719049, gradient norm = 0.0000217 (50 iterations in 0.359s)
# [t-SNE] Iteration 3300: error = 1.2718810, gradient norm = 0.0000242 (50 iterations in 0.365s)
# [t-SNE] Iteration 3350: error = 1.2718700, gradient norm = 0.0000238 (50 iterations in 0.355s)
# [t-SNE] Iteration 3400: error = 1.2718906, gradient norm = 0.0000224 (50 iterations in 0.347s)
# [t-SNE] Iteration 3450: error = 1.2718855, gradient norm = 0.0000288 (50 iterations in 0.355s)
# [t-SNE] Iteration 3500: error = 1.2718308, gradient norm = 0.0000324 (50 iterations in 0.351s)
# [t-SNE] Iteration 3550: error = 1.2718494, gradient norm = 0.0000244 (50 iterations in 0.347s)
# [t-SNE] Iteration 3600: error = 1.2718881, gradient norm = 0.0000302 (50 iterations in 0.370s)
# [t-SNE] Iteration 3650: error = 1.2718230, gradient norm = 0.0000198 (50 iterations in 0.345s)
# [t-SNE] Iteration 3700: error = 1.2718258, gradient norm = 0.0000230 (50 iterations in 0.360s)
# [t-SNE] Iteration 3750: error = 1.2718321, gradient norm = 0.0000220 (50 iterations in 0.355s)
# [t-SNE] Iteration 3800: error = 1.2717879, gradient norm = 0.0000266 (50 iterations in 0.344s)
# [t-SNE] Iteration 3850: error = 1.2718203, gradient norm = 0.0000232 (50 iterations in 0.373s)
# [t-SNE] Iteration 3900: error = 1.2718327, gradient norm = 0.0000260 (50 iterations in 0.350s)
# [t-SNE] Iteration 3950: error = 1.2717793, gradient norm = 0.0000315 (50 iterations in 0.347s)
# [t-SNE] Iteration 4000: error = 1.2717764, gradient norm = 0.0000280 (50 iterations in 0.362s)
# [t-SNE] Iteration 4050: error = 1.2717694, gradient norm = 0.0000295 (50 iterations in 0.348s)
# [t-SNE] Iteration 4100: error = 1.2717962, gradient norm = 0.0000311 (50 iterations in 0.345s)
# [t-SNE] Iteration 4150: error = 1.2717235, gradient norm = 0.0000259 (50 iterations in 0.348s)
# [t-SNE] Iteration 4200: error = 1.2717227, gradient norm = 0.0000308 (50 iterations in 0.343s)
# [t-SNE] Iteration 4250: error = 1.2717593, gradient norm = 0.0000404 (50 iterations in 0.350s)
# [t-SNE] Iteration 4300: error = 1.2717224, gradient norm = 0.0000341 (50 iterations in 0.347s)
# [t-SNE] Iteration 4350: error = 1.2717314, gradient norm = 0.0000324 (50 iterations in 0.360s)
# [t-SNE] Iteration 4400: error = 1.2717106, gradient norm = 0.0000351 (50 iterations in 0.351s)
# [t-SNE] Iteration 4450: error = 1.2717447, gradient norm = 0.0000283 (50 iterations in 0.357s)
# [t-SNE] Iteration 4500: error = 1.2717234, gradient norm = 0.0000320 (50 iterations in 0.397s)
# [t-SNE] Iteration 4550: error = 1.2717150, gradient norm = 0.0000301 (50 iterations in 0.358s)
# [t-SNE] Iteration 4600: error = 1.2716392, gradient norm = 0.0000294 (50 iterations in 0.350s)
# [t-SNE] Iteration 4650: error = 1.2716993, gradient norm = 0.0000297 (50 iterations in 0.353s)
# [t-SNE] Iteration 4700: error = 1.2716587, gradient norm = 0.0000450 (50 iterations in 0.356s)
# [t-SNE] Iteration 4750: error = 1.2717071, gradient norm = 0.0000199 (50 iterations in 0.369s)
# [t-SNE] Iteration 4800: error = 1.2716720, gradient norm = 0.0000469 (50 iterations in 0.352s)
# [t-SNE] Iteration 4850: error = 1.2716731, gradient norm = 0.0000195 (50 iterations in 0.360s)
# [t-SNE] Iteration 4900: error = 1.2716119, gradient norm = 0.0000329 (50 iterations in 0.362s)
# [t-SNE] Iteration 4950: error = 1.2716233, gradient norm = 0.0000267 (50 iterations in 0.364s)
# [t-SNE] Iteration 5000: error = 1.2716008, gradient norm = 0.0000185 (50 iterations in 0.390s)
# [t-SNE] KL divergence after 5000 iterations: 1.271601
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 786 samples in 0.001s...
# [t-SNE] Computed neighbors for 786 samples in 0.067s...
# [t-SNE] Computed conditional probabilities for sample 786 / 786
# [t-SNE] Mean sigma: 2.111098
# [t-SNE] Computed conditional probabilities in 0.035s
# [t-SNE] Iteration 50: error = 72.4368134, gradient norm = 0.3598678 (50 iterations in 0.309s)
# [t-SNE] Iteration 100: error = 73.2133026, gradient norm = 0.3692288 (50 iterations in 0.319s)
# [t-SNE] Iteration 150: error = 72.6288910, gradient norm = 0.3773475 (50 iterations in 0.318s)
# [t-SNE] Iteration 200: error = 73.5134811, gradient norm = 0.3556928 (50 iterations in 0.314s)
# [t-SNE] Iteration 250: error = 74.4620132, gradient norm = 0.3580793 (50 iterations in 0.381s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 74.462013
# [t-SNE] Iteration 300: error = 1.2822418, gradient norm = 0.0042521 (50 iterations in 0.261s)
# [t-SNE] Iteration 350: error = 1.2171851, gradient norm = 0.0004688 (50 iterations in 0.217s)
# [t-SNE] Iteration 400: error = 1.1971294, gradient norm = 0.0002174 (50 iterations in 0.222s)
# [t-SNE] Iteration 450: error = 1.1879237, gradient norm = 0.0001984 (50 iterations in 0.218s)
# [t-SNE] Iteration 500: error = 1.1800199, gradient norm = 0.0001698 (50 iterations in 0.215s)
# [t-SNE] Iteration 550: error = 1.1761906, gradient norm = 0.0001777 (50 iterations in 0.206s)
# [t-SNE] Iteration 600: error = 1.1714652, gradient norm = 0.0001726 (50 iterations in 0.211s)
# [t-SNE] Iteration 650: error = 1.1680355, gradient norm = 0.0000996 (50 iterations in 0.215s)
# [t-SNE] Iteration 700: error = 1.1667985, gradient norm = 0.0000779 (50 iterations in 0.214s)
# [t-SNE] Iteration 750: error = 1.1666429, gradient norm = 0.0000572 (50 iterations in 0.224s)
# [t-SNE] Iteration 800: error = 1.1662730, gradient norm = 0.0000755 (50 iterations in 0.214s)
# [t-SNE] Iteration 850: error = 1.1660473, gradient norm = 0.0000582 (50 iterations in 0.212s)
# [t-SNE] Iteration 900: error = 1.1659031, gradient norm = 0.0000732 (50 iterations in 0.210s)
# [t-SNE] Iteration 950: error = 1.1657094, gradient norm = 0.0000413 (50 iterations in 0.213s)
# [t-SNE] Iteration 1000: error = 1.1656059, gradient norm = 0.0000431 (50 iterations in 0.210s)
# [t-SNE] Iteration 1050: error = 1.1654030, gradient norm = 0.0000345 (50 iterations in 0.209s)
# [t-SNE] Iteration 1100: error = 1.1652958, gradient norm = 0.0000347 (50 iterations in 0.214s)
# [t-SNE] Iteration 1150: error = 1.1653044, gradient norm = 0.0000403 (50 iterations in 0.209s)
# [t-SNE] Iteration 1200: error = 1.1652358, gradient norm = 0.0000512 (50 iterations in 0.220s)
# [t-SNE] Iteration 1250: error = 1.1651559, gradient norm = 0.0000445 (50 iterations in 0.210s)
# [t-SNE] Iteration 1300: error = 1.1650845, gradient norm = 0.0000376 (50 iterations in 0.211s)
# [t-SNE] Iteration 1350: error = 1.1651077, gradient norm = 0.0000439 (50 iterations in 0.216s)
# [t-SNE] Iteration 1400: error = 1.1650882, gradient norm = 0.0000505 (50 iterations in 0.209s)
# [t-SNE] Iteration 1450: error = 1.1650528, gradient norm = 0.0000460 (50 iterations in 0.214s)
# [t-SNE] Iteration 1500: error = 1.1650342, gradient norm = 0.0000506 (50 iterations in 0.227s)
# [t-SNE] Iteration 1550: error = 1.1649653, gradient norm = 0.0000562 (50 iterations in 0.212s)
# [t-SNE] Iteration 1600: error = 1.1649938, gradient norm = 0.0000391 (50 iterations in 0.209s)
# [t-SNE] Iteration 1650: error = 1.1649951, gradient norm = 0.0000612 (50 iterations in 0.210s)
# [t-SNE] Iteration 1700: error = 1.1649207, gradient norm = 0.0000537 (50 iterations in 0.214s)
# [t-SNE] Iteration 1750: error = 1.1648929, gradient norm = 0.0000424 (50 iterations in 0.215s)
# [t-SNE] Iteration 1800: error = 1.1648556, gradient norm = 0.0000455 (50 iterations in 0.212s)
# [t-SNE] Iteration 1850: error = 1.1648889, gradient norm = 0.0000475 (50 iterations in 0.210s)
# [t-SNE] Iteration 1900: error = 1.1647655, gradient norm = 0.0000547 (50 iterations in 0.215s)
# [t-SNE] Iteration 1950: error = 1.1648103, gradient norm = 0.0000345 (50 iterations in 0.206s)
# [t-SNE] Iteration 2000: error = 1.1648117, gradient norm = 0.0000393 (50 iterations in 0.211s)
# [t-SNE] Iteration 2050: error = 1.1648039, gradient norm = 0.0000511 (50 iterations in 0.208s)
# [t-SNE] Iteration 2100: error = 1.1647885, gradient norm = 0.0000478 (50 iterations in 0.211s)
# [t-SNE] Iteration 2150: error = 1.1647422, gradient norm = 0.0000473 (50 iterations in 0.219s)
# [t-SNE] Iteration 2200: error = 1.1647515, gradient norm = 0.0000349 (50 iterations in 0.207s)
# [t-SNE] Iteration 2250: error = 1.1647609, gradient norm = 0.0000476 (50 iterations in 0.210s)
# [t-SNE] Iteration 2300: error = 1.1646967, gradient norm = 0.0000591 (50 iterations in 0.213s)
# [t-SNE] Iteration 2350: error = 1.1647491, gradient norm = 0.0000631 (50 iterations in 0.209s)
# [t-SNE] Iteration 2400: error = 1.1646876, gradient norm = 0.0000478 (50 iterations in 0.213s)
# [t-SNE] Iteration 2450: error = 1.1647286, gradient norm = 0.0000534 (50 iterations in 0.208s)
# [t-SNE] Iteration 2500: error = 1.1647089, gradient norm = 0.0000415 (50 iterations in 0.219s)
# [t-SNE] Iteration 2550: error = 1.1647445, gradient norm = 0.0000373 (50 iterations in 0.210s)
# [t-SNE] Iteration 2600: error = 1.1646816, gradient norm = 0.0000357 (50 iterations in 0.218s)
# [t-SNE] Iteration 2650: error = 1.1646734, gradient norm = 0.0000232 (50 iterations in 0.217s)
# [t-SNE] Iteration 2700: error = 1.1646717, gradient norm = 0.0000211 (50 iterations in 0.219s)
# [t-SNE] Iteration 2750: error = 1.1646875, gradient norm = 0.0000217 (50 iterations in 0.212s)
# [t-SNE] Iteration 2800: error = 1.1646491, gradient norm = 0.0000237 (50 iterations in 0.208s)
# [t-SNE] Iteration 2850: error = 1.1647360, gradient norm = 0.0000306 (50 iterations in 0.214s)
# [t-SNE] Iteration 2900: error = 1.1646916, gradient norm = 0.0000216 (50 iterations in 0.209s)
# [t-SNE] Iteration 2950: error = 1.1646396, gradient norm = 0.0000326 (50 iterations in 0.208s)
# [t-SNE] Iteration 3000: error = 1.1646838, gradient norm = 0.0000475 (50 iterations in 0.210s)
# [t-SNE] Iteration 3050: error = 1.1646398, gradient norm = 0.0000321 (50 iterations in 0.215s)
# [t-SNE] Iteration 3100: error = 1.1646647, gradient norm = 0.0000351 (50 iterations in 0.219s)
# [t-SNE] Iteration 3150: error = 1.1645747, gradient norm = 0.0000423 (50 iterations in 0.209s)
# [t-SNE] Iteration 3200: error = 1.1645364, gradient norm = 0.0000317 (50 iterations in 0.212s)
# [t-SNE] Iteration 3250: error = 1.1645474, gradient norm = 0.0000498 (50 iterations in 0.209s)
# [t-SNE] Iteration 3300: error = 1.1645496, gradient norm = 0.0000257 (50 iterations in 0.212s)
# [t-SNE] Iteration 3350: error = 1.1646426, gradient norm = 0.0000422 (50 iterations in 0.212s)
# [t-SNE] Iteration 3400: error = 1.1645653, gradient norm = 0.0000285 (50 iterations in 0.208s)
# [t-SNE] Iteration 3450: error = 1.1646053, gradient norm = 0.0000224 (50 iterations in 0.221s)
# [t-SNE] Iteration 3500: error = 1.1645240, gradient norm = 0.0000310 (50 iterations in 0.212s)
# [t-SNE] Iteration 3550: error = 1.1644711, gradient norm = 0.0000320 (50 iterations in 0.218s)
# [t-SNE] Iteration 3600: error = 1.1644523, gradient norm = 0.0000301 (50 iterations in 0.216s)
# [t-SNE] Iteration 3650: error = 1.1644573, gradient norm = 0.0000286 (50 iterations in 0.209s)
# [t-SNE] Iteration 3700: error = 1.1644739, gradient norm = 0.0000216 (50 iterations in 0.214s)
# [t-SNE] Iteration 3750: error = 1.1645459, gradient norm = 0.0000326 (50 iterations in 0.211s)
# [t-SNE] Iteration 3800: error = 1.1645559, gradient norm = 0.0000352 (50 iterations in 0.216s)
# [t-SNE] Iteration 3850: error = 1.1645262, gradient norm = 0.0000336 (50 iterations in 0.209s)
# [t-SNE] Iteration 3900: error = 1.1645299, gradient norm = 0.0000250 (50 iterations in 0.222s)
# [t-SNE] Iteration 3950: error = 1.1645049, gradient norm = 0.0000325 (50 iterations in 0.210s)
# [t-SNE] Iteration 3950: did not make any progress during the last 300 episodes. Finished.
# [t-SNE] KL divergence after 3950 iterations: 1.164505
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 432 samples in 0.001s...
# [t-SNE] Computed neighbors for 432 samples in 0.021s...
# [t-SNE] Computed conditional probabilities for sample 432 / 432
# [t-SNE] Mean sigma: 2.296230
# [t-SNE] Computed conditional probabilities in 0.020s
# [t-SNE] Iteration 50: error = 67.8209686, gradient norm = 0.4930419 (50 iterations in 0.149s)
# [t-SNE] Iteration 100: error = 70.5864258, gradient norm = 0.4680839 (50 iterations in 0.158s)
# [t-SNE] Iteration 150: error = 70.3998413, gradient norm = 0.4734312 (50 iterations in 0.149s)
# [t-SNE] Iteration 200: error = 70.5906754, gradient norm = 0.4912684 (50 iterations in 0.150s)
# [t-SNE] Iteration 250: error = 70.2736206, gradient norm = 0.4852558 (50 iterations in 0.142s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 70.273621
# [t-SNE] Iteration 300: error = 0.9456455, gradient norm = 0.0029861 (50 iterations in 0.101s)
# [t-SNE] Iteration 350: error = 0.9127790, gradient norm = 0.0004828 (50 iterations in 0.097s)
# [t-SNE] Iteration 400: error = 0.8880301, gradient norm = 0.0011458 (50 iterations in 0.097s)
# [t-SNE] Iteration 450: error = 0.8848750, gradient norm = 0.0001590 (50 iterations in 0.097s)
# [t-SNE] Iteration 500: error = 0.8820537, gradient norm = 0.0000910 (50 iterations in 0.101s)
# [t-SNE] Iteration 550: error = 0.8808995, gradient norm = 0.0001029 (50 iterations in 0.096s)
# [t-SNE] Iteration 600: error = 0.8804320, gradient norm = 0.0000537 (50 iterations in 0.097s)
# [t-SNE] Iteration 650: error = 0.8803846, gradient norm = 0.0000978 (50 iterations in 0.096s)
# [t-SNE] Iteration 700: error = 0.8801219, gradient norm = 0.0000779 (50 iterations in 0.099s)
# [t-SNE] Iteration 750: error = 0.8799490, gradient norm = 0.0000735 (50 iterations in 0.098s)
# [t-SNE] Iteration 800: error = 0.8801086, gradient norm = 0.0001122 (50 iterations in 0.096s)
# [t-SNE] Iteration 850: error = 0.8789797, gradient norm = 0.0001373 (50 iterations in 0.096s)
# [t-SNE] Iteration 900: error = 0.8788789, gradient norm = 0.0000738 (50 iterations in 0.098s)
# [t-SNE] Iteration 950: error = 0.8788297, gradient norm = 0.0000673 (50 iterations in 0.102s)
# [t-SNE] Iteration 1000: error = 0.8788674, gradient norm = 0.0000671 (50 iterations in 0.100s)
# [t-SNE] Iteration 1050: error = 0.8789568, gradient norm = 0.0000723 (50 iterations in 0.101s)
# [t-SNE] Iteration 1100: error = 0.8787835, gradient norm = 0.0000343 (50 iterations in 0.097s)
# [t-SNE] Iteration 1150: error = 0.8789410, gradient norm = 0.0001189 (50 iterations in 0.097s)
# [t-SNE] Iteration 1200: error = 0.8789734, gradient norm = 0.0000528 (50 iterations in 0.099s)
# [t-SNE] Iteration 1250: error = 0.8790216, gradient norm = 0.0000739 (50 iterations in 0.097s)
# [t-SNE] Iteration 1300: error = 0.8788815, gradient norm = 0.0000704 (50 iterations in 0.101s)
# [t-SNE] Iteration 1350: error = 0.8789611, gradient norm = 0.0001077 (50 iterations in 0.097s)
# [t-SNE] Iteration 1400: error = 0.8791016, gradient norm = 0.0000605 (50 iterations in 0.101s)
# [t-SNE] Iteration 1450: error = 0.8791733, gradient norm = 0.0001041 (50 iterations in 0.099s)
# [t-SNE] Iteration 1450: did not make any progress during the last 300 episodes. Finished.
# [t-SNE] KL divergence after 1450 iterations: 0.879173
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 363 samples in 0.001s...
# [t-SNE] Computed neighbors for 363 samples in 0.015s...
# [t-SNE] Computed conditional probabilities for sample 363 / 363
# [t-SNE] Mean sigma: 2.413132
# [t-SNE] Computed conditional probabilities in 0.016s
# [t-SNE] Iteration 50: error = 68.5298996, gradient norm = 0.4841121 (50 iterations in 0.110s)
# [t-SNE] Iteration 100: error = 66.9159851, gradient norm = 0.5253321 (50 iterations in 0.130s)
# [t-SNE] Iteration 150: error = 69.5053711, gradient norm = 0.5087170 (50 iterations in 0.123s)
# [t-SNE] Iteration 200: error = 71.4852982, gradient norm = 0.4877273 (50 iterations in 0.114s)
# [t-SNE] Iteration 250: error = 71.8355179, gradient norm = 0.4651693 (50 iterations in 0.111s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 71.835518
# [t-SNE] Iteration 300: error = 1.0638714, gradient norm = 0.0044062 (50 iterations in 0.083s)
# [t-SNE] Iteration 350: error = 0.9066796, gradient norm = 0.0021872 (50 iterations in 0.078s)
# [t-SNE] Iteration 400: error = 0.8619633, gradient norm = 0.0005173 (50 iterations in 0.080s)
# [t-SNE] Iteration 450: error = 0.8482764, gradient norm = 0.0003715 (50 iterations in 0.081s)
# [t-SNE] Iteration 500: error = 0.8403659, gradient norm = 0.0004562 (50 iterations in 0.084s)
# [t-SNE] Iteration 550: error = 0.8317502, gradient norm = 0.0001502 (50 iterations in 0.088s)
# [t-SNE] Iteration 600: error = 0.8306696, gradient norm = 0.0001454 (50 iterations in 0.085s)
# [t-SNE] Iteration 650: error = 0.8096029, gradient norm = 0.0006160 (50 iterations in 0.084s)
# [t-SNE] Iteration 700: error = 0.8068413, gradient norm = 0.0001288 (50 iterations in 0.083s)
# [t-SNE] Iteration 750: error = 0.8067871, gradient norm = 0.0001161 (50 iterations in 0.082s)
# [t-SNE] Iteration 800: error = 0.8066639, gradient norm = 0.0000802 (50 iterations in 0.084s)
# [t-SNE] Iteration 850: error = 0.8067740, gradient norm = 0.0000809 (50 iterations in 0.085s)
# [t-SNE] Iteration 900: error = 0.8068050, gradient norm = 0.0000644 (50 iterations in 0.089s)
# [t-SNE] Iteration 950: error = 0.8068183, gradient norm = 0.0000543 (50 iterations in 0.091s)
# [t-SNE] Iteration 1000: error = 0.8068918, gradient norm = 0.0000637 (50 iterations in 0.088s)
# [t-SNE] Iteration 1050: error = 0.8068889, gradient norm = 0.0000725 (50 iterations in 0.096s)
# [t-SNE] Iteration 1100: error = 0.8067648, gradient norm = 0.0000698 (50 iterations in 0.088s)
# [t-SNE] Iteration 1150: error = 0.8068726, gradient norm = 0.0000672 (50 iterations in 0.088s)
# [t-SNE] Iteration 1150: did not make any progress during the last 300 episodes. Finished.
# [t-SNE] KL divergence after 1150 iterations: 0.806873

# %% [markdown]
# ### the t-SNE dimensions for the four datasets are put into dataframes

# %%
tsne_df_train = pd.DataFrame(data = my_tsne_train, columns = ['tsne1', 'tsne2'])
tsne_df_bedrock_train = pd.DataFrame(data = my_tsne_bedrock_train, columns = ['tsne1', 'tsne2'])
tsne_df_superficial_train = pd.DataFrame(data = my_tsne_superficial_train, columns = ['tsne1', 'tsne2'])
tsne_df_test = pd.DataFrame(data = my_tsne_test, columns = ['tsne1', 'tsne2'])

# %% [markdown]
# ### datasets are stored for the purpose of two-dimensional visualisations

# %%
# %store PC_df_train
# %store my_pca_train

# %store PC_df_bedrock_train
# %store my_pca_train_bedrock

# %store PC_df_superficial_train
# %store my_pca_train_superficial

# %store PC_df_test
# %store my_pca_test

# %store tsne_df_train

# %store tsne_df_bedrock_train
# %store tsne_df_superficial_train


# %store tsne_df_test
# Out:
# Stored 'PC_df_train' (DataFrame)
# Stored 'my_pca_train' (PCA)
# Stored 'PC_df_bedrock_train' (DataFrame)
# Stored 'my_pca_train_bedrock' (PCA)
# Stored 'PC_df_superficial_train' (DataFrame)
# Stored 'my_pca_train_superficial' (PCA)
# Stored 'PC_df_test' (DataFrame)
# Stored 'my_pca_test' (PCA)
# Stored 'tsne_df_train' (DataFrame)
# Stored 'tsne_df_bedrock_train' (DataFrame)
# Stored 'tsne_df_superficial_train' (DataFrame)
# Stored 'tsne_df_test' (DataFrame)
