# %% [markdown]
# # data preproccessing

# %% [markdown]
# ## import modules and configure notebook

# %%
import pandas as pd
import numpy as np
import swifter
import seaborn as sns
import matplotlib.pyplot


pd.set_option('max.rows', None)
pd.set_option('max.columns', None)

from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.metrics import log_loss, accuracy_score, f1_score
from sklearn.decomposition import PCA 
from sklearn.manifold import TSNE
from sklearn.preprocessing import StandardScaler


# %matplotlib inline
# Out:
# /home/robert/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d

# %% [markdown]
# ### Configurations

# %%
data_input_path = '../data/AllData_2_All_Details_3_OutliersRem_1_SupDep_Regions.csv'
classify_bedrock_only = False
group_superficial = True

# %% [markdown]
# ### Import data

# %%
my_data = pd.read_csv(data_input_path)

# %%
my_data['Site'].unique()
# Out:
# array(['FH', 'ER', 'WW', 'TC', 'CS', 'BC', 'KQ', 'AR', 'SL', 'FG', 'WB',
#        'BX', 'PF', 'BM', 'WH', 'SQ', 'BP', 'WN', 'BH', 'PH', 'LB', 'AB',
#        'LV', 'BR', 'KY', 'BF', 'ST', 'SH', 'CF', 'BG', 'AC', 'CR', 'GH',
#        'PX', 'WF', 'DH', 'NMAG_Gold', 'NMW_Gold', 'NMWGwern', 'UBSS',
#        'Cefn', 'Stockley', 'Pucha', 'Woodbury', 'Pimple', 'Wellington',
#        'Lyonshall', 'SymondsYatE', 'Madawg'], dtype=object)

# %% [markdown]
# ### make labels for classification

# %%
def make_classes_grouped(row):
    if row['Geology'] == 'Bedrock':
        if row['Site'] == 'WB' or row['Site'] == 'BX':
            return('WB_BX')
        elif row['Site'] == 'BC' or row['Site'] == 'CS':
            return('BC_CS')
        elif row['Site'] == 'SQ' or row['Site'] == 'BP':
            return('SQ_BP')
        else:
            return(row['Site'])
    elif row['Geology'] == 'Superficial':
        if row['Region'] == 'SV' or row['Region'] == 'SE':
            return('SV_SE')
        else:
            return(row['Region'])

def make_classes_raw(row):
    if row['Geology'] == 'Bedrock':
        return(row['Site'])
    elif row['Geology'] == 'Superficial':
        return(row['Region'])

# %%
my_data['class'] = 'init'   

if group_superficial:
    my_data['class'] = my_data.apply(make_classes_grouped, axis = 1)
else:
    my_data['class'] = my_data.apply(make_classes_raw, axis = 1)

# %% [markdown]
# ### Remove '<' signs.

# %%
for column_name in my_data.columns.values[9:-1]:
    def fill_less_than(row):
        if '<' in str(row[column_name]):
            return(float(row[column_name].replace('<', '').replace('DL', '').replace(',','')))
        else:
            return(float(row[column_name]))
    my_data[column_name] = my_data.swifter.apply(fill_less_than, axis = 1)
# Out:
# Pandas Apply: 100%|██████████| 1606/1606 [00:00<00:00, 20255.94it/s]
# Pandas Apply: 100%|██████████| 1606/1606 [00:00<00:00, 21880.67it/s]
# Pandas Apply: 100%|██████████| 1606/1606 [00:00<00:00, 21975.97it/s]
# Pandas Apply: 100%|██████████| 1606/1606 [00:00<00:00, 21734.32it/s]
# Pandas Apply: 100%|██████████| 1606/1606 [00:00<00:00, 18545.02it/s]
# Pandas Apply: 100%|██████████| 1606/1606 [00:00<00:00, 21091.23it/s]
# Pandas Apply: 100%|██████████| 1606/1606 [00:00<00:00, 16916.47it/s]
# Pandas Apply: 100%|██████████| 1606/1606 [00:00<00:00, 18365.07it/s]
# Pandas Apply: 100%|██████████| 1606/1606 [00:00<00:00, 15100.34it/s]
# Pandas Apply: 100%|██████████| 1606/1606 [00:00<00:00, 19101.08it/s]
# Pandas Apply: 100%|██████████| 1606/1606 [00:00<00:00, 17482.34it/s]
# Pandas Apply: 100%|██████████| 1606/1606 [00:00<00:00, 18748.18it/s]
# Pandas Apply: 100%|██████████| 1606/1606 [00:00<00:00, 21453.08it/s]
# Pandas Apply: 100%|██████████| 1606/1606 [00:00<00:00, 16619.92it/s]
# Pandas Apply: 100%|██████████| 1606/1606 [00:00<00:00, 18125.31it/s]
# Pandas Apply: 100%|██████████| 1606/1606 [00:00<00:00, 20225.89it/s]
# Pandas Apply: 100%|██████████| 1606/1606 [00:00<00:00, 19696.23it/s]
# Pandas Apply: 100%|██████████| 1606/1606 [00:00<00:00, 21363.34it/s]
# Pandas Apply: 100%|██████████| 1606/1606 [00:00<00:00, 22404.37it/s]
# Pandas Apply: 100%|██████████| 1606/1606 [00:00<00:00, 22921.33it/s]
# Pandas Apply: 100%|██████████| 1606/1606 [00:00<00:00, 14686.09it/s]
# Pandas Apply: 100%|██████████| 1606/1606 [00:00<00:00, 20336.85it/s]
# Pandas Apply: 100%|██████████| 1606/1606 [00:00<00:00, 19079.87it/s]
# Pandas Apply: 100%|██████████| 1606/1606 [00:00<00:00, 20071.55it/s]
# Pandas Apply: 100%|██████████| 1606/1606 [00:00<00:00, 14802.69it/s]
# Pandas Apply: 100%|██████████| 1606/1606 [00:00<00:00, 17881.55it/s]
# Pandas Apply: 100%|██████████| 1606/1606 [00:00<00:00, 19160.19it/s]
# Pandas Apply: 100%|██████████| 1606/1606 [00:00<00:00, 18202.99it/s]
# Pandas Apply: 100%|██████████| 1606/1606 [00:00<00:00, 20631.28it/s]
# Pandas Apply: 100%|██████████| 1606/1606 [00:00<00:00, 21105.10it/s]
# Pandas Apply: 100%|██████████| 1606/1606 [00:00<00:00, 18715.26it/s]
# Pandas Apply: 100%|██████████| 1606/1606 [00:00<00:00, 19203.07it/s]
# Pandas Apply: 100%|██████████| 1606/1606 [00:00<00:00, 21543.58it/s]
# Pandas Apply: 100%|██████████| 1606/1606 [00:00<00:00, 16945.36it/s]
# Pandas Apply: 100%|██████████| 1606/1606 [00:00<00:00, 19892.84it/s]
# Pandas Apply: 100%|██████████| 1606/1606 [00:00<00:00, 19149.62it/s]
# Pandas Apply: 100%|██████████| 1606/1606 [00:00<00:00, 19191.25it/s]
# Pandas Apply: 100%|██████████| 1606/1606 [00:00<00:00, 18523.30it/s]
# Pandas Apply: 100%|██████████| 1606/1606 [00:00<00:00, 17416.44it/s]
# Pandas Apply: 100%|██████████| 1606/1606 [00:00<00:00, 14793.10it/s]
# Pandas Apply: 100%|██████████| 1606/1606 [00:00<00:00, 18582.16it/s]
# Pandas Apply: 100%|██████████| 1606/1606 [00:00<00:00, 21235.64it/s]
# Pandas Apply: 100%|██████████| 1606/1606 [00:00<00:00, 15459.98it/s]
# Pandas Apply: 100%|██████████| 1606/1606 [00:00<00:00, 17327.73it/s]
# Pandas Apply: 100%|██████████| 1606/1606 [00:00<00:00, 18970.57it/s]
# Pandas Apply: 100%|██████████| 1606/1606 [00:00<00:00, 17907.94it/s]
# Pandas Apply: 100%|██████████| 1606/1606 [00:00<00:00, 14957.31it/s]
# Pandas Apply: 100%|██████████| 1606/1606 [00:00<00:00, 17613.86it/s]
# Pandas Apply: 100%|██████████| 1606/1606 [00:00<00:00, 17825.43it/s]
# Pandas Apply: 100%|██████████| 1606/1606 [00:00<00:00, 19495.46it/s]
# Pandas Apply: 100%|██████████| 1606/1606 [00:00<00:00, 18615.90it/s]
# Pandas Apply: 100%|██████████| 1606/1606 [00:00<00:00, 21209.43it/s]
# Pandas Apply: 100%|██████████| 1606/1606 [00:00<00:00, 14526.50it/s]

# %% [markdown]
# ### Impute na values with variable median, this is more resistant to the effect of outliers

# %%
for column_name in my_data.columns.values[9:-1]:
    my_data[column_name] = my_data[column_name].fillna(my_data[column_name].median())

# %%
my_data.head()
# Out:
#      Analysis  Geology  Province Region Site SubSite Formation Band   Nodule  \
# 0  10_FH1_1_1  Bedrock  Northern    NaN   FH     FH1   Burnham  FH1  FH1_1_1
# 1  11_FH1_1_1  Bedrock  Northern    NaN   FH     FH1   Burnham  FH1  FH1_1_1
# 2  12_FH1_1_1  Bedrock  Northern    NaN   FH     FH1   Burnham  FH1  FH1_1_1
# 3  13_FH1_1_2  Bedrock  Northern    NaN   FH     FH1   Burnham  FH1  FH1_1_2
# 4  14_FH1_1_2  Bedrock  Northern    NaN   FH     FH1   Burnham  FH1  FH1_1_2
#
#      Li7   Be9    B11    Mg24     Al27       Si28       P31      S33     K39  \
# 0  15.63  0.12  48.36  154.63   943.71  464944.18     50.28   538.57  455.94
# 1  11.50  0.09  44.77   22.42  1077.11  465010.94     70.91   438.20  387.82
# 2  20.05  0.06  44.88   42.70   620.21  465295.41    104.47   372.66  363.71
# 3  11.16  0.73  47.06  162.42  1143.19  465099.89  56367.93  1075.89  547.55
# 4  17.71  0.32  48.26   33.52   547.22  465027.11     44.44   464.78  278.25
#
#       Ca42  Sc45   Ti47   V51    Cr52  Mn55    Fe56  Co59  Ni60  Cu63   Zn68  \
# 0   712.39  0.42  15.58  0.27    3.30  0.69    8.46  0.05  0.80  1.62  10.82
# 1   515.24  0.44  18.47  0.29    3.45  1.01   11.59  0.11  0.36  0.53   8.93
# 2   957.89  0.76  19.89  0.55    3.25  1.21   87.99  0.21  1.68  1.53  11.98
# 3  2174.30  0.43  42.30  0.67  152.42  4.84  145.34  0.30  2.45  5.02  17.15
# 4  1551.63  0.71  11.18  0.27    2.56  1.73   25.38  0.05  0.80  0.55   9.80
#
#    Ga69  Ge72  As75  Rb85   Sr88   Y89  Zr90  Nb93  Mo95  Cd111  In115  Sn118  \
# 0  0.25  1.22  0.16  0.43  12.94  0.88  1.51  0.09  0.05   0.02   0.00   0.05
# 1  0.34  0.85  0.10  0.45  13.22  0.95  1.74  0.07  0.01   0.02   0.00   0.04
# 2  0.25  1.71  0.13  0.43   8.52  0.87  0.93  0.10  0.02   0.02   0.00   0.05
# 3  0.35  2.13  0.84  0.76  13.16  0.97  2.00  0.10  0.29   0.18   0.01   0.78
# 4  0.41  1.41  0.12  0.28   9.90  0.90  0.90  0.08  0.04   0.10   0.00   0.09
#
#    Cs133  Ba137  La139  Ce140  Pr141  Nd146  Sm147  Eu153  Gd157  Tb159  \
# 0   0.01   6.54   0.84   0.95   0.23   0.87   0.16   0.04   0.16   0.02
# 1   0.02   8.04   0.92   1.01   0.23   0.98   0.18   0.04   0.18   0.02
# 2   0.01   3.13   0.90   1.08   0.26   0.84   0.15   0.04   0.19   0.02
# 3   0.04   8.74   0.93   0.95   0.21   0.75   0.13   0.04   0.25   0.02
# 4   0.01   2.74   0.97   1.09   0.27   1.00   0.17   0.04   0.19   0.02
#
#    Dy163  Ho165  Er166  Tm169  Yb172  Lu175  Hf178  Ta181  Pb208  Th232  U238  \
# 0   0.11   0.03   0.06   0.01   0.02   0.00   0.04   0.01   0.24   0.07  0.05
# 1   0.13   0.03   0.06   0.01   0.04   0.01   0.05   0.00   0.07   0.08  0.04
# 2   0.14   0.02   0.07   0.01   0.06   0.00   0.02   0.01   0.46   0.05  0.05
# 3   0.09   0.03   0.05   0.00   0.03   0.00   0.08   0.00   0.64   0.05  0.03
# 4   0.15   0.03   0.05   0.01   0.05   0.01   0.02   0.01   0.59   0.06  0.09
#
#   class
# 0    FH
# 1    FH
# 2    FH
# 3    FH
# 4    FH

# %% [markdown]
# ### Filter for known data bedrock data for training the model

# %%
train_data = my_data[(my_data['Geology']== 'Bedrock') | (my_data['Geology'] == 'Superficial')]
test_data = my_data[my_data['Geology']=='Artefacts']

# %% [markdown]
# ### label encode the class to be predicted

# %%
train_data_formodel = train_data.copy(deep = True)
if classify_bedrock_only == False: 
    train_data_formodel['class'], uniques = pd.factorize(train_data_formodel['class'])

# %% [markdown]
# ### order of class labels as numbers 0 through 20

# %%
print(uniques)
# Out:
# Index(['FH', 'ER', 'WW', 'TC', 'BC_CS', 'KQ', 'AR', 'SL', 'FG', 'WB_BX', 'PF',
#        'BM', 'WH', 'SQ_BP', 'WN', 'BH', 'PH', 'LB', 'AB', 'LV', 'SV_SE', 'BA',
#        'WA', 'MM'],
#       dtype='object')

# %%
# %store train_data_formodel
# %store train_data
# %store test_data
# %store my_data
# %store uniques
# Out:
# Stored 'train_data_formodel' (DataFrame)
# Stored 'train_data' (DataFrame)
# Stored 'test_data' (DataFrame)
# Stored 'my_data' (DataFrame)
# Stored 'uniques' (Index)

# %%
train_data_bedrock = train_data[train_data['Geology'] == 'Bedrock']
train_data_superficial = train_data[train_data['Geology'] == 'Superficial']

# %%
train_data_bedrock.columns.values[9:-1]
# Out:
# array(['Li7', 'Be9', 'B11', 'Mg24', 'Al27', 'Si28', 'P31', 'S33', 'K39',
#        'Ca42', 'Sc45', 'Ti47', 'V51', 'Cr52', 'Mn55', 'Fe56', 'Co59',
#        'Ni60', 'Cu63', 'Zn68', 'Ga69', 'Ge72', 'As75', 'Rb85', 'Sr88',
#        'Y89', 'Zr90', 'Nb93', 'Mo95', 'Cd111', 'In115', 'Sn118', 'Cs133',
#        'Ba137', 'La139', 'Ce140', 'Pr141', 'Nd146', 'Sm147', 'Eu153',
#        'Gd157', 'Tb159', 'Dy163', 'Ho165', 'Er166', 'Tm169', 'Yb172',
#        'Lu175', 'Hf178', 'Ta181', 'Pb208', 'Th232', 'U238'], dtype=object)

# %%
element_data_train = train_data[train_data.columns.values[9:-1]]
element_data_train_bedrock = train_data_bedrock[train_data.columns.values[9:-1]]
element_data_train_superficial = train_data_superficial[train_data.columns.values[9:-1]]
element_data_test = test_data[test_data.columns.values[9:-1]]

# %%
my_scaler_train = StandardScaler()
my_scaler_train_bedrock = StandardScaler()
my_scaler_train_superficial = StandardScaler()
my_scaler_test = StandardScaler()

# %%
element_data_train_scaled = my_scaler_train.fit_transform(element_data_train)
element_data_train_bedrock_scaled = my_scaler_train_bedrock.fit_transform(element_data_train_bedrock)
element_data_train_superficial_scaled = my_scaler_train_superficial.fit_transform(element_data_train_superficial)
element_data_test_scaled = my_scaler_test.fit_transform(element_data_test)

# %%
my_pca_train = PCA(n_components=element_data_train_scaled.shape[1])

my_pca_train_bedrock = PCA(n_components=element_data_train_bedrock_scaled.shape[1])
my_pca_train_superficial = PCA(n_components=element_data_train_superficial_scaled.shape[1])

my_pca_test = PCA(n_components=element_data_test_scaled.shape[1])

element_data_train_pca = my_pca_train.fit_transform(element_data_train_scaled)

element_data_train_bedrock_pca = my_pca_train_bedrock.fit_transform(element_data_train_bedrock_scaled)
element_data_train_superficial_pca = my_pca_train_superficial.fit_transform(element_data_train_superficial_scaled)

element_data_test_pca = my_pca_test.fit_transform(element_data_test_scaled)

# %%
no_PCs = element_data_train_scaled.shape[1]
PC_names = []
for i in range(0, no_PCs):
    number = i + 1
    column_name = 'PC' + str(number)
    PC_names.append(column_name)

# %%
PC_df_train = pd.DataFrame(data = element_data_train_pca, columns = PC_names)

PC_df_bedrock_train = pd.DataFrame(data = element_data_train_bedrock_pca, columns = PC_names)
PC_df_superficial_train = pd.DataFrame(data = element_data_train_superficial_pca, columns = PC_names)

PC_df_test = pd.DataFrame(data = element_data_test_pca, columns = PC_names)

# %%
my_tsne_train = TSNE(n_components=3, n_iter=750, verbose=3).fit_transform(element_data_train_scaled)

my_tsne_bedrock_train = TSNE(n_components=3, n_iter=750, verbose=3).fit_transform(element_data_train_bedrock_scaled)
my_tsne_superficial_train = TSNE(n_components=3, n_iter=750, verbose=3).fit_transform(element_data_train_superficial_scaled)

my_tsne_test = TSNE(n_components=3, n_iter=750, verbose=3).fit_transform(element_data_test_scaled)
# Out:
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 1243 samples in 0.003s...
# [t-SNE] Computed neighbors for 1243 samples in 0.310s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 1243
# [t-SNE] Computed conditional probabilities for sample 1243 / 1243
# [t-SNE] Mean sigma: 1.771276
# [t-SNE] Computed conditional probabilities in 0.112s
# [t-SNE] Iteration 50: error = 77.6048279, gradient norm = 0.0629518 (50 iterations in 7.709s)
# [t-SNE] Iteration 100: error = 78.8231506, gradient norm = 0.0362661 (50 iterations in 5.129s)
# [t-SNE] Iteration 150: error = 80.4020309, gradient norm = 0.0267530 (50 iterations in 5.134s)
# [t-SNE] Iteration 200: error = 80.7569046, gradient norm = 0.0220706 (50 iterations in 5.497s)
# [t-SNE] Iteration 250: error = 81.0692520, gradient norm = 0.0351373 (50 iterations in 4.999s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 81.069252
# [t-SNE] Iteration 300: error = 1.8298072, gradient norm = 0.0006273 (50 iterations in 5.415s)
# [t-SNE] Iteration 350: error = 1.6376424, gradient norm = 0.0003509 (50 iterations in 5.931s)
# [t-SNE] Iteration 400: error = 1.5382822, gradient norm = 0.0001493 (50 iterations in 6.085s)
# [t-SNE] Iteration 450: error = 1.4248346, gradient norm = 0.0002011 (50 iterations in 6.214s)
# [t-SNE] Iteration 500: error = 1.3752900, gradient norm = 0.0001363 (50 iterations in 6.287s)
# [t-SNE] Iteration 550: error = 1.3344343, gradient norm = 0.0001393 (50 iterations in 6.435s)
# [t-SNE] Iteration 600: error = 1.3086313, gradient norm = 0.0001695 (50 iterations in 6.552s)
# [t-SNE] Iteration 650: error = 1.2880497, gradient norm = 0.0000605 (50 iterations in 6.563s)
# [t-SNE] Iteration 700: error = 1.2753860, gradient norm = 0.0000473 (50 iterations in 6.689s)
# [t-SNE] Iteration 750: error = 1.2432489, gradient norm = 0.0001718 (50 iterations in 6.697s)
# [t-SNE] Error after 750 iterations: 1.243249
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 808 samples in 0.001s...
# [t-SNE] Computed neighbors for 808 samples in 0.120s...
# [t-SNE] Computed conditional probabilities for sample 808 / 808
# [t-SNE] Mean sigma: 1.875790
# [t-SNE] Computed conditional probabilities in 0.066s
# [t-SNE] Iteration 50: error = 79.6627045, gradient norm = 0.1877136 (50 iterations in 4.348s)
# [t-SNE] Iteration 100: error = 83.9497910, gradient norm = 0.1858941 (50 iterations in 4.150s)
# [t-SNE] Iteration 150: error = 84.3324890, gradient norm = 0.1560835 (50 iterations in 3.856s)
# [t-SNE] Iteration 200: error = 86.4647980, gradient norm = 0.1741968 (50 iterations in 3.720s)
# [t-SNE] Iteration 250: error = 88.0803375, gradient norm = 0.1672464 (50 iterations in 3.670s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 88.080338
# [t-SNE] Iteration 300: error = 2.3007848, gradient norm = 0.0011936 (50 iterations in 3.340s)
# [t-SNE] Iteration 350: error = 2.1106589, gradient norm = 0.0003240 (50 iterations in 3.689s)
# [t-SNE] Iteration 400: error = 1.9755816, gradient norm = 0.0001621 (50 iterations in 3.635s)
# [t-SNE] Iteration 450: error = 1.8506989, gradient norm = 0.0001178 (50 iterations in 3.630s)
# [t-SNE] Iteration 500: error = 1.7665956, gradient norm = 0.0000980 (50 iterations in 3.587s)
# [t-SNE] Iteration 550: error = 1.7116433, gradient norm = 0.0000595 (50 iterations in 3.948s)
# [t-SNE] Iteration 600: error = 1.6564351, gradient norm = 0.0000478 (50 iterations in 3.830s)
# [t-SNE] Iteration 650: error = 1.6137913, gradient norm = 0.0000438 (50 iterations in 3.537s)
# [t-SNE] Iteration 700: error = 1.5699654, gradient norm = 0.0000388 (50 iterations in 3.497s)
# [t-SNE] Iteration 750: error = 1.5307690, gradient norm = 0.0000320 (50 iterations in 3.704s)
# [t-SNE] Error after 750 iterations: 1.530769
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 435 samples in 0.001s...
# [t-SNE] Computed neighbors for 435 samples in 0.038s...
# [t-SNE] Computed conditional probabilities for sample 435 / 435
# [t-SNE] Mean sigma: 2.099944
# [t-SNE] Computed conditional probabilities in 0.046s
# [t-SNE] Iteration 50: error = 86.9078674, gradient norm = 0.2822898 (50 iterations in 1.864s)
# [t-SNE] Iteration 100: error = 102.3156433, gradient norm = 0.2369485 (50 iterations in 1.715s)
# [t-SNE] Iteration 150: error = 111.5508118, gradient norm = 0.2411002 (50 iterations in 1.661s)
# [t-SNE] Iteration 200: error = 120.8267441, gradient norm = 0.2020606 (50 iterations in 1.704s)
# [t-SNE] Iteration 250: error = 124.0915680, gradient norm = 0.1813811 (50 iterations in 1.655s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 124.091568
# [t-SNE] Iteration 300: error = 3.7339683, gradient norm = 0.0006303 (50 iterations in 1.693s)
# [t-SNE] Iteration 350: error = 3.1614892, gradient norm = 0.0002336 (50 iterations in 1.698s)
# [t-SNE] Iteration 400: error = 2.8515010, gradient norm = 0.0001331 (50 iterations in 1.698s)
# [t-SNE] Iteration 450: error = 2.6695514, gradient norm = 0.0000883 (50 iterations in 1.786s)
# [t-SNE] Iteration 500: error = 2.5413375, gradient norm = 0.0000638 (50 iterations in 1.653s)
# [t-SNE] Iteration 550: error = 2.4416583, gradient norm = 0.0000496 (50 iterations in 1.630s)
# [t-SNE] Iteration 600: error = 2.3610232, gradient norm = 0.0000418 (50 iterations in 1.711s)
# [t-SNE] Iteration 650: error = 2.2890384, gradient norm = 0.0000363 (50 iterations in 1.640s)
# [t-SNE] Iteration 700: error = 2.2187021, gradient norm = 0.0000341 (50 iterations in 1.717s)
# [t-SNE] Iteration 750: error = 2.1572342, gradient norm = 0.0000330 (50 iterations in 1.622s)
# [t-SNE] Error after 750 iterations: 2.157234
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 363 samples in 0.001s...
# [t-SNE] Computed neighbors for 363 samples in 0.028s...
# [t-SNE] Computed conditional probabilities for sample 363 / 363
# [t-SNE] Mean sigma: 2.333606
# [t-SNE] Computed conditional probabilities in 0.031s
# [t-SNE] Iteration 50: error = 88.5135574, gradient norm = 0.3011276 (50 iterations in 1.410s)
# [t-SNE] Iteration 100: error = 104.2610550, gradient norm = 0.2383108 (50 iterations in 1.370s)
# [t-SNE] Iteration 150: error = 119.5287704, gradient norm = 0.2046189 (50 iterations in 1.353s)
# [t-SNE] Iteration 200: error = 124.5423126, gradient norm = 0.2015290 (50 iterations in 1.297s)
# [t-SNE] Iteration 250: error = 131.2630005, gradient norm = 0.1830868 (50 iterations in 1.333s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 131.263000
# [t-SNE] Iteration 300: error = 3.7811108, gradient norm = 0.0005428 (50 iterations in 1.425s)
# [t-SNE] Iteration 350: error = 3.2815092, gradient norm = 0.0002086 (50 iterations in 1.368s)
# [t-SNE] Iteration 400: error = 3.0319633, gradient norm = 0.0001227 (50 iterations in 1.340s)
# [t-SNE] Iteration 450: error = 2.8626366, gradient norm = 0.0000867 (50 iterations in 1.401s)
# [t-SNE] Iteration 500: error = 2.7328429, gradient norm = 0.0000640 (50 iterations in 1.334s)
# [t-SNE] Iteration 550: error = 2.6328170, gradient norm = 0.0000495 (50 iterations in 1.357s)
# [t-SNE] Iteration 600: error = 2.5526230, gradient norm = 0.0000416 (50 iterations in 1.360s)
# [t-SNE] Iteration 650: error = 2.4918869, gradient norm = 0.0000334 (50 iterations in 1.370s)
# [t-SNE] Iteration 700: error = 2.4428709, gradient norm = 0.0000316 (50 iterations in 1.325s)
# [t-SNE] Iteration 750: error = 2.3980913, gradient norm = 0.0000258 (50 iterations in 1.395s)
# [t-SNE] Error after 750 iterations: 2.398091

# %%
tsne_df_train = pd.DataFrame(data = my_tsne_train, columns = ['tsne1', 'tsne2', 'tsne3'])

tsne_df_bedrock_train = pd.DataFrame(data = my_tsne_bedrock_train, columns = ['tsne1', 'tsne2', 'tsne3'])
tsne_df_superficial_train = pd.DataFrame(data = my_tsne_superficial_train, columns = ['tsne1', 'tsne2', 'tsne3'])

tsne_df_test = pd.DataFrame(data = my_tsne_test, columns = ['tsne1', 'tsne2', 'tsne3'])

# %%
# %store PC_df_train
# %store my_pca_train

# %store PC_df_bedrock_train
# %store my_pca_train_bedrock

# %store PC_df_superficial_train
# %store my_pca_train_superficial

# %store PC_df_test
# %store my_pca_test

# %store tsne_df_train

# %store tsne_df_bedrock_train
# %store tsne_df_superficial_train


# %store tsne_df_test
# Out:
# UsageError: Unknown variable 'PC_df_train'

# %% [markdown]
# import pandas as pd
# %store -r tsne_df_train
# tsne_df_train.to_csv('tsne_df_train.csv', index = False)
# %store -r tsne_df_test
# tsne_df_test.to_csv('tsne_df_test.csv', index=False)
#
# %store -r PC_df_train
# PC_df_train.to_csv(' PC_df_train.csv', index=False)
# %store -r PC_df_test
# PC_df_test.to_csv('PC_df_test.csv', index=False)
